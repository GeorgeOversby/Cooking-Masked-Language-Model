# %% [markdown]
# # Masked language models

# %%
from transformers import pipeline

fill_mask = pipeline("fill-mask")
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['lm_head.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask("Share your Opinion Shop & Search to earn real cash rewards!")

# %% [markdown]
# # Training on recipes

# %% [markdown]
# https://huggingface.co/blog/how-to-train

# %%
# !head ../data/processed/recipes_train.txt
# Out:
# garlic eggplant flour salt olive_oil seasoned_bread_crumbs grated_parmesan_cheese pepper rounds mozzarella_cheese tomatoes
# eggs oreo cookies margarine water sugar_cookie_mix brownie ingredients
# nutmeg cinnamon_sticks apple_juice orange_blossom water tea_bags
# red_chili pepper_sauce chili_paste olive_oil pork_loin mirin cornstarch oyster_sauce
# medium_shrimp dried_red_pepper fillets olive_oil fennel_fronds garlic_cloves bottled_clam_juice dry_white_wine lemon arugula
# black_beans salt olive_oil avocado cilantro bell_pepper ground_cumin red_onion lime_juice
# dark_chocolate eggs salt vanilla_extract unsalted_butter confectioners_sugar skim_milk brioche_bread heavy_cream
# cake_flour white_sugar salt milk vanilla_extract unsalted_butter pumpkin_pie_spice ground_cloves egg_white powdered_sugar ground_cinnamon canola_oil baking_powder temperature
# boneless_pork_loin salt pork_loin_chops golden_delicious_apples ground_cinnamon brown_sugar
# melted_butter flour salt dry_milk water sugar instant_yeast temperature baking_soda

# %%
# !cat ../data/processed/recipes_train.txt | wc -l
# Out:
# 1039974

# %%
import sys
from pathlib import Path
sys.path.append(str(Path(sys.path[0]).parent))
from src.ingredient_tokenizer import load_tokenizer

tokenizer = load_tokenizer('../artifacts')

fill_mask_recipe = pipeline("fill-mask", 
                     model='../artifacts/', 
                     tokenizer=tokenizer,
                     topk=500)
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at ../artifacts/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask_recipe('<mask> pepper salt chicken celery onion carrot flour hen')
# Out:
# [{'sequence': '<s> water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.4776608943939209,
#   'token': 13,
#   'token_str': 'water'},
#  {'sequence': '<s> milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0520767867565155,
#   'token': 20,
#   'token_str': 'milk'},
#  {'sequence': '<s> butter pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.04503853991627693,
#   'token': 7,
#   'token_str': 'butter'},
#  {'sequence': '<s> egg pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0331474170088768,
#   'token': 29,
#   'token_str': 'egg'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.020470695570111275,
#   'token': 253,
#   'token_str': 'cold_water'},
#  {'sequence': '<s> eggs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.019405586645007133,
#   'token': 18,
#   'token_str': 'eggs'},
#  {'sequence': '<s> shortening pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.01566903106868267,
#   'token': 192,
#   'token_str': 'shortening'},
#  {'sequence': '<s> oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.014237483032047749,
#   'token': 76,
#   'token_str': 'oil'},
#  {'sequence': '<s> potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00986656453460455,
#   'token': 52,
#   'token_str': 'potatoes'},
#  {'sequence': '<s> bay_leaf pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0098305344581604,
#   'token': 217,
#   'token_str': 'bay_leaf'},
#  {'sequence': '<s> buttermilk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.008830356411635876,
#   'token': 160,
#   'token_str': 'buttermilk'},
#  {'sequence': '<s> hot_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00876740925014019,
#   'token': 342,
#   'token_str': 'hot_water'},
#  {'sequence': '<s> parsley pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.008729245513677597,
#   'token': 36,
#   'token_str': 'parsley'},
#  {'sequence': '<s> stick_butter pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.008520006202161312,
#   'token': 405,
#   'token_str': 'stick_butter'},
#  {'sequence': '<s> fat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.008353540673851967,
#   'token': 937,
#   'token_str': 'fat'},
#  {'sequence': '<s> cream_of_chicken_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.007584451697766781,
#   'token': 386,
#   'token_str': 'cream_of_chicken_soup'},
#  {'sequence': '<s> boiling_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.007174027152359486,
#   'token': 254,
#   'token_str': 'boiling_water'},
#  {'sequence': '<s> margarine pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.006907891482114792,
#   'token': 80,
#   'token_str': 'margarine'},
#  {'sequence': '<s> paprika pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00603795750066638,
#   'token': 96,
#   'token_str': 'paprika'},
#  {'sequence': '<s> warm_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0058753290213644505,
#   'token': 296,
#   'token_str': 'warm_water'},
#  {'sequence': '<s> vegetable_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0055136182345449924,
#   'token': 40,
#   'token_str': 'vegetable_oil'},
#  {'sequence': '<s> turkey pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.005179051775485277,
#   'token': 206,
#   'token_str': 'turkey'},
#  {'sequence': '<s> poultry_seasoning pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0046555218286812305,
#   'token': 809,
#   'token_str': 'poultry_seasoning'},
#  {'sequence': '<s> baking_powder pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.004594964440912008,
#   'token': 42,
#   'token_str': 'baking_powder'},
#  {'sequence': '<s> thyme pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.004376549739390612,
#   'token': 75,
#   'token_str': 'thyme'},
#  {'sequence': '<s> cubed_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0041060554794967175,
#   'token': 2305,
#   'token_str': 'cubed_potatoes'},
#  {'sequence': '<s> parsley_flakes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.004066637251526117,
#   'token': 727,
#   'token_str': 'parsley_flakes'},
#  {'sequence': '<s> egg_noodles pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0040166801773011684,
#   'token': 504,
#   'token_str': 'egg_noodles'},
#  {'sequence': '<s> mushrooms pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.003969033248722553,
#   'token': 70,
#   'token_str': 'mushrooms'},
#  {'sequence': '<s> sugar pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0039360374212265015,
#   'token': 9,
#   'token_str': 'sugar'},
#  {'sequence': '<s> tomatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0038711735978722572,
#   'token': 26,
#   'token_str': 'tomatoes'},
#  {'sequence': '<s> potato pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.003749365685507655,
#   'token': 208,
#   'token_str': 'potato'},
#  {'sequence': '<s> evaporated_milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0035102032124996185,
#   'token': 393,
#   'token_str': 'evaporated_milk'},
#  {'sequence': '<s> vegetable_shortening pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0030737274792045355,
#   'token': 524,
#   'token_str': 'vegetable_shortening'},
#  {'sequence': '<s> rosemary pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.003072616644203663,
#   'token': 155,
#   'token_str': 'rosemary'},
#  {'sequence': '<s> meat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0030395621433854103,
#   'token': 370,
#   'token_str': 'meat'},
#  {'sequence': '<s> olive_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0029188215266913176,
#   'token': 12,
#   'token_str': 'olive_oil'},
#  {'sequence': '<s> hen pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.002865260001271963,
#   'token': 2935,
#   'token_str': 'hen'},
#  {'sequence': '<s> lard pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0027880172710865736,
#   'token': 911,
#   'token_str': 'lard'},
#  {'sequence': '<s> cooking_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00260324333794415,
#   'token': 554,
#   'token_str': 'cooking_oil'},
#  {'sequence': '<s> soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0024784135166555643,
#   'token': 539,
#   'token_str': 'soup'},
#  {'sequence': '<s> ice_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0024675107561051846,
#   'token': 662,
#   'token_str': 'ice_water'},
#  {'sequence': '<s> carcass pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.002396807074546814,
#   'token': 2982,
#   'token_str': 'carcass'},
#  {'sequence': '<s> bay_leaves pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0023440802469849586,
#   'token': 213,
#   'token_str': 'bay_leaves'},
#  {'sequence': '<s> garlic pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0023144541773945093,
#   'token': 8,
#   'token_str': 'garlic'},
#  {'sequence': '<s> drippings pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.002096551936119795,
#   'token': 1110,
#   'token_str': 'drippings'},
#  {'sequence': '<s> cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0019888372626155615,
#   'token': 22,
#   'token_str': 'cream'},
#  {'sequence': '<s> broiler pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.001973971724510193,
#   'token': 2795,
#   'token_str': 'broiler'},
#  {'sequence': '<s> melted_butter pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0018567017978057265,
#   'token': 270,
#   'token_str': 'melted_butter'},
#  {'sequence': '<s> turkey_broth pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0018434426747262478,
#   'token': 2021,
#   'token_str': 'turkey_broth'},
#  {'sequence': '<s> stock pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.001776986406184733,
#   'token': 176,
#   'token_str': 'stock'},
#  {'sequence': '<s> rice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0016484360676258802,
#   'token': 122,
#   'token_str': 'rice'},
#  {'sequence': '<s> cream_of_mushroom_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0014660053420811892,
#   'token': 312,
#   'token_str': 'cream_of_mushroom_soup'},
#  {'sequence': '<s> crisco pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0014229799853637815,
#   'token': 908,
#   'token_str': 'crisco'},
#  {'sequence': '<s> bacon_grease pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0014170599170029163,
#   'token': 2023,
#   'token_str': 'bacon_grease'},
#  {'sequence': '<s> pie_crust pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0014116355450823903,
#   'token': 498,
#   'token_str': 'pie_crust'},
#  {'sequence': '<s> liquid pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0014109464827924967,
#   'token': 252,
#   'token_str': 'liquid'},
#  {'sequence': '<s> crisco_shortening pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0014093286590650678,
#   'token': 2496,
#   'token_str': 'crisco_shortening'},
#  {'sequence': '<s> gravy pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0013434718130156398,
#   'token': 1078,
#   'token_str': 'gravy'},
#  {'sequence': '<s> pork pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.001252995221875608,
#   'token': 180,
#   'token_str': 'pork'},
#  {'sequence': '<s> liver pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0012398798717185855,
#   'token': 1344,
#   'token_str': 'liver'},
#  {'sequence': '<s> breast pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0012166390661150217,
#   'token': 468,
#   'token_str': 'breast'},
#  {'sequence': '<s> medium_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0012009446509182453,
#   'token': 610,
#   'token_str': 'medium_potatoes'},
#  {'sequence': '<s> mushroom pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.001182439038529992,
#   'token': 164,
#   'token_str': 'mushroom'},
#  {'sequence': '<s> beer pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0011654299451038241,
#   'token': 392,
#   'token_str': 'beer'},
#  {'sequence': '<s> garlic_cloves pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0011295421281829476,
#   'token': 38,
#   'token_str': 'garlic_cloves'},
#  {'sequence': '<s> noodles pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0011147644836455584,
#   'token': 183,
#   'token_str': 'noodles'},
#  {'sequence': '<s> peas pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0010974225588142872,
#   'token': 193,
#   'token_str': 'peas'},
#  {'sequence': '<s> frozen_peas pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.001083888579159975,
#   'token': 417,
#   'token_str': 'frozen_peas'},
#  {'sequence': '<s> bone_in pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0010572138708084822,
#   'token': 1716,
#   'token_str': 'bone_in'},
#  {'sequence': '<s> corn_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0010485773673281074,
#   'token': 802,
#   'token_str': 'corn_oil'},
#  {'sequence': '<s> corn pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.001046224613673985,
#   'token': 109,
#   'token_str': 'corn'},
#  {'sequence': '<s> turkey_stock pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0010241377167403698,
#   'token': 2173,
#   'token_str': 'turkey_stock'},
#  {'sequence': '<s> stewed_tomatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0010135642951354384,
#   'token': 660,
#   'token_str': 'stewed_tomatoes'},
#  {'sequence': '<s> garlic_minced pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0009952554246410728,
#   'token': 88,
#   'token_str': 'garlic_minced'},
#  {'sequence': '<s> bacon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0009680716320872307,
#   'token': 90,
#   'token_str': 'bacon'},
#  {'sequence': '<s> sage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0009590520639903843,
#   'token': 341,
#   'token_str': 'sage'},
#  {'sequence': '<s> mushroom_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0009562860359437764,
#   'token': 271,
#   'token_str': 'mushroom_soup'},
#  {'sequence': '<s> ingredients pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000930826470721513,
#   'token': 1424,
#   'token_str': 'ingredients'},
#  {'sequence': '<s> sour_cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0009188386611640453,
#   'token': 59,
#   'token_str': 'sour_cream'},
#  {'sequence': '<s> dumplings pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0009088811930269003,
#   'token': 2719,
#   'token_str': 'dumplings'},
#  {'sequence': '<s> worcestershire_sauce pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000900717917829752,
#   'token': 123,
#   'token_str': 'worcestershire_sauce'},
#  {'sequence': '<s> canned_tomatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008889432065188885,
#   'token': 658,
#   'token_str': 'canned_tomatoes'},
#  {'sequence': '<s> mashed_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008798569906502962,
#   'token': 839,
#   'token_str': 'mashed_potatoes'},
#  {'sequence': '<s> skin pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008683628402650356,
#   'token': 831,
#   'token_str': 'skin'},
#  {'sequence': '<s> halfandhalf pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008667776128277183,
#   'token': 283,
#   'token_str': 'halfandhalf'},
#  {'sequence': '<s> canola_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008502716082148254,
#   'token': 152,
#   'token_str': 'canola_oil'},
#  {'sequence': '<s> dried_thyme pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008300667395815253,
#   'token': 214,
#   'token_str': 'dried_thyme'},
#  {'sequence': '<s> chicken_fat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008222340838983655,
#   'token': 2512,
#   'token_str': 'chicken_fat'},
#  {'sequence': '<s> broth pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008142699371092021,
#   'token': 242,
#   'token_str': 'broth'},
#  {'sequence': '<s> savory pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0008036667131818831,
#   'token': 992,
#   'token_str': 'savory'},
#  {'sequence': '<s> vegetable pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0007907661492936313,
#   'token': 32,
#   'token_str': 'vegetable'},
#  {'sequence': '<s> okra pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0007647735765203834,
#   'token': 957,
#   'token_str': 'okra'},
#  {'sequence': '<s> cheddar_cheese pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000747628859244287,
#   'token': 64,
#   'token_str': 'cheddar_cheese'},
#  {'sequence': '<s> green_beans pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0007353808614425361,
#   'token': 272,
#   'token_str': 'green_beans'},
#  {'sequence': '<s> ginger pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006876243278384209,
#   'token': 45,
#   'token_str': 'ginger'},
#  {'sequence': '<s> tarragon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006874774699099362,
#   'token': 315,
#   'token_str': 'tarragon'},
#  {'sequence': '<s> garlic_powder pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006641803774982691,
#   'token': 84,
#   'token_str': 'garlic_powder'},
#  {'sequence': '<s> biscuits pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006630235002376139,
#   'token': 899,
#   'token_str': 'biscuits'},
#  {'sequence': '<s> soda pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006297103827819228,
#   'token': 48,
#   'token_str': 'soda'},
#  {'sequence': '<s> heavy_cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006235429318621755,
#   'token': 93,
#   'token_str': 'heavy_cream'},
#  {'sequence': '<s> light_cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006229259888641536,
#   'token': 589,
#   'token_str': 'light_cream'},
#  {'sequence': '<s> bouillon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006163968937471509,
#   'token': 268,
#   'token_str': 'bouillon'},
#  {'sequence': '<s> turkey_carcass pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0006085922941565514,
#   'token': 3432,
#   'token_str': 'turkey_carcass'},
#  {'sequence': '<s> mixed_vegetables pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005848904838785529,
#   'token': 745,
#   'token_str': 'mixed_vegetables'},
#  {'sequence': '<s> barley pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005777916521765292,
#   'token': 678,
#   'token_str': 'barley'},
#  {'sequence': '<s> goose pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000573356170207262,
#   'token': 2206,
#   'token_str': 'goose'},
#  {'sequence': '<s> stuffing pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005732517456635833,
#   'token': 549,
#   'token_str': 'stuffing'},
#  {'sequence': '<s> tomato pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005587497144006193,
#   'token': 50,
#   'token_str': 'tomato'},
#  {'sequence': '<s> unsalted_butter pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005544411833398044,
#   'token': 44,
#   'token_str': 'unsalted_butter'},
#  {'sequence': '<s> corn_bread pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000552533776499331,
#   'token': 1902,
#   'token_str': 'corn_bread'},
#  {'sequence': '<s> seasonings pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005236068973317742,
#   'token': 1652,
#   'token_str': 'seasonings'},
#  {'sequence': '<s> pork_chops pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005233201081864536,
#   'token': 491,
#   'token_str': 'pork_chops'},
#  {'sequence': '<s> kitchen_bouquet pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005216163117438555,
#   'token': 2825,
#   'token_str': 'kitchen_bouquet'},
#  {'sequence': '<s> cold_milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005143535672686994,
#   'token': 813,
#   'token_str': 'cold_milk'},
#  {'sequence': '<s> beef pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005103094154037535,
#   'token': 188,
#   'token_str': 'beef'},
#  {'sequence': '<s> vegetables pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0005011813482269645,
#   'token': 420,
#   'token_str': 'vegetables'},
#  {'sequence': '<s> cloves pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000484102318296209,
#   'token': 87,
#   'token_str': 'cloves'},
#  {'sequence': '<s> gumbo pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00047687708865851164,
#   'token': 3231,
#   'token_str': 'gumbo'},
#  {'sequence': '<s> cheese pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00045571153168566525,
#   'token': 21,
#   'token_str': 'cheese'},
#  {'sequence': '<s> oysters pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00044434849405661225,
#   'token': 1080,
#   'token_str': 'oysters'},
#  {'sequence': '<s> bouillon_powder pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004358822188805789,
#   'token': 2026,
#   'token_str': 'bouillon_powder'},
#  {'sequence': '<s> rutabaga pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004350275848992169,
#   'token': 1867,
#   'token_str': 'rutabaga'},
#  {'sequence': '<s> sliced_mushrooms pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004309392243158072,
#   'token': 359,
#   'token_str': 'sliced_mushrooms'},
#  {'sequence': '<s> baking_soda pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00041931596933864057,
#   'token': 57,
#   'token_str': 'baking_soda'},
#  {'sequence': '<s> corn_kernels pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004127564316149801,
#   'token': 503,
#   'token_str': 'corn_kernels'},
#  {'sequence': '<s> gravy_mix pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004125084960833192,
#   'token': 1591,
#   'token_str': 'gravy_mix'},
#  {'sequence': '<s> lemon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000405298313125968,
#   'token': 23,
#   'token_str': 'lemon'},
#  {'sequence': '<s> accent pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004038672486785799,
#   'token': 3266,
#   'token_str': 'accent'},
#  {'sequence': '<s> cabbage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0004011508426629007,
#   'token': 182,
#   'token_str': 'cabbage'},
#  {'sequence': '<s> season pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00039875475340522826,
#   'token': 960,
#   'token_str': 'season'},
#  {'sequence': '<s> zucchini pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003930491511709988,
#   'token': 170,
#   'token_str': 'zucchini'},
#  {'sequence': '<s> rotel_tomatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003891214437317103,
#   'token': 1223,
#   'token_str': 'rotel_tomatoes'},
#  {'sequence': '<s> cooked_rice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003874390386044979,
#   'token': 514,
#   'token_str': 'cooked_rice'},
#  {'sequence': '<s> cream_of_celery_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00038708909414708614,
#   'token': 938,
#   'token_str': 'cream_of_celery_soup'},
#  {'sequence': '<s> carrots pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00037542067002505064,
#   'token': 67,
#   'token_str': 'carrots'},
#  {'sequence': '<s> ground_sage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00037509697722271085,
#   'token': 1463,
#   'token_str': 'ground_sage'},
#  {'sequence': '<s> russet_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003747476439457387,
#   'token': 616,
#   'token_str': 'russet_potatoes'},
#  {'sequence': '<s> butter_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003695613704621792,
#   'token': 2455,
#   'token_str': 'butter_oil'},
#  {'sequence': '<s> pan_drippings pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00036548791103996336,
#   'token': 2890,
#   'token_str': 'pan_drippings'},
#  {'sequence': '<s> cooked_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00036025623558089137,
#   'token': 2317,
#   'token_str': 'cooked_potatoes'},
#  {'sequence': '<s> seasoning pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00034538665204308927,
#   'token': 78,
#   'token_str': 'seasoning'},
#  {'sequence': '<s> cooked_turkey pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00034337275428697467,
#   'token': 882,
#   'token_str': 'cooked_turkey'},
#  {'sequence': '<s> whipping_cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003431825607549399,
#   'token': 171,
#   'token_str': 'whipping_cream'},
#  {'sequence': '<s> egg_yolks pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00034288549795746803,
#   'token': 179,
#   'token_str': 'egg_yolks'},
#  {'sequence': '<s> dried_sage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003426810435485095,
#   'token': 1089,
#   'token_str': 'dried_sage'},
#  {'sequence': '<s> wide_egg_noodles pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00033337881905026734,
#   'token': 1393,
#   'token_str': 'wide_egg_noodles'},
#  {'sequence': '<s> salad_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003301204415038228,
#   'token': 906,
#   'token_str': 'salad_oil'},
#  {'sequence': '<s> green_peas pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003274919290561229,
#   'token': 798,
#   'token_str': 'green_peas'},
#  {'sequence': '<s> rounds pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00031407337519340217,
#   'token': 778,
#   'token_str': 'rounds'},
#  {'sequence': '<s> pork_sausage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00031381589360535145,
#   'token': 684,
#   'token_str': 'pork_sausage'},
#  {'sequence': '<s> bacon_drippings pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00031285814475268126,
#   'token': 1678,
#   'token_str': 'bacon_drippings'},
#  {'sequence': '<s> stew_meat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003121823538094759,
#   'token': 834,
#   'token_str': 'stew_meat'},
#  {'sequence': '<s> dough pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00030869379406794906,
#   'token': 431,
#   'token_str': 'dough'},
#  {'sequence': '<s> tomato_juice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0003064083866775036,
#   'token': 708,
#   'token_str': 'tomato_juice'},
#  {'sequence': '<s> shells pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00030589409288950264,
#   'token': 483,
#   'token_str': 'shells'},
#  {'sequence': '<s> lima_beans pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00030370062449947,
#   'token': 1193,
#   'token_str': 'lima_beans'},
#  {'sequence': '<s> rib pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00030166644137352705,
#   'token': 721,
#   'token_str': 'rib'},
#  {'sequence': '<s> marjoram pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002998031268361956,
#   'token': 520,
#   'token_str': 'marjoram'},
#  {'sequence': '<s> crumbled_cornbread pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00029120317776687443,
#   'token': 2929,
#   'token_str': 'crumbled_cornbread'},
#  {'sequence': '<s> roast pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002904820430558175,
#   'token': 292,
#   'token_str': 'roast'},
#  {'sequence': '<s> lemon_juice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002888345334213227,
#   'token': 34,
#   'token_str': 'lemon_juice'},
#  {'sequence': '<s> sweet_peas pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002789877471514046,
#   'token': 2503,
#   'token_str': 'sweet_peas'},
#  {'sequence': '<s> accent_seasoning pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00027740176301449537,
#   'token': 2756,
#   'token_str': 'accent_seasoning'},
#  {'sequence': '<s> cornstarch pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00027226924430578947,
#   'token': 116,
#   'token_str': 'cornstarch'},
#  {'sequence': '<s> carrot pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00027203865465708077,
#   'token': 140,
#   'token_str': 'carrot'},
#  {'sequence': '<s> egg_yolk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00026925725978799164,
#   'token': 336,
#   'token_str': 'egg_yolk'},
#  {'sequence': '<s> turnips pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00026686600176617503,
#   'token': 1024,
#   'token_str': 'turnips'},
#  {'sequence': '<s> tomato_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002660815080162138,
#   'token': 804,
#   'token_str': 'tomato_soup'},
#  {'sequence': '<s> bacon_fat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00026568316388875246,
#   'token': 1834,
#   'token_str': 'bacon_fat'},
#  {'sequence': '<s> popcorn pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002636677527334541,
#   'token': 939,
#   'token_str': 'popcorn'},
#  {'sequence': '<s> dried_parsley pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00026193694793619215,
#   'token': 445,
#   'token_str': 'dried_parsley'},
#  {'sequence': '<s> sausage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00025951897259801626,
#   'token': 161,
#   'token_str': 'sausage'},
#  {'sequence': '<s> onion pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002582308661658317,
#   'token': 11,
#   'token_str': 'onion'},
#  {'sequence': '<s> vinegar pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002544491726439446,
#   'token': 31,
#   'token_str': 'vinegar'},
#  {'sequence': '<s> brown pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00024654334993101656,
#   'token': 27,
#   'token_str': 'brown'},
#  {'sequence': '<s> tap_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00024469030904583633,
#   'token': 2664,
#   'token_str': 'tap_water'},
#  {'sequence': '<s> buttermilk_biscuits pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00024205658701248467,
#   'token': 1608,
#   'token_str': 'buttermilk_biscuits'},
#  {'sequence': '<s> lemons pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00024021949502639472,
#   'token': 310,
#   'token_str': 'lemons'},
#  {'sequence': '<s> rabbit pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00024002220015972853,
#   'token': 2102,
#   'token_str': 'rabbit'},
#  {'sequence': '<s> apple_cider pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002377158380113542,
#   'token': 284,
#   'token_str': 'apple_cider'},
#  {'sequence': '<s> garnish pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00022961712966207415,
#   'token': 95,
#   'token_str': 'garnish'},
#  {'sequence': '<s> skim_milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00022873120906297117,
#   'token': 438,
#   'token_str': 'skim_milk'},
#  {'sequence': '<s> beef_stock pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00022790303046349436,
#   'token': 495,
#   'token_str': 'beef_stock'},
#  {'sequence': '<s> butter_flavor pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002258738677483052,
#   'token': 1582,
#   'token_str': 'butter_flavor'},
#  {'sequence': '<s> monosodium_glutamate pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002228824159828946,
#   'token': 2623,
#   'token_str': 'monosodium_glutamate'},
#  {'sequence': '<s> canned_corn pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00021814520005136728,
#   'token': 1920,
#   'token_str': 'canned_corn'},
#  {'sequence': '<s> veal pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00021766172721982002,
#   'token': 1053,
#   'token_str': 'veal'},
#  {'sequence': '<s> curry pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00021545954223256558,
#   'token': 525,
#   'token_str': 'curry'},
#  {'sequence': '<s> chicken_broth pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00021480875147972256,
#   'token': 69,
#   'token_str': 'chicken_broth'},
#  {'sequence': '<s> duck pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00021014962112531066,
#   'token': 887,
#   'token_str': 'duck'},
#  {'sequence': '<s> minced_parsley pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0002096927782986313,
#   'token': 497,
#   'token_str': 'minced_parsley'},
#  {'sequence': '<s> celery_leaves pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00020861129451077431,
#   'token': 1438,
#   'token_str': 'celery_leaves'},
#  {'sequence': '<s> dried_split_peas pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00020595754904206842,
#   'token': 3393,
#   'token_str': 'dried_split_peas'},
#  {'sequence': '<s> ham pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00020074602798558772,
#   'token': 239,
#   'token_str': 'ham'},
#  {'sequence': '<s> extra_virgin_olive_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00019885858637280762,
#   'token': 101,
#   'token_str': 'extra_virgin_olive_oil'},
#  {'sequence': '<s> condensed_cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001971151796169579,
#   'token': 582,
#   'token_str': 'condensed_cream'},
#  {'sequence': '<s> italian_tomatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00019611389143392444,
#   'token': 2149,
#   'token_str': 'italian_tomatoes'},
#  {'sequence': '<s> tomato_sauce pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00019542721565812826,
#   'token': 186,
#   'token_str': 'tomato_sauce'},
#  {'sequence': '<s> apple pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00019403771148063242,
#   'token': 172,
#   'token_str': 'apple'},
#  {'sequence': '<s> sauce pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018822714628186077,
#   'token': 25,
#   'token_str': 'sauce'},
#  {'sequence': '<s> frying_oil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018541819008532912,
#   'token': 2118,
#   'token_str': 'frying_oil'},
#  {'sequence': '<s> oregano pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018452815129421651,
#   'token': 65,
#   'token_str': 'oregano'},
#  {'sequence': '<s> herbs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018322051619179547,
#   'token': 656,
#   'token_str': 'herbs'},
#  {'sequence': '<s> soy_sauce pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018151465337723494,
#   'token': 61,
#   'token_str': 'soy_sauce'},
#  {'sequence': '<s> frozen_okra pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018117240688297898,
#   'token': 2276,
#   'token_str': 'frozen_okra'},
#  {'sequence': '<s> butter_flavor_shortening pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00018003623699769378,
#   'token': 2658,
#   'token_str': 'butter_flavor_shortening'},
#  {'sequence': '<s> instant_potato_flakes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00017891349853016436,
#   'token': 3119,
#   'token_str': 'instant_potato_flakes'},
#  {'sequence': '<s> corn_meal pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00017716492584440857,
#   'token': 1721,
#   'token_str': 'corn_meal'},
#  {'sequence': '<s> white_rice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00017681391909718513,
#   'token': 293,
#   'token_str': 'white_rice'},
#  {'sequence': '<s> poultry pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00017465393466409296,
#   'token': 1931,
#   'token_str': 'poultry'},
#  {'sequence': '<s> bread pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001744029432302341,
#   'token': 74,
#   'token_str': 'bread'},
#  {'sequence': '<s> basil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001711435616016388,
#   'token': 77,
#   'token_str': 'basil'},
#  {'sequence': '<s> frozen_green_beans pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00016883411444723606,
#   'token': 1812,
#   'token_str': 'frozen_green_beans'},
#  {'sequence': '<s> bouquet_garni pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001682616421021521,
#   'token': 1439,
#   'token_str': 'bouquet_garni'},
#  {'sequence': '<s> minced_garlic pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00016700684500392526,
#   'token': 134,
#   'token_str': 'minced_garlic'},
#  {'sequence': '<s> white_corn pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00016574852634221315,
#   'token': 1313,
#   'token_str': 'white_corn'},
#  {'sequence': '<s> juice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00016463236534036696,
#   'token': 56,
#   'token_str': 'juice'},
#  {'sequence': '<s> browning pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001646318269195035,
#   'token': 2064,
#   'token_str': 'browning'},
#  {'sequence': '<s> round_steaks pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00016172330651897937,
#   'token': 1592,
#   'token_str': 'round_steaks'},
#  {'sequence': '<s> onion_tops pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015922969032544643,
#   'token': 1950,
#   'token_str': 'onion_tops'},
#  {'sequence': '<s> condensed_cream_of_chicken_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015908731438685209,
#   'token': 1097,
#   'token_str': 'condensed_cream_of_chicken_soup'},
#  {'sequence': '<s> nutmeg pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015803772839717567,
#   'token': 85,
#   'token_str': 'nutmeg'},
#  {'sequence': '<s> spice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015753618208691478,
#   'token': 546,
#   'token_str': 'spice'},
#  {'sequence': '<s> hash_brown pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015711893502157182,
#   'token': 1199,
#   'token_str': 'hash_brown'},
#  {'sequence': '<s> chicken_thighs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015540339518338442,
#   'token': 388,
#   'token_str': 'chicken_thighs'},
#  {'sequence': '<s> spices pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00015473186795134097,
#   'token': 910,
#   'token_str': 'spices'},
#  {'sequence': '<s> softened_butter pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001532563619548455,
#   'token': 916,
#   'token_str': 'softened_butter'},
#  {'sequence': '<s> american_cheese pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001526432897662744,
#   'token': 700,
#   'token_str': 'american_cheese'},
#  {'sequence': '<s> roux pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001515960175311193,
#   'token': 2289,
#   'token_str': 'roux'},
#  {'sequence': '<s> thyme_leaves pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001511888694949448,
#   'token': 384,
#   'token_str': 'thyme_leaves'},
#  {'sequence': '<s> oyster pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014835003821644932,
#   'token': 612,
#   'token_str': 'oyster'},
#  {'sequence': '<s> cut_up_chicken pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014736609591636807,
#   'token': 2858,
#   'token_str': 'cut_up_chicken'},
#  {'sequence': '<s> beef_bouillon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014716049190610647,
#   'token': 685,
#   'token_str': 'beef_bouillon'},
#  {'sequence': '<s> frozen_corn pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014682083565276116,
#   'token': 542,
#   'token_str': 'frozen_corn'},
#  {'sequence': '<s> boiled_eggs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.000146517573739402,
#   'token': 1256,
#   'token_str': 'boiled_eggs'},
#  {'sequence': '<s> mace pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014611556252930313,
#   'token': 1095,
#   'token_str': 'mace'},
#  {'sequence': '<s> pastry pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001450314448447898,
#   'token': 287,
#   'token_str': 'pastry'},
#  {'sequence': '<s> veggies pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014481390826404095,
#   'token': 2111,
#   'token_str': 'veggies'},
#  {'sequence': '<s> chicken_meat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014458470104727894,
#   'token': 1620,
#   'token_str': 'chicken_meat'},
#  {'sequence': '<s> scallions pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00014280664618127048,
#   'token': 167,
#   'token_str': 'scallions'},
#  {'sequence': '<s> sausages pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001423796493327245,
#   'token': 766,
#   'token_str': 'sausages'},
#  {'sequence': '<s> parsnips pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001395751751260832,
#   'token': 845,
#   'token_str': 'parsnips'},
#  {'sequence': '<s> olive pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00013779944856651127,
#   'token': 15,
#   'token_str': 'olive'},
#  {'sequence': '<s> ground_beef pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00013479989138431847,
#   'token': 114,
#   'token_str': 'ground_beef'},
#  {'sequence': '<s> onions pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00013243628200143576,
#   'token': 30,
#   'token_str': 'onions'},
#  {'sequence': '<s> granulated_garlic pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001315231347689405,
#   'token': 926,
#   'token_str': 'granulated_garlic'},
#  {'sequence': '<s> crescent_rolls pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001313055690843612,
#   'token': 1116,
#   'token_str': 'crescent_rolls'},
#  {'sequence': '<s> sharp_cheddar_cheese pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00013105361722409725,
#   'token': 301,
#   'token_str': 'sharp_cheddar_cheese'},
#  {'sequence': '<s> fish pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00013052563008386642,
#   'token': 669,
#   'token_str': 'fish'},
#  {'sequence': '<s> split_peas pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012954557314515114,
#   'token': 1435,
#   'token_str': 'split_peas'},
#  {'sequence': '<s> much pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012921773304697126,
#   'token': 1555,
#   'token_str': 'much'},
#  {'sequence': '<s> chicken_bouillon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001285004400415346,
#   'token': 450,
#   'token_str': 'chicken_bouillon'},
#  {'sequence': '<s> paste pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012742493709083647,
#   'token': 570,
#   'token_str': 'paste'},
#  {'sequence': '<s> pimento pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012680873624049127,
#   'token': 1140,
#   'token_str': 'pimento'},
#  {'sequence': '<s> crackers pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012643547961488366,
#   'token': 320,
#   'token_str': 'crackers'},
#  {'sequence': '<s> apple_juice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012471101945266128,
#   'token': 460,
#   'token_str': 'apple_juice'},
#  {'sequence': '<s> refrigerated_biscuits pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012464800965972245,
#   'token': 1938,
#   'token_str': 'refrigerated_biscuits'},
#  {'sequence': '<s> dill_pickles pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012382905697450042,
#   'token': 1350,
#   'token_str': 'dill_pickles'},
#  {'sequence': '<s> breadcrumbs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012319040251895785,
#   'token': 204,
#   'token_str': 'breadcrumbs'},
#  {'sequence': '<s> boneless pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012285474804230034,
#   'token': 94,
#   'token_str': 'boneless'},
#  {'sequence': '<s> sherry pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012273038737475872,
#   'token': 267,
#   'token_str': 'sherry'},
#  {'sequence': '<s> dried_basil pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001216361197293736,
#   'token': 262,
#   'token_str': 'dried_basil'},
#  {'sequence': '<s> pimiento pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00012118478480260819,
#   'token': 1280,
#   'token_str': 'pimiento'},
#  {'sequence': '<s> navy_beans pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001210558766615577,
#   'token': 1396,
#   'token_str': 'navy_beans'},
#  {'sequence': '<s> pepper pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011998959234915674,
#   'token': 6,
#   'token_str': 'pepper'},
#  {'sequence': '<s> sour_milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011991649807896465,
#   'token': 1709,
#   'token_str': 'sour_milk'},
#  {'sequence': '<s> salt pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011953889770666137,
#   'token': 5,
#   'token_str': 'salt'},
#  {'sequence': '<s> white_wine pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011951837950618938,
#   'token': 89,
#   'token_str': 'white_wine'},
#  {'sequence': '<s> brown_sugar pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011928050662390888,
#   'token': 33,
#   'token_str': 'brown_sugar'},
#  {'sequence': '<s> powdered_milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001165677240351215,
#   'token': 1273,
#   'token_str': 'powdered_milk'},
#  {'sequence': '<s> italian_seasoning pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011575493408599868,
#   'token': 377,
#   'token_str': 'italian_seasoning'},
#  {'sequence': '<s> coating pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011426187120378017,
#   'token': 923,
#   'token_str': 'coating'},
#  {'sequence': '<s> dry_sherry pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011375780741218477,
#   'token': 501,
#   'token_str': 'dry_sherry'},
#  {'sequence': '<s> crust pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.0001134888589149341,
#   'token': 362,
#   'token_str': 'crust'},
#  {'sequence': '<s> flavor pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011348572297720239,
#   'token': 344,
#   'token_str': 'flavor'},
#  {'sequence': '<s> chicken pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011330783308949322,
#   'token': 24,
#   'token_str': 'chicken'},
#  {'sequence': '<s> cream_of_potato_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011323254148010164,
#   'token': 2091,
#   'token_str': 'cream_of_potato_soup'},
#  {'sequence': '<s> temperature pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011275312135694548,
#   'token': 135,
#   'token_str': 'temperature'},
#  {'sequence': '<s> broccoli pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011213940160814673,
#   'token': 197,
#   'token_str': 'broccoli'},
#  {'sequence': '<s> celery pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011178341810591519,
#   'token': 51,
#   'token_str': 'celery'},
#  {'sequence': '<s> peppercorns pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011104400618933141,
#   'token': 281,
#   'token_str': 'peppercorns'},
#  {'sequence': '<s> hungarian_paprika pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011036451905965805,
#   'token': 1542,
#   'token_str': 'hungarian_paprika'},
#  {'sequence': '<s> bell_pepper pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00011034042108803988,
#   'token': 82,
#   'token_str': 'bell_pepper'},
#  {'sequence': '<s> bisquick pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00010991925955750048,
#   'token': 788,
#   'token_str': 'bisquick'},
#  {'sequence': '<s> in_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00010957795166177675,
#   'token': 585,
#   'token_str': 'in_water'},
#  {'sequence': '<s> yellow_summer_squash pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00010901062341872603,
#   'token': 3151,
#   'token_str': 'yellow_summer_squash'},
#  {'sequence': '<s> dry_mustard pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.00010823731281561777,
#   'token': 317,
# ...
#   'token_str': 'dark_meat'},
#  {'sequence': '<s> color pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.868676089448854e-05,
#   'token': 1061,
#   'token_str': 'color'},
#  {'sequence': '<s> rotisserie_chicken pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.758909901487641e-05,
#   'token': 1175,
#   'token_str': 'rotisserie_chicken'},
#  {'sequence': '<s> ground_sausage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.75874510104768e-05,
#   'token': 2247,
#   'token_str': 'ground_sausage'},
#  {'sequence': '<s> sherry_wine pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.740447522839531e-05,
#   'token': 663,
#   'token_str': 'sherry_wine'},
#  {'sequence': '<s> venison pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.738280015066266e-05,
#   'token': 1226,
#   'token_str': 'venison'},
#  {'sequence': '<s> chicken_liver pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.6877357565099373e-05,
#   'token': 2994,
#   'token_str': 'chicken_liver'},
#  {'sequence': '<s> white_mushrooms pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.6450884585501626e-05,
#   'token': 1031,
#   'token_str': 'white_mushrooms'},
#  {'sequence': '<s> steak pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.641396273858845e-05,
#   'token': 324,
#   'token_str': 'steak'},
#  {'sequence': '<s> butterscotch_chips pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.6399174354737625e-05,
#   'token': 1062,
#   'token_str': 'butterscotch_chips'},
#  {'sequence': '<s> power pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.6220505939563736e-05,
#   'token': 3070,
#   'token_str': 'power'},
#  {'sequence': '<s> boneless_pork pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.58203537366353e-05,
#   'token': 558,
#   'token_str': 'boneless_pork'},
#  {'sequence': '<s> refrigerated_buttermilk_biscuits pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.581343430094421e-05,
#   'token': 2193,
#   'token_str': 'refrigerated_buttermilk_biscuits'},
#  {'sequence': '<s> ground_black_pepper pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.57617204322014e-05,
#   'token': 35,
#   'token_str': 'ground_black_pepper'},
#  {'sequence': '<s> bulb pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.550413698074408e-05,
#   'token': 2155,
#   'token_str': 'bulb'},
#  {'sequence': '<s> worchestershire_sauce pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.512133066076785e-05,
#   'token': 2773,
#   'token_str': 'worchestershire_sauce'},
#  {'sequence': '<s> red_potato pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.4292944696499035e-05,
#   'token': 1821,
#   'token_str': 'red_potato'},
#  {'sequence': '<s> asparagus pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.42796915397048e-05,
#   'token': 307,
#   'token_str': 'asparagus'},
#  {'sequence': '<s> matzo_meal pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.392332604969852e-05,
#   'token': 1857,
#   'token_str': 'matzo_meal'},
#  {'sequence': '<s> tater_tots pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.371878432924859e-05,
#   'token': 1789,
#   'token_str': 'tater_tots'},
#  {'sequence': '<s> peppercorn pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.370393046177924e-05,
#   'token': 1255,
#   'token_str': 'peppercorn'},
#  {'sequence': '<s> minced_onion pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.3656574891647324e-05,
#   'token': 424,
#   'token_str': 'minced_onion'},
#  {'sequence': '<s> andouille_sausage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.332910950528458e-05,
#   'token': 1457,
#   'token_str': 'andouille_sausage'},
#  {'sequence': '<s> yellow_onion pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.3220435802359134e-05,
#   'token': 247,
#   'token_str': 'yellow_onion'},
#  {'sequence': '<s> cubed_beef pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.298318137647584e-05,
#   'token': 2784,
#   'token_str': 'cubed_beef'},
#  {'sequence': '<s> dry_white_wine pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.259779209154658e-05,
#   'token': 207,
#   'token_str': 'dry_white_wine'},
#  {'sequence': '<s> salmon pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.192985918256454e-05,
#   'token': 318,
#   'token_str': 'salmon'},
#  {'sequence': '<s> jimmy_dean_sausage pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.1352177251828834e-05,
#   'token': 3447,
#   'token_str': 'jimmy_dean_sausage'},
#  {'sequence': '<s> pineapple pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.130723729962483e-05,
#   'token': 149,
#   'token_str': 'pineapple'},
#  {'sequence': '<s> pink pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.107578544993885e-05,
#   'token': 1261,
#   'token_str': 'pink'},
#  {'sequence': '<s> nonfat_milk pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.0874281441792846e-05,
#   'token': 945,
#   'token_str': 'nonfat_milk'},
#  {'sequence': '<s> sauerkraut pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.081817653262988e-05,
#   'token': 754,
#   'token_str': 'sauerkraut'},
#  {'sequence': '<s> chicken_legs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.072579006082378e-05,
#   'token': 1123,
#   'token_str': 'chicken_legs'},
#  {'sequence': '<s> yellow_squash pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.060171315562911e-05,
#   'token': 661,
#   'token_str': 'yellow_squash'},
#  {'sequence': '<s> water_chestnuts pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.05239368067123e-05,
#   'token': 703,
#   'token_str': 'water_chestnuts'},
#  {'sequence': '<s> turkey_legs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.046754449722357e-05,
#   'token': 3365,
#   'token_str': 'turkey_legs'},
#  {'sequence': '<s> baby_carrots pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.035662979935296e-05,
#   'token': 664,
#   'token_str': 'baby_carrots'},
#  {'sequence': '<s> chicken_breasts pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 5.0182508857687935e-05,
#   'token': 104,
#   'token_str': 'chicken_breasts'},
#  {'sequence': '<s> pearl_barley pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.999067823518999e-05,
#   'token': 1238,
#   'token_str': 'pearl_barley'},
#  {'sequence': '<s> green_chilies pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.978766446583904e-05,
#   'token': 330,
#   'token_str': 'green_chilies'},
#  {'sequence': '<s> chives pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.959928628522903e-05,
#   'token': 190,
#   'token_str': 'chives'},
#  {'sequence': '<s> onion_powder pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.943834210280329e-05,
#   'token': 228,
#   'token_str': 'onion_powder'},
#  {'sequence': '<s> low_fat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.8848811275092885e-05,
#   'token': 710,
#   'token_str': 'low_fat'},
#  {'sequence': '<s> ham_hock pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.856430314248428e-05,
#   'token': 2066,
#   'token_str': 'ham_hock'},
#  {'sequence': '<s> homemade_chicken_stock pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.8371693992521614e-05,
#   'token': 1839,
#   'token_str': 'homemade_chicken_stock'},
#  {'sequence': '<s> cooking_sherry pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.829932004213333e-05,
#   'token': 1904,
#   'token_str': 'cooking_sherry'},
#  {'sequence': '<s> chicken_parts pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.770680607180111e-05,
#   'token': 1905,
#   'token_str': 'chicken_parts'},
#  {'sequence': '<s> coffee_creamer pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.751334199681878e-05,
#   'token': 1840,
#   'token_str': 'coffee_creamer'},
#  {'sequence': '<s> pot_roast pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.745587284560315e-05,
#   'token': 2045,
#   'token_str': 'pot_roast'},
#  {'sequence': '<s> heavy_whipping_cream pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.732115121441893e-05,
#   'token': 369,
#   'token_str': 'heavy_whipping_cream'},
#  {'sequence': '<s> love pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.7261575673474e-05,
#   'token': 2391,
#   'token_str': 'love'},
#  {'sequence': '<s> turkey_breast pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.7065201215445995e-05,
#   'token': 730,
#   'token_str': 'turkey_breast'},
#  {'sequence': '<s> pie_shell pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.695840470958501e-05,
#   'token': 775,
#   'token_str': 'pie_shell'},
#  {'sequence': '<s> sweet_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.691248250310309e-05,
#   'token': 353,
#   'token_str': 'sweet_potatoes'},
#  {'sequence': '<s> ground_pork pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.6837689296808094e-05,
#   'token': 469,
#   'token_str': 'ground_pork'},
#  {'sequence': '<s> light_beer pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.661488492274657e-05,
#   'token': 2938,
#   'token_str': 'light_beer'},
#  {'sequence': '<s> bread_crumbs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.65745797555428e-05,
#   'token': 216,
#   'token_str': 'bread_crumbs'},
#  {'sequence': '<s> pork_fat pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.622667984222062e-05,
#   'token': 2354,
#   'token_str': 'pork_fat'},
#  {'sequence': '<s> sliced_almonds pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.584743510349654e-05,
#   'token': 416,
#   'token_str': 'sliced_almonds'},
#  {'sequence': '<s> canned_chicken_broth pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.578665902954526e-05,
#   'token': 1730,
#   'token_str': 'canned_chicken_broth'},
#  {'sequence': '<s> chili pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.5639088057214394e-05,
#   'token': 185,
#   'token_str': 'chili'},
#  {'sequence': '<s> green_onion pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.5545821194536984e-05,
#   'token': 209,
#   'token_str': 'green_onion'},
#  {'sequence': '<s> ranch_dressing pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.549520599539392e-05,
#   'token': 623,
#   'token_str': 'ranch_dressing'},
#  {'sequence': '<s> celery_seed pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.546809577732347e-05,
#   'token': 718,
#   'token_str': 'celery_seed'},
#  {'sequence': '<s> scallion pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.5072716602589935e-05,
#   'token': 476,
#   'token_str': 'scallion'},
#  {'sequence': '<s> dijon_mustard pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.494591848924756e-05,
#   'token': 148,
#   'token_str': 'dijon_mustard'},
#  {'sequence': '<s> french_dressing pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.489164348342456e-05,
#   'token': 2177,
#   'token_str': 'french_dressing'},
#  {'sequence': '<s> yellow_cornmeal pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.475412788451649e-05,
#   'token': 816,
#   'token_str': 'yellow_cornmeal'},
#  {'sequence': '<s> sliced_carrots pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.467660255613737e-05,
#   'token': 1268,
#   'token_str': 'sliced_carrots'},
#  {'sequence': '<s> not_available pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.457705654203892e-05,
#   'token': 2885,
#   'token_str': 'not_available'},
#  {'sequence': '<s> black_peppercorns pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.4230910134501755e-05,
#   'token': 440,
#   'token_str': 'black_peppercorns'},
#  {'sequence': '<s> applesauce pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.419241668074392e-05,
#   'token': 473,
#   'token_str': 'applesauce'},
#  {'sequence': '<s> condensed_cream_of_celery_soup pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.412057751324028e-05,
#   'token': 1947,
#   'token_str': 'condensed_cream_of_celery_soup'},
#  {'sequence': '<s> vermouth pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.390880712890066e-05,
#   'token': 874,
#   'token_str': 'vermouth'},
#  {'sequence': '<s> crawfish pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.365981658338569e-05,
#   'token': 1910,
#   'token_str': 'crawfish'},
#  {'sequence': '<s> frozen_spinach pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.346091373008676e-05,
#   'token': 453,
#   'token_str': 'frozen_spinach'},
#  {'sequence': '<s> yukon_gold_potatoes pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.2919527913909405e-05,
#   'token': 647,
#   'token_str': 'yukon_gold_potatoes'},
#  {'sequence': '<s> vegetable_juice pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.2813728214241564e-05,
#   'token': 1510,
#   'token_str': 'vegetable_juice'},
#  {'sequence': '<s> smoked_pork pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.2804258555406705e-05,
#   'token': 2229,
#   'token_str': 'smoked_pork'},
#  {'sequence': '<s> hominy pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.273646482033655e-05,
#   'token': 1139,
#   'token_str': 'hominy'},
#  {'sequence': '<s> butternut_squash pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.25075413659215e-05,
#   'token': 502,
#   'token_str': 'butternut_squash'},
#  {'sequence': '<s> fish_bones pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.2459771066205576e-05,
#   'token': 2966,
#   'token_str': 'fish_bones'},
#  {'sequence': '<s> pearl_onions pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.192394044366665e-05,
#   'token': 1159,
#   'token_str': 'pearl_onions'},
#  {'sequence': '<s> beans pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.1643172153271735e-05,
#   'token': 98,
#   'token_str': 'beans'},
#  {'sequence': '<s> meatballs pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.159252785029821e-05,
#   'token': 1279,
#   'token_str': 'meatballs'},
#  {'sequence': '<s> egg_whites pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.1577062802389264e-05,
#   'token': 184,
#   'token_str': 'egg_whites'},
#  {'sequence': '<s> chicken_skin pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.138428994338028e-05,
#   'token': 2931,
#   'token_str': 'chicken_skin'},
#  {'sequence': '<s> beef_round pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.1026578401215374e-05,
#   'token': 1668,
#   'token_str': 'beef_round'},
#  {'sequence': '<s> tasso pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.100337901036255e-05,
#   'token': 3367,
#   'token_str': 'tasso'},
#  {'sequence': '<s> pork_shoulder pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.093859752174467e-05,
#   'token': 776,
#   'token_str': 'pork_shoulder'},
#  {'sequence': '<s> dill_pickle pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.072473893756978e-05,
#   'token': 1225,
#   'token_str': 'dill_pickle'},
#  {'sequence': '<s> cucumbers pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.032624201499857e-05,
#   'token': 500,
#   'token_str': 'cucumbers'},
#  {'sequence': '<s> bottom_round pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.010108386864886e-05,
#   'token': 2712,
#   'token_str': 'bottom_round'},
#  {'sequence': '<s> swede pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 4.005101800430566e-05,
#   'token': 3251,
#   'token_str': 'swede'}]

# %% [markdown]
# # Validation

# %%
from src.validation import validate
import pandas as pd
ks=[1, 2, 5, 10, 20, 50, 100]
validation_result = validate(fill_mask_recipe.model, tokenizer, 
                             ks=ks,
                             device=-1,
                             limit=5000, relative_base_path='../')
# Out:
# 382it [13:42,  2.15s/it]

# %%
df = pd.DataFrame([validation_result], columns=ks, index=['accuracy'])
(df*100).style.format('{:,.1f}%'.format)
# Out:
# <style  type="text/css" >
# </style><table id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >10</th>        <th class="col_heading level0 col4" >20</th>        <th class="col_heading level0 col5" >50</th>        <th class="col_heading level0 col6" >100</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col0" class="data row0 col0" >20.1%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col1" class="data row0 col1" >28.2%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col2" class="data row0 col2" >39.3%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col3" class="data row0 col3" >48.1%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col4" class="data row0 col4" >56.9%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col5" class="data row0 col5" >68.3%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col6" class="data row0 col6" >75.7%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # The Model (Transformer)

# %% [markdown]
# [<img src="https://miro.medium.com/max/700/0*ViwaI3Vvbnd-CJSQ.png">](https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270)
# https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270

# %%
model = fill_mask_recipe.model

# %%
fill_mask_recipe('dough pizza_sauce <mask>')
# Out:
# [{'sequence': '<s> dough pizza_sauce mozzarella_cheese </s>',
#   'score': 0.23033706843852997,
#   'token': 156,
#   'token_str': 'mozzarella_cheese'},
#  {'sequence': '<s> dough pizza_sauce pepperoni </s>',
#   'score': 0.20622113347053528,
#   'token': 733,
#   'token_str': 'pepperoni'},
#  {'sequence': '<s> dough pizza_sauce olive_oil </s>',
#   'score': 0.0663054808974266,
#   'token': 12,
#   'token_str': 'olive_oil'},
#  {'sequence': '<s> dough pizza_sauce cheese </s>',
#   'score': 0.06030401214957237,
#   'token': 21,
#   'token_str': 'cheese'},
#  {'sequence': '<s> dough pizza_sauce parmesan </s>',
#   'score': 0.03762682154774666,
#   'token': 49,
#   'token_str': 'parmesan'},
#  {'sequence': '<s> dough pizza_sauce mozzarella </s>',
#   'score': 0.03502006083726883,
#   'token': 125,
#   'token_str': 'mozzarella'},
#  {'sequence': '<s> dough pizza_sauce meatballs </s>',
#   'score': 0.012741947546601295,
#   'token': 1279,
#   'token_str': 'meatballs'},
#  {'sequence': '<s> dough pizza_sauce pepperoni_slices </s>',
#   'score': 0.011586504988372326,
#   'token': 2059,
#   'token_str': 'pepperoni_slices'},
#  {'sequence': '<s> dough pizza_sauce italian_cheese_blend </s>',
#   'score': 0.01147366501390934,
#   'token': 1829,
#   'token_str': 'italian_cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce breadstick </s>',
#   'score': 0.010369864292442799,
#   'token': 2976,
#   'token_str': 'breadstick'},
#  {'sequence': '<s> dough pizza_sauce sausages </s>',
#   'score': 0.009140487760305405,
#   'token': 766,
#   'token_str': 'sausages'},
#  {'sequence': '<s> dough pizza_sauce bacon </s>',
#   'score': 0.00897382665425539,
#   'token': 90,
#   'token_str': 'bacon'},
#  {'sequence': '<s> dough pizza_sauce oregano </s>',
#   'score': 0.008889516815543175,
#   'token': 65,
#   'token_str': 'oregano'},
#  {'sequence': '<s> dough pizza_sauce grated_parmesan_cheese </s>',
#   'score': 0.00880028959363699,
#   'token': 127,
#   'token_str': 'grated_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce italian_sausage </s>',
#   'score': 0.0076999664306640625,
#   'token': 529,
#   'token_str': 'italian_sausage'},
#  {'sequence': '<s> dough pizza_sauce salt </s>',
#   'score': 0.006830540951341391,
#   'token': 5,
#   'token_str': 'salt'},
#  {'sequence': '<s> dough pizza_sauce dried_oregano </s>',
#   'score': 0.0064731165766716,
#   'token': 163,
#   'token_str': 'dried_oregano'},
#  {'sequence': '<s> dough pizza_sauce provolone_cheese </s>',
#   'score': 0.006322799250483513,
#   'token': 748,
#   'token_str': 'provolone_cheese'},
#  {'sequence': '<s> dough pizza_sauce sausage </s>',
#   'score': 0.005986591335386038,
#   'token': 161,
#   'token_str': 'sausage'},
#  {'sequence': '<s> dough pizza_sauce extra_virgin_olive_oil </s>',
#   'score': 0.0056977784261107445,
#   'token': 101,
#   'token_str': 'extra_virgin_olive_oil'},
#  {'sequence': '<s> dough pizza_sauce hot_dogs </s>',
#   'score': 0.0055270022712647915,
#   'token': 1221,
#   'token_str': 'hot_dogs'},
#  {'sequence': '<s> dough pizza_sauce butter </s>',
#   'score': 0.005109061952680349,
#   'token': 7,
#   'token_str': 'butter'},
#  {'sequence': '<s> dough pizza_sauce cooking_spray </s>',
#   'score': 0.005068848375231028,
#   'token': 199,
#   'token_str': 'cooking_spray'},
#  {'sequence': '<s> dough pizza_sauce parmesan_cheese </s>',
#   'score': 0.0047526550479233265,
#   'token': 63,
#   'token_str': 'parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce cheese_blend </s>',
#   'score': 0.004453964065760374,
#   'token': 869,
#   'token_str': 'cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce cream_cheese </s>',
#   'score': 0.003995680250227451,
#   'token': 62,
#   'token_str': 'cream_cheese'},
#  {'sequence': '<s> dough pizza_sauce olive </s>',
#   'score': 0.0035061798989772797,
#   'token': 15,
#   'token_str': 'olive'},
#  {'sequence': '<s> dough pizza_sauce mozzarella_string_cheese </s>',
#   'score': 0.003325254423543811,
#   'token': 3265,
#   'token_str': 'mozzarella_string_cheese'},
#  {'sequence': '<s> dough pizza_sauce egg </s>',
#   'score': 0.0029907089192420244,
#   'token': 29,
#   'token_str': 'egg'},
#  {'sequence': '<s> dough pizza_sauce italian_cheese </s>',
#   'score': 0.002945713000372052,
#   'token': 1647,
#   'token_str': 'italian_cheese'},
#  {'sequence': '<s> dough pizza_sauce black_pepper </s>',
#   'score': 0.00278812600299716,
#   'token': 19,
#   'token_str': 'black_pepper'},
#  {'sequence': '<s> dough pizza_sauce basil_leaves </s>',
#   'score': 0.0027358499355614185,
#   'token': 238,
#   'token_str': 'basil_leaves'},
#  {'sequence': '<s> dough pizza_sauce flour </s>',
#   'score': 0.002715807408094406,
#   'token': 10,
#   'token_str': 'flour'},
#  {'sequence': '<s> dough pizza_sauce cornmeal </s>',
#   'score': 0.0025921077467501163,
#   'token': 259,
#   'token_str': 'cornmeal'},
#  {'sequence': '<s> dough pizza_sauce mozzarella_balls </s>',
#   'score': 0.002572515746578574,
#   'token': 2051,
#   'token_str': 'mozzarella_balls'},
#  {'sequence': '<s> dough pizza_sauce italian_seasoning </s>',
#   'score': 0.0025557116605341434,
#   'token': 377,
#   'token_str': 'italian_seasoning'},
#  {'sequence': '<s> dough pizza_sauce corn_meal </s>',
#   'score': 0.002527666976675391,
#   'token': 1721,
#   'token_str': 'corn_meal'},
#  {'sequence': '<s> dough pizza_sauce pesto </s>',
#   'score': 0.0025068114046007395,
#   'token': 565,
#   'token_str': 'pesto'},
#  {'sequence': '<s> dough pizza_sauce semolina </s>',
#   'score': 0.0024929088540375233,
#   'token': 1181,
#   'token_str': 'semolina'},
#  {'sequence': '<s> dough pizza_sauce ground_beef </s>',
#   'score': 0.0023224647156894207,
#   'token': 114,
#   'token_str': 'ground_beef'},
#  {'sequence': '<s> dough pizza_sauce salami </s>',
#   'score': 0.002191012492403388,
#   'token': 968,
#   'token_str': 'salami'},
#  {'sequence': '<s> dough pizza_sauce fresh_mozzarella </s>',
#   'score': 0.0021510825026780367,
#   'token': 3198,
#   'token_str': 'fresh_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce loaves </s>',
#   'score': 0.0019883164204657078,
#   'token': 1526,
#   'token_str': 'loaves'},
#  {'sequence': '<s> dough pizza_sauce jack_cheese </s>',
#   'score': 0.0018718816572800279,
#   'token': 246,
#   'token_str': 'jack_cheese'},
#  {'sequence': '<s> dough pizza_sauce garlic </s>',
#   'score': 0.0018674035090953112,
#   'token': 8,
#   'token_str': 'garlic'},
#  {'sequence': '<s> dough pizza_sauce american_cheese </s>',
#   'score': 0.0018469293136149645,
#   'token': 700,
#   'token_str': 'american_cheese'},
#  {'sequence': '<s> dough pizza_sauce ground_black_pepper </s>',
#   'score': 0.0018286118283867836,
#   'token': 35,
#   'token_str': 'ground_black_pepper'},
#  {'sequence': '<s> dough pizza_sauce meat </s>',
#   'score': 0.0018094576662406325,
#   'token': 370,
#   'token_str': 'meat'},
#  {'sequence': '<s> dough pizza_sauce ham </s>',
#   'score': 0.0017440526280552149,
#   'token': 239,
#   'token_str': 'ham'},
#  {'sequence': '<s> dough pizza_sauce red_bell_pepper </s>',
#   'score': 0.0017125963931903243,
#   'token': 162,
#   'token_str': 'red_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce temperature </s>',
#   'score': 0.0016658548265695572,
#   'token': 135,
#   'token_str': 'temperature'},
#  {'sequence': '<s> dough pizza_sauce bread </s>',
#   'score': 0.0016417220467701554,
#   'token': 74,
#   'token_str': 'bread'},
#  {'sequence': '<s> dough pizza_sauce sea_salt </s>',
#   'score': 0.0016082418151199818,
#   'token': 137,
#   'token_str': 'sea_salt'},
#  {'sequence': '<s> dough pizza_sauce button_mushrooms </s>',
#   'score': 0.0015988430241122842,
#   'token': 657,
#   'token_str': 'button_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce muenster_cheese </s>',
#   'score': 0.0015787804732099175,
#   'token': 1771,
#   'token_str': 'muenster_cheese'},
#  {'sequence': '<s> dough pizza_sauce mushrooms </s>',
#   'score': 0.0015685668913647532,
#   'token': 70,
#   'token_str': 'mushrooms'},
#  {'sequence': '<s> dough pizza_sauce prosciutto </s>',
#   'score': 0.0014899814268574119,
#   'token': 528,
#   'token_str': 'prosciutto'},
#  {'sequence': '<s> dough pizza_sauce basil </s>',
#   'score': 0.0014802288496866822,
#   'token': 77,
#   'token_str': 'basil'},
#  {'sequence': '<s> dough pizza_sauce garlic_salt </s>',
#   'score': 0.0014777182368561625,
#   'token': 335,
#   'token_str': 'garlic_salt'},
#  {'sequence': '<s> dough pizza_sauce goat_cheese </s>',
#   'score': 0.0014520360855385661,
#   'token': 457,
#   'token_str': 'goat_cheese'},
#  {'sequence': '<s> dough pizza_sauce gouda_cheese </s>',
#   'score': 0.0014457973884418607,
#   'token': 1360,
#   'token_str': 'gouda_cheese'},
#  {'sequence': '<s> dough pizza_sauce chiffonade </s>',
#   'score': 0.0014310282422229648,
#   'token': 1229,
#   'token_str': 'chiffonade'},
#  {'sequence': '<s> dough pizza_sauce sliced_ham </s>',
#   'score': 0.0014169146306812763,
#   'token': 1682,
#   'token_str': 'sliced_ham'},
#  {'sequence': '<s> dough pizza_sauce cheddar </s>',
#   'score': 0.0013926711399108171,
#   'token': 55,
#   'token_str': 'cheddar'},
#  {'sequence': '<s> dough pizza_sauce kosher_salt </s>',
#   'score': 0.0013011251576244831,
#   'token': 53,
#   'token_str': 'kosher_salt'},
#  {'sequence': '<s> dough pizza_sauce kalamata_olives </s>',
#   'score': 0.0012798004318028688,
#   'token': 768,
#   'token_str': 'kalamata_olives'},
#  {'sequence': '<s> dough pizza_sauce sauce_mix </s>',
#   'score': 0.0012732502073049545,
#   'token': 1852,
#   'token_str': 'sauce_mix'},
#  {'sequence': '<s> dough pizza_sauce coarse_salt </s>',
#   'score': 0.0012523512123152614,
#   'token': 348,
#   'token_str': 'coarse_salt'},
#  {'sequence': '<s> dough pizza_sauce chicken_breasts </s>',
#   'score': 0.0012148505775257945,
#   'token': 104,
#   'token_str': 'chicken_breasts'},
#  {'sequence': '<s> dough pizza_sauce cheddar_cheese </s>',
#   'score': 0.0012083787005394697,
#   'token': 64,
#   'token_str': 'cheddar_cheese'},
#  {'sequence': '<s> dough pizza_sauce chicken </s>',
#   'score': 0.0011814002646133304,
#   'token': 24,
#   'token_str': 'chicken'},
#  {'sequence': '<s> dough pizza_sauce vegetable_oil </s>',
#   'score': 0.0011381858494132757,
#   'token': 40,
#   'token_str': 'vegetable_oil'},
#  {'sequence': '<s> dough pizza_sauce asiago_cheese </s>',
#   'score': 0.001137454411946237,
#   'token': 1051,
#   'token_str': 'asiago_cheese'},
#  {'sequence': '<s> dough pizza_sauce cheeses </s>',
#   'score': 0.0011275638826191425,
#   'token': 2072,
#   'token_str': 'cheeses'},
#  {'sequence': '<s> dough pizza_sauce tomato </s>',
#   'score': 0.0010365641210228205,
#   'token': 50,
#   'token_str': 'tomato'},
#  {'sequence': '<s> dough pizza_sauce sugar </s>',
#   'score': 0.0010119595099240541,
#   'token': 9,
#   'token_str': 'sugar'},
#  {'sequence': '<s> dough pizza_sauce oil </s>',
#   'score': 0.0009941986063495278,
#   'token': 76,
#   'token_str': 'oil'},
#  {'sequence': '<s> dough pizza_sauce garlic_powder </s>',
#   'score': 0.0009782484266906977,
#   'token': 84,
#   'token_str': 'garlic_powder'},
#  {'sequence': '<s> dough pizza_sauce pizza_crust </s>',
#   'score': 0.0009764806600287557,
#   'token': 1075,
#   'token_str': 'pizza_crust'},
#  {'sequence': '<s> dough pizza_sauce bread_flour </s>',
#   'score': 0.0009737071231938899,
#   'token': 464,
#   'token_str': 'bread_flour'},
#  {'sequence': '<s> dough pizza_sauce flour_for_dusting </s>',
#   'score': 0.0009624750819057226,
#   'token': 1115,
#   'token_str': 'flour_for_dusting'},
#  {'sequence': '<s> dough pizza_sauce buffalo_mozzarella </s>',
#   'score': 0.0009462565649300814,
#   'token': 3194,
#   'token_str': 'buffalo_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce mortadella </s>',
#   'score': 0.0009378018439747393,
#   'token': 3148,
#   'token_str': 'mortadella'},
#  {'sequence': '<s> dough pizza_sauce wheat_flour </s>',
#   'score': 0.0009172718273475766,
#   'token': 258,
#   'token_str': 'wheat_flour'},
#  {'sequence': '<s> dough pizza_sauce fontina_cheese </s>',
#   'score': 0.0009145296644419432,
#   'token': 1137,
#   'token_str': 'fontina_cheese'},
#  {'sequence': '<s> dough pizza_sauce ricotta_cheese </s>',
#   'score': 0.0009035203838720918,
#   'token': 328,
#   'token_str': 'ricotta_cheese'},
#  {'sequence': '<s> dough pizza_sauce sweet_italian_sausage </s>',
#   'score': 0.0009007088956423104,
#   'token': 1453,
#   'token_str': 'sweet_italian_sausage'},
#  {'sequence': '<s> dough pizza_sauce hamburger </s>',
#   'score': 0.0008933432982303202,
#   'token': 429,
#   'token_str': 'hamburger'},
#  {'sequence': '<s> dough pizza_sauce mild_italian_sausage </s>',
#   'score': 0.0008571103098802269,
#   'token': 1940,
#   'token_str': 'mild_italian_sausage'},
#  {'sequence': '<s> dough pizza_sauce red_onion </s>',
#   'score': 0.0008521813433617353,
#   'token': 120,
#   'token_str': 'red_onion'},
#  {'sequence': '<s> dough pizza_sauce tomato_sauce </s>',
#   'score': 0.0008476406801491976,
#   'token': 186,
#   'token_str': 'tomato_sauce'},
#  {'sequence': '<s> dough pizza_sauce velveeta </s>',
#   'score': 0.0008475493523292243,
#   'token': 578,
#   'token_str': 'velveeta'},
#  {'sequence': '<s> dough pizza_sauce ground_sausage </s>',
#   'score': 0.0008350852294825017,
#   'token': 2247,
#   'token_str': 'ground_sausage'},
#  {'sequence': '<s> dough pizza_sauce salted_butter </s>',
#   'score': 0.000833544007036835,
#   'token': 716,
#   'token_str': 'salted_butter'},
#  {'sequence': '<s> dough pizza_sauce table_salt </s>',
#   'score': 0.0008317525498569012,
#   'token': 955,
#   'token_str': 'table_salt'},
#  {'sequence': '<s> dough pizza_sauce monterey_jack_cheese </s>',
#   'score': 0.0008129601483233273,
#   'token': 313,
#   'token_str': 'monterey_jack_cheese'},
#  {'sequence': '<s> dough pizza_sauce focaccia </s>',
#   'score': 0.0008051073527894914,
#   'token': 2759,
#   'token_str': 'focaccia'},
#  {'sequence': '<s> dough pizza_sauce minced_garlic </s>',
#   'score': 0.0007776582497172058,
#   'token': 134,
#   'token_str': 'minced_garlic'},
#  {'sequence': '<s> dough pizza_sauce pitted_black_olives </s>',
#   'score': 0.0007611666806042194,
#   'token': 1580,
#   'token_str': 'pitted_black_olives'},
#  {'sequence': '<s> dough pizza_sauce arugula </s>',
#   'score': 0.0007458722102455795,
#   'token': 432,
#   'token_str': 'arugula'},
#  {'sequence': '<s> dough pizza_sauce black_olives </s>',
#   'score': 0.0007371646934188902,
#   'token': 309,
#   'token_str': 'black_olives'},
#  {'sequence': '<s> dough pizza_sauce garlic_cloves </s>',
#   'score': 0.0007278392440639436,
#   'token': 38,
#   'token_str': 'garlic_cloves'},
#  {'sequence': '<s> dough pizza_sauce wheat </s>',
#   'score': 0.0007028005784377456,
#   'token': 147,
#   'token_str': 'wheat'},
#  {'sequence': '<s> dough pizza_sauce mushroom </s>',
#   'score': 0.0006976888980716467,
#   'token': 164,
#   'token_str': 'mushroom'},
#  {'sequence': '<s> dough pizza_sauce swiss_cheese </s>',
#   'score': 0.0006932328687980771,
#   'token': 338,
#   'token_str': 'swiss_cheese'},
#  {'sequence': '<s> dough pizza_sauce cooked_ham </s>',
#   'score': 0.0006904914043843746,
#   'token': 767,
#   'token_str': 'cooked_ham'},
#  {'sequence': '<s> dough pizza_sauce pepper </s>',
#   'score': 0.0006790859042666852,
#   'token': 6,
#   'token_str': 'pepper'},
#  {'sequence': '<s> dough pizza_sauce sauce_tomato </s>',
#   'score': 0.000674867129418999,
#   'token': 3433,
#   'token_str': 'sauce_tomato'},
#  {'sequence': '<s> dough pizza_sauce italian_salad_dressing </s>',
#   'score': 0.0006505902274511755,
#   'token': 919,
#   'token_str': 'italian_salad_dressing'},
#  {'sequence': '<s> dough pizza_sauce oregano_leaves </s>',
#   'score': 0.0006429890636354685,
#   'token': 655,
#   'token_str': 'oregano_leaves'},
#  {'sequence': '<s> dough pizza_sauce gorgonzola </s>',
#   'score': 0.0006401809514500201,
#   'token': 970,
#   'token_str': 'gorgonzola'},
#  {'sequence': '<s> dough pizza_sauce melted_butter </s>',
#   'score': 0.0006400909624062479,
#   'token': 270,
#   'token_str': 'melted_butter'},
#  {'sequence': '<s> dough pizza_sauce smoked_sausage </s>',
#   'score': 0.0006163206999190152,
#   'token': 1196,
#   'token_str': 'smoked_sausage'},
#  {'sequence': '<s> dough pizza_sauce cooked_bacon </s>',
#   'score': 0.0006109523819759488,
#   'token': 898,
#   'token_str': 'cooked_bacon'},
#  {'sequence': '<s> dough pizza_sauce pepperoncini </s>',
#   'score': 0.0006028968491591513,
#   'token': 1502,
#   'token_str': 'pepperoncini'},
#  {'sequence': '<s> dough pizza_sauce lean_ground_beef </s>',
#   'score': 0.0006009305361658335,
#   'token': 334,
#   'token_str': 'lean_ground_beef'},
#  {'sequence': '<s> dough pizza_sauce yellow_cornmeal </s>',
#   'score': 0.0005996192921884358,
#   'token': 816,
#   'token_str': 'yellow_cornmeal'},
#  {'sequence': '<s> dough pizza_sauce yeast_packet </s>',
#   'score': 0.0005936656380072236,
#   'token': 2331,
#   'token_str': 'yeast_packet'},
#  {'sequence': '<s> dough pizza_sauce spinach </s>',
#   'score': 0.0005879770615138113,
#   'token': 113,
#   'token_str': 'spinach'},
#  {'sequence': '<s> dough pizza_sauce onion </s>',
#   'score': 0.0005736671155318618,
#   'token': 11,
#   'token_str': 'onion'},
#  {'sequence': '<s> dough pizza_sauce unsalted_butter </s>',
#   'score': 0.0005634500412270427,
#   'token': 44,
#   'token_str': 'unsalted_butter'},
#  {'sequence': '<s> dough pizza_sauce feta_cheese </s>',
#   'score': 0.0005514401709660888,
#   'token': 280,
#   'token_str': 'feta_cheese'},
#  {'sequence': '<s> dough pizza_sauce eggs </s>',
#   'score': 0.0005450962344184518,
#   'token': 18,
#   'token_str': 'eggs'},
#  {'sequence': '<s> dough pizza_sauce ricotta </s>',
#   'score': 0.0005422536050900817,
#   'token': 289,
#   'token_str': 'ricotta'},
#  {'sequence': '<s> dough pizza_sauce kraft_grated_parmesan_cheese </s>',
#   'score': 0.0005332928849384189,
#   'token': 997,
#   'token_str': 'kraft_grated_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce gruyere_cheese </s>',
#   'score': 0.0005329163977876306,
#   'token': 757,
#   'token_str': 'gruyere_cheese'},
#  {'sequence': '<s> dough pizza_sauce noodles </s>',
#   'score': 0.0005293461726978421,
#   'token': 183,
#   'token_str': 'noodles'},
#  {'sequence': '<s> dough pizza_sauce romano_cheese </s>',
#   'score': 0.0005277188611216843,
#   'token': 588,
#   'token_str': 'romano_cheese'},
#  {'sequence': '<s> dough pizza_sauce crumbled_goat_cheese </s>',
#   'score': 0.0005053014610894024,
#   'token': 1763,
#   'token_str': 'crumbled_goat_cheese'},
#  {'sequence': '<s> dough pizza_sauce pizza_seasoning </s>',
#   'score': 0.0004987310967408121,
#   'token': 2895,
#   'token_str': 'pizza_seasoning'},
#  {'sequence': '<s> dough pizza_sauce olive_oil_spray </s>',
#   'score': 0.0004935865290462971,
#   'token': 1835,
#   'token_str': 'olive_oil_spray'},
#  {'sequence': '<s> dough pizza_sauce red_pepper </s>',
#   'score': 0.0004917930928058922,
#   'token': 66,
#   'token_str': 'red_pepper'},
#  {'sequence': '<s> dough pizza_sauce peppers </s>',
#   'score': 0.0004898211336694658,
#   'token': 91,
#   'token_str': 'peppers'},
#  {'sequence': '<s> dough pizza_sauce mexican_cheese </s>',
#   'score': 0.0004760834272019565,
#   'token': 1218,
#   'token_str': 'mexican_cheese'},
#  {'sequence': '<s> dough pizza_sauce mayonnaise </s>',
#   'score': 0.00046515362919308245,
#   'token': 81,
#   'token_str': 'mayonnaise'},
#  {'sequence': '<s> dough pizza_sauce sliced_black_olives </s>',
#   'score': 0.00045917622628621757,
#   'token': 934,
#   'token_str': 'sliced_black_olives'},
#  {'sequence': '<s> dough pizza_sauce hot_sausage </s>',
#   'score': 0.0004576362553052604,
#   'token': 2501,
#   'token_str': 'hot_sausage'},
#  {'sequence': '<s> dough pizza_sauce white_sugar </s>',
#   'score': 0.00045678316382691264,
#   'token': 117,
#   'token_str': 'white_sugar'},
#  {'sequence': '<s> dough pizza_sauce shredded_mozzarella_cheese </s>',
#   'score': 0.0004447486426215619,
#   'token': 1811,
#   'token_str': 'shredded_mozzarella_cheese'},
#  {'sequence': '<s> dough pizza_sauce pecorino_romano_cheese </s>',
#   'score': 0.00043674162589013577,
#   'token': 1305,
#   'token_str': 'pecorino_romano_cheese'},
#  {'sequence': '<s> dough pizza_sauce processed_cheese </s>',
#   'score': 0.00043589965207502246,
#   'token': 1587,
#   'token_str': 'processed_cheese'},
#  {'sequence': '<s> dough pizza_sauce water </s>',
#   'score': 0.00043206120608374476,
#   'token': 13,
#   'token_str': 'water'},
#  {'sequence': '<s> dough pizza_sauce cooked_chicken </s>',
#   'score': 0.00042935964302159846,
#   'token': 316,
#   'token_str': 'cooked_chicken'},
#  {'sequence': '<s> dough pizza_sauce pancetta </s>',
#   'score': 0.0004273687081877142,
#   'token': 815,
#   'token_str': 'pancetta'},
#  {'sequence': '<s> dough pizza_sauce grated_romano_cheese </s>',
#   'score': 0.00042488204780966043,
#   'token': 1285,
#   'token_str': 'grated_romano_cheese'},
#  {'sequence': '<s> dough pizza_sauce brown_sugar </s>',
#   'score': 0.0004234288935549557,
#   'token': 33,
#   'token_str': 'brown_sugar'},
#  {'sequence': '<s> dough pizza_sauce spam </s>',
#   'score': 0.000420470634708181,
#   'token': 2607,
#   'token_str': 'spam'},
#  {'sequence': '<s> dough pizza_sauce easy </s>',
#   'score': 0.00041879600030370057,
#   'token': 2556,
#   'token_str': 'easy'},
#  {'sequence': '<s> dough pizza_sauce deli_ham </s>',
#   'score': 0.0004169355670455843,
#   'token': 1272,
#   'token_str': 'deli_ham'},
#  {'sequence': '<s> dough pizza_sauce crumbled_blue_cheese </s>',
#   'score': 0.00041507769492454827,
#   'token': 982,
#   'token_str': 'crumbled_blue_cheese'},
#  {'sequence': '<s> dough pizza_sauce smoked_salmon </s>',
#   'score': 0.0004059226193930954,
#   'token': 995,
#   'token_str': 'smoked_salmon'},
#  {'sequence': '<s> dough pizza_sauce chicken_breast </s>',
#   'score': 0.0004058771301060915,
#   'token': 154,
#   'token_str': 'chicken_breast'},
#  {'sequence': '<s> dough pizza_sauce seasonings </s>',
#   'score': 0.00040242966497316957,
#   'token': 1652,
#   'token_str': 'seasonings'},
#  {'sequence': '<s> dough pizza_sauce coarse_sea_salt </s>',
#   'score': 0.0004010825650766492,
#   'token': 1122,
#   'token_str': 'coarse_sea_salt'},
#  {'sequence': '<s> dough pizza_sauce roast_beef </s>',
#   'score': 0.0003904227924067527,
#   'token': 1258,
#   'token_str': 'roast_beef'},
#  {'sequence': '<s> dough pizza_sauce sliced_mushrooms </s>',
#   'score': 0.0003898098657373339,
#   'token': 359,
#   'token_str': 'sliced_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce dried_rosemary </s>',
#   'score': 0.0003805575834121555,
#   'token': 573,
#   'token_str': 'dried_rosemary'},
#  {'sequence': '<s> dough pizza_sauce cheese_spread </s>',
#   'score': 0.0003774160286411643,
#   'token': 1000,
#   'token_str': 'cheese_spread'},
#  {'sequence': '<s> dough pizza_sauce parsley </s>',
#   'score': 0.0003742888511624187,
#   'token': 36,
#   'token_str': 'parsley'},
#  {'sequence': '<s> dough pizza_sauce chorizo </s>',
#   'score': 0.000368308974429965,
#   'token': 1038,
#   'token_str': 'chorizo'},
#  {'sequence': '<s> dough pizza_sauce artichoke_hearts </s>',
#   'score': 0.00036818900844082236,
#   'token': 465,
#   'token_str': 'artichoke_hearts'},
#  {'sequence': '<s> dough pizza_sauce seasoned_salt </s>',
#   'score': 0.000366489082807675,
#   'token': 755,
#   'token_str': 'seasoned_salt'},
#  {'sequence': '<s> dough pizza_sauce ground </s>',
#   'score': 0.0003661790397018194,
#   'token': 14,
#   'token_str': 'ground'},
#  {'sequence': '<s> dough pizza_sauce shaved_parmesan_cheese </s>',
#   'score': 0.00036461977288126945,
#   'token': 1957,
#   'token_str': 'shaved_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce parmigiano </s>',
#   'score': 0.0003632753505371511,
#   'token': 1189,
#   'token_str': 'parmigiano'},
#  {'sequence': '<s> dough pizza_sauce baby_spinach </s>',
#   'score': 0.0003618915216065943,
#   'token': 376,
#   'token_str': 'baby_spinach'},
#  {'sequence': '<s> dough pizza_sauce green_bell_peppers </s>',
#   'score': 0.00035455479519441724,
#   'token': 568,
#   'token_str': 'green_bell_peppers'},
#  {'sequence': '<s> dough pizza_sauce canola_oil </s>',
#   'score': 0.00035169816692359746,
#   'token': 152,
#   'token_str': 'canola_oil'},
#  {'sequence': '<s> dough pizza_sauce grana_padano </s>',
#   'score': 0.00034667528234422207,
#   'token': 2022,
#   'token_str': 'grana_padano'},
#  {'sequence': '<s> dough pizza_sauce dried_tomatoes </s>',
#   'score': 0.0003428146883379668,
#   'token': 1503,
#   'token_str': 'dried_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce smoked_mozzarella </s>',
#   'score': 0.00034199183573946357,
#   'token': 2236,
#   'token_str': 'smoked_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce eggplant </s>',
#   'score': 0.00033977956627495587,
#   'token': 493,
#   'token_str': 'eggplant'},
#  {'sequence': '<s> dough pizza_sauce cheese_slices </s>',
#   'score': 0.00033738318597897887,
#   'token': 1330,
#   'token_str': 'cheese_slices'},
#  {'sequence': '<s> dough pizza_sauce thyme_leaves </s>',
#   'score': 0.00033082510344684124,
#   'token': 384,
#   'token_str': 'thyme_leaves'},
#  {'sequence': '<s> dough pizza_sauce tomatoes </s>',
#   'score': 0.00032449784339405596,
#   'token': 26,
#   'token_str': 'tomatoes'},
#  {'sequence': '<s> dough pizza_sauce genoa_salami </s>',
#   'score': 0.0003235163167119026,
#   'token': 2266,
#   'token_str': 'genoa_salami'},
#  {'sequence': '<s> dough pizza_sauce ground_pork </s>',
#   'score': 0.0003231815935578197,
#   'token': 469,
#   'token_str': 'ground_pork'},
#  {'sequence': '<s> dough pizza_sauce onions </s>',
#   'score': 0.000321587169310078,
#   'token': 30,
#   'token_str': 'onions'},
#  {'sequence': '<s> dough pizza_sauce havarti_cheese </s>',
#   'score': 0.0003183704102411866,
#   'token': 2164,
#   'token_str': 'havarti_cheese'},
#  {'sequence': '<s> dough pizza_sauce much </s>',
#   'score': 0.0003163326473440975,
#   'token': 1555,
#   'token_str': 'much'},
#  {'sequence': '<s> dough pizza_sauce fontina </s>',
#   'score': 0.00031518476316705346,
#   'token': 994,
#   'token_str': 'fontina'},
#  {'sequence': '<s> dough pizza_sauce ground_chuck </s>',
#   'score': 0.0003105369978584349,
#   'token': 942,
#   'token_str': 'ground_chuck'},
#  {'sequence': '<s> dough pizza_sauce warm_water </s>',
#   'score': 0.0003093552659265697,
#   'token': 296,
#   'token_str': 'warm_water'},
#  {'sequence': '<s> dough pizza_sauce string_cheese </s>',
#   'score': 0.0003088052326347679,
#   'token': 3036,
#   'token_str': 'string_cheese'},
#  {'sequence': '<s> dough pizza_sauce veggies </s>',
#   'score': 0.0003054476110264659,
#   'token': 2111,
#   'token_str': 'veggies'},
#  {'sequence': '<s> dough pizza_sauce crust </s>',
#   'score': 0.00029998310492374003,
#   'token': 362,
#   'token_str': 'crust'},
#  {'sequence': '<s> dough pizza_sauce beef </s>',
#   'score': 0.0002991259389091283,
#   'token': 188,
#   'token_str': 'beef'},
#  {'sequence': '<s> dough pizza_sauce english_muffins </s>',
#   'score': 0.0002989236090797931,
#   'token': 1204,
#   'token_str': 'english_muffins'},
#  {'sequence': '<s> dough pizza_sauce canadian_bacon </s>',
#   'score': 0.00029687158530578017,
#   'token': 1635,
#   'token_str': 'canadian_bacon'},
#  {'sequence': '<s> dough pizza_sauce roma_tomatoes </s>',
#   'score': 0.00029621648718602955,
#   'token': 579,
#   'token_str': 'roma_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce pesto_sauce </s>',
#   'score': 0.0002948451729025692,
#   'token': 1048,
#   'token_str': 'pesto_sauce'},
#  {'sequence': '<s> dough pizza_sauce hot_water </s>',
#   'score': 0.0002944095467682928,
#   'token': 342,
#   'token_str': 'hot_water'},
#  {'sequence': '<s> dough pizza_sauce sour_cream </s>',
#   'score': 0.0002926828165072948,
#   'token': 59,
#   'token_str': 'sour_cream'},
#  {'sequence': '<s> dough pizza_sauce pepper_cheese </s>',
#   'score': 0.0002915812365245074,
#   'token': 1302,
#   'token_str': 'pepper_cheese'},
#  {'sequence': '<s> dough pizza_sauce honey </s>',
#   'score': 0.00028873924748040736,
#   'token': 71,
#   'token_str': 'honey'},
#  {'sequence': '<s> dough pizza_sauce giardiniera </s>',
#   'score': 0.0002850480959750712,
#   'token': 2469,
#   'token_str': 'giardiniera'},
#  {'sequence': '<s> dough pizza_sauce hard_salami </s>',
#   'score': 0.0002815231855493039,
#   'token': 2865,
#   'token_str': 'hard_salami'},
#  {'sequence': '<s> dough pizza_sauce medium_tomatoes </s>',
#   'score': 0.0002792656305246055,
#   'token': 499,
#   'token_str': 'medium_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce flatbread </s>',
#   'score': 0.0002771411382127553,
#   'token': 2605,
#   'token_str': 'flatbread'},
#  {'sequence': '<s> dough pizza_sauce cracked_black_pepper </s>',
#   'score': 0.00027650067931972444,
#   'token': 479,
#   'token_str': 'cracked_black_pepper'},
#  {'sequence': '<s> dough pizza_sauce semolina_flour </s>',
#   'score': 0.0002750978746917099,
#   'token': 1755,
#   'token_str': 'semolina_flour'},
#  {'sequence': '<s> dough pizza_sauce romano </s>',
#   'score': 0.00027104601031169295,
#   'token': 531,
#   'token_str': 'romano'},
#  {'sequence': '<s> dough pizza_sauce pitted_kalamata_olives </s>',
#   'score': 0.00026765535585582256,
#   'token': 1143,
#   'token_str': 'pitted_kalamata_olives'},
#  {'sequence': '<s> dough pizza_sauce dried_tomato </s>',
#   'score': 0.00026356015587225556,
#   'token': 2602,
#   'token_str': 'dried_tomato'},
#  {'sequence': '<s> dough pizza_sauce scallions </s>',
#   'score': 0.00026305305073037744,
#   'token': 167,
#   'token_str': 'scallions'},
#  {'sequence': '<s> dough pizza_sauce boneless_chicken_breast </s>',
#   'score': 0.0002619497827254236,
#   'token': 461,
#   'token_str': 'boneless_chicken_breast'},
#  {'sequence': '<s> dough pizza_sauce poppy_seed </s>',
#   'score': 0.0002617451245896518,
#   'token': 1120,
#   'token_str': 'poppy_seed'},
#  {'sequence': '<s> dough pizza_sauce margarine </s>',
#   'score': 0.00026151747442781925,
#   'token': 80,
#   'token_str': 'margarine'},
#  {'sequence': '<s> dough pizza_sauce bocconcini </s>',
#   'score': 0.00026140050613321364,
#   'token': 2412,
#   'token_str': 'bocconcini'},
#  {'sequence': '<s> dough pizza_sauce hot_peppers </s>',
#   'score': 0.0002612343232613057,
#   'token': 1810,
#   'token_str': 'hot_peppers'},
#  {'sequence': '<s> dough pizza_sauce frozen_meatballs </s>',
#   'score': 0.0002589421928860247,
#   'token': 2108,
#   'token_str': 'frozen_meatballs'},
#  {'sequence': '<s> dough pizza_sauce italian_bread </s>',
#   'score': 0.00025492985150776803,
#   'token': 799,
#   'token_str': 'italian_bread'},
#  {'sequence': '<s> dough pizza_sauce olives </s>',
#   'score': 0.00025450572138652205,
#   'token': 196,
#   'token_str': 'olives'},
#  {'sequence': '<s> dough pizza_sauce white_cheese </s>',
#   'score': 0.00025443348567932844,
#   'token': 2750,
#   'token_str': 'white_cheese'},
#  {'sequence': '<s> dough pizza_sauce green_pepper </s>',
#   'score': 0.00024966226192191243,
#   'token': 235,
#   'token_str': 'green_pepper'},
#  {'sequence': '<s> dough pizza_sauce cheddar_cheese_soup </s>',
#   'score': 0.00024791364558041096,
#   'token': 1700,
#   'token_str': 'cheddar_cheese_soup'},
#  {'sequence': '<s> dough pizza_sauce tomato_paste </s>',
#   'score': 0.00024756707716733217,
#   'token': 189,
#   'token_str': 'tomato_paste'},
#  {'sequence': '<s> dough pizza_sauce filling </s>',
#   'score': 0.0002465487632434815,
#   'token': 418,
#   'token_str': 'filling'},
#  {'sequence': '<s> dough pizza_sauce crimini_mushrooms </s>',
#   'score': 0.00024371191102545708,
#   'token': 2525,
#   'token_str': 'crimini_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce paste </s>',
#   'score': 0.0002397217322140932,
#   'token': 570,
#   'token_str': 'paste'},
#  {'sequence': '<s> dough pizza_sauce potatoes </s>',
#   'score': 0.00023965429863892496,
#   'token': 52,
#   'token_str': 'potatoes'},
#  {'sequence': '<s> dough pizza_sauce yellow_squash </s>',
#   'score': 0.00023854711616877466,
#   'token': 661,
#   'token_str': 'yellow_squash'},
#  {'sequence': '<s> dough pizza_sauce ciabatta </s>',
#   'score': 0.0002383593819104135,
#   'token': 1186,
#   'token_str': 'ciabatta'},
#  {'sequence': '<s> dough pizza_sauce artichokes </s>',
#   'score': 0.0002379772486165166,
#   'token': 1042,
#   'token_str': 'artichokes'},
#  {'sequence': '<s> dough pizza_sauce green_peppers </s>',
#   'score': 0.00023787195095792413,
#   'token': 676,
#   'token_str': 'green_peppers'},
#  {'sequence': '<s> dough pizza_sauce toast </s>',
#   'score': 0.00023645114561077207,
#   'token': 1286,
#   'token_str': 'toast'},
#  {'sequence': '<s> dough pizza_sauce cherry_tomatoes </s>',
#   'score': 0.00023389964189846069,
#   'token': 308,
#   'token_str': 'cherry_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce cilantro_leaves </s>',
#   'score': 0.00023170886561274529,
#   'token': 368,
#   'token_str': 'cilantro_leaves'},
#  {'sequence': '<s> dough pizza_sauce virgin_olive_oil </s>',
#   'score': 0.00022758623526897281,
#   'token': 100,
#   'token_str': 'virgin_olive_oil'},
#  {'sequence': '<s> dough pizza_sauce turkey_sausage </s>',
#   'score': 0.00022662895207758993,
#   'token': 1271,
#   'token_str': 'turkey_sausage'},
#  {'sequence': '<s> dough pizza_sauce vegetables </s>',
#   'score': 0.0002256116276839748,
#   'token': 420,
#   'token_str': 'vegetables'},
#  {'sequence': '<s> dough pizza_sauce gouda </s>',
#   'score': 0.00022489650291390717,
#   'token': 2207,
#   'token_str': 'gouda'},
#  {'sequence': '<s> dough pizza_sauce pitted_olives </s>',
#   'score': 0.00022259562683757395,
#   'token': 3024,
#   'token_str': 'pitted_olives'},
#  {'sequence': '<s> dough pizza_sauce ripe_olives </s>',
#   'score': 0.00022160603839438409,
#   'token': 1046,
#   'token_str': 'ripe_olives'},
#  {'sequence': '<s> dough pizza_sauce rounds </s>',
#   'score': 0.00021812928025610745,
#   'token': 778,
#   'token_str': 'rounds'},
#  {'sequence': '<s> dough pizza_sauce cheddar_cheese_blend </s>',
#   'score': 0.00021784291311632842,
#   'token': 3084,
#   'token_str': 'cheddar_cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce cilantro </s>',
#   'score': 0.00021679431665688753,
#   'token': 60,
#   'token_str': 'cilantro'},
#  {'sequence': '<s> dough pizza_sauce smoked_ham </s>',
#   'score': 0.00021590835240203887,
#   'token': 860,
#   'token_str': 'smoked_ham'},
#  {'sequence': '<s> dough pizza_sauce salt_and_ground_black_pepper </s>',
#   'score': 0.00021449870837386698,
#   'token': 533,
#   'token_str': 'salt_and_ground_black_pepper'},
#  {'sequence': '<s> dough pizza_sauce hot_italian_sausages </s>',
#   'score': 0.00021386284788604826,
#   'token': 3093,
#   'token_str': 'hot_italian_sausages'},
#  {'sequence': '<s> dough pizza_sauce hummus </s>',
#   'score': 0.000212589991861023,
#   'token': 1452,
#   'token_str': 'hummus'},
#  {'sequence': '<s> dough pizza_sauce ground_meat </s>',
#   'score': 0.00021222060604486614,
#   'token': 1561,
#   'token_str': 'ground_meat'},
#  {'sequence': '<s> dough pizza_sauce tomato_puree </s>',
#   'score': 0.00021100159210618585,
#   'token': 797,
#   'token_str': 'tomato_puree'},
#  {'sequence': '<s> dough pizza_sauce jack </s>',
#   'score': 0.00021017617837060243,
#   'token': 1431,
#   'token_str': 'jack'},
#  {'sequence': '<s> dough pizza_sauce italian_turkey_sausage </s>',
#   'score': 0.00020869246509391814,
#   'token': 2366,
#   'token_str': 'italian_turkey_sausage'},
#  {'sequence': '<s> dough pizza_sauce bbq_sauce </s>',
#   'score': 0.00020742337801493704,
#   'token': 1493,
#   'token_str': 'bbq_sauce'},
#  {'sequence': '<s> dough pizza_sauce turkey </s>',
#   'score': 0.00020731164840981364,
#   'token': 206,
#   'token_str': 'turkey'},
#  {'sequence': '<s> dough pizza_sauce mushroom_caps </s>',
#   'score': 0.0002049594186246395,
#   'token': 1188,
#   'token_str': 'mushroom_caps'},
#  {'sequence': '<s> dough pizza_sauce dough </s>',
#   'score': 0.00020270240202080458,
#   'token': 431,
#   'token_str': 'dough'},
#  {'sequence': '<s> dough pizza_sauce sesame_seeds </s>',
#   'score': 0.0002026224829023704,
#   'token': 234,
#   'token_str': 'sesame_seeds'},
#  {'sequence': '<s> dough pizza_sauce tapenade </s>',
#   'score': 0.00020111969206482172,
#   'token': 2855,
#   'token_str': 'tapenade'},
#  {'sequence': '<s> dough pizza_sauce french_bread </s>',
#   'score': 0.00020025279081892222,
#   'token': 576,
#   'token_str': 'french_bread'},
#  {'sequence': '<s> dough pizza_sauce kielbasa </s>',
#   'score': 0.00019899886683560908,
#   'token': 1087,
#   'token_str': 'kielbasa'},
#  {'sequence': '<s> dough pizza_sauce meatloaf </s>',
#   'score': 0.0001989508600672707,
#   'token': 2340,
#   'token_str': 'meatloaf'},
#  {'sequence': '<s> dough pizza_sauce chicken_strips </s>',
#   'score': 0.00019876063743140548,
#   'token': 2357,
#   'token_str': 'chicken_strips'},
#  {'sequence': '<s> dough pizza_sauce sausage_links </s>',
#   'score': 0.000197368543012999,
#   'token': 1206,
#   'token_str': 'sausage_links'},
#  {'sequence': '<s> dough pizza_sauce iron </s>',
#   'score': 0.00019646956934593618,
#   'token': 3218,
#   'token_str': 'iron'},
#  {'sequence': '<s> dough pizza_sauce macaroni </s>',
#   'score': 0.00019481730123516172,
#   'token': 360,
#   'token_str': 'macaroni'},
#  {'sequence': '<s> dough pizza_sauce white_onion </s>',
#   'score': 0.00019461443298496306,
#   'token': 398,
#   'token_str': 'white_onion'},
#  {'sequence': '<s> dough pizza_sauce parsley_flakes </s>',
#   'score': 0.0001940826914506033,
#   'token': 727,
#   'token_str': 'parsley_flakes'},
#  {'sequence': '<s> dough pizza_sauce sliced_salami </s>',
#   'score': 0.00018998965970240533,
#   'token': 3157,
#   'token_str': 'sliced_salami'},
#  {'sequence': '<s> dough pizza_sauce asparagus </s>',
#   'score': 0.00018949131481349468,
#   'token': 307,
#   'token_str': 'asparagus'},
#  {'sequence': '<s> dough pizza_sauce ingredients </s>',
#   'score': 0.00018308908329345286,
#   'token': 1424,
#   'token_str': 'ingredients'},
#  {'sequence': '<s> dough pizza_sauce links </s>',
#   'score': 0.00018184998771175742,
#   'token': 1701,
#   'token_str': 'links'},
#  {'sequence': '<s> dough pizza_sauce herbs </s>',
#   'score': 0.00018082578026223928,
#   'token': 656,
#   'token_str': 'herbs'},
#  {'sequence': '<s> dough pizza_sauce colby_cheese </s>',
#   'score': 0.0001762797764968127,
#   'token': 1768,
#   'token_str': 'colby_cheese'},
#  {'sequence': '<s> dough pizza_sauce granulated_garlic </s>',
#   'score': 0.00017519509128760546,
#   'token': 926,
#   'token_str': 'granulated_garlic'},
#  {'sequence': '<s> dough pizza_sauce boneless_skinless_chicken_breasts </s>',
#   'score': 0.0001727286580717191,
#   'token': 233,
#   'token_str': 'boneless_skinless_chicken_breasts'},
#  {'sequence': '<s> dough pizza_sauce cooked_meatballs </s>',
#   'score': 0.0001720441650832072,
#   'token': 3495,
#   'token_str': 'cooked_meatballs'},
#  {'sequence': '<s> dough pizza_sauce freshly_grated_parmesan </s>',
#   'score': 0.00017077622760552913,
#   'token': 437,
#   'token_str': 'freshly_grated_parmesan'},
#  {'sequence': '<s> dough pizza_sauce white_bread_flour </s>',
#   'score': 0.000170502025866881,
#   'token': 2429,
#   'token_str': 'white_bread_flour'},
#  {'sequence': '<s> dough pizza_sauce basil_leaf </s>',
#   'score': 0.00017036036297213286,
#   'token': 1211,
#   'token_str': 'basil_leaf'},
#  {'sequence': '<s> dough pizza_sauce rosemary </s>',
#   'score': 0.00016835049609653652,
#   'token': 155,
#   'token_str': 'rosemary'},
#  {'sequence': '<s> dough pizza_sauce rolls </s>',
#   'score': 0.0001669576158747077,
#   'token': 422,
#   'token_str': 'rolls'},
#  {'sequence': '<s> dough pizza_sauce cherry_peppers </s>',
#   'score': 0.00016463760402984917,
#   'token': 2244,
#   'token_str': 'cherry_peppers'},
#  {'sequence': '<s> dough pizza_sauce ground_turkey </s>',
#   'score': 0.00016453464922960848,
#   'token': 396,
#   'token_str': 'ground_turkey'},
#  {'sequence': '<s> dough pizza_sauce roasted_garlic </s>',
#   'score': 0.00016152470197994262,
#   'token': 925,
#   'token_str': 'roasted_garlic'},
#  {'sequence': '<s> dough pizza_sauce in_water </s>',
#   'score': 0.00015873806842137128,
#   'token': 585,
#   'token_str': 'in_water'},
#  {'sequence': '<s> dough pizza_sauce banana_peppers </s>',
#   'score': 0.00015853284276090562,
#   'token': 2509,
#   'token_str': 'banana_peppers'},
#  {'sequence': '<s> dough pizza_sauce ranch_dressing </s>',
#   'score': 0.000156655180035159,
#   'token': 623,
#   'token_str': 'ranch_dressing'},
#  {'sequence': '<s> dough pizza_sauce fine_salt </s>',
#   'score': 0.00015618407633155584,
#   'token': 932,
#   'token_str': 'fine_salt'},
#  {'sequence': '<s> dough pizza_sauce sundried_tomato </s>',
#   'score': 0.00015545912901870906,
#   'token': 914,
#   'token_str': 'sundried_tomato'},
#  {'sequence': '<s> dough pizza_sauce franks </s>',
#   'score': 0.00015466302284039557,
#   'token': 1021,
#   'token_str': 'franks'},
#  {'sequence': '<s> dough pizza_sauce red_pepper_flakes </s>',
#   'score': 0.00015167547098826617,
#   'token': 146,
#   'token_str': 'red_pepper_flakes'},
#  {'sequence': '<s> dough pizza_sauce olive_oil_flavored_cooking_spray </s>',
#   'score': 0.0001512064627604559,
#   'token': 2515,
#   'token_str': 'olive_oil_flavored_cooking_spray'},
#  {'sequence': '<s> dough pizza_sauce blue_cheese </s>',
#   'score': 0.0001502195227658376,
#   'token': 463,
#   'token_str': 'blue_cheese'},
#  {'sequence': '<s> dough pizza_sauce marinara_sauce </s>',
#   'score': 0.000147875864058733,
#   'token': 750,
#   'token_str': 'marinara_sauce'},
#  {'sequence': '<s> dough pizza_sauce garlic_minced </s>',
#   'score': 0.00014685539645142853,
#   'token': 88,
#   'token_str': 'garlic_minced'},
#  {'sequence': '<s> dough pizza_sauce yellow_onion </s>',
#   'score': 0.00014457793440669775,
#   'token': 247,
#   'token_str': 'yellow_onion'},
#  {'sequence': '<s> dough pizza_sauce garlic_bread </s>',
#   'score': 0.0001430131815141067,
#   'token': 3477,
#   'token_str': 'garlic_bread'},
#  {'sequence': '<s> dough pizza_sauce dried_basil </s>',
#   'score': 0.0001425813534297049,
#   'token': 262,
#   'token_str': 'dried_basil'},
#  {'sequence': '<s> dough pizza_sauce cooked_pasta </s>',
#   'score': 0.00014202954480424523,
#   'token': 1695,
#   'token_str': 'cooked_pasta'},
#  {'sequence': '<s> dough pizza_sauce pie_crust_mix </s>',
#   'score': 0.0001380259927827865,
#   'token': 3242,
#   'token_str': 'pie_crust_mix'},
#  {'sequence': '<s> dough pizza_sauce jalapeno </s>',
#   'score': 0.00013797472638543695,
#   'token': 143,
#   'token_str': 'jalapeno'},
#  {'sequence': '<s> dough pizza_sauce pizza_sauce </s>',
#   'score': 0.00013738196867052466,
#   'token': 856,
#   'token_str': 'pizza_sauce'},
#  {'sequence': '<s> dough pizza_sauce sundried_tomatoes </s>',
#   'score': 0.00013716498506255448,
#   'token': 638,
#   'token_str': 'sundried_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce rosemary_leaves </s>',
#   'score': 0.00013645534636452794,
#   'token': 859,
#   'token_str': 'rosemary_leaves'},
#  {'sequence': '<s> dough pizza_sauce part-skim_mozzarella_cheese </s>',
#   'score': 0.00013627692533191293,
#   'token': 3369,
#   'token_str': 'part-skim_mozzarella_cheese'},
#  {'sequence': '<s> dough pizza_sauce alfredo_sauce </s>',
#   'score': 0.0001360228779958561,
#   'token': 1359,
#   'token_str': 'alfredo_sauce'},
#  {'sequence': '<s> dough pizza_sauce potato </s>',
#   'score': 0.00013545711408369243,
#   'token': 208,
#   'token_str': 'potato'},
#  {'sequence': '<s> dough pizza_sauce parmigiano_reggiano_cheese </s>',
#   'score': 0.00013465931988321245,
#   'token': 1856,
#   'token_str': 'parmigiano_reggiano_cheese'},
#  {'sequence': '<s> dough pizza_sauce yellow_bell_pepper </s>',
#   'score': 0.00013400506577454507,
#   'token': 586,
#   'token_str': 'yellow_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce tuna </s>',
#   'score': 0.0001338943256996572,
#   'token': 517,
#   'token_str': 'tuna'},
#  {'sequence': '<s> dough pizza_sauce pork </s>',
#   'score': 0.00013264692097436637,
#   'token': 180,
#   'token_str': 'pork'},
#  {'sequence': '<s> dough pizza_sauce plum_tomatoes </s>',
#   'score': 0.0001315743720624596,
#   'token': 350,
#   'token_str': 'plum_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce crumbled_gorgonzola </s>',
#   'score': 0.00013103761011734605,
#   'token': 1889,
#   'token_str': 'crumbled_gorgonzola'},
#  {'sequence': '<s> dough pizza_sauce biscuits </s>',
#   'score': 0.0001309786457568407,
#   'token': 899,
#   'token_str': 'biscuits'},
#  {'sequence': '<s> dough pizza_sauce mexican_cheese_blend </s>',
#   'score': 0.00013007076631765813,
#   'token': 1841,
#   'token_str': 'mexican_cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce yellow_peppers </s>',
#   'score': 0.00012970830721314996,
#   'token': 1518,
#   'token_str': 'yellow_peppers'},
#  {'sequence': '<s> dough pizza_sauce active_dry_yeast </s>',
#   'score': 0.00012953253462910652,
#   'token': 389,
#   'token_str': 'active_dry_yeast'},
#  {'sequence': '<s> dough pizza_sauce walnuts </s>',
#   'score': 0.0001286846090806648,
#   'token': 129,
#   'token_str': 'walnuts'},
#  {'sequence': '<s> dough pizza_sauce cheese_cubes </s>',
#   'score': 0.00012863960000686347,
#   'token': 3128,
#   'token_str': 'cheese_cubes'},
#  {'sequence': '<s> dough pizza_sauce philadelphia_cream_cheese </s>',
#   'score': 0.000128276165924035,
#   'token': 591,
#   'token_str': 'philadelphia_cream_cheese'},
#  {'sequence': '<s> dough pizza_sauce cake_flour </s>',
#   'score': 0.00012752834300044924,
#   'token': 371,
#   'token_str': 'cake_flour'},
#  {'sequence': '<s> dough pizza_sauce sausage_casings </s>',
#   'score': 0.00012698002683464438,
#   'token': 1461,
#   'token_str': 'sausage_casings'},
#  {'sequence': '<s> dough pizza_sauce sesame </s>',
#   'score': 0.00012661085929721594,
#   'token': 106,
#   'token_str': 'sesame'},
#  {'sequence': '<s> dough pizza_sauce cookie </s>',
#   'score': 0.00012494494148995727,
#   'token': 770,
#   'token_str': 'cookie'},
#  {'sequence': '<s> dough pizza_sauce sardines </s>',
#   'score': 0.00012429768685251474,
#   'token': 1853,
#   'token_str': 'sardines'},
#  {'sequence': '<s> dough pizza_sauce herb </s>',
#   'score': 0.00012315034109633416,
#   'token': 978,
#   'token_str': 'herb'},
#  {'sequence': '<s> dough pizza_sauce fresh_parmesan_cheese </s>',
#   'score': 0.00012174264702480286,
#   'token': 2433,
#   'token_str': 'fresh_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce nori_seaweed </s>',
#   'score': 0.00012043077731505036,
#   'token': 1760,
#   'token_str': 'nori_seaweed'},
#  {'sequence': '<s> dough pizza_sauce boiled_ham </s>',
#   'score': 0.00012004091695416719,
#   'token': 2319,
#   'token_str': 'boiled_ham'},
#  {'sequence': '<s> dough pizza_sauce green_bell_pepper </s>',
#   'score': 0.00012001195864286274,
#   'token': 223,
#   'token_str': 'green_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce dry_yeast </s>',
#   'score': 0.00011822799569927156,
#   'token': 288,
#   'token_str': 'dry_yeast'},
#  {'sequence': '<s> dough pizza_sauce ragu </s>',
#   'score': 0.00011722595809260383,
#   'token': 2683,
#   'token_str': 'ragu'},
#  {'sequence': '<s> dough pizza_sauce white_flour </s>',
#   'score': 0.0001166657020803541,
#   'token': 698,
#   'token_str': 'white_flour'},
#  {'sequence': '<s> dough pizza_sauce roasted_turkey_breast </s>',
#   'score': 0.00011666369391605258,
#   'token': 2210,
#   'token_str': 'roasted_turkey_breast'},
#  {'sequence': '<s> dough pizza_sauce raw_cane_sugar </s>',
#   'score': 0.0001159740932052955,
#   'token': 2563,
#   'token_str': 'raw_cane_sugar'},
#  {'sequence': '<s> dough pizza_sauce broccoli </s>',
#   'score': 0.0001157238584710285,
#   'token': 197,
#   'token_str': 'broccoli'},
#  {'sequence': '<s> dough pizza_sauce italian_herbs </s>',
#   'score': 0.00011559756239876151,
#   'token': 2286,
#   'token_str': 'italian_herbs'},
#  {'sequence': '<s> dough pizza_sauce corn </s>',
#   'score': 0.00011444622941780835,
#   'token': 109,
#   'token_str': 'corn'},
#  {'sequence': '<s> dough pizza_sauce chuck </s>',
#   'score': 0.00011409934086259454,
#   'token': 823,
#   'token_str': 'chuck'},
#  {'sequence': '<s> dough pizza_sauce yeast </s>',
#   'score': 0.00011394396278774366,
#   'token': 191,
#   'token_str': 'yeast'},
#  {'sequence': '<s> dough pizza_sauce broccoli_rabe </s>',
#   'score': 0.00011389903374947608,
#   'token': 2140,
#   'token_str': 'broccoli_rabe'},
#  {'sequence': '<s> dough pizza_sauce prepared_pizza_crust </s>',
#   'score': 0.00011270989489275962,
#   'token': 2043,
#   'token_str': 'prepared_pizza_crust'},
#  {'sequence': '<s> dough pizza_sauce ground_sirloin </s>',
#   'score': 0.00011198186984984204,
#   'token': 1403,
#   'token_str': 'ground_sirloin'},
#  {'sequence': '<s> dough pizza_sauce seasoning_salt </s>',
#   'score': 0.00011112541687907651,
#   'token': 556,
#   'token_str': 'seasoning_salt'},
#  {'sequence': '<s> dough pizza_sauce brie_cheese </s>',
#   'score': 0.00011094799265265465,
#   'token': 1111,
#   'token_str': 'brie_cheese'},
#  {'sequence': '<s> dough pizza_sauce fine_sea_salt </s>',
#   'score': 0.00011054348578909412,
#   'token': 806,
#   'token_str': 'fine_sea_salt'},
#  {'sequence': '<s> dough pizza_sauce ground_oregano </s>',
#   'score': 0.00011022992839571089,
#   'token': 2371,
#   'token_str': 'ground_oregano'},
#  {'sequence': '<s> dough pizza_sauce sharp_white_cheddar_cheese </s>',
#   'score': 0.00010996151104336604,
#   'token': 2359,
#   'token_str': 'sharp_white_cheddar_cheese'},
#  {'sequence': '<s> dough pizza_sauce brown </s>',
#   'score': 0.00010927604307653382,
#   'token': 27,
#   'token_str': 'brown'},
#  {'sequence': '<s> dough pizza_sauce zucchini </s>',
#   'score': 0.00010836806904990226,
#   'token': 170,
#   'token_str': 'zucchini'},
#  {'sequence': '<s> dough pizza_sauce aubergine </s>',
#   'score': 0.00010656702215783298,
#   'token': 2698,
#   'token_str': 'aubergine'},
#  {'sequence': '<s> dough pizza_sauce sweet_basil_leaves </s>',
#   'score': 0.00010643985297065228,
#   'token': 3131,
# ...
#   'score': 8.102595893433318e-05,
#   'token': 2274,
#   'token_str': 'boursin'},
#  {'sequence': '<s> dough pizza_sauce pita_bread </s>',
#   'score': 8.022537804208696e-05,
#   'token': 1093,
#   'token_str': 'pita_bread'},
#  {'sequence': '<s> dough pizza_sauce ketchup </s>',
#   'score': 7.991981692612171e-05,
#   'token': 222,
#   'token_str': 'ketchup'},
#  {'sequence': '<s> dough pizza_sauce olive_oil_cooking_spray </s>',
#   'score': 7.96938402345404e-05,
#   'token': 2717,
#   'token_str': 'olive_oil_cooking_spray'},
#  {'sequence': '<s> dough pizza_sauce summer_squash </s>',
#   'score': 7.820028986316174e-05,
#   'token': 1450,
#   'token_str': 'summer_squash'},
#  {'sequence': '<s> dough pizza_sauce corn_kernels </s>',
#   'score': 7.780884334351867e-05,
#   'token': 503,
#   'token_str': 'corn_kernels'},
#  {'sequence': '<s> dough pizza_sauce colby_jack_cheese </s>',
#   'score': 7.762159657431766e-05,
#   'token': 2075,
#   'token_str': 'colby_jack_cheese'},
#  {'sequence': '<s> dough pizza_sauce carrots </s>',
#   'score': 7.72859129938297e-05,
#   'token': 67,
#   'token_str': 'carrots'},
#  {'sequence': '<s> dough pizza_sauce dried_parsley </s>',
#   'score': 7.644481956958771e-05,
#   'token': 445,
#   'token_str': 'dried_parsley'},
#  {'sequence': '<s> dough pizza_sauce seasoned_bread_crumbs </s>',
#   'score': 7.627042214153334e-05,
#   'token': 1043,
#   'token_str': 'seasoned_bread_crumbs'},
#  {'sequence': '<s> dough pizza_sauce cherry </s>',
#   'score': 7.626053411513567e-05,
#   'token': 402,
#   'token_str': 'cherry'},
#  {'sequence': '<s> dough pizza_sauce instant_yeast </s>',
#   'score': 7.623980491189286e-05,
#   'token': 1166,
#   'token_str': 'instant_yeast'},
#  {'sequence': '<s> dough pizza_sauce crisco </s>',
#   'score': 7.622199336765334e-05,
#   'token': 908,
#   'token_str': 'crisco'},
#  {'sequence': '<s> dough pizza_sauce sliced_green_olives </s>',
#   'score': 7.589688175357878e-05,
#   'token': 2914,
#   'token_str': 'sliced_green_olives'},
#  {'sequence': '<s> dough pizza_sauce baby_spinach_leaves </s>',
#   'score': 7.58685200707987e-05,
#   'token': 814,
#   'token_str': 'baby_spinach_leaves'},
#  {'sequence': '<s> dough pizza_sauce pastrami </s>',
#   'score': 7.579764496767893e-05,
#   'token': 2644,
#   'token_str': 'pastrami'},
#  {'sequence': '<s> dough pizza_sauce cubed_ham </s>',
#   'score': 7.536839984823018e-05,
#   'token': 2417,
#   'token_str': 'cubed_ham'},
#  {'sequence': '<s> dough pizza_sauce top_sirloin_steak </s>',
#   'score': 7.482989167328924e-05,
#   'token': 2098,
#   'token_str': 'top_sirloin_steak'},
#  {'sequence': '<s> dough pizza_sauce vegetable </s>',
#   'score': 7.470774289686233e-05,
#   'token': 32,
#   'token_str': 'vegetable'},
#  {'sequence': '<s> dough pizza_sauce batter </s>',
#   'score': 7.411102706100792e-05,
#   'token': 1480,
#   'token_str': 'batter'},
#  {'sequence': '<s> dough pizza_sauce sliced_tomatoes </s>',
#   'score': 7.321903831325471e-05,
#   'token': 2009,
#   'token_str': 'sliced_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce capsicum </s>',
#   'score': 7.290542271221057e-05,
#   'token': 1249,
#   'token_str': 'capsicum'},
#  {'sequence': '<s> dough pizza_sauce muffin </s>',
#   'score': 7.260484562721103e-05,
#   'token': 1101,
#   'token_str': 'muffin'},
#  {'sequence': '<s> dough pizza_sauce heavy_cream </s>',
#   'score': 7.20256139175035e-05,
#   'token': 93,
#   'token_str': 'heavy_cream'},
#  {'sequence': '<s> dough pizza_sauce boneless_chicken_breast_halves </s>',
#   'score': 7.200398249551654e-05,
#   'token': 627,
#   'token_str': 'boneless_chicken_breast_halves'},
#  {'sequence': '<s> dough pizza_sauce chorizo_sausage </s>',
#   'score': 7.157430081861094e-05,
#   'token': 1012,
#   'token_str': 'chorizo_sausage'},
#  {'sequence': '<s> dough pizza_sauce bell_pepper </s>',
#   'score': 7.118615030776709e-05,
#   'token': 82,
#   'token_str': 'bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce italian_pork_sausage </s>',
#   'score': 7.096984336385503e-05,
#   'token': 2883,
#   'token_str': 'italian_pork_sausage'},
#  {'sequence': '<s> dough pizza_sauce cream </s>',
#   'score': 7.071703294059262e-05,
#   'token': 22,
#   'token_str': 'cream'},
#  {'sequence': '<s> dough pizza_sauce pineapple </s>',
#   'score': 6.98655640007928e-05,
#   'token': 149,
#   'token_str': 'pineapple'},
#  {'sequence': '<s> dough pizza_sauce fennel </s>',
#   'score': 6.98184740031138e-05,
#   'token': 300,
#   'token_str': 'fennel'},
#  {'sequence': '<s> dough pizza_sauce sourdough_starter </s>',
#   'score': 6.918040162418038e-05,
#   'token': 1997,
#   'token_str': 'sourdough_starter'},
#  {'sequence': '<s> dough pizza_sauce beans </s>',
#   'score': 6.902704626554623e-05,
#   'token': 98,
#   'token_str': 'beans'},
#  {'sequence': '<s> dough pizza_sauce sharp_cheddar_cheese </s>',
#   'score': 6.868538912385702e-05,
#   'token': 301,
#   'token_str': 'sharp_cheddar_cheese'},
#  {'sequence': '<s> dough pizza_sauce top_sirloin </s>',
#   'score': 6.799512630095705e-05,
#   'token': 1602,
#   'token_str': 'top_sirloin'},
#  {'sequence': '<s> dough pizza_sauce avocado </s>',
#   'score': 6.751606269972399e-05,
#   'token': 257,
#   'token_str': 'avocado'},
#  {'sequence': '<s> dough pizza_sauce banana </s>',
#   'score': 6.734141061315313e-05,
#   'token': 274,
#   'token_str': 'banana'},
#  {'sequence': '<s> dough pizza_sauce heirloom_tomatoes </s>',
#   'score': 6.69189466862008e-05,
#   'token': 2050,
#   'token_str': 'heirloom_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce brisket </s>',
#   'score': 6.675685290247202e-05,
#   'token': 979,
#   'token_str': 'brisket'},
#  {'sequence': '<s> dough pizza_sauce bologna </s>',
#   'score': 6.671401206403971e-05,
#   'token': 3040,
#   'token_str': 'bologna'},
#  {'sequence': '<s> dough pizza_sauce butter_oil </s>',
#   'score': 6.639937782892957e-05,
#   'token': 2455,
#   'token_str': 'butter_oil'},
#  {'sequence': '<s> dough pizza_sauce sweet_pepper </s>',
#   'score': 6.636291072936729e-05,
#   'token': 1599,
#   'token_str': 'sweet_pepper'},
#  {'sequence': '<s> dough pizza_sauce japanese_eggplants </s>',
#   'score': 6.605849921470508e-05,
#   'token': 1748,
#   'token_str': 'japanese_eggplants'},
#  {'sequence': '<s> dough pizza_sauce firm_tofu </s>',
#   'score': 6.60093137412332e-05,
#   'token': 594,
#   'token_str': 'firm_tofu'},
#  {'sequence': '<s> dough pizza_sauce spice </s>',
#   'score': 6.590898556169122e-05,
#   'token': 546,
#   'token_str': 'spice'},
#  {'sequence': '<s> dough pizza_sauce anchovies </s>',
#   'score': 6.580541230505332e-05,
#   'token': 1259,
#   'token_str': 'anchovies'},
#  {'sequence': '<s> dough pizza_sauce chicken_thighs </s>',
#   'score': 6.55493640806526e-05,
#   'token': 388,
#   'token_str': 'chicken_thighs'},
#  {'sequence': '<s> dough pizza_sauce minced_meat </s>',
#   'score': 6.534782005473971e-05,
#   'token': 2674,
#   'token_str': 'minced_meat'},
#  {'sequence': '<s> dough pizza_sauce cutlet </s>',
#   'score': 6.477945862570778e-05,
#   'token': 3471,
#   'token_str': 'cutlet'},
#  {'sequence': '<s> dough pizza_sauce smoked_turkey </s>',
#   'score': 6.473523535532877e-05,
#   'token': 1125,
#   'token_str': 'smoked_turkey'},
#  {'sequence': '<s> dough pizza_sauce grated_pecorino </s>',
#   'score': 6.468314677476883e-05,
#   'token': 1289,
#   'token_str': 'grated_pecorino'},
#  {'sequence': '<s> dough pizza_sauce orange_bell_pepper </s>',
#   'score': 6.453521200455725e-05,
#   'token': 1371,
#   'token_str': 'orange_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce sausage_meat </s>',
#   'score': 6.447086343541741e-05,
#   'token': 2529,
#   'token_str': 'sausage_meat'},
#  {'sequence': '<s> dough pizza_sauce red_peppers </s>',
#   'score': 6.445451435865834e-05,
#   'token': 426,
#   'token_str': 'red_peppers'},
#  {'sequence': '<s> dough pizza_sauce bread_dough </s>',
#   'score': 6.406861211871728e-05,
#   'token': 1655,
#   'token_str': 'bread_dough'},
#  {'sequence': '<s> dough pizza_sauce russet_potatoes </s>',
#   'score': 6.370164919644594e-05,
#   'token': 616,
#   'token_str': 'russet_potatoes'},
#  {'sequence': '<s> dough pizza_sauce onion_salt </s>',
#   'score': 6.358129758154973e-05,
#   'token': 1107,
#   'token_str': 'onion_salt'},
#  {'sequence': '<s> dough pizza_sauce angel_hair </s>',
#   'score': 6.294064951362088e-05,
#   'token': 1102,
#   'token_str': 'angel_hair'},
#  {'sequence': '<s> dough pizza_sauce roasted_red_peppers </s>',
#   'score': 6.281898095039651e-05,
#   'token': 793,
#   'token_str': 'roasted_red_peppers'},
#  {'sequence': '<s> dough pizza_sauce kitchens </s>',
#   'score': 6.202562508406118e-05,
#   'token': 3344,
#   'token_str': 'kitchens'},
#  {'sequence': '<s> dough pizza_sauce sage_leaves </s>',
#   'score': 6.176102033350617e-05,
#   'token': 842,
#   'token_str': 'sage_leaves'},
#  {'sequence': '<s> dough pizza_sauce rotini </s>',
#   'score': 6.171244604047388e-05,
#   'token': 940,
#   'token_str': 'rotini'},
#  {'sequence': '<s> dough pizza_sauce bread_crumbs </s>',
#   'score': 6.12397852819413e-05,
#   'token': 216,
#   'token_str': 'bread_crumbs'},
#  {'sequence': '<s> dough pizza_sauce confit </s>',
#   'score': 6.10517236054875e-05,
#   'token': 2468,
#   'token_str': 'confit'},
#  {'sequence': '<s> dough pizza_sauce vegetarian </s>',
#   'score': 6.097631194279529e-05,
#   'token': 1103,
#   'token_str': 'vegetarian'},
#  {'sequence': '<s> dough pizza_sauce red_bell_peppers </s>',
#   'score': 6.0797992773586884e-05,
#   'token': 455,
#   'token_str': 'red_bell_peppers'},
#  {'sequence': '<s> dough pizza_sauce steaks </s>',
#   'score': 6.0342812503222376e-05,
#   'token': 401,
#   'token_str': 'steaks'},
#  {'sequence': '<s> dough pizza_sauce balsamic_vinegar </s>',
#   'score': 6.002581358188763e-05,
#   'token': 203,
#   'token_str': 'balsamic_vinegar'},
#  {'sequence': '<s> dough pizza_sauce ranch_dip </s>',
#   'score': 5.9724658058257774e-05,
#   'token': 2905,
#   'token_str': 'ranch_dip'},
#  {'sequence': '<s> dough pizza_sauce cucumbers </s>',
#   'score': 5.96708596276585e-05,
#   'token': 500,
#   'token_str': 'cucumbers'},
#  {'sequence': '<s> dough pizza_sauce liquid </s>',
#   'score': 5.9391590184532106e-05,
#   'token': 252,
#   'token_str': 'liquid'},
#  {'sequence': '<s> dough pizza_sauce medium_zucchini </s>',
#   'score': 5.929905455559492e-05,
#   'token': 649,
#   'token_str': 'medium_zucchini'},
#  {'sequence': '<s> dough pizza_sauce cooking_oil </s>',
#   'score': 5.920395415159874e-05,
#   'token': 554,
#   'token_str': 'cooking_oil'},
#  {'sequence': '<s> dough pizza_sauce hand </s>',
#   'score': 5.862709440407343e-05,
#   'token': 1727,
#   'token_str': 'hand'},
#  {'sequence': '<s> dough pizza_sauce powdered_sugar </s>',
#   'score': 5.8571939007379115e-05,
#   'token': 158,
#   'token_str': 'powdered_sugar'},
#  {'sequence': '<s> dough pizza_sauce flank_steak </s>',
#   'score': 5.851297828485258e-05,
#   'token': 950,
#   'token_str': 'flank_steak'},
#  {'sequence': '<s> dough pizza_sauce sun_dried_tomatoes </s>',
#   'score': 5.836067066411488e-05,
#   'token': 1626,
#   'token_str': 'sun_dried_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce black_forest_ham </s>',
#   'score': 5.8169523981632665e-05,
#   'token': 3113,
#   'token_str': 'black_forest_ham'},
#  {'sequence': '<s> dough pizza_sauce sliced_onion </s>',
#   'score': 5.7913239288609475e-05,
#   'token': 1351,
#   'token_str': 'sliced_onion'},
#  {'sequence': '<s> dough pizza_sauce pure_olive_oil </s>',
#   'score': 5.786416295450181e-05,
#   'token': 1980,
#   'token_str': 'pure_olive_oil'},
#  {'sequence': '<s> dough pizza_sauce muenster </s>',
#   'score': 5.754146695835516e-05,
#   'token': 1546,
#   'token_str': 'muenster'},
#  {'sequence': '<s> dough pizza_sauce steak_seasoning </s>',
#   'score': 5.752138895331882e-05,
#   'token': 1114,
#   'token_str': 'steak_seasoning'},
#  {'sequence': '<s> dough pizza_sauce marinade </s>',
#   'score': 5.696994412573986e-05,
#   'token': 1047,
#   'token_str': 'marinade'},
#  {'sequence': '<s> dough pizza_sauce plain_flour </s>',
#   'score': 5.670980681315996e-05,
#   'token': 505,
#   'token_str': 'plain_flour'},
#  {'sequence': '<s> dough pizza_sauce roasted_peppers </s>',
#   'score': 5.6700126151554286e-05,
#   'token': 3418,
#   'token_str': 'roasted_peppers'},
#  {'sequence': '<s> dough pizza_sauce turkey_breast </s>',
#   'score': 5.6633598433109e-05,
#   'token': 730,
#   'token_str': 'turkey_breast'},
#  {'sequence': '<s> dough pizza_sauce part-skim_mozzarella </s>',
#   'score': 5.633463661069982e-05,
#   'token': 2961,
#   'token_str': 'part-skim_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce nonstick_spray </s>',
#   'score': 5.612448148895055e-05,
#   'token': 2332,
#   'token_str': 'nonstick_spray'},
#  {'sequence': '<s> dough pizza_sauce savory </s>',
#   'score': 5.601454176940024e-05,
#   'token': 992,
#   'token_str': 'savory'},
#  {'sequence': '<s> dough pizza_sauce white_mushrooms </s>',
#   'score': 5.5874759709695354e-05,
#   'token': 1031,
#   'token_str': 'white_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce biscuit_dough </s>',
#   'score': 5.575897739618085e-05,
#   'token': 2381,
#   'token_str': 'biscuit_dough'},
#  {'sequence': '<s> dough pizza_sauce ground_pepper </s>',
#   'score': 5.567730840994045e-05,
#   'token': 111,
#   'token_str': 'ground_pepper'},
#  {'sequence': '<s> dough pizza_sauce spinach_leaves </s>',
#   'score': 5.5188575061038136e-05,
#   'token': 470,
#   'token_str': 'spinach_leaves'},
#  {'sequence': '<s> dough pizza_sauce portabella_mushrooms </s>',
#   'score': 5.5066026106942445e-05,
#   'token': 1402,
#   'token_str': 'portabella_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce aioli </s>',
#   'score': 5.4947890021139756e-05,
#   'token': 2440,
#   'token_str': 'aioli'},
#  {'sequence': '<s> dough pizza_sauce herbes_de_provence </s>',
#   'score': 5.477058221003972e-05,
#   'token': 1184,
#   'token_str': 'herbes_de_provence'},
#  {'sequence': '<s> dough pizza_sauce mixed_vegetables </s>',
#   'score': 5.4759042541263625e-05,
#   'token': 745,
#   'token_str': 'mixed_vegetables'},
#  {'sequence': '<s> dough pizza_sauce gluten </s>',
#   'score': 5.472254997584969e-05,
#   'token': 933,
#   'token_str': 'gluten'},
#  {'sequence': '<s> dough pizza_sauce cheese_ravioli </s>',
#   'score': 5.386619159253314e-05,
#   'token': 2378,
#   'token_str': 'cheese_ravioli'},
#  {'sequence': '<s> dough pizza_sauce italian_seasoned_breadcrumbs </s>',
#   'score': 5.370139115257189e-05,
#   'token': 1673,
#   'token_str': 'italian_seasoned_breadcrumbs'},
#  {'sequence': '<s> dough pizza_sauce chianti </s>',
#   'score': 5.35867948201485e-05,
#   'token': 2517,
#   'token_str': 'chianti'},
#  {'sequence': '<s> dough pizza_sauce wheat_bran </s>',
#   'score': 5.3388979722512886e-05,
#   'token': 1799,
#   'token_str': 'wheat_bran'},
#  {'sequence': '<s> dough pizza_sauce mentsuyu </s>',
#   'score': 5.3222134738462046e-05,
#   'token': 1796,
#   'token_str': 'mentsuyu'},
#  {'sequence': '<s> dough pizza_sauce center_cut_bacon </s>',
#   'score': 5.321178105077706e-05,
#   'token': 2356,
#   'token_str': 'center_cut_bacon'},
#  {'sequence': '<s> dough pizza_sauce cheese_sauce </s>',
#   'score': 5.320356285665184e-05,
#   'token': 1553,
#   'token_str': 'cheese_sauce'},
#  {'sequence': '<s> dough pizza_sauce red_chili </s>',
#   'score': 5.2924369811080396e-05,
#   'token': 462,
#   'token_str': 'red_chili'},
#  {'sequence': '<s> dough pizza_sauce extra_lean_ground_beef </s>',
#   'score': 5.2885166951455176e-05,
#   'token': 1509,
#   'token_str': 'extra_lean_ground_beef'},
#  {'sequence': '<s> dough pizza_sauce squid </s>',
#   'score': 5.271924237604253e-05,
#   'token': 1375,
#   'token_str': 'squid'},
#  {'sequence': '<s> dough pizza_sauce oscar_mayer_bacon </s>',
#   'score': 5.255584619590081e-05,
#   'token': 1198,
#   'token_str': 'oscar_mayer_bacon'},
#  {'sequence': '<s> dough pizza_sauce pecorino_cheese </s>',
#   'score': 5.245279680821113e-05,
#   'token': 1495,
#   'token_str': 'pecorino_cheese'},
#  {'sequence': '<s> dough pizza_sauce egg_whites </s>',
#   'score': 5.223096741246991e-05,
#   'token': 184,
#   'token_str': 'egg_whites'},
#  {'sequence': '<s> dough pizza_sauce canola </s>',
#   'score': 5.2048428187845275e-05,
#   'token': 139,
#   'token_str': 'canola'},
#  {'sequence': '<s> dough pizza_sauce turkey_bacon </s>',
#   'score': 5.1982155127916485e-05,
#   'token': 1543,
#   'token_str': 'turkey_bacon'},
#  {'sequence': '<s> dough pizza_sauce tap_water </s>',
#   'score': 5.180933294468559e-05,
#   'token': 2664,
#   'token_str': 'tap_water'},
#  {'sequence': '<s> dough pizza_sauce green_chiles </s>',
#   'score': 5.1387276471359655e-05,
#   'token': 868,
#   'token_str': 'green_chiles'}]

# %%
tokenized_input = tokenizer('dough pizza_sauce <mask>', return_tensors='pt')['input_ids']
tokenized_input
# Out:
# tensor([[  0, 431, 856,   4,   2]])

# %%
model(tokenized_input)
# Out:
# (tensor([[[ 20.7888,  -5.7311,  -2.3179,  ...,  -1.1549,   1.2096,  -0.6517],
#           [ -3.5585, -10.7750,  -3.0984,  ...,  -2.4188,  -3.7403,  -3.7300],
#           [ -4.2900, -10.2704,  -1.8199,  ...,  -1.9546,  -2.8219,  -1.6147],
#           [ -3.2282, -12.2347,  -5.2322,  ...,  -2.8265,  -3.5606,  -4.4717],
#           [ -3.3837,  -7.7216,  17.7582,  ...,  -4.7777,  -3.7840,  -2.4419]]],
#         grad_fn=<AddBackward0>),)

# %%
x = tokenized_input
x = model.roberta.embeddings(x)
x = model.roberta.encoder(x)
x = model.lm_head(x[0])
x
# Out:
# tensor([[[ 20.7888,  -5.7311,  -2.3179,  ...,  -1.1549,   1.2096,  -0.6517],
#          [ -3.5585, -10.7750,  -3.0984,  ...,  -2.4188,  -3.7403,  -3.7300],
#          [ -4.2900, -10.2704,  -1.8199,  ...,  -1.9546,  -2.8219,  -1.6147],
#          [ -3.2282, -12.2347,  -5.2322,  ...,  -2.8265,  -3.5606,  -4.4717],
#          [ -3.3837,  -7.7216,  17.7582,  ...,  -4.7777,  -3.7840,  -2.4419]]],
#        grad_fn=<AddBackward0>)

# %%
x.shape
# Out:
# torch.Size([1, 5, 3505])

# %%
mask_part = x[0, 3, :]
mask_part
# Out:
# tensor([ -3.2282, -12.2347,  -5.2322,  ...,  -2.8265,  -3.5606,  -4.4717],
#        grad_fn=<SliceBackward>)

# %%
import torch
topk = torch.topk(mask_part, k=5)
topk
# Out:
# torch.return_types.topk(
# values=tensor([7.6516, 7.5410, 6.4063, 6.3114, 5.8397], grad_fn=<TopkBackward>),
# indices=tensor([156, 733,  12,  21,  49]))

# %%
tokenizer.convert_ids_to_tokens(topk.indices)
# Out:
# ['mozzarella_cheese', 'pepperoni', 'olive_oil', 'cheese', 'parmesan']
