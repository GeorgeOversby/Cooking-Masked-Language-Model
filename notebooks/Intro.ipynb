# %% [markdown]
# # Masked language models

# %%
from transformers import pipeline

fill_mask = pipeline("fill-mask")
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['lm_head.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask("Share your Opinion, Shop & Search to earn real cash rewards.")
# Out:
# ---------------------------------------------------------------------------
# PipelineException                         Traceback (most recent call last)
# <ipython-input-4-8d2ef9e658fe> in <module>
# ----> 1 fill_mask("Share your Opinion, Shop & Search to earn real cash rewards.")
#
# ~/anaconda3/lib/python3.8/site-packages/transformers/pipelines.py in __call__(self, targets, *args, **kwargs)
#    1259
#    1260                 # Fill mask pipeline supports only one ${mask_token} per sample
# -> 1261                 self.ensure_exactly_one_mask_token(masked_index.numpy())
#    1262
#    1263                 logits = outputs[i, masked_index.item(), :]
#
# ~/anaconda3/lib/python3.8/site-packages/transformers/pipelines.py in ensure_exactly_one_mask_token(self, masked_index)
#    1184             )
#    1185         elif numel < 1:
# -> 1186             raise PipelineException(
#    1187                 "fill-mask",
#    1188                 self.model.base_model_prefix,
#
# PipelineException: No mask_token (<mask>) found on the input

# %% [markdown]
# # Training on recipes

# %% [markdown]
# https://huggingface.co/blog/how-to-train

# %%
# !head ../data/processed/recipes_train.txt
# Out:
# garlic eggplant flour salt olive_oil seasoned_bread_crumbs grated_parmesan_cheese pepper rounds mozzarella_cheese tomatoes
# eggs oreo cookies margarine water sugar_cookie_mix brownie ingredients
# nutmeg cinnamon_sticks apple_juice orange_blossom water tea_bags
# red_chili pepper_sauce chili_paste olive_oil pork_loin mirin cornstarch oyster_sauce
# medium_shrimp dried_red_pepper fillets olive_oil fennel_fronds garlic_cloves bottled_clam_juice dry_white_wine lemon arugula
# black_beans salt olive_oil avocado cilantro bell_pepper ground_cumin red_onion lime_juice
# dark_chocolate eggs salt vanilla_extract unsalted_butter confectioners_sugar skim_milk brioche_bread heavy_cream
# cake_flour white_sugar salt milk vanilla_extract unsalted_butter pumpkin_pie_spice ground_cloves egg_white powdered_sugar ground_cinnamon canola_oil baking_powder temperature
# boneless_pork_loin salt pork_loin_chops golden_delicious_apples ground_cinnamon brown_sugar
# melted_butter flour salt dry_milk water sugar instant_yeast temperature baking_soda

# %%
# !cat ../data/processed/recipes_train.txt | wc -l
# Out:
# 1039974

# %%
import sys
from pathlib import Path
sys.path.append(str(Path(sys.path[0]).parent))
from src.ingredient_tokenizer import load_tokenizer

tokenizer = load_tokenizer('../artifacts')

fill_mask_recipe = pipeline("fill-mask", 
                     model='../artifacts/', 
                     tokenizer=tokenizer,
                     topk=500)
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at ../artifacts/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask_recipe('cold_water pepper salt chicken celery onion carrot <mask> hen')
# Out:
# [{'sequence': '<s> cold_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.19535516202449799,
#   'token': 10,
#   'token_str': 'flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsley hen </s>',
#   'score': 0.08524889498949051,
#   'token': 36,
#   'token_str': 'parsley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot eggs hen </s>',
#   'score': 0.051332026720047,
#   'token': 18,
#   'token_str': 'eggs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg_noodles hen </s>',
#   'score': 0.050168510526418686,
#   'token': 504,
#   'token_str': 'egg_noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot carcass hen </s>',
#   'score': 0.03739031404256821,
#   'token': 2982,
#   'token_str': 'carcass'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bay_leaf hen </s>',
#   'score': 0.03536321967840195,
#   'token': 217,
#   'token_str': 'bay_leaf'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cornstarch hen </s>',
#   'score': 0.0298247579485178,
#   'token': 116,
#   'token_str': 'cornstarch'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg hen </s>',
#   'score': 0.02967856451869011,
#   'token': 29,
#   'token_str': 'egg'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic hen </s>',
#   'score': 0.015317129902541637,
#   'token': 8,
#   'token_str': 'garlic'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bay_leaves hen </s>',
#   'score': 0.014853989705443382,
#   'token': 213,
#   'token_str': 'bay_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot potato hen </s>',
#   'score': 0.012879885733127594,
#   'token': 208,
#   'token_str': 'potato'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot butter hen </s>',
#   'score': 0.01228400319814682,
#   'token': 7,
#   'token_str': 'butter'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot thyme hen </s>',
#   'score': 0.011690010316669941,
#   'token': 75,
#   'token_str': 'thyme'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetable_oil hen </s>',
#   'score': 0.01146712526679039,
#   'token': 40,
#   'token_str': 'vegetable_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soup hen </s>',
#   'score': 0.010760366916656494,
#   'token': 539,
#   'token_str': 'soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shortening hen </s>',
#   'score': 0.008811378851532936,
#   'token': 192,
#   'token_str': 'shortening'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream_of_chicken_soup hen </s>',
#   'score': 0.008372491225600243,
#   'token': 386,
#   'token_str': 'cream_of_chicken_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sugar hen </s>',
#   'score': 0.00818611215800047,
#   'token': 9,
#   'token_str': 'sugar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stock hen </s>',
#   'score': 0.006999934557825327,
#   'token': 176,
#   'token_str': 'stock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot poultry_seasoning hen </s>',
#   'score': 0.00688935536891222,
#   'token': 809,
#   'token_str': 'poultry_seasoning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot oil hen </s>',
#   'score': 0.006795125547796488,
#   'token': 76,
#   'token_str': 'oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rice hen </s>',
#   'score': 0.00649622967466712,
#   'token': 122,
#   'token_str': 'rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot potatoes hen </s>',
#   'score': 0.00621799798682332,
#   'token': 52,
#   'token_str': 'potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot breast hen </s>',
#   'score': 0.005901187192648649,
#   'token': 468,
#   'token_str': 'breast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot barley hen </s>',
#   'score': 0.005741634871810675,
#   'token': 678,
#   'token_str': 'barley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot meat hen </s>',
#   'score': 0.005360784940421581,
#   'token': 370,
#   'token_str': 'meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_minced hen </s>',
#   'score': 0.005186691880226135,
#   'token': 88,
#   'token_str': 'garlic_minced'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mushrooms hen </s>',
#   'score': 0.004971184302121401,
#   'token': 70,
#   'token_str': 'mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey hen </s>',
#   'score': 0.004839666187763214,
#   'token': 206,
#   'token_str': 'turkey'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_cloves hen </s>',
#   'score': 0.004762222990393639,
#   'token': 38,
#   'token_str': 'garlic_cloves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rosemary hen </s>',
#   'score': 0.004618292674422264,
#   'token': 155,
#   'token_str': 'rosemary'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot hen hen </s>',
#   'score': 0.004195543006062508,
#   'token': 2935,
#   'token_str': 'hen'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsley_flakes hen </s>',
#   'score': 0.003955243155360222,
#   'token': 727,
#   'token_str': 'parsley_flakes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fat hen </s>',
#   'score': 0.003933234605938196,
#   'token': 937,
#   'token_str': 'fat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot broth hen </s>',
#   'score': 0.0038249301724135876,
#   'token': 242,
#   'token_str': 'broth'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_thyme hen </s>',
#   'score': 0.003724898910149932,
#   'token': 214,
#   'token_str': 'dried_thyme'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cubed_potatoes hen </s>',
#   'score': 0.003675284795463085,
#   'token': 2305,
#   'token_str': 'cubed_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomatoes hen </s>',
#   'score': 0.0036590101663023233,
#   'token': 26,
#   'token_str': 'tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot noodles hen </s>',
#   'score': 0.003644163953140378,
#   'token': 183,
#   'token_str': 'noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_peas hen </s>',
#   'score': 0.0032627542968839407,
#   'token': 417,
#   'token_str': 'frozen_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot leek hen </s>',
#   'score': 0.0031608068384230137,
#   'token': 615,
#   'token_str': 'leek'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wide_egg_noodles hen </s>',
#   'score': 0.0030606677755713463,
#   'token': 1393,
#   'token_str': 'wide_egg_noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot liquid hen </s>',
#   'score': 0.0029979932587593794,
#   'token': 252,
#   'token_str': 'liquid'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot skin hen </s>',
#   'score': 0.002892564982175827,
#   'token': 831,
#   'token_str': 'skin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato hen </s>',
#   'score': 0.002849799580872059,
#   'token': 50,
#   'token_str': 'tomato'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot broiler hen </s>',
#   'score': 0.002754615619778633,
#   'token': 2795,
#   'token_str': 'broiler'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot olive_oil hen </s>',
#   'score': 0.0027000331319868565,
#   'token': 12,
#   'token_str': 'olive_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetable hen </s>',
#   'score': 0.002552861114963889,
#   'token': 32,
#   'token_str': 'vegetable'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rib hen </s>',
#   'score': 0.0024771227035671473,
#   'token': 721,
#   'token_str': 'rib'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_split_peas hen </s>',
#   'score': 0.002466576173901558,
#   'token': 3393,
#   'token_str': 'dried_split_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mushroom hen </s>',
#   'score': 0.002441519172862172,
#   'token': 164,
#   'token_str': 'mushroom'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot milk hen </s>',
#   'score': 0.0023881809320300817,
#   'token': 20,
#   'token_str': 'milk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ginger hen </s>',
#   'score': 0.002371251815930009,
#   'token': 45,
#   'token_str': 'ginger'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ingredients hen </s>',
#   'score': 0.0023543653078377247,
#   'token': 1424,
#   'token_str': 'ingredients'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot savory hen </s>',
#   'score': 0.002347355941310525,
#   'token': 992,
#   'token_str': 'savory'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot hot_water hen </s>',
#   'score': 0.0022603673860430717,
#   'token': 342,
#   'token_str': 'hot_water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot split_peas hen </s>',
#   'score': 0.0022391043603420258,
#   'token': 1435,
#   'token_str': 'split_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bouillon hen </s>',
#   'score': 0.0020654150284826756,
#   'token': 268,
#   'token_str': 'bouillon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sage hen </s>',
#   'score': 0.0020358716137707233,
#   'token': 341,
#   'token_str': 'sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey_carcass hen </s>',
#   'score': 0.0019861955661326647,
#   'token': 3432,
#   'token_str': 'turkey_carcass'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsley_sprigs hen </s>',
#   'score': 0.0019626158755272627,
#   'token': 1323,
#   'token_str': 'parsley_sprigs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cloves hen </s>',
#   'score': 0.0019526564283296466,
#   'token': 87,
#   'token_str': 'cloves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lard hen </s>',
#   'score': 0.0019318528939038515,
#   'token': 911,
#   'token_str': 'lard'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetable_shortening hen </s>',
#   'score': 0.0019101729849353433,
#   'token': 524,
#   'token_str': 'vegetable_shortening'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lemons hen </s>',
#   'score': 0.001905048149637878,
#   'token': 310,
#   'token_str': 'lemons'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_fat hen </s>',
#   'score': 0.001826237072236836,
#   'token': 2512,
#   'token_str': 'chicken_fat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot leeks hen </s>',
#   'score': 0.0017295050201937556,
#   'token': 535,
#   'token_str': 'leeks'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot liver hen </s>',
#   'score': 0.001707065966911614,
#   'token': 1344,
#   'token_str': 'liver'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot peas hen </s>',
#   'score': 0.0017058950616046786,
#   'token': 193,
#   'token_str': 'peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dumplings hen </s>',
#   'score': 0.0016702464781701565,
#   'token': 2719,
#   'token_str': 'dumplings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot plain_flour hen </s>',
#   'score': 0.001665571820922196,
#   'token': 505,
#   'token_str': 'plain_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gravy_mix hen </s>',
#   'score': 0.0016351341037079692,
#   'token': 1591,
#   'token_str': 'gravy_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bouquet_garni hen </s>',
#   'score': 0.0016268924809992313,
#   'token': 1439,
#   'token_str': 'bouquet_garni'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot margarine hen </s>',
#   'score': 0.0015933417016640306,
#   'token': 80,
#   'token_str': 'margarine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn hen </s>',
#   'score': 0.0015602654311805964,
#   'token': 109,
#   'token_str': 'corn'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot water hen </s>',
#   'score': 0.001520719612017274,
#   'token': 13,
#   'token_str': 'water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dill hen </s>',
#   'score': 0.0014593005180358887,
#   'token': 231,
#   'token_str': 'dill'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot evaporated_milk hen </s>',
#   'score': 0.0014212430687621236,
#   'token': 393,
#   'token_str': 'evaporated_milk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot brown hen </s>',
#   'score': 0.0014211778761819005,
#   'token': 27,
#   'token_str': 'brown'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot matzo_meal hen </s>',
#   'score': 0.0014190158108249307,
#   'token': 1857,
#   'token_str': 'matzo_meal'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_rice hen </s>',
#   'score': 0.0013867042725905776,
#   'token': 293,
#   'token_str': 'white_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef hen </s>',
#   'score': 0.0013718674890697002,
#   'token': 188,
#   'token_str': 'beef'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetables hen </s>',
#   'score': 0.0013603097759187222,
#   'token': 420,
#   'token_str': 'vegetables'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot okra hen </s>',
#   'score': 0.0013468916295096278,
#   'token': 957,
#   'token_str': 'okra'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pearl_barley hen </s>',
#   'score': 0.0013340454315766692,
#   'token': 1238,
#   'token_str': 'pearl_barley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lemon hen </s>',
#   'score': 0.0013144217664375901,
#   'token': 23,
#   'token_str': 'lemon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vinegar hen </s>',
#   'score': 0.0012953998520970345,
#   'token': 31,
#   'token_str': 'vinegar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooked_rice hen </s>',
#   'score': 0.0012546589132398367,
#   'token': 514,
#   'token_str': 'cooked_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stuffing hen </s>',
#   'score': 0.0012387775350362062,
#   'token': 549,
#   'token_str': 'stuffing'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot minced_garlic hen </s>',
#   'score': 0.0012245315592736006,
#   'token': 134,
#   'token_str': 'minced_garlic'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg_yolk hen </s>',
#   'score': 0.0011765799717977643,
#   'token': 336,
#   'token_str': 'egg_yolk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mashed_potatoes hen </s>',
#   'score': 0.0011703744530677795,
#   'token': 839,
#   'token_str': 'mashed_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shells hen </s>',
#   'score': 0.00109556142706424,
#   'token': 483,
#   'token_str': 'shells'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cabbage hen </s>',
#   'score': 0.0010898368200287223,
#   'token': 182,
#   'token_str': 'cabbage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wondra_flour hen </s>',
#   'score': 0.0010665662121027708,
#   'token': 3436,
#   'token_str': 'wondra_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot peppercorns hen </s>',
#   'score': 0.0010572654427960515,
#   'token': 281,
#   'token_str': 'peppercorns'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot onions hen </s>',
#   'score': 0.001054601394571364,
#   'token': 30,
#   'token_str': 'onions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tarragon hen </s>',
#   'score': 0.0010450870031490922,
#   'token': 315,
#   'token_str': 'tarragon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bacon hen </s>',
#   'score': 0.0010293476516380906,
#   'token': 90,
#   'token_str': 'bacon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chestnuts hen </s>',
#   'score': 0.0010287475306540728,
#   'token': 590,
#   'token_str': 'chestnuts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_flour hen </s>',
#   'score': 0.0010151229798793793,
#   'token': 698,
#   'token_str': 'white_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot paprika hen </s>',
#   'score': 0.001011760556139052,
#   'token': 96,
#   'token_str': 'paprika'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stewed_tomatoes hen </s>',
#   'score': 0.0009911013767123222,
#   'token': 660,
#   'token_str': 'stewed_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cold_water hen </s>',
#   'score': 0.0009841095888987184,
#   'token': 253,
#   'token_str': 'cold_water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot worcestershire_sauce hen </s>',
#   'score': 0.0009639943018555641,
#   'token': 123,
#   'token_str': 'worcestershire_sauce'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unflavored_gelatin hen </s>',
#   'score': 0.0009606771054677665,
#   'token': 704,
#   'token_str': 'unflavored_gelatin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot basil hen </s>',
#   'score': 0.0009553310228511691,
#   'token': 77,
#   'token_str': 'basil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_potatoes hen </s>',
#   'score': 0.0009488856885582209,
#   'token': 610,
#   'token_str': 'medium_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_paste hen </s>',
#   'score': 0.0009360442054457963,
#   'token': 189,
#   'token_str': 'tomato_paste'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_powder hen </s>',
#   'score': 0.0009331015753559768,
#   'token': 84,
#   'token_str': 'garlic_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boiling_water hen </s>',
#   'score': 0.0009288922301493585,
#   'token': 254,
#   'token_str': 'boiling_water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turnips hen </s>',
#   'score': 0.0009230427676811814,
#   'token': 1024,
#   'token_str': 'turnips'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gravy hen </s>',
#   'score': 0.0009137231390923262,
#   'token': 1078,
#   'token_str': 'gravy'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scallions hen </s>',
#   'score': 0.0009085118654184043,
#   'token': 167,
#   'token_str': 'scallions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot grain hen </s>',
#   'score': 0.0008740894263610244,
#   'token': 379,
#   'token_str': 'grain'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot flour_for_dusting hen </s>',
#   'score': 0.0008726546657271683,
#   'token': 1115,
#   'token_str': 'flour_for_dusting'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sliced_mushrooms hen </s>',
#   'score': 0.0008635562844574451,
#   'token': 359,
#   'token_str': 'sliced_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stick_butter hen </s>',
#   'score': 0.000855597376357764,
#   'token': 405,
#   'token_str': 'stick_butter'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pie_crust hen </s>',
#   'score': 0.000847404939122498,
#   'token': 498,
#   'token_str': 'pie_crust'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream_of_mushroom_soup hen </s>',
#   'score': 0.0008373127784579992,
#   'token': 312,
#   'token_str': 'cream_of_mushroom_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot goose hen </s>',
#   'score': 0.0008355822064913809,
#   'token': 2206,
#   'token_str': 'goose'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot drippings hen </s>',
#   'score': 0.0008342806831933558,
#   'token': 1110,
#   'token_str': 'drippings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot carrot hen </s>',
#   'score': 0.0008336369064636528,
#   'token': 140,
#   'token_str': 'carrot'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unsalted_butter hen </s>',
#   'score': 0.0008250054670497775,
#   'token': 44,
#   'token_str': 'unsalted_butter'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soy_sauce hen </s>',
#   'score': 0.0008126285974867642,
#   'token': 61,
#   'token_str': 'soy_sauce'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot with_skin hen </s>',
#   'score': 0.0008092984207905829,
#   'token': 915,
#   'token_str': 'with_skin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot roux hen </s>',
#   'score': 0.0007715713582001626,
#   'token': 2289,
#   'token_str': 'roux'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooking_oil hen </s>',
#   'score': 0.0007478251354768872,
#   'token': 554,
#   'token_str': 'cooking_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot seasonings hen </s>',
#   'score': 0.0007445048540830612,
#   'token': 1652,
#   'token_str': 'seasonings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_shiitake_mushrooms hen </s>',
#   'score': 0.0007434827275574207,
#   'token': 2055,
#   'token_str': 'dried_shiitake_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot kitchen_bouquet hen </s>',
#   'score': 0.0007265277672559023,
#   'token': 2825,
#   'token_str': 'kitchen_bouquet'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot condensed_cream_of_chicken_soup hen </s>',
#   'score': 0.0007153631886467338,
#   'token': 1097,
#   'token_str': 'condensed_cream_of_chicken_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bouillon_powder hen </s>',
#   'score': 0.0007089177379384637,
#   'token': 2026,
#   'token_str': 'bouillon_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot minced_parsley hen </s>',
#   'score': 0.0007034955197013915,
#   'token': 497,
#   'token_str': 'minced_parsley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork hen </s>',
#   'score': 0.0007016445742920041,
#   'token': 180,
#   'token_str': 'pork'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot canned_tomatoes hen </s>',
#   'score': 0.0006999296601861715,
#   'token': 658,
#   'token_str': 'canned_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot powder hen </s>',
#   'score': 0.0006970041431486607,
#   'token': 16,
#   'token_str': 'powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot onion hen </s>',
#   'score': 0.0006836982211098075,
#   'token': 11,
#   'token_str': 'onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_oil hen </s>',
#   'score': 0.0006784009165130556,
#   'token': 802,
#   'token_str': 'corn_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot accent hen </s>',
#   'score': 0.0006729161832481623,
#   'token': 3266,
#   'token_str': 'accent'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rutabaga hen </s>',
#   'score': 0.0006727874861098826,
#   'token': 1867,
#   'token_str': 'rutabaga'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot seasoning hen </s>',
#   'score': 0.0006626842077821493,
#   'token': 78,
#   'token_str': 'seasoning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crisco_shortening hen </s>',
#   'score': 0.0006546820513904095,
#   'token': 2496,
#   'token_str': 'crisco_shortening'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream_of_celery_soup hen </s>',
#   'score': 0.0006387038738466799,
#   'token': 938,
#   'token_str': 'cream_of_celery_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mushroom_soup hen </s>',
#   'score': 0.0006324378191493452,
#   'token': 271,
#   'token_str': 'mushroom_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crisco hen </s>',
#   'score': 0.0006313151679933071,
#   'token': 908,
#   'token_str': 'crisco'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_peas hen </s>',
#   'score': 0.0006222018273547292,
#   'token': 798,
#   'token_str': 'green_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_wine hen </s>',
#   'score': 0.0006198192131705582,
#   'token': 89,
#   'token_str': 'white_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_parsley hen </s>',
#   'score': 0.0006159246549941599,
#   'token': 445,
#   'token_str': 'dried_parsley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vermicelli hen </s>',
#   'score': 0.0006128604873083532,
#   'token': 1168,
#   'token_str': 'vermicelli'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_beans hen </s>',
#   'score': 0.0006008995114825666,
#   'token': 272,
#   'token_str': 'green_beans'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot black_peppercorns hen </s>',
#   'score': 0.0005997739499434829,
#   'token': 440,
#   'token_str': 'black_peppercorns'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot celery_leaves hen </s>',
#   'score': 0.0005915692890994251,
#   'token': 1438,
#   'token_str': 'celery_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot canola_oil hen </s>',
#   'score': 0.0005818333011120558,
#   'token': 152,
#   'token_str': 'canola_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot oysters hen </s>',
#   'score': 0.0005760926869697869,
#   'token': 1080,
#   'token_str': 'oysters'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lemon_juice hen </s>',
#   'score': 0.0005739066982641816,
#   'token': 34,
#   'token_str': 'lemon_juice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken hen </s>',
#   'score': 0.0005600120639428496,
#   'token': 24,
#   'token_str': 'chicken'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot thyme_sprigs hen </s>',
#   'score': 0.0005548115586861968,
#   'token': 936,
#   'token_str': 'thyme_sprigs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot veal hen </s>',
#   'score': 0.0005545716849155724,
#   'token': 1053,
#   'token_str': 'veal'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey_broth hen </s>',
#   'score': 0.0005506932502612472,
#   'token': 2021,
#   'token_str': 'turkey_broth'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chestnut hen </s>',
#   'score': 0.000547773961443454,
#   'token': 1338,
#   'token_str': 'chestnut'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot spices hen </s>',
#   'score': 0.00054098543478176,
#   'token': 910,
#   'token_str': 'spices'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_kernels hen </s>',
#   'score': 0.0005366854020394385,
#   'token': 503,
#   'token_str': 'corn_kernels'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yellow_split_peas hen </s>',
#   'score': 0.0005315352464094758,
#   'token': 1809,
#   'token_str': 'yellow_split_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream hen </s>',
#   'score': 0.000521709444001317,
#   'token': 22,
#   'token_str': 'cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot thyme_leaves hen </s>',
#   'score': 0.0005212869727984071,
#   'token': 384,
#   'token_str': 'thyme_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dry_sherry hen </s>',
#   'score': 0.0005133904633112252,
#   'token': 501,
#   'token_str': 'dry_sherry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_powder hen </s>',
#   'score': 0.000512288068421185,
#   'token': 42,
#   'token_str': 'baking_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_thighs hen </s>',
#   'score': 0.0004967754939571023,
#   'token': 388,
#   'token_str': 'chicken_thighs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot duck hen </s>',
#   'score': 0.00048671424156054854,
#   'token': 887,
#   'token_str': 'duck'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot carrots hen </s>',
#   'score': 0.00048301086644642055,
#   'token': 67,
#   'token_str': 'carrots'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot apple_cider hen </s>',
#   'score': 0.0004750246007461101,
#   'token': 284,
#   'token_str': 'apple_cider'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bone_in hen </s>',
#   'score': 0.00047288957284763455,
#   'token': 1716,
#   'token_str': 'bone_in'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot heavy_cream hen </s>',
#   'score': 0.0004701227881014347,
#   'token': 93,
#   'token_str': 'heavy_cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot marjoram hen </s>',
#   'score': 0.0004694731323979795,
#   'token': 520,
#   'token_str': 'marjoram'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bread_flour hen </s>',
#   'score': 0.0004652939969673753,
#   'token': 464,
#   'token_str': 'bread_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_sage hen </s>',
#   'score': 0.0004607964074239135,
#   'token': 1463,
#   'token_str': 'ground_sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot buttermilk hen </s>',
#   'score': 0.00045759082422591746,
#   'token': 160,
#   'token_str': 'buttermilk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot paste hen </s>',
#   'score': 0.00045622867764905095,
#   'token': 570,
#   'token_str': 'paste'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_shank hen </s>',
#   'score': 0.000450054241809994,
#   'token': 2361,
#   'token_str': 'beef_shank'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soup_mix hen </s>',
#   'score': 0.0004480387142393738,
#   'token': 496,
#   'token_str': 'soup_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot long_grain_rice hen </s>',
#   'score': 0.0004478639748413116,
#   'token': 903,
#   'token_str': 'long_grain_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot monosodium_glutamate hen </s>',
#   'score': 0.00044362706830725074,
#   'token': 2623,
#   'token_str': 'monosodium_glutamate'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_meat hen </s>',
#   'score': 0.00043933826964348555,
#   'token': 1620,
#   'token_str': 'chicken_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boiled_eggs hen </s>',
#   'score': 0.0004247181350365281,
#   'token': 1256,
#   'token_str': 'boiled_eggs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooked_turkey hen </s>',
#   'score': 0.0004242784925736487,
#   'token': 882,
#   'token_str': 'cooked_turkey'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bread hen </s>',
#   'score': 0.0004193148633930832,
#   'token': 74,
#   'token_str': 'bread'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fish_bones hen </s>',
#   'score': 0.0004155184142291546,
#   'token': 2966,
#   'token_str': 'fish_bones'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rounds hen </s>',
#   'score': 0.000410691398428753,
#   'token': 778,
#   'token_str': 'rounds'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cheese hen </s>',
#   'score': 0.0004105693951714784,
#   'token': 21,
#   'token_str': 'cheese'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dry_white_wine hen </s>',
#   'score': 0.00040897028520703316,
#   'token': 207,
#   'token_str': 'dry_white_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_sauce hen </s>',
#   'score': 0.0004088550922460854,
#   'token': 186,
#   'token_str': 'tomato_sauce'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot game hen </s>',
#   'score': 0.0004012087592855096,
#   'token': 2049,
#   'token_str': 'game'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_bouillon hen </s>',
#   'score': 0.00039567830390296876,
#   'token': 450,
#   'token_str': 'chicken_bouillon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pan_drippings hen </s>',
#   'score': 0.0003909879887942225,
#   'token': 2890,
#   'token_str': 'pan_drippings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot butter_oil hen </s>',
#   'score': 0.0003875669790431857,
#   'token': 2455,
#   'token_str': 'butter_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garnish hen </s>',
#   'score': 0.0003874086542055011,
#   'token': 95,
#   'token_str': 'garnish'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot herbs hen </s>',
#   'score': 0.000386421219445765,
#   'token': 656,
#   'token_str': 'herbs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot italian_tomatoes hen </s>',
#   'score': 0.0003741124819498509,
#   'token': 2149,
#   'token_str': 'italian_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot roast hen </s>',
#   'score': 0.0003741019463632256,
#   'token': 292,
#   'token_str': 'roast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot peppercorn hen </s>',
#   'score': 0.00037209055153653026,
#   'token': 1255,
#   'token_str': 'peppercorn'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fish hen </s>',
#   'score': 0.00037002592580392957,
#   'token': 669,
#   'token_str': 'fish'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot jasmine hen </s>',
#   'score': 0.0003656957997009158,
#   'token': 1212,
#   'token_str': 'jasmine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shallot hen </s>',
#   'score': 0.00036566617200151086,
#   'token': 264,
#   'token_str': 'shallot'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless hen </s>',
#   'score': 0.00036475068191066384,
#   'token': 94,
#   'token_str': 'boneless'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sour_cream hen </s>',
#   'score': 0.0003640084178186953,
#   'token': 59,
#   'token_str': 'sour_cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot msg hen </s>',
#   'score': 0.00035931807360611856,
#   'token': 2139,
#   'token_str': 'msg'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg_yolks hen </s>',
#   'score': 0.00035878183552995324,
#   'token': 179,
#   'token_str': 'egg_yolks'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gumbo hen </s>',
#   'score': 0.00035456707701087,
#   'token': 3231,
#   'token_str': 'gumbo'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_base hen </s>',
#   'score': 0.0003526869404595345,
#   'token': 1859,
#   'token_str': 'chicken_base'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sweet_peas hen </s>',
#   'score': 0.00035237090196460485,
#   'token': 2503,
#   'token_str': 'sweet_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsnips hen </s>',
#   'score': 0.00035016966285184026,
#   'token': 845,
#   'token_str': 'parsnips'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_mushrooms hen </s>',
#   'score': 0.00034709437750279903,
#   'token': 2916,
#   'token_str': 'dried_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot jasmine_rice hen </s>',
#   'score': 0.000344287371262908,
#   'token': 1310,
#   'token_str': 'jasmine_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot basmati hen </s>',
#   'score': 0.00034267199225723743,
#   'token': 674,
#   'token_str': 'basmati'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot instant_potato_flakes hen </s>',
#   'score': 0.000339521502610296,
#   'token': 3119,
#   'token_str': 'instant_potato_flakes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork_chops hen </s>',
#   'score': 0.00033588020596653223,
#   'token': 491,
#   'token_str': 'pork_chops'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot red_wine hen </s>',
#   'score': 0.00032552500488236547,
#   'token': 128,
#   'token_str': 'red_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_tomatoes hen </s>',
#   'score': 0.00032390712294727564,
#   'token': 499,
#   'token_str': 'medium_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stew_meat hen </s>',
#   'score': 0.0003210674040019512,
#   'token': 834,
#   'token_str': 'stew_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot allspice hen </s>',
#   'score': 0.00031912102713249624,
#   'token': 232,
#   'token_str': 'allspice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_liver hen </s>',
#   'score': 0.0003150772536173463,
#   'token': 2994,
#   'token_str': 'chicken_liver'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot spring hen </s>',
#   'score': 0.0003128576499875635,
#   'token': 562,
#   'token_str': 'spring'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_breast hen </s>',
#   'score': 0.00031205383129417896,
#   'token': 154,
#   'token_str': 'chicken_breast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot marrow hen </s>',
#   'score': 0.00030660329503007233,
#   'token': 2993,
#   'token_str': 'marrow'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_green_beans hen </s>',
#   'score': 0.0003065698256250471,
#   'token': 1812,
#   'token_str': 'frozen_green_beans'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_sage hen </s>',
#   'score': 0.0003065559430979192,
#   'token': 1089,
#   'token_str': 'dried_sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_parts hen </s>',
#   'score': 0.0003031473024748266,
#   'token': 1905,
#   'token_str': 'chicken_parts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mixed_vegetables hen </s>',
#   'score': 0.00030108881765045226,
#   'token': 745,
#   'token_str': 'mixed_vegetables'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot brown_sugar hen </s>',
#   'score': 0.00029913760954514146,
#   'token': 33,
#   'token_str': 'brown_sugar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wine hen </s>',
#   'score': 0.00029599067056551576,
#   'token': 107,
#   'token_str': 'wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_juice hen </s>',
#   'score': 0.00029169616755098104,
#   'token': 708,
#   'token_str': 'tomato_juice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot russet_potatoes hen </s>',
#   'score': 0.0002899405953940004,
#   'token': 616,
#   'token_str': 'russet_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_soda hen </s>',
#   'score': 0.00028692311025224626,
#   'token': 57,
#   'token_str': 'baking_soda'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot season hen </s>',
#   'score': 0.0002865126880351454,
#   'token': 960,
#   'token_str': 'season'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crumbled_cornbread hen </s>',
#   'score': 0.00028619999648071826,
#   'token': 2929,
#   'token_str': 'crumbled_cornbread'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_basil hen </s>',
#   'score': 0.00028589338762685657,
#   'token': 262,
#   'token_str': 'dried_basil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unbleached_flour hen </s>',
#   'score': 0.00028538028709590435,
#   'token': 1131,
#   'token_str': 'unbleached_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot oyster hen </s>',
#   'score': 0.00028516497695818543,
#   'token': 612,
#   'token_str': 'oyster'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot zucchini hen </s>',
#   'score': 0.0002844487316906452,
#   'token': 170,
#   'token_str': 'zucchini'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ham_hock hen </s>',
#   'score': 0.0002843581314664334,
#   'token': 2066,
#   'token_str': 'ham_hock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot extra_virgin_olive_oil hen </s>',
#   'score': 0.00027903239242732525,
#   'token': 101,
#   'token_str': 'extra_virgin_olive_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_base hen </s>',
#   'score': 0.00027473887894302607,
#   'token': 3108,
#   'token_str': 'beef_base'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beer hen </s>',
#   'score': 0.0002725029771681875,
#   'token': 392,
#   'token_str': 'beer'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot browning hen </s>',
#   'score': 0.0002713454596232623,
#   'token': 2064,
#   'token_str': 'browning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot broccoli hen </s>',
#   'score': 0.00027004850562661886,
#   'token': 197,
#   'token_str': 'broccoli'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fennel hen </s>',
#   'score': 0.00026995991356670856,
#   'token': 300,
#   'token_str': 'fennel'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_onions hen </s>',
#   'score': 0.0002696529554668814,
#   'token': 1127,
#   'token_str': 'white_onions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shrimp hen </s>',
#   'score': 0.00026664932374842465,
#   'token': 145,
#   'token_str': 'shrimp'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bulb hen </s>',
#   'score': 0.00026525690918788314,
#   'token': 2155,
#   'token_str': 'bulb'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork_shoulder hen </s>',
#   'score': 0.00026489701122045517,
#   'token': 776,
#   'token_str': 'pork_shoulder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_stock hen </s>',
#   'score': 0.00026461336528882384,
#   'token': 495,
#   'token_str': 'beef_stock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shallots hen </s>',
#   'score': 0.00026453036116436124,
#   'token': 201,
#   'token_str': 'shallots'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot curry_powder hen </s>',
#   'score': 0.00026167373289354146,
#   'token': 266,
#   'token_str': 'curry_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chives hen </s>',
#   'score': 0.00026127934688702226,
#   'token': 190,
#   'token_str': 'chives'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stuffing_mix hen </s>',
#   'score': 0.0002574218378867954,
#   'token': 739,
#   'token_str': 'stuffing_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot curry hen </s>',
#   'score': 0.0002538433182053268,
#   'token': 525,
#   'token_str': 'curry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sausage hen </s>',
#   'score': 0.00025371721130795777,
#   'token': 161,
#   'token_str': 'sausage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wild_rice hen </s>',
#   'score': 0.00025328024639748037,
#   'token': 863,
#   'token_str': 'wild_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tapioca hen </s>',
#   'score': 0.000252032361458987,
#   'token': 812,
#   'token_str': 'tapioca'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rabbit hen </s>',
#   'score': 0.00025122941588051617,
#   'token': 2102,
#   'token_str': 'rabbit'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_livers hen </s>',
#   'score': 0.0002492144121788442,
#   'token': 1991,
#   'token_str': 'chicken_livers'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_egg_noodles hen </s>',
#   'score': 0.0002491193590685725,
#   'token': 2806,
#   'token_str': 'medium_egg_noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot seafood hen </s>',
#   'score': 0.0002470454201102257,
#   'token': 1200,
#   'token_str': 'seafood'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_potatoes hen </s>',
#   'score': 0.00024301899247802794,
#   'token': 683,
#   'token_str': 'baking_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot granulated_garlic hen </s>',
#   'score': 0.0002428655861876905,
#   'token': 926,
#   'token_str': 'granulated_garlic'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_meal hen </s>',
#   'score': 0.0002424329868517816,
#   'token': 1721,
#   'token_str': 'corn_meal'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_onion hen </s>',
#   'score': 0.0002414439368294552,
#   'token': 398,
#   'token_str': 'white_onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yellow_onions hen </s>',
#   'score': 0.00024120633315760642,
#   'token': 652,
#   'token_str': 'yellow_onions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot potato_flakes hen </s>',
#   'score': 0.00023899486404843628,
#   'token': 2156,
#   'token_str': 'potato_flakes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yellow_onion hen </s>',
#   'score': 0.0002380044461460784,
#   'token': 247,
#   'token_str': 'yellow_onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot olive hen </s>',
#   'score': 0.00023798800248187035,
#   'token': 15,
#   'token_str': 'olive'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mixed_mushrooms hen </s>',
#   'score': 0.0002360506186960265,
#   'token': 1565,
#   'token_str': 'mixed_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_flour hen </s>',
#   'score': 0.0002338463964406401,
#   'token': 907,
#   'token_str': 'corn_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cheddar_cheese hen </s>',
#   'score': 0.00023254440748132765,
#   'token': 64,
#   'token_str': 'cheddar_cheese'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot summer_savory hen </s>',
#   'score': 0.00023243566101882607,
#   'token': 2933,
#   'token_str': 'summer_savory'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scallion hen </s>',
#   'score': 0.00023055083875078708,
#   'token': 476,
#   'token_str': 'scallion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_vinegar hen </s>',
#   'score': 0.00022832003014627844,
#   'token': 291,
#   'token_str': 'white_vinegar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sherry hen </s>',
#   'score': 0.00022821422317065299,
#   'token': 267,
#   'token_str': 'sherry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless_chicken hen </s>',
#   'score': 0.00022545532556250691,
#   'token': 282,
# ...
#   'score': 0.00012568618694785982,
#   'token': 1361,
#   'token_str': 'italian_parsley_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot petite_peas hen </s>',
#   'score': 0.0001247969048563391,
#   'token': 2384,
#   'token_str': 'petite_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless_pork hen </s>',
#   'score': 0.00012468494242057204,
#   'token': 558,
#   'token_str': 'boneless_pork'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_onion hen </s>',
#   'score': 0.00012177925964351743,
#   'token': 209,
#   'token_str': 'green_onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cinnamon hen </s>',
#   'score': 0.00012150148540968075,
#   'token': 37,
#   'token_str': 'cinnamon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scotch hen </s>',
#   'score': 0.0001214608273585327,
#   'token': 1315,
#   'token_str': 'scotch'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mutton hen </s>',
#   'score': 0.00012126019282732159,
#   'token': 2383,
#   'token_str': 'mutton'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fennel_seed hen </s>',
#   'score': 0.00012119024904677644,
#   'token': 975,
#   'token_str': 'fennel_seed'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot brown_rice hen </s>',
#   'score': 0.00011969931802013889,
#   'token': 412,
#   'token_str': 'brown_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vermouth hen </s>',
#   'score': 0.00011950729094678536,
#   'token': 874,
#   'token_str': 'vermouth'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_thyme hen </s>',
#   'score': 0.00011934528447454795,
#   'token': 1473,
#   'token_str': 'ground_thyme'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_vegetables hen </s>',
#   'score': 0.00011890715541085228,
#   'token': 2255,
#   'token_str': 'frozen_vegetables'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_navy_beans hen </s>',
#   'score': 0.0001183919157483615,
#   'token': 2816,
#   'token_str': 'dried_navy_beans'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot buttermilk_biscuits hen </s>',
#   'score': 0.0001173128403024748,
#   'token': 1608,
#   'token_str': 'buttermilk_biscuits'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot hungarian_paprika hen </s>',
#   'score': 0.00011729756806744263,
#   'token': 1542,
#   'token_str': 'hungarian_paprika'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_puree hen </s>',
#   'score': 0.00011669049854390323,
#   'token': 797,
#   'token_str': 'tomato_puree'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pepper_powder hen </s>',
#   'score': 0.00011578566045500338,
#   'token': 2089,
#   'token_str': 'pepper_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_ginger hen </s>',
#   'score': 0.00011565791646717116,
#   'token': 215,
#   'token_str': 'ground_ginger'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cider hen </s>',
#   'score': 0.00011558695405256003,
#   'token': 1511,
#   'token_str': 'cider'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot color hen </s>',
#   'score': 0.00011518739484017715,
#   'token': 1061,
#   'token_str': 'color'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scallops hen </s>',
#   'score': 0.00011474790517240763,
#   'token': 671,
#   'token_str': 'scallops'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_bouillon_granules hen </s>',
#   'score': 0.00011447808356024325,
#   'token': 1410,
#   'token_str': 'chicken_bouillon_granules'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_celery hen </s>',
#   'score': 0.00011415690823923796,
#   'token': 3054,
#   'token_str': 'dried_celery'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_mix hen </s>',
#   'score': 0.00011305339285172522,
#   'token': 924,
#   'token_str': 'baking_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_zucchini hen </s>',
#   'score': 0.00011285137588856742,
#   'token': 649,
#   'token_str': 'medium_zucchini'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot instant_chicken_bouillon hen </s>',
#   'score': 0.00011206230556126684,
#   'token': 1948,
#   'token_str': 'instant_chicken_bouillon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey_meat hen </s>',
#   'score': 0.00011118863767478615,
#   'token': 2491,
#   'token_str': 'turkey_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooking_wine hen </s>',
#   'score': 0.00011056561197619885,
#   'token': 1816,
#   'token_str': 'cooking_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_stew hen </s>',
#   'score': 0.00011026024731108919,
#   'token': 1197,
#   'token_str': 'beef_stew'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mustard hen </s>',
#   'score': 0.00010935609316220507,
#   'token': 54,
#   'token_str': 'mustard'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_black_pepper hen </s>',
#   'score': 0.00010752923844847828,
#   'token': 35,
#   'token_str': 'ground_black_pepper'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gelatin hen </s>',
#   'score': 0.00010702491272240877,
#   'token': 311,
#   'token_str': 'gelatin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cut_up_chicken hen </s>',
#   'score': 0.00010678766557248309,
#   'token': 2858,
#   'token_str': 'cut_up_chicken'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cubed_beef hen </s>',
#   'score': 0.00010644918074831367,
#   'token': 2784,
#   'token_str': 'cubed_beef'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot granulated_sugar hen </s>',
#   'score': 0.00010572473547654226,
#   'token': 110,
#   'token_str': 'granulated_sugar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cake_flour hen </s>',
#   'score': 0.00010509783896850422,
#   'token': 371,
#   'token_str': 'cake_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot whipping_cream hen </s>',
#   'score': 0.00010494245361769572,
#   'token': 171,
#   'token_str': 'whipping_cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot blood hen </s>',
#   'score': 0.00010483776713954285,
#   'token': 1759,
#   'token_str': 'blood'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bass hen </s>',
#   'score': 0.00010476565512362868,
#   'token': 1712,
#   'token_str': 'bass'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot minute_rice hen </s>',
#   'score': 0.00010472095164004713,
#   'token': 1552,
#   'token_str': 'minute_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bacon_drippings hen </s>',
#   'score': 0.00010469294647919014,
#   'token': 1678,
#   'token_str': 'bacon_drippings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pastry hen </s>',
#   'score': 0.00010458048927830532,
#   'token': 287,
#   'token_str': 'pastry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_spinach hen </s>',
#   'score': 0.00010443262726766989,
#   'token': 453,
#   'token_str': 'frozen_spinach'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless_skinless_chicken hen </s>',
#   'score': 0.0001038476184476167,
#   'token': 142,
#   'token_str': 'boneless_skinless_chicken'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boiling_potatoes hen </s>',
#   'score': 0.00010351133823860437,
#   'token': 1487,
#   'token_str': 'boiling_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_round hen </s>',
#   'score': 0.00010345404734835029,
#   'token': 1668,
#   'token_str': 'beef_round'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crescent_rolls hen </s>',
#   'score': 0.000102761056041345,
#   'token': 1116,
#   'token_str': 'crescent_rolls'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sprig hen </s>',
#   'score': 0.00010248150647385046,
#   'token': 547,
#   'token_str': 'sprig'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork_roast hen </s>',
#   'score': 0.0001024664961732924,
#   'token': 1270,
#   'token_str': 'pork_roast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sweet_basil hen </s>',
#   'score': 0.0001011135900625959,
#   'token': 1764,
#   'token_str': 'sweet_basil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_stock hen </s>',
#   'score': 0.00010036266030510888,
#   'token': 141,
#   'token_str': 'chicken_stock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_pepper_seasoning hen </s>',
#   'score': 0.0001003510260488838,
#   'token': 2223,
#   'token_str': 'garlic_pepper_seasoning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_cabbage hen </s>',
#   'score': 0.00010019004548666999,
#   'token': 761,
#   'token_str': 'green_cabbage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_pepper hen </s>',
#   'score': 9.972408588510007e-05,
#   'token': 244,
#   'token_str': 'white_pepper'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot kale hen </s>',
#   'score': 9.969318489311263e-05,
#   'token': 689,
#   'token_str': 'kale'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lardons hen </s>',
#   'score': 9.962490003090352e-05,
#   'token': 2720,
#   'token_str': 'lardons'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot light_corn_syrup hen </s>',
#   'score': 9.956130816135556e-05,
#   'token': 425,
#   'token_str': 'light_corn_syrup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot katakuriko hen </s>',
#   'score': 9.88391402643174e-05,
#   'token': 1076,
#   'token_str': 'katakuriko'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cumin hen </s>',
#   'score': 9.854046220425516e-05,
#   'token': 168,
#   'token_str': 'cumin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot much hen </s>',
#   'score': 9.849100024439394e-05,
#   'token': 1555,
#   'token_str': 'much'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot artichoke_hearts hen </s>',
#   'score': 9.812582720769569e-05,
#   'token': 465,
#   'token_str': 'artichoke_hearts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_bulb hen </s>',
#   'score': 9.79523392743431e-05,
#   'token': 3305,
#   'token_str': 'garlic_bulb'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_stew_meat hen </s>',
#   'score': 9.753357153385878e-05,
#   'token': 1235,
#   'token_str': 'beef_stew_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot kosher hen </s>',
#   'score': 9.75230650510639e-05,
#   'token': 58,
#   'token_str': 'kosher'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pie_pastry hen </s>',
#   'score': 9.723197581479326e-05,
#   'token': 2936,
#   'token_str': 'pie_pastry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot condensed_cream_of_celery_soup hen </s>',
#   'score': 9.654649329604581e-05,
#   'token': 1947,
#   'token_str': 'condensed_cream_of_celery_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot self_rising_flour hen </s>',
#   'score': 9.612539724912494e-05,
#   'token': 1316,
#   'token_str': 'self_rising_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_soup hen </s>',
#   'score': 9.583012433722615e-05,
#   'token': 804,
#   'token_str': 'tomato_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soda hen </s>',
#   'score': 9.56239746301435e-05,
#   'token': 48,
#   'token_str': 'soda'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot radish hen </s>',
#   'score': 9.548437083140016e-05,
#   'token': 1079,
#   'token_str': 'radish'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot partially hen </s>',
#   'score': 9.518021397525445e-05,
#   'token': 1365,
#   'token_str': 'partially'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cilantro hen </s>',
#   'score': 9.498136205365881e-05,
#   'token': 60,
#   'token_str': 'cilantro'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shimeji_mushrooms hen </s>',
#   'score': 9.493037941865623e-05,
#   'token': 2251,
#   'token_str': 'shimeji_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot plum_tomatoes hen </s>',
#   'score': 9.454810060560703e-05,
#   'token': 350,
#   'token_str': 'plum_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crabmeat hen </s>',
#   'score': 9.443861927138641e-05,
#   'token': 597,
#   'token_str': 'crabmeat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rubbed_sage hen </s>',
#   'score': 9.423201117897406e-05,
#   'token': 1531,
#   'token_str': 'rubbed_sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot orzo_pasta hen </s>',
#   'score': 9.408909681951627e-05,
#   'token': 1118,
#   'token_str': 'orzo_pasta'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sliced_carrots hen </s>',
#   'score': 9.302858234150335e-05,
#   'token': 1268,
#   'token_str': 'sliced_carrots'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot liquor hen </s>',
#   'score': 9.283811959903687e-05,
#   'token': 2152,
#   'token_str': 'liquor'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot celery_heart hen </s>',
#   'score': 9.256684279534966e-05,
#   'token': 2951,
#   'token_str': 'celery_heart'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_granules hen </s>',
#   'score': 9.236045298166573e-05,
#   'token': 3089,
#   'token_str': 'garlic_granules'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unbaked_pie_crusts hen </s>',
#   'score': 9.232654701918364e-05,
#   'token': 2937,
#   'token_str': 'unbaked_pie_crusts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_wings hen </s>',
#   'score': 9.226828115060925e-05,
#   'token': 782,
#   'token_str': 'chicken_wings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cucumbers hen </s>',
#   'score': 9.204688831232488e-05,
#   'token': 500,
#   'token_str': 'cucumbers'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dough hen </s>',
#   'score': 9.198791667586192e-05,
#   'token': 431,
#   'token_str': 'dough'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot artichokes hen </s>',
#   'score': 9.173149737762287e-05,
#   'token': 1042,
#   'token_str': 'artichokes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_shoulder hen </s>',
#   'score': 9.154988947557285e-05,
#   'token': 3428,
#   'token_str': 'beef_shoulder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot allspice_berries hen </s>',
#   'score': 9.124429925577715e-05,
#   'token': 1366,
#   'token_str': 'allspice_berries'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot porcini_mushrooms hen </s>',
#   'score': 9.081449388759211e-05,
#   'token': 1349,
#   'token_str': 'porcini_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yams hen </s>',
#   'score': 9.001775470096618e-05,
#   'token': 2042,
#   'token_str': 'yams'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot slab_bacon hen </s>',
#   'score': 8.984241139842197e-05,
#   'token': 2151,
#   'token_str': 'slab_bacon'}]

# %% [markdown]
# # Validation

# %%
from src.validation import validate
import pandas as pd
ks=[1, 2, 5, 10, 20, 50, 100]
validation_result = validate(fill_mask_recipe.model, tokenizer, 
                             ks=ks,
                             device=-1,
                             limit=5000, relative_base_path='../')
# Out:
# 382it [13:42,  2.15s/it]

# %%
df = pd.DataFrame([validation_result], columns=ks, index=['accuracy'])
(df*100).style.format('{:,.1f}%'.format)
# Out:
# <style  type="text/css" >
# </style><table id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >10</th>        <th class="col_heading level0 col4" >20</th>        <th class="col_heading level0 col5" >50</th>        <th class="col_heading level0 col6" >100</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col0" class="data row0 col0" >20.1%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col1" class="data row0 col1" >28.2%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col2" class="data row0 col2" >39.3%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col3" class="data row0 col3" >48.1%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col4" class="data row0 col4" >56.9%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col5" class="data row0 col5" >68.3%</td>
#                         <td id="T_1083f4e2_24fb_11eb_82b5_3920859d39f7row0_col6" class="data row0 col6" >75.7%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # The Model (Transformer)

# %% [markdown]
# [<img src="https://miro.medium.com/max/700/0*ViwaI3Vvbnd-CJSQ.png">](https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270)
# https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270

# %%
model = fill_mask_recipe.model

# %%
fill_mask_recipe('dough pizza_sauce <mask>')
# Out:
# [{'sequence': '<s> dough pizza_sauce mozzarella_cheese </s>',
#   'score': 0.23033706843852997,
#   'token': 156,
#   'token_str': 'mozzarella_cheese'},
#  {'sequence': '<s> dough pizza_sauce pepperoni </s>',
#   'score': 0.20622113347053528,
#   'token': 733,
#   'token_str': 'pepperoni'},
#  {'sequence': '<s> dough pizza_sauce olive_oil </s>',
#   'score': 0.0663054808974266,
#   'token': 12,
#   'token_str': 'olive_oil'},
#  {'sequence': '<s> dough pizza_sauce cheese </s>',
#   'score': 0.06030401214957237,
#   'token': 21,
#   'token_str': 'cheese'},
#  {'sequence': '<s> dough pizza_sauce parmesan </s>',
#   'score': 0.03762682154774666,
#   'token': 49,
#   'token_str': 'parmesan'},
#  {'sequence': '<s> dough pizza_sauce mozzarella </s>',
#   'score': 0.03502006083726883,
#   'token': 125,
#   'token_str': 'mozzarella'},
#  {'sequence': '<s> dough pizza_sauce meatballs </s>',
#   'score': 0.012741947546601295,
#   'token': 1279,
#   'token_str': 'meatballs'},
#  {'sequence': '<s> dough pizza_sauce pepperoni_slices </s>',
#   'score': 0.011586504988372326,
#   'token': 2059,
#   'token_str': 'pepperoni_slices'},
#  {'sequence': '<s> dough pizza_sauce italian_cheese_blend </s>',
#   'score': 0.01147366501390934,
#   'token': 1829,
#   'token_str': 'italian_cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce breadstick </s>',
#   'score': 0.010369864292442799,
#   'token': 2976,
#   'token_str': 'breadstick'},
#  {'sequence': '<s> dough pizza_sauce sausages </s>',
#   'score': 0.009140487760305405,
#   'token': 766,
#   'token_str': 'sausages'},
#  {'sequence': '<s> dough pizza_sauce bacon </s>',
#   'score': 0.00897382665425539,
#   'token': 90,
#   'token_str': 'bacon'},
#  {'sequence': '<s> dough pizza_sauce oregano </s>',
#   'score': 0.008889516815543175,
#   'token': 65,
#   'token_str': 'oregano'},
#  {'sequence': '<s> dough pizza_sauce grated_parmesan_cheese </s>',
#   'score': 0.00880028959363699,
#   'token': 127,
#   'token_str': 'grated_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce italian_sausage </s>',
#   'score': 0.0076999664306640625,
#   'token': 529,
#   'token_str': 'italian_sausage'},
#  {'sequence': '<s> dough pizza_sauce salt </s>',
#   'score': 0.006830540951341391,
#   'token': 5,
#   'token_str': 'salt'},
#  {'sequence': '<s> dough pizza_sauce dried_oregano </s>',
#   'score': 0.0064731165766716,
#   'token': 163,
#   'token_str': 'dried_oregano'},
#  {'sequence': '<s> dough pizza_sauce provolone_cheese </s>',
#   'score': 0.006322799250483513,
#   'token': 748,
#   'token_str': 'provolone_cheese'},
#  {'sequence': '<s> dough pizza_sauce sausage </s>',
#   'score': 0.005986591335386038,
#   'token': 161,
#   'token_str': 'sausage'},
#  {'sequence': '<s> dough pizza_sauce extra_virgin_olive_oil </s>',
#   'score': 0.0056977784261107445,
#   'token': 101,
#   'token_str': 'extra_virgin_olive_oil'},
#  {'sequence': '<s> dough pizza_sauce hot_dogs </s>',
#   'score': 0.0055270022712647915,
#   'token': 1221,
#   'token_str': 'hot_dogs'},
#  {'sequence': '<s> dough pizza_sauce butter </s>',
#   'score': 0.005109061952680349,
#   'token': 7,
#   'token_str': 'butter'},
#  {'sequence': '<s> dough pizza_sauce cooking_spray </s>',
#   'score': 0.005068848375231028,
#   'token': 199,
#   'token_str': 'cooking_spray'},
#  {'sequence': '<s> dough pizza_sauce parmesan_cheese </s>',
#   'score': 0.0047526550479233265,
#   'token': 63,
#   'token_str': 'parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce cheese_blend </s>',
#   'score': 0.004453964065760374,
#   'token': 869,
#   'token_str': 'cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce cream_cheese </s>',
#   'score': 0.003995680250227451,
#   'token': 62,
#   'token_str': 'cream_cheese'},
#  {'sequence': '<s> dough pizza_sauce olive </s>',
#   'score': 0.0035061798989772797,
#   'token': 15,
#   'token_str': 'olive'},
#  {'sequence': '<s> dough pizza_sauce mozzarella_string_cheese </s>',
#   'score': 0.003325254423543811,
#   'token': 3265,
#   'token_str': 'mozzarella_string_cheese'},
#  {'sequence': '<s> dough pizza_sauce egg </s>',
#   'score': 0.0029907089192420244,
#   'token': 29,
#   'token_str': 'egg'},
#  {'sequence': '<s> dough pizza_sauce italian_cheese </s>',
#   'score': 0.002945713000372052,
#   'token': 1647,
#   'token_str': 'italian_cheese'},
#  {'sequence': '<s> dough pizza_sauce black_pepper </s>',
#   'score': 0.00278812600299716,
#   'token': 19,
#   'token_str': 'black_pepper'},
#  {'sequence': '<s> dough pizza_sauce basil_leaves </s>',
#   'score': 0.0027358499355614185,
#   'token': 238,
#   'token_str': 'basil_leaves'},
#  {'sequence': '<s> dough pizza_sauce flour </s>',
#   'score': 0.002715807408094406,
#   'token': 10,
#   'token_str': 'flour'},
#  {'sequence': '<s> dough pizza_sauce cornmeal </s>',
#   'score': 0.0025921077467501163,
#   'token': 259,
#   'token_str': 'cornmeal'},
#  {'sequence': '<s> dough pizza_sauce mozzarella_balls </s>',
#   'score': 0.002572515746578574,
#   'token': 2051,
#   'token_str': 'mozzarella_balls'},
#  {'sequence': '<s> dough pizza_sauce italian_seasoning </s>',
#   'score': 0.0025557116605341434,
#   'token': 377,
#   'token_str': 'italian_seasoning'},
#  {'sequence': '<s> dough pizza_sauce corn_meal </s>',
#   'score': 0.002527666976675391,
#   'token': 1721,
#   'token_str': 'corn_meal'},
#  {'sequence': '<s> dough pizza_sauce pesto </s>',
#   'score': 0.0025068114046007395,
#   'token': 565,
#   'token_str': 'pesto'},
#  {'sequence': '<s> dough pizza_sauce semolina </s>',
#   'score': 0.0024929088540375233,
#   'token': 1181,
#   'token_str': 'semolina'},
#  {'sequence': '<s> dough pizza_sauce ground_beef </s>',
#   'score': 0.0023224647156894207,
#   'token': 114,
#   'token_str': 'ground_beef'},
#  {'sequence': '<s> dough pizza_sauce salami </s>',
#   'score': 0.002191012492403388,
#   'token': 968,
#   'token_str': 'salami'},
#  {'sequence': '<s> dough pizza_sauce fresh_mozzarella </s>',
#   'score': 0.0021510825026780367,
#   'token': 3198,
#   'token_str': 'fresh_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce loaves </s>',
#   'score': 0.0019883164204657078,
#   'token': 1526,
#   'token_str': 'loaves'},
#  {'sequence': '<s> dough pizza_sauce jack_cheese </s>',
#   'score': 0.0018718816572800279,
#   'token': 246,
#   'token_str': 'jack_cheese'},
#  {'sequence': '<s> dough pizza_sauce garlic </s>',
#   'score': 0.0018674035090953112,
#   'token': 8,
#   'token_str': 'garlic'},
#  {'sequence': '<s> dough pizza_sauce american_cheese </s>',
#   'score': 0.0018469293136149645,
#   'token': 700,
#   'token_str': 'american_cheese'},
#  {'sequence': '<s> dough pizza_sauce ground_black_pepper </s>',
#   'score': 0.0018286118283867836,
#   'token': 35,
#   'token_str': 'ground_black_pepper'},
#  {'sequence': '<s> dough pizza_sauce meat </s>',
#   'score': 0.0018094576662406325,
#   'token': 370,
#   'token_str': 'meat'},
#  {'sequence': '<s> dough pizza_sauce ham </s>',
#   'score': 0.0017440526280552149,
#   'token': 239,
#   'token_str': 'ham'},
#  {'sequence': '<s> dough pizza_sauce red_bell_pepper </s>',
#   'score': 0.0017125963931903243,
#   'token': 162,
#   'token_str': 'red_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce temperature </s>',
#   'score': 0.0016658548265695572,
#   'token': 135,
#   'token_str': 'temperature'},
#  {'sequence': '<s> dough pizza_sauce bread </s>',
#   'score': 0.0016417220467701554,
#   'token': 74,
#   'token_str': 'bread'},
#  {'sequence': '<s> dough pizza_sauce sea_salt </s>',
#   'score': 0.0016082418151199818,
#   'token': 137,
#   'token_str': 'sea_salt'},
#  {'sequence': '<s> dough pizza_sauce button_mushrooms </s>',
#   'score': 0.0015988430241122842,
#   'token': 657,
#   'token_str': 'button_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce muenster_cheese </s>',
#   'score': 0.0015787804732099175,
#   'token': 1771,
#   'token_str': 'muenster_cheese'},
#  {'sequence': '<s> dough pizza_sauce mushrooms </s>',
#   'score': 0.0015685668913647532,
#   'token': 70,
#   'token_str': 'mushrooms'},
#  {'sequence': '<s> dough pizza_sauce prosciutto </s>',
#   'score': 0.0014899814268574119,
#   'token': 528,
#   'token_str': 'prosciutto'},
#  {'sequence': '<s> dough pizza_sauce basil </s>',
#   'score': 0.0014802288496866822,
#   'token': 77,
#   'token_str': 'basil'},
#  {'sequence': '<s> dough pizza_sauce garlic_salt </s>',
#   'score': 0.0014777182368561625,
#   'token': 335,
#   'token_str': 'garlic_salt'},
#  {'sequence': '<s> dough pizza_sauce goat_cheese </s>',
#   'score': 0.0014520360855385661,
#   'token': 457,
#   'token_str': 'goat_cheese'},
#  {'sequence': '<s> dough pizza_sauce gouda_cheese </s>',
#   'score': 0.0014457973884418607,
#   'token': 1360,
#   'token_str': 'gouda_cheese'},
#  {'sequence': '<s> dough pizza_sauce chiffonade </s>',
#   'score': 0.0014310282422229648,
#   'token': 1229,
#   'token_str': 'chiffonade'},
#  {'sequence': '<s> dough pizza_sauce sliced_ham </s>',
#   'score': 0.0014169146306812763,
#   'token': 1682,
#   'token_str': 'sliced_ham'},
#  {'sequence': '<s> dough pizza_sauce cheddar </s>',
#   'score': 0.0013926711399108171,
#   'token': 55,
#   'token_str': 'cheddar'},
#  {'sequence': '<s> dough pizza_sauce kosher_salt </s>',
#   'score': 0.0013011251576244831,
#   'token': 53,
#   'token_str': 'kosher_salt'},
#  {'sequence': '<s> dough pizza_sauce kalamata_olives </s>',
#   'score': 0.0012798004318028688,
#   'token': 768,
#   'token_str': 'kalamata_olives'},
#  {'sequence': '<s> dough pizza_sauce sauce_mix </s>',
#   'score': 0.0012732502073049545,
#   'token': 1852,
#   'token_str': 'sauce_mix'},
#  {'sequence': '<s> dough pizza_sauce coarse_salt </s>',
#   'score': 0.0012523512123152614,
#   'token': 348,
#   'token_str': 'coarse_salt'},
#  {'sequence': '<s> dough pizza_sauce chicken_breasts </s>',
#   'score': 0.0012148505775257945,
#   'token': 104,
#   'token_str': 'chicken_breasts'},
#  {'sequence': '<s> dough pizza_sauce cheddar_cheese </s>',
#   'score': 0.0012083787005394697,
#   'token': 64,
#   'token_str': 'cheddar_cheese'},
#  {'sequence': '<s> dough pizza_sauce chicken </s>',
#   'score': 0.0011814002646133304,
#   'token': 24,
#   'token_str': 'chicken'},
#  {'sequence': '<s> dough pizza_sauce vegetable_oil </s>',
#   'score': 0.0011381858494132757,
#   'token': 40,
#   'token_str': 'vegetable_oil'},
#  {'sequence': '<s> dough pizza_sauce asiago_cheese </s>',
#   'score': 0.001137454411946237,
#   'token': 1051,
#   'token_str': 'asiago_cheese'},
#  {'sequence': '<s> dough pizza_sauce cheeses </s>',
#   'score': 0.0011275638826191425,
#   'token': 2072,
#   'token_str': 'cheeses'},
#  {'sequence': '<s> dough pizza_sauce tomato </s>',
#   'score': 0.0010365641210228205,
#   'token': 50,
#   'token_str': 'tomato'},
#  {'sequence': '<s> dough pizza_sauce sugar </s>',
#   'score': 0.0010119595099240541,
#   'token': 9,
#   'token_str': 'sugar'},
#  {'sequence': '<s> dough pizza_sauce oil </s>',
#   'score': 0.0009941986063495278,
#   'token': 76,
#   'token_str': 'oil'},
#  {'sequence': '<s> dough pizza_sauce garlic_powder </s>',
#   'score': 0.0009782484266906977,
#   'token': 84,
#   'token_str': 'garlic_powder'},
#  {'sequence': '<s> dough pizza_sauce pizza_crust </s>',
#   'score': 0.0009764806600287557,
#   'token': 1075,
#   'token_str': 'pizza_crust'},
#  {'sequence': '<s> dough pizza_sauce bread_flour </s>',
#   'score': 0.0009737071231938899,
#   'token': 464,
#   'token_str': 'bread_flour'},
#  {'sequence': '<s> dough pizza_sauce flour_for_dusting </s>',
#   'score': 0.0009624750819057226,
#   'token': 1115,
#   'token_str': 'flour_for_dusting'},
#  {'sequence': '<s> dough pizza_sauce buffalo_mozzarella </s>',
#   'score': 0.0009462565649300814,
#   'token': 3194,
#   'token_str': 'buffalo_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce mortadella </s>',
#   'score': 0.0009378018439747393,
#   'token': 3148,
#   'token_str': 'mortadella'},
#  {'sequence': '<s> dough pizza_sauce wheat_flour </s>',
#   'score': 0.0009172718273475766,
#   'token': 258,
#   'token_str': 'wheat_flour'},
#  {'sequence': '<s> dough pizza_sauce fontina_cheese </s>',
#   'score': 0.0009145296644419432,
#   'token': 1137,
#   'token_str': 'fontina_cheese'},
#  {'sequence': '<s> dough pizza_sauce ricotta_cheese </s>',
#   'score': 0.0009035203838720918,
#   'token': 328,
#   'token_str': 'ricotta_cheese'},
#  {'sequence': '<s> dough pizza_sauce sweet_italian_sausage </s>',
#   'score': 0.0009007088956423104,
#   'token': 1453,
#   'token_str': 'sweet_italian_sausage'},
#  {'sequence': '<s> dough pizza_sauce hamburger </s>',
#   'score': 0.0008933432982303202,
#   'token': 429,
#   'token_str': 'hamburger'},
#  {'sequence': '<s> dough pizza_sauce mild_italian_sausage </s>',
#   'score': 0.0008571103098802269,
#   'token': 1940,
#   'token_str': 'mild_italian_sausage'},
#  {'sequence': '<s> dough pizza_sauce red_onion </s>',
#   'score': 0.0008521813433617353,
#   'token': 120,
#   'token_str': 'red_onion'},
#  {'sequence': '<s> dough pizza_sauce tomato_sauce </s>',
#   'score': 0.0008476406801491976,
#   'token': 186,
#   'token_str': 'tomato_sauce'},
#  {'sequence': '<s> dough pizza_sauce velveeta </s>',
#   'score': 0.0008475493523292243,
#   'token': 578,
#   'token_str': 'velveeta'},
#  {'sequence': '<s> dough pizza_sauce ground_sausage </s>',
#   'score': 0.0008350852294825017,
#   'token': 2247,
#   'token_str': 'ground_sausage'},
#  {'sequence': '<s> dough pizza_sauce salted_butter </s>',
#   'score': 0.000833544007036835,
#   'token': 716,
#   'token_str': 'salted_butter'},
#  {'sequence': '<s> dough pizza_sauce table_salt </s>',
#   'score': 0.0008317525498569012,
#   'token': 955,
#   'token_str': 'table_salt'},
#  {'sequence': '<s> dough pizza_sauce monterey_jack_cheese </s>',
#   'score': 0.0008129601483233273,
#   'token': 313,
#   'token_str': 'monterey_jack_cheese'},
#  {'sequence': '<s> dough pizza_sauce focaccia </s>',
#   'score': 0.0008051073527894914,
#   'token': 2759,
#   'token_str': 'focaccia'},
#  {'sequence': '<s> dough pizza_sauce minced_garlic </s>',
#   'score': 0.0007776582497172058,
#   'token': 134,
#   'token_str': 'minced_garlic'},
#  {'sequence': '<s> dough pizza_sauce pitted_black_olives </s>',
#   'score': 0.0007611666806042194,
#   'token': 1580,
#   'token_str': 'pitted_black_olives'},
#  {'sequence': '<s> dough pizza_sauce arugula </s>',
#   'score': 0.0007458722102455795,
#   'token': 432,
#   'token_str': 'arugula'},
#  {'sequence': '<s> dough pizza_sauce black_olives </s>',
#   'score': 0.0007371646934188902,
#   'token': 309,
#   'token_str': 'black_olives'},
#  {'sequence': '<s> dough pizza_sauce garlic_cloves </s>',
#   'score': 0.0007278392440639436,
#   'token': 38,
#   'token_str': 'garlic_cloves'},
#  {'sequence': '<s> dough pizza_sauce wheat </s>',
#   'score': 0.0007028005784377456,
#   'token': 147,
#   'token_str': 'wheat'},
#  {'sequence': '<s> dough pizza_sauce mushroom </s>',
#   'score': 0.0006976888980716467,
#   'token': 164,
#   'token_str': 'mushroom'},
#  {'sequence': '<s> dough pizza_sauce swiss_cheese </s>',
#   'score': 0.0006932328687980771,
#   'token': 338,
#   'token_str': 'swiss_cheese'},
#  {'sequence': '<s> dough pizza_sauce cooked_ham </s>',
#   'score': 0.0006904914043843746,
#   'token': 767,
#   'token_str': 'cooked_ham'},
#  {'sequence': '<s> dough pizza_sauce pepper </s>',
#   'score': 0.0006790859042666852,
#   'token': 6,
#   'token_str': 'pepper'},
#  {'sequence': '<s> dough pizza_sauce sauce_tomato </s>',
#   'score': 0.000674867129418999,
#   'token': 3433,
#   'token_str': 'sauce_tomato'},
#  {'sequence': '<s> dough pizza_sauce italian_salad_dressing </s>',
#   'score': 0.0006505902274511755,
#   'token': 919,
#   'token_str': 'italian_salad_dressing'},
#  {'sequence': '<s> dough pizza_sauce oregano_leaves </s>',
#   'score': 0.0006429890636354685,
#   'token': 655,
#   'token_str': 'oregano_leaves'},
#  {'sequence': '<s> dough pizza_sauce gorgonzola </s>',
#   'score': 0.0006401809514500201,
#   'token': 970,
#   'token_str': 'gorgonzola'},
#  {'sequence': '<s> dough pizza_sauce melted_butter </s>',
#   'score': 0.0006400909624062479,
#   'token': 270,
#   'token_str': 'melted_butter'},
#  {'sequence': '<s> dough pizza_sauce smoked_sausage </s>',
#   'score': 0.0006163206999190152,
#   'token': 1196,
#   'token_str': 'smoked_sausage'},
#  {'sequence': '<s> dough pizza_sauce cooked_bacon </s>',
#   'score': 0.0006109523819759488,
#   'token': 898,
#   'token_str': 'cooked_bacon'},
#  {'sequence': '<s> dough pizza_sauce pepperoncini </s>',
#   'score': 0.0006028968491591513,
#   'token': 1502,
#   'token_str': 'pepperoncini'},
#  {'sequence': '<s> dough pizza_sauce lean_ground_beef </s>',
#   'score': 0.0006009305361658335,
#   'token': 334,
#   'token_str': 'lean_ground_beef'},
#  {'sequence': '<s> dough pizza_sauce yellow_cornmeal </s>',
#   'score': 0.0005996192921884358,
#   'token': 816,
#   'token_str': 'yellow_cornmeal'},
#  {'sequence': '<s> dough pizza_sauce yeast_packet </s>',
#   'score': 0.0005936656380072236,
#   'token': 2331,
#   'token_str': 'yeast_packet'},
#  {'sequence': '<s> dough pizza_sauce spinach </s>',
#   'score': 0.0005879770615138113,
#   'token': 113,
#   'token_str': 'spinach'},
#  {'sequence': '<s> dough pizza_sauce onion </s>',
#   'score': 0.0005736671155318618,
#   'token': 11,
#   'token_str': 'onion'},
#  {'sequence': '<s> dough pizza_sauce unsalted_butter </s>',
#   'score': 0.0005634500412270427,
#   'token': 44,
#   'token_str': 'unsalted_butter'},
#  {'sequence': '<s> dough pizza_sauce feta_cheese </s>',
#   'score': 0.0005514401709660888,
#   'token': 280,
#   'token_str': 'feta_cheese'},
#  {'sequence': '<s> dough pizza_sauce eggs </s>',
#   'score': 0.0005450962344184518,
#   'token': 18,
#   'token_str': 'eggs'},
#  {'sequence': '<s> dough pizza_sauce ricotta </s>',
#   'score': 0.0005422536050900817,
#   'token': 289,
#   'token_str': 'ricotta'},
#  {'sequence': '<s> dough pizza_sauce kraft_grated_parmesan_cheese </s>',
#   'score': 0.0005332928849384189,
#   'token': 997,
#   'token_str': 'kraft_grated_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce gruyere_cheese </s>',
#   'score': 0.0005329163977876306,
#   'token': 757,
#   'token_str': 'gruyere_cheese'},
#  {'sequence': '<s> dough pizza_sauce noodles </s>',
#   'score': 0.0005293461726978421,
#   'token': 183,
#   'token_str': 'noodles'},
#  {'sequence': '<s> dough pizza_sauce romano_cheese </s>',
#   'score': 0.0005277188611216843,
#   'token': 588,
#   'token_str': 'romano_cheese'},
#  {'sequence': '<s> dough pizza_sauce crumbled_goat_cheese </s>',
#   'score': 0.0005053014610894024,
#   'token': 1763,
#   'token_str': 'crumbled_goat_cheese'},
#  {'sequence': '<s> dough pizza_sauce pizza_seasoning </s>',
#   'score': 0.0004987310967408121,
#   'token': 2895,
#   'token_str': 'pizza_seasoning'},
#  {'sequence': '<s> dough pizza_sauce olive_oil_spray </s>',
#   'score': 0.0004935865290462971,
#   'token': 1835,
#   'token_str': 'olive_oil_spray'},
#  {'sequence': '<s> dough pizza_sauce red_pepper </s>',
#   'score': 0.0004917930928058922,
#   'token': 66,
#   'token_str': 'red_pepper'},
#  {'sequence': '<s> dough pizza_sauce peppers </s>',
#   'score': 0.0004898211336694658,
#   'token': 91,
#   'token_str': 'peppers'},
#  {'sequence': '<s> dough pizza_sauce mexican_cheese </s>',
#   'score': 0.0004760834272019565,
#   'token': 1218,
#   'token_str': 'mexican_cheese'},
#  {'sequence': '<s> dough pizza_sauce mayonnaise </s>',
#   'score': 0.00046515362919308245,
#   'token': 81,
#   'token_str': 'mayonnaise'},
#  {'sequence': '<s> dough pizza_sauce sliced_black_olives </s>',
#   'score': 0.00045917622628621757,
#   'token': 934,
#   'token_str': 'sliced_black_olives'},
#  {'sequence': '<s> dough pizza_sauce hot_sausage </s>',
#   'score': 0.0004576362553052604,
#   'token': 2501,
#   'token_str': 'hot_sausage'},
#  {'sequence': '<s> dough pizza_sauce white_sugar </s>',
#   'score': 0.00045678316382691264,
#   'token': 117,
#   'token_str': 'white_sugar'},
#  {'sequence': '<s> dough pizza_sauce shredded_mozzarella_cheese </s>',
#   'score': 0.0004447486426215619,
#   'token': 1811,
#   'token_str': 'shredded_mozzarella_cheese'},
#  {'sequence': '<s> dough pizza_sauce pecorino_romano_cheese </s>',
#   'score': 0.00043674162589013577,
#   'token': 1305,
#   'token_str': 'pecorino_romano_cheese'},
#  {'sequence': '<s> dough pizza_sauce processed_cheese </s>',
#   'score': 0.00043589965207502246,
#   'token': 1587,
#   'token_str': 'processed_cheese'},
#  {'sequence': '<s> dough pizza_sauce water </s>',
#   'score': 0.00043206120608374476,
#   'token': 13,
#   'token_str': 'water'},
#  {'sequence': '<s> dough pizza_sauce cooked_chicken </s>',
#   'score': 0.00042935964302159846,
#   'token': 316,
#   'token_str': 'cooked_chicken'},
#  {'sequence': '<s> dough pizza_sauce pancetta </s>',
#   'score': 0.0004273687081877142,
#   'token': 815,
#   'token_str': 'pancetta'},
#  {'sequence': '<s> dough pizza_sauce grated_romano_cheese </s>',
#   'score': 0.00042488204780966043,
#   'token': 1285,
#   'token_str': 'grated_romano_cheese'},
#  {'sequence': '<s> dough pizza_sauce brown_sugar </s>',
#   'score': 0.0004234288935549557,
#   'token': 33,
#   'token_str': 'brown_sugar'},
#  {'sequence': '<s> dough pizza_sauce spam </s>',
#   'score': 0.000420470634708181,
#   'token': 2607,
#   'token_str': 'spam'},
#  {'sequence': '<s> dough pizza_sauce easy </s>',
#   'score': 0.00041879600030370057,
#   'token': 2556,
#   'token_str': 'easy'},
#  {'sequence': '<s> dough pizza_sauce deli_ham </s>',
#   'score': 0.0004169355670455843,
#   'token': 1272,
#   'token_str': 'deli_ham'},
#  {'sequence': '<s> dough pizza_sauce crumbled_blue_cheese </s>',
#   'score': 0.00041507769492454827,
#   'token': 982,
#   'token_str': 'crumbled_blue_cheese'},
#  {'sequence': '<s> dough pizza_sauce smoked_salmon </s>',
#   'score': 0.0004059226193930954,
#   'token': 995,
#   'token_str': 'smoked_salmon'},
#  {'sequence': '<s> dough pizza_sauce chicken_breast </s>',
#   'score': 0.0004058771301060915,
#   'token': 154,
#   'token_str': 'chicken_breast'},
#  {'sequence': '<s> dough pizza_sauce seasonings </s>',
#   'score': 0.00040242966497316957,
#   'token': 1652,
#   'token_str': 'seasonings'},
#  {'sequence': '<s> dough pizza_sauce coarse_sea_salt </s>',
#   'score': 0.0004010825650766492,
#   'token': 1122,
#   'token_str': 'coarse_sea_salt'},
#  {'sequence': '<s> dough pizza_sauce roast_beef </s>',
#   'score': 0.0003904227924067527,
#   'token': 1258,
#   'token_str': 'roast_beef'},
#  {'sequence': '<s> dough pizza_sauce sliced_mushrooms </s>',
#   'score': 0.0003898098657373339,
#   'token': 359,
#   'token_str': 'sliced_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce dried_rosemary </s>',
#   'score': 0.0003805575834121555,
#   'token': 573,
#   'token_str': 'dried_rosemary'},
#  {'sequence': '<s> dough pizza_sauce cheese_spread </s>',
#   'score': 0.0003774160286411643,
#   'token': 1000,
#   'token_str': 'cheese_spread'},
#  {'sequence': '<s> dough pizza_sauce parsley </s>',
#   'score': 0.0003742888511624187,
#   'token': 36,
#   'token_str': 'parsley'},
#  {'sequence': '<s> dough pizza_sauce chorizo </s>',
#   'score': 0.000368308974429965,
#   'token': 1038,
#   'token_str': 'chorizo'},
#  {'sequence': '<s> dough pizza_sauce artichoke_hearts </s>',
#   'score': 0.00036818900844082236,
#   'token': 465,
#   'token_str': 'artichoke_hearts'},
#  {'sequence': '<s> dough pizza_sauce seasoned_salt </s>',
#   'score': 0.000366489082807675,
#   'token': 755,
#   'token_str': 'seasoned_salt'},
#  {'sequence': '<s> dough pizza_sauce ground </s>',
#   'score': 0.0003661790397018194,
#   'token': 14,
#   'token_str': 'ground'},
#  {'sequence': '<s> dough pizza_sauce shaved_parmesan_cheese </s>',
#   'score': 0.00036461977288126945,
#   'token': 1957,
#   'token_str': 'shaved_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce parmigiano </s>',
#   'score': 0.0003632753505371511,
#   'token': 1189,
#   'token_str': 'parmigiano'},
#  {'sequence': '<s> dough pizza_sauce baby_spinach </s>',
#   'score': 0.0003618915216065943,
#   'token': 376,
#   'token_str': 'baby_spinach'},
#  {'sequence': '<s> dough pizza_sauce green_bell_peppers </s>',
#   'score': 0.00035455479519441724,
#   'token': 568,
#   'token_str': 'green_bell_peppers'},
#  {'sequence': '<s> dough pizza_sauce canola_oil </s>',
#   'score': 0.00035169816692359746,
#   'token': 152,
#   'token_str': 'canola_oil'},
#  {'sequence': '<s> dough pizza_sauce grana_padano </s>',
#   'score': 0.00034667528234422207,
#   'token': 2022,
#   'token_str': 'grana_padano'},
#  {'sequence': '<s> dough pizza_sauce dried_tomatoes </s>',
#   'score': 0.0003428146883379668,
#   'token': 1503,
#   'token_str': 'dried_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce smoked_mozzarella </s>',
#   'score': 0.00034199183573946357,
#   'token': 2236,
#   'token_str': 'smoked_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce eggplant </s>',
#   'score': 0.00033977956627495587,
#   'token': 493,
#   'token_str': 'eggplant'},
#  {'sequence': '<s> dough pizza_sauce cheese_slices </s>',
#   'score': 0.00033738318597897887,
#   'token': 1330,
#   'token_str': 'cheese_slices'},
#  {'sequence': '<s> dough pizza_sauce thyme_leaves </s>',
#   'score': 0.00033082510344684124,
#   'token': 384,
#   'token_str': 'thyme_leaves'},
#  {'sequence': '<s> dough pizza_sauce tomatoes </s>',
#   'score': 0.00032449784339405596,
#   'token': 26,
#   'token_str': 'tomatoes'},
#  {'sequence': '<s> dough pizza_sauce genoa_salami </s>',
#   'score': 0.0003235163167119026,
#   'token': 2266,
#   'token_str': 'genoa_salami'},
#  {'sequence': '<s> dough pizza_sauce ground_pork </s>',
#   'score': 0.0003231815935578197,
#   'token': 469,
#   'token_str': 'ground_pork'},
#  {'sequence': '<s> dough pizza_sauce onions </s>',
#   'score': 0.000321587169310078,
#   'token': 30,
#   'token_str': 'onions'},
#  {'sequence': '<s> dough pizza_sauce havarti_cheese </s>',
#   'score': 0.0003183704102411866,
#   'token': 2164,
#   'token_str': 'havarti_cheese'},
#  {'sequence': '<s> dough pizza_sauce much </s>',
#   'score': 0.0003163326473440975,
#   'token': 1555,
#   'token_str': 'much'},
#  {'sequence': '<s> dough pizza_sauce fontina </s>',
#   'score': 0.00031518476316705346,
#   'token': 994,
#   'token_str': 'fontina'},
#  {'sequence': '<s> dough pizza_sauce ground_chuck </s>',
#   'score': 0.0003105369978584349,
#   'token': 942,
#   'token_str': 'ground_chuck'},
#  {'sequence': '<s> dough pizza_sauce warm_water </s>',
#   'score': 0.0003093552659265697,
#   'token': 296,
#   'token_str': 'warm_water'},
#  {'sequence': '<s> dough pizza_sauce string_cheese </s>',
#   'score': 0.0003088052326347679,
#   'token': 3036,
#   'token_str': 'string_cheese'},
#  {'sequence': '<s> dough pizza_sauce veggies </s>',
#   'score': 0.0003054476110264659,
#   'token': 2111,
#   'token_str': 'veggies'},
#  {'sequence': '<s> dough pizza_sauce crust </s>',
#   'score': 0.00029998310492374003,
#   'token': 362,
#   'token_str': 'crust'},
#  {'sequence': '<s> dough pizza_sauce beef </s>',
#   'score': 0.0002991259389091283,
#   'token': 188,
#   'token_str': 'beef'},
#  {'sequence': '<s> dough pizza_sauce english_muffins </s>',
#   'score': 0.0002989236090797931,
#   'token': 1204,
#   'token_str': 'english_muffins'},
#  {'sequence': '<s> dough pizza_sauce canadian_bacon </s>',
#   'score': 0.00029687158530578017,
#   'token': 1635,
#   'token_str': 'canadian_bacon'},
#  {'sequence': '<s> dough pizza_sauce roma_tomatoes </s>',
#   'score': 0.00029621648718602955,
#   'token': 579,
#   'token_str': 'roma_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce pesto_sauce </s>',
#   'score': 0.0002948451729025692,
#   'token': 1048,
#   'token_str': 'pesto_sauce'},
#  {'sequence': '<s> dough pizza_sauce hot_water </s>',
#   'score': 0.0002944095467682928,
#   'token': 342,
#   'token_str': 'hot_water'},
#  {'sequence': '<s> dough pizza_sauce sour_cream </s>',
#   'score': 0.0002926828165072948,
#   'token': 59,
#   'token_str': 'sour_cream'},
#  {'sequence': '<s> dough pizza_sauce pepper_cheese </s>',
#   'score': 0.0002915812365245074,
#   'token': 1302,
#   'token_str': 'pepper_cheese'},
#  {'sequence': '<s> dough pizza_sauce honey </s>',
#   'score': 0.00028873924748040736,
#   'token': 71,
#   'token_str': 'honey'},
#  {'sequence': '<s> dough pizza_sauce giardiniera </s>',
#   'score': 0.0002850480959750712,
#   'token': 2469,
#   'token_str': 'giardiniera'},
#  {'sequence': '<s> dough pizza_sauce hard_salami </s>',
#   'score': 0.0002815231855493039,
#   'token': 2865,
#   'token_str': 'hard_salami'},
#  {'sequence': '<s> dough pizza_sauce medium_tomatoes </s>',
#   'score': 0.0002792656305246055,
#   'token': 499,
#   'token_str': 'medium_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce flatbread </s>',
#   'score': 0.0002771411382127553,
#   'token': 2605,
#   'token_str': 'flatbread'},
#  {'sequence': '<s> dough pizza_sauce cracked_black_pepper </s>',
#   'score': 0.00027650067931972444,
#   'token': 479,
#   'token_str': 'cracked_black_pepper'},
#  {'sequence': '<s> dough pizza_sauce semolina_flour </s>',
#   'score': 0.0002750978746917099,
#   'token': 1755,
#   'token_str': 'semolina_flour'},
#  {'sequence': '<s> dough pizza_sauce romano </s>',
#   'score': 0.00027104601031169295,
#   'token': 531,
#   'token_str': 'romano'},
#  {'sequence': '<s> dough pizza_sauce pitted_kalamata_olives </s>',
#   'score': 0.00026765535585582256,
#   'token': 1143,
#   'token_str': 'pitted_kalamata_olives'},
#  {'sequence': '<s> dough pizza_sauce dried_tomato </s>',
#   'score': 0.00026356015587225556,
#   'token': 2602,
#   'token_str': 'dried_tomato'},
#  {'sequence': '<s> dough pizza_sauce scallions </s>',
#   'score': 0.00026305305073037744,
#   'token': 167,
#   'token_str': 'scallions'},
#  {'sequence': '<s> dough pizza_sauce boneless_chicken_breast </s>',
#   'score': 0.0002619497827254236,
#   'token': 461,
#   'token_str': 'boneless_chicken_breast'},
#  {'sequence': '<s> dough pizza_sauce poppy_seed </s>',
#   'score': 0.0002617451245896518,
#   'token': 1120,
#   'token_str': 'poppy_seed'},
#  {'sequence': '<s> dough pizza_sauce margarine </s>',
#   'score': 0.00026151747442781925,
#   'token': 80,
#   'token_str': 'margarine'},
#  {'sequence': '<s> dough pizza_sauce bocconcini </s>',
#   'score': 0.00026140050613321364,
#   'token': 2412,
#   'token_str': 'bocconcini'},
#  {'sequence': '<s> dough pizza_sauce hot_peppers </s>',
#   'score': 0.0002612343232613057,
#   'token': 1810,
#   'token_str': 'hot_peppers'},
#  {'sequence': '<s> dough pizza_sauce frozen_meatballs </s>',
#   'score': 0.0002589421928860247,
#   'token': 2108,
#   'token_str': 'frozen_meatballs'},
#  {'sequence': '<s> dough pizza_sauce italian_bread </s>',
#   'score': 0.00025492985150776803,
#   'token': 799,
#   'token_str': 'italian_bread'},
#  {'sequence': '<s> dough pizza_sauce olives </s>',
#   'score': 0.00025450572138652205,
#   'token': 196,
#   'token_str': 'olives'},
#  {'sequence': '<s> dough pizza_sauce white_cheese </s>',
#   'score': 0.00025443348567932844,
#   'token': 2750,
#   'token_str': 'white_cheese'},
#  {'sequence': '<s> dough pizza_sauce green_pepper </s>',
#   'score': 0.00024966226192191243,
#   'token': 235,
#   'token_str': 'green_pepper'},
#  {'sequence': '<s> dough pizza_sauce cheddar_cheese_soup </s>',
#   'score': 0.00024791364558041096,
#   'token': 1700,
#   'token_str': 'cheddar_cheese_soup'},
#  {'sequence': '<s> dough pizza_sauce tomato_paste </s>',
#   'score': 0.00024756707716733217,
#   'token': 189,
#   'token_str': 'tomato_paste'},
#  {'sequence': '<s> dough pizza_sauce filling </s>',
#   'score': 0.0002465487632434815,
#   'token': 418,
#   'token_str': 'filling'},
#  {'sequence': '<s> dough pizza_sauce crimini_mushrooms </s>',
#   'score': 0.00024371191102545708,
#   'token': 2525,
#   'token_str': 'crimini_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce paste </s>',
#   'score': 0.0002397217322140932,
#   'token': 570,
#   'token_str': 'paste'},
#  {'sequence': '<s> dough pizza_sauce potatoes </s>',
#   'score': 0.00023965429863892496,
#   'token': 52,
#   'token_str': 'potatoes'},
#  {'sequence': '<s> dough pizza_sauce yellow_squash </s>',
#   'score': 0.00023854711616877466,
#   'token': 661,
#   'token_str': 'yellow_squash'},
#  {'sequence': '<s> dough pizza_sauce ciabatta </s>',
#   'score': 0.0002383593819104135,
#   'token': 1186,
#   'token_str': 'ciabatta'},
#  {'sequence': '<s> dough pizza_sauce artichokes </s>',
#   'score': 0.0002379772486165166,
#   'token': 1042,
#   'token_str': 'artichokes'},
#  {'sequence': '<s> dough pizza_sauce green_peppers </s>',
#   'score': 0.00023787195095792413,
#   'token': 676,
#   'token_str': 'green_peppers'},
#  {'sequence': '<s> dough pizza_sauce toast </s>',
#   'score': 0.00023645114561077207,
#   'token': 1286,
#   'token_str': 'toast'},
#  {'sequence': '<s> dough pizza_sauce cherry_tomatoes </s>',
#   'score': 0.00023389964189846069,
#   'token': 308,
#   'token_str': 'cherry_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce cilantro_leaves </s>',
#   'score': 0.00023170886561274529,
#   'token': 368,
#   'token_str': 'cilantro_leaves'},
#  {'sequence': '<s> dough pizza_sauce virgin_olive_oil </s>',
#   'score': 0.00022758623526897281,
#   'token': 100,
#   'token_str': 'virgin_olive_oil'},
#  {'sequence': '<s> dough pizza_sauce turkey_sausage </s>',
#   'score': 0.00022662895207758993,
#   'token': 1271,
#   'token_str': 'turkey_sausage'},
#  {'sequence': '<s> dough pizza_sauce vegetables </s>',
#   'score': 0.0002256116276839748,
#   'token': 420,
#   'token_str': 'vegetables'},
#  {'sequence': '<s> dough pizza_sauce gouda </s>',
#   'score': 0.00022489650291390717,
#   'token': 2207,
#   'token_str': 'gouda'},
#  {'sequence': '<s> dough pizza_sauce pitted_olives </s>',
#   'score': 0.00022259562683757395,
#   'token': 3024,
#   'token_str': 'pitted_olives'},
#  {'sequence': '<s> dough pizza_sauce ripe_olives </s>',
#   'score': 0.00022160603839438409,
#   'token': 1046,
#   'token_str': 'ripe_olives'},
#  {'sequence': '<s> dough pizza_sauce rounds </s>',
#   'score': 0.00021812928025610745,
#   'token': 778,
#   'token_str': 'rounds'},
#  {'sequence': '<s> dough pizza_sauce cheddar_cheese_blend </s>',
#   'score': 0.00021784291311632842,
#   'token': 3084,
#   'token_str': 'cheddar_cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce cilantro </s>',
#   'score': 0.00021679431665688753,
#   'token': 60,
#   'token_str': 'cilantro'},
#  {'sequence': '<s> dough pizza_sauce smoked_ham </s>',
#   'score': 0.00021590835240203887,
#   'token': 860,
#   'token_str': 'smoked_ham'},
#  {'sequence': '<s> dough pizza_sauce salt_and_ground_black_pepper </s>',
#   'score': 0.00021449870837386698,
#   'token': 533,
#   'token_str': 'salt_and_ground_black_pepper'},
#  {'sequence': '<s> dough pizza_sauce hot_italian_sausages </s>',
#   'score': 0.00021386284788604826,
#   'token': 3093,
#   'token_str': 'hot_italian_sausages'},
#  {'sequence': '<s> dough pizza_sauce hummus </s>',
#   'score': 0.000212589991861023,
#   'token': 1452,
#   'token_str': 'hummus'},
#  {'sequence': '<s> dough pizza_sauce ground_meat </s>',
#   'score': 0.00021222060604486614,
#   'token': 1561,
#   'token_str': 'ground_meat'},
#  {'sequence': '<s> dough pizza_sauce tomato_puree </s>',
#   'score': 0.00021100159210618585,
#   'token': 797,
#   'token_str': 'tomato_puree'},
#  {'sequence': '<s> dough pizza_sauce jack </s>',
#   'score': 0.00021017617837060243,
#   'token': 1431,
#   'token_str': 'jack'},
#  {'sequence': '<s> dough pizza_sauce italian_turkey_sausage </s>',
#   'score': 0.00020869246509391814,
#   'token': 2366,
#   'token_str': 'italian_turkey_sausage'},
#  {'sequence': '<s> dough pizza_sauce bbq_sauce </s>',
#   'score': 0.00020742337801493704,
#   'token': 1493,
#   'token_str': 'bbq_sauce'},
#  {'sequence': '<s> dough pizza_sauce turkey </s>',
#   'score': 0.00020731164840981364,
#   'token': 206,
#   'token_str': 'turkey'},
#  {'sequence': '<s> dough pizza_sauce mushroom_caps </s>',
#   'score': 0.0002049594186246395,
#   'token': 1188,
#   'token_str': 'mushroom_caps'},
#  {'sequence': '<s> dough pizza_sauce dough </s>',
#   'score': 0.00020270240202080458,
#   'token': 431,
#   'token_str': 'dough'},
#  {'sequence': '<s> dough pizza_sauce sesame_seeds </s>',
#   'score': 0.0002026224829023704,
#   'token': 234,
#   'token_str': 'sesame_seeds'},
#  {'sequence': '<s> dough pizza_sauce tapenade </s>',
#   'score': 0.00020111969206482172,
#   'token': 2855,
#   'token_str': 'tapenade'},
#  {'sequence': '<s> dough pizza_sauce french_bread </s>',
#   'score': 0.00020025279081892222,
#   'token': 576,
#   'token_str': 'french_bread'},
#  {'sequence': '<s> dough pizza_sauce kielbasa </s>',
#   'score': 0.00019899886683560908,
#   'token': 1087,
#   'token_str': 'kielbasa'},
#  {'sequence': '<s> dough pizza_sauce meatloaf </s>',
#   'score': 0.0001989508600672707,
#   'token': 2340,
#   'token_str': 'meatloaf'},
#  {'sequence': '<s> dough pizza_sauce chicken_strips </s>',
#   'score': 0.00019876063743140548,
#   'token': 2357,
#   'token_str': 'chicken_strips'},
#  {'sequence': '<s> dough pizza_sauce sausage_links </s>',
#   'score': 0.000197368543012999,
#   'token': 1206,
#   'token_str': 'sausage_links'},
#  {'sequence': '<s> dough pizza_sauce iron </s>',
#   'score': 0.00019646956934593618,
#   'token': 3218,
#   'token_str': 'iron'},
#  {'sequence': '<s> dough pizza_sauce macaroni </s>',
#   'score': 0.00019481730123516172,
#   'token': 360,
#   'token_str': 'macaroni'},
#  {'sequence': '<s> dough pizza_sauce white_onion </s>',
#   'score': 0.00019461443298496306,
#   'token': 398,
#   'token_str': 'white_onion'},
#  {'sequence': '<s> dough pizza_sauce parsley_flakes </s>',
#   'score': 0.0001940826914506033,
#   'token': 727,
#   'token_str': 'parsley_flakes'},
#  {'sequence': '<s> dough pizza_sauce sliced_salami </s>',
#   'score': 0.00018998965970240533,
#   'token': 3157,
#   'token_str': 'sliced_salami'},
#  {'sequence': '<s> dough pizza_sauce asparagus </s>',
#   'score': 0.00018949131481349468,
#   'token': 307,
#   'token_str': 'asparagus'},
#  {'sequence': '<s> dough pizza_sauce ingredients </s>',
#   'score': 0.00018308908329345286,
#   'token': 1424,
#   'token_str': 'ingredients'},
#  {'sequence': '<s> dough pizza_sauce links </s>',
#   'score': 0.00018184998771175742,
#   'token': 1701,
#   'token_str': 'links'},
#  {'sequence': '<s> dough pizza_sauce herbs </s>',
#   'score': 0.00018082578026223928,
#   'token': 656,
#   'token_str': 'herbs'},
#  {'sequence': '<s> dough pizza_sauce colby_cheese </s>',
#   'score': 0.0001762797764968127,
#   'token': 1768,
#   'token_str': 'colby_cheese'},
#  {'sequence': '<s> dough pizza_sauce granulated_garlic </s>',
#   'score': 0.00017519509128760546,
#   'token': 926,
#   'token_str': 'granulated_garlic'},
#  {'sequence': '<s> dough pizza_sauce boneless_skinless_chicken_breasts </s>',
#   'score': 0.0001727286580717191,
#   'token': 233,
#   'token_str': 'boneless_skinless_chicken_breasts'},
#  {'sequence': '<s> dough pizza_sauce cooked_meatballs </s>',
#   'score': 0.0001720441650832072,
#   'token': 3495,
#   'token_str': 'cooked_meatballs'},
#  {'sequence': '<s> dough pizza_sauce freshly_grated_parmesan </s>',
#   'score': 0.00017077622760552913,
#   'token': 437,
#   'token_str': 'freshly_grated_parmesan'},
#  {'sequence': '<s> dough pizza_sauce white_bread_flour </s>',
#   'score': 0.000170502025866881,
#   'token': 2429,
#   'token_str': 'white_bread_flour'},
#  {'sequence': '<s> dough pizza_sauce basil_leaf </s>',
#   'score': 0.00017036036297213286,
#   'token': 1211,
#   'token_str': 'basil_leaf'},
#  {'sequence': '<s> dough pizza_sauce rosemary </s>',
#   'score': 0.00016835049609653652,
#   'token': 155,
#   'token_str': 'rosemary'},
#  {'sequence': '<s> dough pizza_sauce rolls </s>',
#   'score': 0.0001669576158747077,
#   'token': 422,
#   'token_str': 'rolls'},
#  {'sequence': '<s> dough pizza_sauce cherry_peppers </s>',
#   'score': 0.00016463760402984917,
#   'token': 2244,
#   'token_str': 'cherry_peppers'},
#  {'sequence': '<s> dough pizza_sauce ground_turkey </s>',
#   'score': 0.00016453464922960848,
#   'token': 396,
#   'token_str': 'ground_turkey'},
#  {'sequence': '<s> dough pizza_sauce roasted_garlic </s>',
#   'score': 0.00016152470197994262,
#   'token': 925,
#   'token_str': 'roasted_garlic'},
#  {'sequence': '<s> dough pizza_sauce in_water </s>',
#   'score': 0.00015873806842137128,
#   'token': 585,
#   'token_str': 'in_water'},
#  {'sequence': '<s> dough pizza_sauce banana_peppers </s>',
#   'score': 0.00015853284276090562,
#   'token': 2509,
#   'token_str': 'banana_peppers'},
#  {'sequence': '<s> dough pizza_sauce ranch_dressing </s>',
#   'score': 0.000156655180035159,
#   'token': 623,
#   'token_str': 'ranch_dressing'},
#  {'sequence': '<s> dough pizza_sauce fine_salt </s>',
#   'score': 0.00015618407633155584,
#   'token': 932,
#   'token_str': 'fine_salt'},
#  {'sequence': '<s> dough pizza_sauce sundried_tomato </s>',
#   'score': 0.00015545912901870906,
#   'token': 914,
#   'token_str': 'sundried_tomato'},
#  {'sequence': '<s> dough pizza_sauce franks </s>',
#   'score': 0.00015466302284039557,
#   'token': 1021,
#   'token_str': 'franks'},
#  {'sequence': '<s> dough pizza_sauce red_pepper_flakes </s>',
#   'score': 0.00015167547098826617,
#   'token': 146,
#   'token_str': 'red_pepper_flakes'},
#  {'sequence': '<s> dough pizza_sauce olive_oil_flavored_cooking_spray </s>',
#   'score': 0.0001512064627604559,
#   'token': 2515,
#   'token_str': 'olive_oil_flavored_cooking_spray'},
#  {'sequence': '<s> dough pizza_sauce blue_cheese </s>',
#   'score': 0.0001502195227658376,
#   'token': 463,
#   'token_str': 'blue_cheese'},
#  {'sequence': '<s> dough pizza_sauce marinara_sauce </s>',
#   'score': 0.000147875864058733,
#   'token': 750,
#   'token_str': 'marinara_sauce'},
#  {'sequence': '<s> dough pizza_sauce garlic_minced </s>',
#   'score': 0.00014685539645142853,
#   'token': 88,
#   'token_str': 'garlic_minced'},
#  {'sequence': '<s> dough pizza_sauce yellow_onion </s>',
#   'score': 0.00014457793440669775,
#   'token': 247,
#   'token_str': 'yellow_onion'},
#  {'sequence': '<s> dough pizza_sauce garlic_bread </s>',
#   'score': 0.0001430131815141067,
#   'token': 3477,
#   'token_str': 'garlic_bread'},
#  {'sequence': '<s> dough pizza_sauce dried_basil </s>',
#   'score': 0.0001425813534297049,
#   'token': 262,
#   'token_str': 'dried_basil'},
#  {'sequence': '<s> dough pizza_sauce cooked_pasta </s>',
#   'score': 0.00014202954480424523,
#   'token': 1695,
#   'token_str': 'cooked_pasta'},
#  {'sequence': '<s> dough pizza_sauce pie_crust_mix </s>',
#   'score': 0.0001380259927827865,
#   'token': 3242,
#   'token_str': 'pie_crust_mix'},
#  {'sequence': '<s> dough pizza_sauce jalapeno </s>',
#   'score': 0.00013797472638543695,
#   'token': 143,
#   'token_str': 'jalapeno'},
#  {'sequence': '<s> dough pizza_sauce pizza_sauce </s>',
#   'score': 0.00013738196867052466,
#   'token': 856,
#   'token_str': 'pizza_sauce'},
#  {'sequence': '<s> dough pizza_sauce sundried_tomatoes </s>',
#   'score': 0.00013716498506255448,
#   'token': 638,
#   'token_str': 'sundried_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce rosemary_leaves </s>',
#   'score': 0.00013645534636452794,
#   'token': 859,
#   'token_str': 'rosemary_leaves'},
#  {'sequence': '<s> dough pizza_sauce part-skim_mozzarella_cheese </s>',
#   'score': 0.00013627692533191293,
#   'token': 3369,
#   'token_str': 'part-skim_mozzarella_cheese'},
#  {'sequence': '<s> dough pizza_sauce alfredo_sauce </s>',
#   'score': 0.0001360228779958561,
#   'token': 1359,
#   'token_str': 'alfredo_sauce'},
#  {'sequence': '<s> dough pizza_sauce potato </s>',
#   'score': 0.00013545711408369243,
#   'token': 208,
#   'token_str': 'potato'},
#  {'sequence': '<s> dough pizza_sauce parmigiano_reggiano_cheese </s>',
#   'score': 0.00013465931988321245,
#   'token': 1856,
#   'token_str': 'parmigiano_reggiano_cheese'},
#  {'sequence': '<s> dough pizza_sauce yellow_bell_pepper </s>',
#   'score': 0.00013400506577454507,
#   'token': 586,
#   'token_str': 'yellow_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce tuna </s>',
#   'score': 0.0001338943256996572,
#   'token': 517,
#   'token_str': 'tuna'},
#  {'sequence': '<s> dough pizza_sauce pork </s>',
#   'score': 0.00013264692097436637,
#   'token': 180,
#   'token_str': 'pork'},
#  {'sequence': '<s> dough pizza_sauce plum_tomatoes </s>',
#   'score': 0.0001315743720624596,
#   'token': 350,
#   'token_str': 'plum_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce crumbled_gorgonzola </s>',
#   'score': 0.00013103761011734605,
#   'token': 1889,
#   'token_str': 'crumbled_gorgonzola'},
#  {'sequence': '<s> dough pizza_sauce biscuits </s>',
#   'score': 0.0001309786457568407,
#   'token': 899,
#   'token_str': 'biscuits'},
#  {'sequence': '<s> dough pizza_sauce mexican_cheese_blend </s>',
#   'score': 0.00013007076631765813,
#   'token': 1841,
#   'token_str': 'mexican_cheese_blend'},
#  {'sequence': '<s> dough pizza_sauce yellow_peppers </s>',
#   'score': 0.00012970830721314996,
#   'token': 1518,
#   'token_str': 'yellow_peppers'},
#  {'sequence': '<s> dough pizza_sauce active_dry_yeast </s>',
#   'score': 0.00012953253462910652,
#   'token': 389,
#   'token_str': 'active_dry_yeast'},
#  {'sequence': '<s> dough pizza_sauce walnuts </s>',
#   'score': 0.0001286846090806648,
#   'token': 129,
#   'token_str': 'walnuts'},
#  {'sequence': '<s> dough pizza_sauce cheese_cubes </s>',
#   'score': 0.00012863960000686347,
#   'token': 3128,
#   'token_str': 'cheese_cubes'},
#  {'sequence': '<s> dough pizza_sauce philadelphia_cream_cheese </s>',
#   'score': 0.000128276165924035,
#   'token': 591,
#   'token_str': 'philadelphia_cream_cheese'},
#  {'sequence': '<s> dough pizza_sauce cake_flour </s>',
#   'score': 0.00012752834300044924,
#   'token': 371,
#   'token_str': 'cake_flour'},
#  {'sequence': '<s> dough pizza_sauce sausage_casings </s>',
#   'score': 0.00012698002683464438,
#   'token': 1461,
#   'token_str': 'sausage_casings'},
#  {'sequence': '<s> dough pizza_sauce sesame </s>',
#   'score': 0.00012661085929721594,
#   'token': 106,
#   'token_str': 'sesame'},
#  {'sequence': '<s> dough pizza_sauce cookie </s>',
#   'score': 0.00012494494148995727,
#   'token': 770,
#   'token_str': 'cookie'},
#  {'sequence': '<s> dough pizza_sauce sardines </s>',
#   'score': 0.00012429768685251474,
#   'token': 1853,
#   'token_str': 'sardines'},
#  {'sequence': '<s> dough pizza_sauce herb </s>',
#   'score': 0.00012315034109633416,
#   'token': 978,
#   'token_str': 'herb'},
#  {'sequence': '<s> dough pizza_sauce fresh_parmesan_cheese </s>',
#   'score': 0.00012174264702480286,
#   'token': 2433,
#   'token_str': 'fresh_parmesan_cheese'},
#  {'sequence': '<s> dough pizza_sauce nori_seaweed </s>',
#   'score': 0.00012043077731505036,
#   'token': 1760,
#   'token_str': 'nori_seaweed'},
#  {'sequence': '<s> dough pizza_sauce boiled_ham </s>',
#   'score': 0.00012004091695416719,
#   'token': 2319,
#   'token_str': 'boiled_ham'},
#  {'sequence': '<s> dough pizza_sauce green_bell_pepper </s>',
#   'score': 0.00012001195864286274,
#   'token': 223,
#   'token_str': 'green_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce dry_yeast </s>',
#   'score': 0.00011822799569927156,
#   'token': 288,
#   'token_str': 'dry_yeast'},
#  {'sequence': '<s> dough pizza_sauce ragu </s>',
#   'score': 0.00011722595809260383,
#   'token': 2683,
#   'token_str': 'ragu'},
#  {'sequence': '<s> dough pizza_sauce white_flour </s>',
#   'score': 0.0001166657020803541,
#   'token': 698,
#   'token_str': 'white_flour'},
#  {'sequence': '<s> dough pizza_sauce roasted_turkey_breast </s>',
#   'score': 0.00011666369391605258,
#   'token': 2210,
#   'token_str': 'roasted_turkey_breast'},
#  {'sequence': '<s> dough pizza_sauce raw_cane_sugar </s>',
#   'score': 0.0001159740932052955,
#   'token': 2563,
#   'token_str': 'raw_cane_sugar'},
#  {'sequence': '<s> dough pizza_sauce broccoli </s>',
#   'score': 0.0001157238584710285,
#   'token': 197,
#   'token_str': 'broccoli'},
#  {'sequence': '<s> dough pizza_sauce italian_herbs </s>',
#   'score': 0.00011559756239876151,
#   'token': 2286,
#   'token_str': 'italian_herbs'},
#  {'sequence': '<s> dough pizza_sauce corn </s>',
#   'score': 0.00011444622941780835,
#   'token': 109,
#   'token_str': 'corn'},
#  {'sequence': '<s> dough pizza_sauce chuck </s>',
#   'score': 0.00011409934086259454,
#   'token': 823,
#   'token_str': 'chuck'},
#  {'sequence': '<s> dough pizza_sauce yeast </s>',
#   'score': 0.00011394396278774366,
#   'token': 191,
#   'token_str': 'yeast'},
#  {'sequence': '<s> dough pizza_sauce broccoli_rabe </s>',
#   'score': 0.00011389903374947608,
#   'token': 2140,
#   'token_str': 'broccoli_rabe'},
#  {'sequence': '<s> dough pizza_sauce prepared_pizza_crust </s>',
#   'score': 0.00011270989489275962,
#   'token': 2043,
#   'token_str': 'prepared_pizza_crust'},
#  {'sequence': '<s> dough pizza_sauce ground_sirloin </s>',
#   'score': 0.00011198186984984204,
#   'token': 1403,
#   'token_str': 'ground_sirloin'},
#  {'sequence': '<s> dough pizza_sauce seasoning_salt </s>',
#   'score': 0.00011112541687907651,
#   'token': 556,
#   'token_str': 'seasoning_salt'},
#  {'sequence': '<s> dough pizza_sauce brie_cheese </s>',
#   'score': 0.00011094799265265465,
#   'token': 1111,
#   'token_str': 'brie_cheese'},
#  {'sequence': '<s> dough pizza_sauce fine_sea_salt </s>',
#   'score': 0.00011054348578909412,
#   'token': 806,
#   'token_str': 'fine_sea_salt'},
#  {'sequence': '<s> dough pizza_sauce ground_oregano </s>',
#   'score': 0.00011022992839571089,
#   'token': 2371,
#   'token_str': 'ground_oregano'},
#  {'sequence': '<s> dough pizza_sauce sharp_white_cheddar_cheese </s>',
#   'score': 0.00010996151104336604,
#   'token': 2359,
#   'token_str': 'sharp_white_cheddar_cheese'},
#  {'sequence': '<s> dough pizza_sauce brown </s>',
#   'score': 0.00010927604307653382,
#   'token': 27,
#   'token_str': 'brown'},
#  {'sequence': '<s> dough pizza_sauce zucchini </s>',
#   'score': 0.00010836806904990226,
#   'token': 170,
#   'token_str': 'zucchini'},
#  {'sequence': '<s> dough pizza_sauce aubergine </s>',
#   'score': 0.00010656702215783298,
#   'token': 2698,
#   'token_str': 'aubergine'},
#  {'sequence': '<s> dough pizza_sauce sweet_basil_leaves </s>',
#   'score': 0.00010643985297065228,
#   'token': 3131,
# ...
#   'score': 8.102595893433318e-05,
#   'token': 2274,
#   'token_str': 'boursin'},
#  {'sequence': '<s> dough pizza_sauce pita_bread </s>',
#   'score': 8.022537804208696e-05,
#   'token': 1093,
#   'token_str': 'pita_bread'},
#  {'sequence': '<s> dough pizza_sauce ketchup </s>',
#   'score': 7.991981692612171e-05,
#   'token': 222,
#   'token_str': 'ketchup'},
#  {'sequence': '<s> dough pizza_sauce olive_oil_cooking_spray </s>',
#   'score': 7.96938402345404e-05,
#   'token': 2717,
#   'token_str': 'olive_oil_cooking_spray'},
#  {'sequence': '<s> dough pizza_sauce summer_squash </s>',
#   'score': 7.820028986316174e-05,
#   'token': 1450,
#   'token_str': 'summer_squash'},
#  {'sequence': '<s> dough pizza_sauce corn_kernels </s>',
#   'score': 7.780884334351867e-05,
#   'token': 503,
#   'token_str': 'corn_kernels'},
#  {'sequence': '<s> dough pizza_sauce colby_jack_cheese </s>',
#   'score': 7.762159657431766e-05,
#   'token': 2075,
#   'token_str': 'colby_jack_cheese'},
#  {'sequence': '<s> dough pizza_sauce carrots </s>',
#   'score': 7.72859129938297e-05,
#   'token': 67,
#   'token_str': 'carrots'},
#  {'sequence': '<s> dough pizza_sauce dried_parsley </s>',
#   'score': 7.644481956958771e-05,
#   'token': 445,
#   'token_str': 'dried_parsley'},
#  {'sequence': '<s> dough pizza_sauce seasoned_bread_crumbs </s>',
#   'score': 7.627042214153334e-05,
#   'token': 1043,
#   'token_str': 'seasoned_bread_crumbs'},
#  {'sequence': '<s> dough pizza_sauce cherry </s>',
#   'score': 7.626053411513567e-05,
#   'token': 402,
#   'token_str': 'cherry'},
#  {'sequence': '<s> dough pizza_sauce instant_yeast </s>',
#   'score': 7.623980491189286e-05,
#   'token': 1166,
#   'token_str': 'instant_yeast'},
#  {'sequence': '<s> dough pizza_sauce crisco </s>',
#   'score': 7.622199336765334e-05,
#   'token': 908,
#   'token_str': 'crisco'},
#  {'sequence': '<s> dough pizza_sauce sliced_green_olives </s>',
#   'score': 7.589688175357878e-05,
#   'token': 2914,
#   'token_str': 'sliced_green_olives'},
#  {'sequence': '<s> dough pizza_sauce baby_spinach_leaves </s>',
#   'score': 7.58685200707987e-05,
#   'token': 814,
#   'token_str': 'baby_spinach_leaves'},
#  {'sequence': '<s> dough pizza_sauce pastrami </s>',
#   'score': 7.579764496767893e-05,
#   'token': 2644,
#   'token_str': 'pastrami'},
#  {'sequence': '<s> dough pizza_sauce cubed_ham </s>',
#   'score': 7.536839984823018e-05,
#   'token': 2417,
#   'token_str': 'cubed_ham'},
#  {'sequence': '<s> dough pizza_sauce top_sirloin_steak </s>',
#   'score': 7.482989167328924e-05,
#   'token': 2098,
#   'token_str': 'top_sirloin_steak'},
#  {'sequence': '<s> dough pizza_sauce vegetable </s>',
#   'score': 7.470774289686233e-05,
#   'token': 32,
#   'token_str': 'vegetable'},
#  {'sequence': '<s> dough pizza_sauce batter </s>',
#   'score': 7.411102706100792e-05,
#   'token': 1480,
#   'token_str': 'batter'},
#  {'sequence': '<s> dough pizza_sauce sliced_tomatoes </s>',
#   'score': 7.321903831325471e-05,
#   'token': 2009,
#   'token_str': 'sliced_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce capsicum </s>',
#   'score': 7.290542271221057e-05,
#   'token': 1249,
#   'token_str': 'capsicum'},
#  {'sequence': '<s> dough pizza_sauce muffin </s>',
#   'score': 7.260484562721103e-05,
#   'token': 1101,
#   'token_str': 'muffin'},
#  {'sequence': '<s> dough pizza_sauce heavy_cream </s>',
#   'score': 7.20256139175035e-05,
#   'token': 93,
#   'token_str': 'heavy_cream'},
#  {'sequence': '<s> dough pizza_sauce boneless_chicken_breast_halves </s>',
#   'score': 7.200398249551654e-05,
#   'token': 627,
#   'token_str': 'boneless_chicken_breast_halves'},
#  {'sequence': '<s> dough pizza_sauce chorizo_sausage </s>',
#   'score': 7.157430081861094e-05,
#   'token': 1012,
#   'token_str': 'chorizo_sausage'},
#  {'sequence': '<s> dough pizza_sauce bell_pepper </s>',
#   'score': 7.118615030776709e-05,
#   'token': 82,
#   'token_str': 'bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce italian_pork_sausage </s>',
#   'score': 7.096984336385503e-05,
#   'token': 2883,
#   'token_str': 'italian_pork_sausage'},
#  {'sequence': '<s> dough pizza_sauce cream </s>',
#   'score': 7.071703294059262e-05,
#   'token': 22,
#   'token_str': 'cream'},
#  {'sequence': '<s> dough pizza_sauce pineapple </s>',
#   'score': 6.98655640007928e-05,
#   'token': 149,
#   'token_str': 'pineapple'},
#  {'sequence': '<s> dough pizza_sauce fennel </s>',
#   'score': 6.98184740031138e-05,
#   'token': 300,
#   'token_str': 'fennel'},
#  {'sequence': '<s> dough pizza_sauce sourdough_starter </s>',
#   'score': 6.918040162418038e-05,
#   'token': 1997,
#   'token_str': 'sourdough_starter'},
#  {'sequence': '<s> dough pizza_sauce beans </s>',
#   'score': 6.902704626554623e-05,
#   'token': 98,
#   'token_str': 'beans'},
#  {'sequence': '<s> dough pizza_sauce sharp_cheddar_cheese </s>',
#   'score': 6.868538912385702e-05,
#   'token': 301,
#   'token_str': 'sharp_cheddar_cheese'},
#  {'sequence': '<s> dough pizza_sauce top_sirloin </s>',
#   'score': 6.799512630095705e-05,
#   'token': 1602,
#   'token_str': 'top_sirloin'},
#  {'sequence': '<s> dough pizza_sauce avocado </s>',
#   'score': 6.751606269972399e-05,
#   'token': 257,
#   'token_str': 'avocado'},
#  {'sequence': '<s> dough pizza_sauce banana </s>',
#   'score': 6.734141061315313e-05,
#   'token': 274,
#   'token_str': 'banana'},
#  {'sequence': '<s> dough pizza_sauce heirloom_tomatoes </s>',
#   'score': 6.69189466862008e-05,
#   'token': 2050,
#   'token_str': 'heirloom_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce brisket </s>',
#   'score': 6.675685290247202e-05,
#   'token': 979,
#   'token_str': 'brisket'},
#  {'sequence': '<s> dough pizza_sauce bologna </s>',
#   'score': 6.671401206403971e-05,
#   'token': 3040,
#   'token_str': 'bologna'},
#  {'sequence': '<s> dough pizza_sauce butter_oil </s>',
#   'score': 6.639937782892957e-05,
#   'token': 2455,
#   'token_str': 'butter_oil'},
#  {'sequence': '<s> dough pizza_sauce sweet_pepper </s>',
#   'score': 6.636291072936729e-05,
#   'token': 1599,
#   'token_str': 'sweet_pepper'},
#  {'sequence': '<s> dough pizza_sauce japanese_eggplants </s>',
#   'score': 6.605849921470508e-05,
#   'token': 1748,
#   'token_str': 'japanese_eggplants'},
#  {'sequence': '<s> dough pizza_sauce firm_tofu </s>',
#   'score': 6.60093137412332e-05,
#   'token': 594,
#   'token_str': 'firm_tofu'},
#  {'sequence': '<s> dough pizza_sauce spice </s>',
#   'score': 6.590898556169122e-05,
#   'token': 546,
#   'token_str': 'spice'},
#  {'sequence': '<s> dough pizza_sauce anchovies </s>',
#   'score': 6.580541230505332e-05,
#   'token': 1259,
#   'token_str': 'anchovies'},
#  {'sequence': '<s> dough pizza_sauce chicken_thighs </s>',
#   'score': 6.55493640806526e-05,
#   'token': 388,
#   'token_str': 'chicken_thighs'},
#  {'sequence': '<s> dough pizza_sauce minced_meat </s>',
#   'score': 6.534782005473971e-05,
#   'token': 2674,
#   'token_str': 'minced_meat'},
#  {'sequence': '<s> dough pizza_sauce cutlet </s>',
#   'score': 6.477945862570778e-05,
#   'token': 3471,
#   'token_str': 'cutlet'},
#  {'sequence': '<s> dough pizza_sauce smoked_turkey </s>',
#   'score': 6.473523535532877e-05,
#   'token': 1125,
#   'token_str': 'smoked_turkey'},
#  {'sequence': '<s> dough pizza_sauce grated_pecorino </s>',
#   'score': 6.468314677476883e-05,
#   'token': 1289,
#   'token_str': 'grated_pecorino'},
#  {'sequence': '<s> dough pizza_sauce orange_bell_pepper </s>',
#   'score': 6.453521200455725e-05,
#   'token': 1371,
#   'token_str': 'orange_bell_pepper'},
#  {'sequence': '<s> dough pizza_sauce sausage_meat </s>',
#   'score': 6.447086343541741e-05,
#   'token': 2529,
#   'token_str': 'sausage_meat'},
#  {'sequence': '<s> dough pizza_sauce red_peppers </s>',
#   'score': 6.445451435865834e-05,
#   'token': 426,
#   'token_str': 'red_peppers'},
#  {'sequence': '<s> dough pizza_sauce bread_dough </s>',
#   'score': 6.406861211871728e-05,
#   'token': 1655,
#   'token_str': 'bread_dough'},
#  {'sequence': '<s> dough pizza_sauce russet_potatoes </s>',
#   'score': 6.370164919644594e-05,
#   'token': 616,
#   'token_str': 'russet_potatoes'},
#  {'sequence': '<s> dough pizza_sauce onion_salt </s>',
#   'score': 6.358129758154973e-05,
#   'token': 1107,
#   'token_str': 'onion_salt'},
#  {'sequence': '<s> dough pizza_sauce angel_hair </s>',
#   'score': 6.294064951362088e-05,
#   'token': 1102,
#   'token_str': 'angel_hair'},
#  {'sequence': '<s> dough pizza_sauce roasted_red_peppers </s>',
#   'score': 6.281898095039651e-05,
#   'token': 793,
#   'token_str': 'roasted_red_peppers'},
#  {'sequence': '<s> dough pizza_sauce kitchens </s>',
#   'score': 6.202562508406118e-05,
#   'token': 3344,
#   'token_str': 'kitchens'},
#  {'sequence': '<s> dough pizza_sauce sage_leaves </s>',
#   'score': 6.176102033350617e-05,
#   'token': 842,
#   'token_str': 'sage_leaves'},
#  {'sequence': '<s> dough pizza_sauce rotini </s>',
#   'score': 6.171244604047388e-05,
#   'token': 940,
#   'token_str': 'rotini'},
#  {'sequence': '<s> dough pizza_sauce bread_crumbs </s>',
#   'score': 6.12397852819413e-05,
#   'token': 216,
#   'token_str': 'bread_crumbs'},
#  {'sequence': '<s> dough pizza_sauce confit </s>',
#   'score': 6.10517236054875e-05,
#   'token': 2468,
#   'token_str': 'confit'},
#  {'sequence': '<s> dough pizza_sauce vegetarian </s>',
#   'score': 6.097631194279529e-05,
#   'token': 1103,
#   'token_str': 'vegetarian'},
#  {'sequence': '<s> dough pizza_sauce red_bell_peppers </s>',
#   'score': 6.0797992773586884e-05,
#   'token': 455,
#   'token_str': 'red_bell_peppers'},
#  {'sequence': '<s> dough pizza_sauce steaks </s>',
#   'score': 6.0342812503222376e-05,
#   'token': 401,
#   'token_str': 'steaks'},
#  {'sequence': '<s> dough pizza_sauce balsamic_vinegar </s>',
#   'score': 6.002581358188763e-05,
#   'token': 203,
#   'token_str': 'balsamic_vinegar'},
#  {'sequence': '<s> dough pizza_sauce ranch_dip </s>',
#   'score': 5.9724658058257774e-05,
#   'token': 2905,
#   'token_str': 'ranch_dip'},
#  {'sequence': '<s> dough pizza_sauce cucumbers </s>',
#   'score': 5.96708596276585e-05,
#   'token': 500,
#   'token_str': 'cucumbers'},
#  {'sequence': '<s> dough pizza_sauce liquid </s>',
#   'score': 5.9391590184532106e-05,
#   'token': 252,
#   'token_str': 'liquid'},
#  {'sequence': '<s> dough pizza_sauce medium_zucchini </s>',
#   'score': 5.929905455559492e-05,
#   'token': 649,
#   'token_str': 'medium_zucchini'},
#  {'sequence': '<s> dough pizza_sauce cooking_oil </s>',
#   'score': 5.920395415159874e-05,
#   'token': 554,
#   'token_str': 'cooking_oil'},
#  {'sequence': '<s> dough pizza_sauce hand </s>',
#   'score': 5.862709440407343e-05,
#   'token': 1727,
#   'token_str': 'hand'},
#  {'sequence': '<s> dough pizza_sauce powdered_sugar </s>',
#   'score': 5.8571939007379115e-05,
#   'token': 158,
#   'token_str': 'powdered_sugar'},
#  {'sequence': '<s> dough pizza_sauce flank_steak </s>',
#   'score': 5.851297828485258e-05,
#   'token': 950,
#   'token_str': 'flank_steak'},
#  {'sequence': '<s> dough pizza_sauce sun_dried_tomatoes </s>',
#   'score': 5.836067066411488e-05,
#   'token': 1626,
#   'token_str': 'sun_dried_tomatoes'},
#  {'sequence': '<s> dough pizza_sauce black_forest_ham </s>',
#   'score': 5.8169523981632665e-05,
#   'token': 3113,
#   'token_str': 'black_forest_ham'},
#  {'sequence': '<s> dough pizza_sauce sliced_onion </s>',
#   'score': 5.7913239288609475e-05,
#   'token': 1351,
#   'token_str': 'sliced_onion'},
#  {'sequence': '<s> dough pizza_sauce pure_olive_oil </s>',
#   'score': 5.786416295450181e-05,
#   'token': 1980,
#   'token_str': 'pure_olive_oil'},
#  {'sequence': '<s> dough pizza_sauce muenster </s>',
#   'score': 5.754146695835516e-05,
#   'token': 1546,
#   'token_str': 'muenster'},
#  {'sequence': '<s> dough pizza_sauce steak_seasoning </s>',
#   'score': 5.752138895331882e-05,
#   'token': 1114,
#   'token_str': 'steak_seasoning'},
#  {'sequence': '<s> dough pizza_sauce marinade </s>',
#   'score': 5.696994412573986e-05,
#   'token': 1047,
#   'token_str': 'marinade'},
#  {'sequence': '<s> dough pizza_sauce plain_flour </s>',
#   'score': 5.670980681315996e-05,
#   'token': 505,
#   'token_str': 'plain_flour'},
#  {'sequence': '<s> dough pizza_sauce roasted_peppers </s>',
#   'score': 5.6700126151554286e-05,
#   'token': 3418,
#   'token_str': 'roasted_peppers'},
#  {'sequence': '<s> dough pizza_sauce turkey_breast </s>',
#   'score': 5.6633598433109e-05,
#   'token': 730,
#   'token_str': 'turkey_breast'},
#  {'sequence': '<s> dough pizza_sauce part-skim_mozzarella </s>',
#   'score': 5.633463661069982e-05,
#   'token': 2961,
#   'token_str': 'part-skim_mozzarella'},
#  {'sequence': '<s> dough pizza_sauce nonstick_spray </s>',
#   'score': 5.612448148895055e-05,
#   'token': 2332,
#   'token_str': 'nonstick_spray'},
#  {'sequence': '<s> dough pizza_sauce savory </s>',
#   'score': 5.601454176940024e-05,
#   'token': 992,
#   'token_str': 'savory'},
#  {'sequence': '<s> dough pizza_sauce white_mushrooms </s>',
#   'score': 5.5874759709695354e-05,
#   'token': 1031,
#   'token_str': 'white_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce biscuit_dough </s>',
#   'score': 5.575897739618085e-05,
#   'token': 2381,
#   'token_str': 'biscuit_dough'},
#  {'sequence': '<s> dough pizza_sauce ground_pepper </s>',
#   'score': 5.567730840994045e-05,
#   'token': 111,
#   'token_str': 'ground_pepper'},
#  {'sequence': '<s> dough pizza_sauce spinach_leaves </s>',
#   'score': 5.5188575061038136e-05,
#   'token': 470,
#   'token_str': 'spinach_leaves'},
#  {'sequence': '<s> dough pizza_sauce portabella_mushrooms </s>',
#   'score': 5.5066026106942445e-05,
#   'token': 1402,
#   'token_str': 'portabella_mushrooms'},
#  {'sequence': '<s> dough pizza_sauce aioli </s>',
#   'score': 5.4947890021139756e-05,
#   'token': 2440,
#   'token_str': 'aioli'},
#  {'sequence': '<s> dough pizza_sauce herbes_de_provence </s>',
#   'score': 5.477058221003972e-05,
#   'token': 1184,
#   'token_str': 'herbes_de_provence'},
#  {'sequence': '<s> dough pizza_sauce mixed_vegetables </s>',
#   'score': 5.4759042541263625e-05,
#   'token': 745,
#   'token_str': 'mixed_vegetables'},
#  {'sequence': '<s> dough pizza_sauce gluten </s>',
#   'score': 5.472254997584969e-05,
#   'token': 933,
#   'token_str': 'gluten'},
#  {'sequence': '<s> dough pizza_sauce cheese_ravioli </s>',
#   'score': 5.386619159253314e-05,
#   'token': 2378,
#   'token_str': 'cheese_ravioli'},
#  {'sequence': '<s> dough pizza_sauce italian_seasoned_breadcrumbs </s>',
#   'score': 5.370139115257189e-05,
#   'token': 1673,
#   'token_str': 'italian_seasoned_breadcrumbs'},
#  {'sequence': '<s> dough pizza_sauce chianti </s>',
#   'score': 5.35867948201485e-05,
#   'token': 2517,
#   'token_str': 'chianti'},
#  {'sequence': '<s> dough pizza_sauce wheat_bran </s>',
#   'score': 5.3388979722512886e-05,
#   'token': 1799,
#   'token_str': 'wheat_bran'},
#  {'sequence': '<s> dough pizza_sauce mentsuyu </s>',
#   'score': 5.3222134738462046e-05,
#   'token': 1796,
#   'token_str': 'mentsuyu'},
#  {'sequence': '<s> dough pizza_sauce center_cut_bacon </s>',
#   'score': 5.321178105077706e-05,
#   'token': 2356,
#   'token_str': 'center_cut_bacon'},
#  {'sequence': '<s> dough pizza_sauce cheese_sauce </s>',
#   'score': 5.320356285665184e-05,
#   'token': 1553,
#   'token_str': 'cheese_sauce'},
#  {'sequence': '<s> dough pizza_sauce red_chili </s>',
#   'score': 5.2924369811080396e-05,
#   'token': 462,
#   'token_str': 'red_chili'},
#  {'sequence': '<s> dough pizza_sauce extra_lean_ground_beef </s>',
#   'score': 5.2885166951455176e-05,
#   'token': 1509,
#   'token_str': 'extra_lean_ground_beef'},
#  {'sequence': '<s> dough pizza_sauce squid </s>',
#   'score': 5.271924237604253e-05,
#   'token': 1375,
#   'token_str': 'squid'},
#  {'sequence': '<s> dough pizza_sauce oscar_mayer_bacon </s>',
#   'score': 5.255584619590081e-05,
#   'token': 1198,
#   'token_str': 'oscar_mayer_bacon'},
#  {'sequence': '<s> dough pizza_sauce pecorino_cheese </s>',
#   'score': 5.245279680821113e-05,
#   'token': 1495,
#   'token_str': 'pecorino_cheese'},
#  {'sequence': '<s> dough pizza_sauce egg_whites </s>',
#   'score': 5.223096741246991e-05,
#   'token': 184,
#   'token_str': 'egg_whites'},
#  {'sequence': '<s> dough pizza_sauce canola </s>',
#   'score': 5.2048428187845275e-05,
#   'token': 139,
#   'token_str': 'canola'},
#  {'sequence': '<s> dough pizza_sauce turkey_bacon </s>',
#   'score': 5.1982155127916485e-05,
#   'token': 1543,
#   'token_str': 'turkey_bacon'},
#  {'sequence': '<s> dough pizza_sauce tap_water </s>',
#   'score': 5.180933294468559e-05,
#   'token': 2664,
#   'token_str': 'tap_water'},
#  {'sequence': '<s> dough pizza_sauce green_chiles </s>',
#   'score': 5.1387276471359655e-05,
#   'token': 868,
#   'token_str': 'green_chiles'}]

# %%
tokenized_input = tokenizer('dough pizza_sauce <mask>', return_tensors='pt')['input_ids']
tokenized_input
# Out:
# tensor([[  0, 431, 856,   4,   2]])

# %%
model(tokenized_input)
# Out:
# (tensor([[[ 20.7888,  -5.7311,  -2.3179,  ...,  -1.1549,   1.2096,  -0.6517],
#           [ -3.5585, -10.7750,  -3.0984,  ...,  -2.4188,  -3.7403,  -3.7300],
#           [ -4.2900, -10.2704,  -1.8199,  ...,  -1.9546,  -2.8219,  -1.6147],
#           [ -3.2282, -12.2347,  -5.2322,  ...,  -2.8265,  -3.5606,  -4.4717],
#           [ -3.3837,  -7.7216,  17.7582,  ...,  -4.7777,  -3.7840,  -2.4419]]],
#         grad_fn=<AddBackward0>),)

# %%
x = tokenized_input
x = model.roberta.embeddings(x)
x = model.roberta.encoder(x)
x = model.lm_head(x[0])
x
# Out:
# tensor([[[ 20.7888,  -5.7311,  -2.3179,  ...,  -1.1549,   1.2096,  -0.6517],
#          [ -3.5585, -10.7750,  -3.0984,  ...,  -2.4188,  -3.7403,  -3.7300],
#          [ -4.2900, -10.2704,  -1.8199,  ...,  -1.9546,  -2.8219,  -1.6147],
#          [ -3.2282, -12.2347,  -5.2322,  ...,  -2.8265,  -3.5606,  -4.4717],
#          [ -3.3837,  -7.7216,  17.7582,  ...,  -4.7777,  -3.7840,  -2.4419]]],
#        grad_fn=<AddBackward0>)

# %%
x.shape
# Out:
# torch.Size([1, 5, 3505])

# %%
mask_part = x[0, 3, :]
mask_part
# Out:
# tensor([ -3.2282, -12.2347,  -5.2322,  ...,  -2.8265,  -3.5606,  -4.4717],
#        grad_fn=<SliceBackward>)

# %%
import torch
topk = torch.topk(mask_part, k=5)
topk
# Out:
# torch.return_types.topk(
# values=tensor([7.6516, 7.5410, 6.4063, 6.3114, 5.8397], grad_fn=<TopkBackward>),
# indices=tensor([156, 733,  12,  21,  49]))

# %%
tokenizer.convert_ids_to_tokens(topk.indices)
# Out:
# ['mozzarella_cheese', 'pepperoni', 'olive_oil', 'cheese', 'parmesan']
