# %% [markdown]
# # Masked language models

# %%
from transformers import pipeline

fill_mask = pipeline("fill-mask")
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['lm_head.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask("Share your Opinion, Shop & Search to earn real cash rewards.")

# %% [markdown]
# # Training on recipes

# %% [markdown]
# https://huggingface.co/blog/how-to-train

# %%
# !head ../data/processed/recipes_train.txt
# Out:
# garlic eggplant flour salt olive_oil seasoned_bread_crumbs grated_parmesan_cheese pepper rounds mozzarella_cheese tomatoes
# eggs oreo cookies margarine water sugar_cookie_mix brownie ingredients
# nutmeg cinnamon_sticks apple_juice orange_blossom water tea_bags
# red_chili pepper_sauce chili_paste olive_oil pork_loin mirin cornstarch oyster_sauce
# medium_shrimp dried_red_pepper fillets olive_oil fennel_fronds garlic_cloves bottled_clam_juice dry_white_wine lemon arugula
# black_beans salt olive_oil avocado cilantro bell_pepper ground_cumin red_onion lime_juice
# dark_chocolate eggs salt vanilla_extract unsalted_butter confectioners_sugar skim_milk brioche_bread heavy_cream
# cake_flour white_sugar salt milk vanilla_extract unsalted_butter pumpkin_pie_spice ground_cloves egg_white powdered_sugar ground_cinnamon canola_oil baking_powder temperature
# boneless_pork_loin salt pork_loin_chops golden_delicious_apples ground_cinnamon brown_sugar
# melted_butter flour salt dry_milk water sugar instant_yeast temperature baking_soda

# %%
# !cat ../data/processed/recipes_train.txt | wc -l
# Out:
# 1039974

# %%
import sys
from pathlib import Path
sys.path.append(str(Path(sys.path[0]).parent))
from src.ingredient_tokenizer import load_tokenizer

tokenizer = load_tokenizer('../artifacts')

fill_mask_recipe = pipeline("fill-mask", 
                     model='../artifacts/', 
                     tokenizer=tokenizer,
                     topk=500)
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at ../artifacts/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask_recipe('cold_water pepper salt chicken celery onion carrot <mask> hen')
# Out:
# [{'sequence': '<s> cold_water pepper salt chicken celery onion carrot flour hen </s>',
#   'score': 0.19535516202449799,
#   'token': 10,
#   'token_str': 'flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsley hen </s>',
#   'score': 0.08524889498949051,
#   'token': 36,
#   'token_str': 'parsley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot eggs hen </s>',
#   'score': 0.051332026720047,
#   'token': 18,
#   'token_str': 'eggs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg_noodles hen </s>',
#   'score': 0.050168510526418686,
#   'token': 504,
#   'token_str': 'egg_noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot carcass hen </s>',
#   'score': 0.03739031404256821,
#   'token': 2982,
#   'token_str': 'carcass'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bay_leaf hen </s>',
#   'score': 0.03536321967840195,
#   'token': 217,
#   'token_str': 'bay_leaf'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cornstarch hen </s>',
#   'score': 0.0298247579485178,
#   'token': 116,
#   'token_str': 'cornstarch'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg hen </s>',
#   'score': 0.02967856451869011,
#   'token': 29,
#   'token_str': 'egg'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic hen </s>',
#   'score': 0.015317129902541637,
#   'token': 8,
#   'token_str': 'garlic'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bay_leaves hen </s>',
#   'score': 0.014853989705443382,
#   'token': 213,
#   'token_str': 'bay_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot potato hen </s>',
#   'score': 0.012879885733127594,
#   'token': 208,
#   'token_str': 'potato'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot butter hen </s>',
#   'score': 0.01228400319814682,
#   'token': 7,
#   'token_str': 'butter'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot thyme hen </s>',
#   'score': 0.011690010316669941,
#   'token': 75,
#   'token_str': 'thyme'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetable_oil hen </s>',
#   'score': 0.01146712526679039,
#   'token': 40,
#   'token_str': 'vegetable_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soup hen </s>',
#   'score': 0.010760366916656494,
#   'token': 539,
#   'token_str': 'soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shortening hen </s>',
#   'score': 0.008811378851532936,
#   'token': 192,
#   'token_str': 'shortening'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream_of_chicken_soup hen </s>',
#   'score': 0.008372491225600243,
#   'token': 386,
#   'token_str': 'cream_of_chicken_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sugar hen </s>',
#   'score': 0.00818611215800047,
#   'token': 9,
#   'token_str': 'sugar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stock hen </s>',
#   'score': 0.006999934557825327,
#   'token': 176,
#   'token_str': 'stock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot poultry_seasoning hen </s>',
#   'score': 0.00688935536891222,
#   'token': 809,
#   'token_str': 'poultry_seasoning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot oil hen </s>',
#   'score': 0.006795125547796488,
#   'token': 76,
#   'token_str': 'oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rice hen </s>',
#   'score': 0.00649622967466712,
#   'token': 122,
#   'token_str': 'rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot potatoes hen </s>',
#   'score': 0.00621799798682332,
#   'token': 52,
#   'token_str': 'potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot breast hen </s>',
#   'score': 0.005901187192648649,
#   'token': 468,
#   'token_str': 'breast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot barley hen </s>',
#   'score': 0.005741634871810675,
#   'token': 678,
#   'token_str': 'barley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot meat hen </s>',
#   'score': 0.005360784940421581,
#   'token': 370,
#   'token_str': 'meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_minced hen </s>',
#   'score': 0.005186691880226135,
#   'token': 88,
#   'token_str': 'garlic_minced'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mushrooms hen </s>',
#   'score': 0.004971184302121401,
#   'token': 70,
#   'token_str': 'mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey hen </s>',
#   'score': 0.004839666187763214,
#   'token': 206,
#   'token_str': 'turkey'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_cloves hen </s>',
#   'score': 0.004762222990393639,
#   'token': 38,
#   'token_str': 'garlic_cloves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rosemary hen </s>',
#   'score': 0.004618292674422264,
#   'token': 155,
#   'token_str': 'rosemary'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot hen hen </s>',
#   'score': 0.004195543006062508,
#   'token': 2935,
#   'token_str': 'hen'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsley_flakes hen </s>',
#   'score': 0.003955243155360222,
#   'token': 727,
#   'token_str': 'parsley_flakes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fat hen </s>',
#   'score': 0.003933234605938196,
#   'token': 937,
#   'token_str': 'fat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot broth hen </s>',
#   'score': 0.0038249301724135876,
#   'token': 242,
#   'token_str': 'broth'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_thyme hen </s>',
#   'score': 0.003724898910149932,
#   'token': 214,
#   'token_str': 'dried_thyme'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cubed_potatoes hen </s>',
#   'score': 0.003675284795463085,
#   'token': 2305,
#   'token_str': 'cubed_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomatoes hen </s>',
#   'score': 0.0036590101663023233,
#   'token': 26,
#   'token_str': 'tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot noodles hen </s>',
#   'score': 0.003644163953140378,
#   'token': 183,
#   'token_str': 'noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_peas hen </s>',
#   'score': 0.0032627542968839407,
#   'token': 417,
#   'token_str': 'frozen_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot leek hen </s>',
#   'score': 0.0031608068384230137,
#   'token': 615,
#   'token_str': 'leek'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wide_egg_noodles hen </s>',
#   'score': 0.0030606677755713463,
#   'token': 1393,
#   'token_str': 'wide_egg_noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot liquid hen </s>',
#   'score': 0.0029979932587593794,
#   'token': 252,
#   'token_str': 'liquid'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot skin hen </s>',
#   'score': 0.002892564982175827,
#   'token': 831,
#   'token_str': 'skin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato hen </s>',
#   'score': 0.002849799580872059,
#   'token': 50,
#   'token_str': 'tomato'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot broiler hen </s>',
#   'score': 0.002754615619778633,
#   'token': 2795,
#   'token_str': 'broiler'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot olive_oil hen </s>',
#   'score': 0.0027000331319868565,
#   'token': 12,
#   'token_str': 'olive_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetable hen </s>',
#   'score': 0.002552861114963889,
#   'token': 32,
#   'token_str': 'vegetable'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rib hen </s>',
#   'score': 0.0024771227035671473,
#   'token': 721,
#   'token_str': 'rib'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_split_peas hen </s>',
#   'score': 0.002466576173901558,
#   'token': 3393,
#   'token_str': 'dried_split_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mushroom hen </s>',
#   'score': 0.002441519172862172,
#   'token': 164,
#   'token_str': 'mushroom'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot milk hen </s>',
#   'score': 0.0023881809320300817,
#   'token': 20,
#   'token_str': 'milk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ginger hen </s>',
#   'score': 0.002371251815930009,
#   'token': 45,
#   'token_str': 'ginger'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ingredients hen </s>',
#   'score': 0.0023543653078377247,
#   'token': 1424,
#   'token_str': 'ingredients'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot savory hen </s>',
#   'score': 0.002347355941310525,
#   'token': 992,
#   'token_str': 'savory'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot hot_water hen </s>',
#   'score': 0.0022603673860430717,
#   'token': 342,
#   'token_str': 'hot_water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot split_peas hen </s>',
#   'score': 0.0022391043603420258,
#   'token': 1435,
#   'token_str': 'split_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bouillon hen </s>',
#   'score': 0.0020654150284826756,
#   'token': 268,
#   'token_str': 'bouillon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sage hen </s>',
#   'score': 0.0020358716137707233,
#   'token': 341,
#   'token_str': 'sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey_carcass hen </s>',
#   'score': 0.0019861955661326647,
#   'token': 3432,
#   'token_str': 'turkey_carcass'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsley_sprigs hen </s>',
#   'score': 0.0019626158755272627,
#   'token': 1323,
#   'token_str': 'parsley_sprigs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cloves hen </s>',
#   'score': 0.0019526564283296466,
#   'token': 87,
#   'token_str': 'cloves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lard hen </s>',
#   'score': 0.0019318528939038515,
#   'token': 911,
#   'token_str': 'lard'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetable_shortening hen </s>',
#   'score': 0.0019101729849353433,
#   'token': 524,
#   'token_str': 'vegetable_shortening'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lemons hen </s>',
#   'score': 0.001905048149637878,
#   'token': 310,
#   'token_str': 'lemons'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_fat hen </s>',
#   'score': 0.001826237072236836,
#   'token': 2512,
#   'token_str': 'chicken_fat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot leeks hen </s>',
#   'score': 0.0017295050201937556,
#   'token': 535,
#   'token_str': 'leeks'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot liver hen </s>',
#   'score': 0.001707065966911614,
#   'token': 1344,
#   'token_str': 'liver'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot peas hen </s>',
#   'score': 0.0017058950616046786,
#   'token': 193,
#   'token_str': 'peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dumplings hen </s>',
#   'score': 0.0016702464781701565,
#   'token': 2719,
#   'token_str': 'dumplings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot plain_flour hen </s>',
#   'score': 0.001665571820922196,
#   'token': 505,
#   'token_str': 'plain_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gravy_mix hen </s>',
#   'score': 0.0016351341037079692,
#   'token': 1591,
#   'token_str': 'gravy_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bouquet_garni hen </s>',
#   'score': 0.0016268924809992313,
#   'token': 1439,
#   'token_str': 'bouquet_garni'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot margarine hen </s>',
#   'score': 0.0015933417016640306,
#   'token': 80,
#   'token_str': 'margarine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn hen </s>',
#   'score': 0.0015602654311805964,
#   'token': 109,
#   'token_str': 'corn'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot water hen </s>',
#   'score': 0.001520719612017274,
#   'token': 13,
#   'token_str': 'water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dill hen </s>',
#   'score': 0.0014593005180358887,
#   'token': 231,
#   'token_str': 'dill'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot evaporated_milk hen </s>',
#   'score': 0.0014212430687621236,
#   'token': 393,
#   'token_str': 'evaporated_milk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot brown hen </s>',
#   'score': 0.0014211778761819005,
#   'token': 27,
#   'token_str': 'brown'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot matzo_meal hen </s>',
#   'score': 0.0014190158108249307,
#   'token': 1857,
#   'token_str': 'matzo_meal'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_rice hen </s>',
#   'score': 0.0013867042725905776,
#   'token': 293,
#   'token_str': 'white_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef hen </s>',
#   'score': 0.0013718674890697002,
#   'token': 188,
#   'token_str': 'beef'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vegetables hen </s>',
#   'score': 0.0013603097759187222,
#   'token': 420,
#   'token_str': 'vegetables'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot okra hen </s>',
#   'score': 0.0013468916295096278,
#   'token': 957,
#   'token_str': 'okra'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pearl_barley hen </s>',
#   'score': 0.0013340454315766692,
#   'token': 1238,
#   'token_str': 'pearl_barley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lemon hen </s>',
#   'score': 0.0013144217664375901,
#   'token': 23,
#   'token_str': 'lemon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vinegar hen </s>',
#   'score': 0.0012953998520970345,
#   'token': 31,
#   'token_str': 'vinegar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooked_rice hen </s>',
#   'score': 0.0012546589132398367,
#   'token': 514,
#   'token_str': 'cooked_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stuffing hen </s>',
#   'score': 0.0012387775350362062,
#   'token': 549,
#   'token_str': 'stuffing'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot minced_garlic hen </s>',
#   'score': 0.0012245315592736006,
#   'token': 134,
#   'token_str': 'minced_garlic'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg_yolk hen </s>',
#   'score': 0.0011765799717977643,
#   'token': 336,
#   'token_str': 'egg_yolk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mashed_potatoes hen </s>',
#   'score': 0.0011703744530677795,
#   'token': 839,
#   'token_str': 'mashed_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shells hen </s>',
#   'score': 0.00109556142706424,
#   'token': 483,
#   'token_str': 'shells'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cabbage hen </s>',
#   'score': 0.0010898368200287223,
#   'token': 182,
#   'token_str': 'cabbage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wondra_flour hen </s>',
#   'score': 0.0010665662121027708,
#   'token': 3436,
#   'token_str': 'wondra_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot peppercorns hen </s>',
#   'score': 0.0010572654427960515,
#   'token': 281,
#   'token_str': 'peppercorns'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot onions hen </s>',
#   'score': 0.001054601394571364,
#   'token': 30,
#   'token_str': 'onions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tarragon hen </s>',
#   'score': 0.0010450870031490922,
#   'token': 315,
#   'token_str': 'tarragon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bacon hen </s>',
#   'score': 0.0010293476516380906,
#   'token': 90,
#   'token_str': 'bacon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chestnuts hen </s>',
#   'score': 0.0010287475306540728,
#   'token': 590,
#   'token_str': 'chestnuts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_flour hen </s>',
#   'score': 0.0010151229798793793,
#   'token': 698,
#   'token_str': 'white_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot paprika hen </s>',
#   'score': 0.001011760556139052,
#   'token': 96,
#   'token_str': 'paprika'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stewed_tomatoes hen </s>',
#   'score': 0.0009911013767123222,
#   'token': 660,
#   'token_str': 'stewed_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cold_water hen </s>',
#   'score': 0.0009841095888987184,
#   'token': 253,
#   'token_str': 'cold_water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot worcestershire_sauce hen </s>',
#   'score': 0.0009639943018555641,
#   'token': 123,
#   'token_str': 'worcestershire_sauce'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unflavored_gelatin hen </s>',
#   'score': 0.0009606771054677665,
#   'token': 704,
#   'token_str': 'unflavored_gelatin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot basil hen </s>',
#   'score': 0.0009553310228511691,
#   'token': 77,
#   'token_str': 'basil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_potatoes hen </s>',
#   'score': 0.0009488856885582209,
#   'token': 610,
#   'token_str': 'medium_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_paste hen </s>',
#   'score': 0.0009360442054457963,
#   'token': 189,
#   'token_str': 'tomato_paste'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_powder hen </s>',
#   'score': 0.0009331015753559768,
#   'token': 84,
#   'token_str': 'garlic_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boiling_water hen </s>',
#   'score': 0.0009288922301493585,
#   'token': 254,
#   'token_str': 'boiling_water'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turnips hen </s>',
#   'score': 0.0009230427676811814,
#   'token': 1024,
#   'token_str': 'turnips'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gravy hen </s>',
#   'score': 0.0009137231390923262,
#   'token': 1078,
#   'token_str': 'gravy'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scallions hen </s>',
#   'score': 0.0009085118654184043,
#   'token': 167,
#   'token_str': 'scallions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot grain hen </s>',
#   'score': 0.0008740894263610244,
#   'token': 379,
#   'token_str': 'grain'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot flour_for_dusting hen </s>',
#   'score': 0.0008726546657271683,
#   'token': 1115,
#   'token_str': 'flour_for_dusting'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sliced_mushrooms hen </s>',
#   'score': 0.0008635562844574451,
#   'token': 359,
#   'token_str': 'sliced_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stick_butter hen </s>',
#   'score': 0.000855597376357764,
#   'token': 405,
#   'token_str': 'stick_butter'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pie_crust hen </s>',
#   'score': 0.000847404939122498,
#   'token': 498,
#   'token_str': 'pie_crust'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream_of_mushroom_soup hen </s>',
#   'score': 0.0008373127784579992,
#   'token': 312,
#   'token_str': 'cream_of_mushroom_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot goose hen </s>',
#   'score': 0.0008355822064913809,
#   'token': 2206,
#   'token_str': 'goose'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot drippings hen </s>',
#   'score': 0.0008342806831933558,
#   'token': 1110,
#   'token_str': 'drippings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot carrot hen </s>',
#   'score': 0.0008336369064636528,
#   'token': 140,
#   'token_str': 'carrot'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unsalted_butter hen </s>',
#   'score': 0.0008250054670497775,
#   'token': 44,
#   'token_str': 'unsalted_butter'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soy_sauce hen </s>',
#   'score': 0.0008126285974867642,
#   'token': 61,
#   'token_str': 'soy_sauce'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot with_skin hen </s>',
#   'score': 0.0008092984207905829,
#   'token': 915,
#   'token_str': 'with_skin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot roux hen </s>',
#   'score': 0.0007715713582001626,
#   'token': 2289,
#   'token_str': 'roux'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooking_oil hen </s>',
#   'score': 0.0007478251354768872,
#   'token': 554,
#   'token_str': 'cooking_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot seasonings hen </s>',
#   'score': 0.0007445048540830612,
#   'token': 1652,
#   'token_str': 'seasonings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_shiitake_mushrooms hen </s>',
#   'score': 0.0007434827275574207,
#   'token': 2055,
#   'token_str': 'dried_shiitake_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot kitchen_bouquet hen </s>',
#   'score': 0.0007265277672559023,
#   'token': 2825,
#   'token_str': 'kitchen_bouquet'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot condensed_cream_of_chicken_soup hen </s>',
#   'score': 0.0007153631886467338,
#   'token': 1097,
#   'token_str': 'condensed_cream_of_chicken_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bouillon_powder hen </s>',
#   'score': 0.0007089177379384637,
#   'token': 2026,
#   'token_str': 'bouillon_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot minced_parsley hen </s>',
#   'score': 0.0007034955197013915,
#   'token': 497,
#   'token_str': 'minced_parsley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork hen </s>',
#   'score': 0.0007016445742920041,
#   'token': 180,
#   'token_str': 'pork'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot canned_tomatoes hen </s>',
#   'score': 0.0006999296601861715,
#   'token': 658,
#   'token_str': 'canned_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot powder hen </s>',
#   'score': 0.0006970041431486607,
#   'token': 16,
#   'token_str': 'powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot onion hen </s>',
#   'score': 0.0006836982211098075,
#   'token': 11,
#   'token_str': 'onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_oil hen </s>',
#   'score': 0.0006784009165130556,
#   'token': 802,
#   'token_str': 'corn_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot accent hen </s>',
#   'score': 0.0006729161832481623,
#   'token': 3266,
#   'token_str': 'accent'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rutabaga hen </s>',
#   'score': 0.0006727874861098826,
#   'token': 1867,
#   'token_str': 'rutabaga'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot seasoning hen </s>',
#   'score': 0.0006626842077821493,
#   'token': 78,
#   'token_str': 'seasoning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crisco_shortening hen </s>',
#   'score': 0.0006546820513904095,
#   'token': 2496,
#   'token_str': 'crisco_shortening'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream_of_celery_soup hen </s>',
#   'score': 0.0006387038738466799,
#   'token': 938,
#   'token_str': 'cream_of_celery_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mushroom_soup hen </s>',
#   'score': 0.0006324378191493452,
#   'token': 271,
#   'token_str': 'mushroom_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crisco hen </s>',
#   'score': 0.0006313151679933071,
#   'token': 908,
#   'token_str': 'crisco'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_peas hen </s>',
#   'score': 0.0006222018273547292,
#   'token': 798,
#   'token_str': 'green_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_wine hen </s>',
#   'score': 0.0006198192131705582,
#   'token': 89,
#   'token_str': 'white_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_parsley hen </s>',
#   'score': 0.0006159246549941599,
#   'token': 445,
#   'token_str': 'dried_parsley'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vermicelli hen </s>',
#   'score': 0.0006128604873083532,
#   'token': 1168,
#   'token_str': 'vermicelli'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_beans hen </s>',
#   'score': 0.0006008995114825666,
#   'token': 272,
#   'token_str': 'green_beans'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot black_peppercorns hen </s>',
#   'score': 0.0005997739499434829,
#   'token': 440,
#   'token_str': 'black_peppercorns'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot celery_leaves hen </s>',
#   'score': 0.0005915692890994251,
#   'token': 1438,
#   'token_str': 'celery_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot canola_oil hen </s>',
#   'score': 0.0005818333011120558,
#   'token': 152,
#   'token_str': 'canola_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot oysters hen </s>',
#   'score': 0.0005760926869697869,
#   'token': 1080,
#   'token_str': 'oysters'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lemon_juice hen </s>',
#   'score': 0.0005739066982641816,
#   'token': 34,
#   'token_str': 'lemon_juice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken hen </s>',
#   'score': 0.0005600120639428496,
#   'token': 24,
#   'token_str': 'chicken'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot thyme_sprigs hen </s>',
#   'score': 0.0005548115586861968,
#   'token': 936,
#   'token_str': 'thyme_sprigs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot veal hen </s>',
#   'score': 0.0005545716849155724,
#   'token': 1053,
#   'token_str': 'veal'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey_broth hen </s>',
#   'score': 0.0005506932502612472,
#   'token': 2021,
#   'token_str': 'turkey_broth'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chestnut hen </s>',
#   'score': 0.000547773961443454,
#   'token': 1338,
#   'token_str': 'chestnut'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot spices hen </s>',
#   'score': 0.00054098543478176,
#   'token': 910,
#   'token_str': 'spices'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_kernels hen </s>',
#   'score': 0.0005366854020394385,
#   'token': 503,
#   'token_str': 'corn_kernels'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yellow_split_peas hen </s>',
#   'score': 0.0005315352464094758,
#   'token': 1809,
#   'token_str': 'yellow_split_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cream hen </s>',
#   'score': 0.000521709444001317,
#   'token': 22,
#   'token_str': 'cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot thyme_leaves hen </s>',
#   'score': 0.0005212869727984071,
#   'token': 384,
#   'token_str': 'thyme_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dry_sherry hen </s>',
#   'score': 0.0005133904633112252,
#   'token': 501,
#   'token_str': 'dry_sherry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_powder hen </s>',
#   'score': 0.000512288068421185,
#   'token': 42,
#   'token_str': 'baking_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_thighs hen </s>',
#   'score': 0.0004967754939571023,
#   'token': 388,
#   'token_str': 'chicken_thighs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot duck hen </s>',
#   'score': 0.00048671424156054854,
#   'token': 887,
#   'token_str': 'duck'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot carrots hen </s>',
#   'score': 0.00048301086644642055,
#   'token': 67,
#   'token_str': 'carrots'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot apple_cider hen </s>',
#   'score': 0.0004750246007461101,
#   'token': 284,
#   'token_str': 'apple_cider'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bone_in hen </s>',
#   'score': 0.00047288957284763455,
#   'token': 1716,
#   'token_str': 'bone_in'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot heavy_cream hen </s>',
#   'score': 0.0004701227881014347,
#   'token': 93,
#   'token_str': 'heavy_cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot marjoram hen </s>',
#   'score': 0.0004694731323979795,
#   'token': 520,
#   'token_str': 'marjoram'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bread_flour hen </s>',
#   'score': 0.0004652939969673753,
#   'token': 464,
#   'token_str': 'bread_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_sage hen </s>',
#   'score': 0.0004607964074239135,
#   'token': 1463,
#   'token_str': 'ground_sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot buttermilk hen </s>',
#   'score': 0.00045759082422591746,
#   'token': 160,
#   'token_str': 'buttermilk'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot paste hen </s>',
#   'score': 0.00045622867764905095,
#   'token': 570,
#   'token_str': 'paste'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_shank hen </s>',
#   'score': 0.000450054241809994,
#   'token': 2361,
#   'token_str': 'beef_shank'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soup_mix hen </s>',
#   'score': 0.0004480387142393738,
#   'token': 496,
#   'token_str': 'soup_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot long_grain_rice hen </s>',
#   'score': 0.0004478639748413116,
#   'token': 903,
#   'token_str': 'long_grain_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot monosodium_glutamate hen </s>',
#   'score': 0.00044362706830725074,
#   'token': 2623,
#   'token_str': 'monosodium_glutamate'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_meat hen </s>',
#   'score': 0.00043933826964348555,
#   'token': 1620,
#   'token_str': 'chicken_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boiled_eggs hen </s>',
#   'score': 0.0004247181350365281,
#   'token': 1256,
#   'token_str': 'boiled_eggs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooked_turkey hen </s>',
#   'score': 0.0004242784925736487,
#   'token': 882,
#   'token_str': 'cooked_turkey'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bread hen </s>',
#   'score': 0.0004193148633930832,
#   'token': 74,
#   'token_str': 'bread'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fish_bones hen </s>',
#   'score': 0.0004155184142291546,
#   'token': 2966,
#   'token_str': 'fish_bones'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rounds hen </s>',
#   'score': 0.000410691398428753,
#   'token': 778,
#   'token_str': 'rounds'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cheese hen </s>',
#   'score': 0.0004105693951714784,
#   'token': 21,
#   'token_str': 'cheese'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dry_white_wine hen </s>',
#   'score': 0.00040897028520703316,
#   'token': 207,
#   'token_str': 'dry_white_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_sauce hen </s>',
#   'score': 0.0004088550922460854,
#   'token': 186,
#   'token_str': 'tomato_sauce'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot game hen </s>',
#   'score': 0.0004012087592855096,
#   'token': 2049,
#   'token_str': 'game'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_bouillon hen </s>',
#   'score': 0.00039567830390296876,
#   'token': 450,
#   'token_str': 'chicken_bouillon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pan_drippings hen </s>',
#   'score': 0.0003909879887942225,
#   'token': 2890,
#   'token_str': 'pan_drippings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot butter_oil hen </s>',
#   'score': 0.0003875669790431857,
#   'token': 2455,
#   'token_str': 'butter_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garnish hen </s>',
#   'score': 0.0003874086542055011,
#   'token': 95,
#   'token_str': 'garnish'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot herbs hen </s>',
#   'score': 0.000386421219445765,
#   'token': 656,
#   'token_str': 'herbs'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot italian_tomatoes hen </s>',
#   'score': 0.0003741124819498509,
#   'token': 2149,
#   'token_str': 'italian_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot roast hen </s>',
#   'score': 0.0003741019463632256,
#   'token': 292,
#   'token_str': 'roast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot peppercorn hen </s>',
#   'score': 0.00037209055153653026,
#   'token': 1255,
#   'token_str': 'peppercorn'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fish hen </s>',
#   'score': 0.00037002592580392957,
#   'token': 669,
#   'token_str': 'fish'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot jasmine hen </s>',
#   'score': 0.0003656957997009158,
#   'token': 1212,
#   'token_str': 'jasmine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shallot hen </s>',
#   'score': 0.00036566617200151086,
#   'token': 264,
#   'token_str': 'shallot'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless hen </s>',
#   'score': 0.00036475068191066384,
#   'token': 94,
#   'token_str': 'boneless'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sour_cream hen </s>',
#   'score': 0.0003640084178186953,
#   'token': 59,
#   'token_str': 'sour_cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot msg hen </s>',
#   'score': 0.00035931807360611856,
#   'token': 2139,
#   'token_str': 'msg'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot egg_yolks hen </s>',
#   'score': 0.00035878183552995324,
#   'token': 179,
#   'token_str': 'egg_yolks'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gumbo hen </s>',
#   'score': 0.00035456707701087,
#   'token': 3231,
#   'token_str': 'gumbo'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_base hen </s>',
#   'score': 0.0003526869404595345,
#   'token': 1859,
#   'token_str': 'chicken_base'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sweet_peas hen </s>',
#   'score': 0.00035237090196460485,
#   'token': 2503,
#   'token_str': 'sweet_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot parsnips hen </s>',
#   'score': 0.00035016966285184026,
#   'token': 845,
#   'token_str': 'parsnips'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_mushrooms hen </s>',
#   'score': 0.00034709437750279903,
#   'token': 2916,
#   'token_str': 'dried_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot jasmine_rice hen </s>',
#   'score': 0.000344287371262908,
#   'token': 1310,
#   'token_str': 'jasmine_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot basmati hen </s>',
#   'score': 0.00034267199225723743,
#   'token': 674,
#   'token_str': 'basmati'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot instant_potato_flakes hen </s>',
#   'score': 0.000339521502610296,
#   'token': 3119,
#   'token_str': 'instant_potato_flakes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork_chops hen </s>',
#   'score': 0.00033588020596653223,
#   'token': 491,
#   'token_str': 'pork_chops'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot red_wine hen </s>',
#   'score': 0.00032552500488236547,
#   'token': 128,
#   'token_str': 'red_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_tomatoes hen </s>',
#   'score': 0.00032390712294727564,
#   'token': 499,
#   'token_str': 'medium_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stew_meat hen </s>',
#   'score': 0.0003210674040019512,
#   'token': 834,
#   'token_str': 'stew_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot allspice hen </s>',
#   'score': 0.00031912102713249624,
#   'token': 232,
#   'token_str': 'allspice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_liver hen </s>',
#   'score': 0.0003150772536173463,
#   'token': 2994,
#   'token_str': 'chicken_liver'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot spring hen </s>',
#   'score': 0.0003128576499875635,
#   'token': 562,
#   'token_str': 'spring'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_breast hen </s>',
#   'score': 0.00031205383129417896,
#   'token': 154,
#   'token_str': 'chicken_breast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot marrow hen </s>',
#   'score': 0.00030660329503007233,
#   'token': 2993,
#   'token_str': 'marrow'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_green_beans hen </s>',
#   'score': 0.0003065698256250471,
#   'token': 1812,
#   'token_str': 'frozen_green_beans'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_sage hen </s>',
#   'score': 0.0003065559430979192,
#   'token': 1089,
#   'token_str': 'dried_sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_parts hen </s>',
#   'score': 0.0003031473024748266,
#   'token': 1905,
#   'token_str': 'chicken_parts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mixed_vegetables hen </s>',
#   'score': 0.00030108881765045226,
#   'token': 745,
#   'token_str': 'mixed_vegetables'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot brown_sugar hen </s>',
#   'score': 0.00029913760954514146,
#   'token': 33,
#   'token_str': 'brown_sugar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wine hen </s>',
#   'score': 0.00029599067056551576,
#   'token': 107,
#   'token_str': 'wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_juice hen </s>',
#   'score': 0.00029169616755098104,
#   'token': 708,
#   'token_str': 'tomato_juice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot russet_potatoes hen </s>',
#   'score': 0.0002899405953940004,
#   'token': 616,
#   'token_str': 'russet_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_soda hen </s>',
#   'score': 0.00028692311025224626,
#   'token': 57,
#   'token_str': 'baking_soda'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot season hen </s>',
#   'score': 0.0002865126880351454,
#   'token': 960,
#   'token_str': 'season'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crumbled_cornbread hen </s>',
#   'score': 0.00028619999648071826,
#   'token': 2929,
#   'token_str': 'crumbled_cornbread'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_basil hen </s>',
#   'score': 0.00028589338762685657,
#   'token': 262,
#   'token_str': 'dried_basil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unbleached_flour hen </s>',
#   'score': 0.00028538028709590435,
#   'token': 1131,
#   'token_str': 'unbleached_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot oyster hen </s>',
#   'score': 0.00028516497695818543,
#   'token': 612,
#   'token_str': 'oyster'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot zucchini hen </s>',
#   'score': 0.0002844487316906452,
#   'token': 170,
#   'token_str': 'zucchini'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ham_hock hen </s>',
#   'score': 0.0002843581314664334,
#   'token': 2066,
#   'token_str': 'ham_hock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot extra_virgin_olive_oil hen </s>',
#   'score': 0.00027903239242732525,
#   'token': 101,
#   'token_str': 'extra_virgin_olive_oil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_base hen </s>',
#   'score': 0.00027473887894302607,
#   'token': 3108,
#   'token_str': 'beef_base'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beer hen </s>',
#   'score': 0.0002725029771681875,
#   'token': 392,
#   'token_str': 'beer'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot browning hen </s>',
#   'score': 0.0002713454596232623,
#   'token': 2064,
#   'token_str': 'browning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot broccoli hen </s>',
#   'score': 0.00027004850562661886,
#   'token': 197,
#   'token_str': 'broccoli'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fennel hen </s>',
#   'score': 0.00026995991356670856,
#   'token': 300,
#   'token_str': 'fennel'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_onions hen </s>',
#   'score': 0.0002696529554668814,
#   'token': 1127,
#   'token_str': 'white_onions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shrimp hen </s>',
#   'score': 0.00026664932374842465,
#   'token': 145,
#   'token_str': 'shrimp'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bulb hen </s>',
#   'score': 0.00026525690918788314,
#   'token': 2155,
#   'token_str': 'bulb'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork_shoulder hen </s>',
#   'score': 0.00026489701122045517,
#   'token': 776,
#   'token_str': 'pork_shoulder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_stock hen </s>',
#   'score': 0.00026461336528882384,
#   'token': 495,
#   'token_str': 'beef_stock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shallots hen </s>',
#   'score': 0.00026453036116436124,
#   'token': 201,
#   'token_str': 'shallots'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot curry_powder hen </s>',
#   'score': 0.00026167373289354146,
#   'token': 266,
#   'token_str': 'curry_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chives hen </s>',
#   'score': 0.00026127934688702226,
#   'token': 190,
#   'token_str': 'chives'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot stuffing_mix hen </s>',
#   'score': 0.0002574218378867954,
#   'token': 739,
#   'token_str': 'stuffing_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot curry hen </s>',
#   'score': 0.0002538433182053268,
#   'token': 525,
#   'token_str': 'curry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sausage hen </s>',
#   'score': 0.00025371721130795777,
#   'token': 161,
#   'token_str': 'sausage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot wild_rice hen </s>',
#   'score': 0.00025328024639748037,
#   'token': 863,
#   'token_str': 'wild_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tapioca hen </s>',
#   'score': 0.000252032361458987,
#   'token': 812,
#   'token_str': 'tapioca'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rabbit hen </s>',
#   'score': 0.00025122941588051617,
#   'token': 2102,
#   'token_str': 'rabbit'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_livers hen </s>',
#   'score': 0.0002492144121788442,
#   'token': 1991,
#   'token_str': 'chicken_livers'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_egg_noodles hen </s>',
#   'score': 0.0002491193590685725,
#   'token': 2806,
#   'token_str': 'medium_egg_noodles'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot seafood hen </s>',
#   'score': 0.0002470454201102257,
#   'token': 1200,
#   'token_str': 'seafood'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_potatoes hen </s>',
#   'score': 0.00024301899247802794,
#   'token': 683,
#   'token_str': 'baking_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot granulated_garlic hen </s>',
#   'score': 0.0002428655861876905,
#   'token': 926,
#   'token_str': 'granulated_garlic'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_meal hen </s>',
#   'score': 0.0002424329868517816,
#   'token': 1721,
#   'token_str': 'corn_meal'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_onion hen </s>',
#   'score': 0.0002414439368294552,
#   'token': 398,
#   'token_str': 'white_onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yellow_onions hen </s>',
#   'score': 0.00024120633315760642,
#   'token': 652,
#   'token_str': 'yellow_onions'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot potato_flakes hen </s>',
#   'score': 0.00023899486404843628,
#   'token': 2156,
#   'token_str': 'potato_flakes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yellow_onion hen </s>',
#   'score': 0.0002380044461460784,
#   'token': 247,
#   'token_str': 'yellow_onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot olive hen </s>',
#   'score': 0.00023798800248187035,
#   'token': 15,
#   'token_str': 'olive'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mixed_mushrooms hen </s>',
#   'score': 0.0002360506186960265,
#   'token': 1565,
#   'token_str': 'mixed_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot corn_flour hen </s>',
#   'score': 0.0002338463964406401,
#   'token': 907,
#   'token_str': 'corn_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cheddar_cheese hen </s>',
#   'score': 0.00023254440748132765,
#   'token': 64,
#   'token_str': 'cheddar_cheese'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot summer_savory hen </s>',
#   'score': 0.00023243566101882607,
#   'token': 2933,
#   'token_str': 'summer_savory'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scallion hen </s>',
#   'score': 0.00023055083875078708,
#   'token': 476,
#   'token_str': 'scallion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_vinegar hen </s>',
#   'score': 0.00022832003014627844,
#   'token': 291,
#   'token_str': 'white_vinegar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sherry hen </s>',
#   'score': 0.00022821422317065299,
#   'token': 267,
#   'token_str': 'sherry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless_chicken hen </s>',
#   'score': 0.00022545532556250691,
#   'token': 282,
# ...
#   'score': 0.00012568618694785982,
#   'token': 1361,
#   'token_str': 'italian_parsley_leaves'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot petite_peas hen </s>',
#   'score': 0.0001247969048563391,
#   'token': 2384,
#   'token_str': 'petite_peas'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless_pork hen </s>',
#   'score': 0.00012468494242057204,
#   'token': 558,
#   'token_str': 'boneless_pork'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_onion hen </s>',
#   'score': 0.00012177925964351743,
#   'token': 209,
#   'token_str': 'green_onion'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cinnamon hen </s>',
#   'score': 0.00012150148540968075,
#   'token': 37,
#   'token_str': 'cinnamon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scotch hen </s>',
#   'score': 0.0001214608273585327,
#   'token': 1315,
#   'token_str': 'scotch'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mutton hen </s>',
#   'score': 0.00012126019282732159,
#   'token': 2383,
#   'token_str': 'mutton'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot fennel_seed hen </s>',
#   'score': 0.00012119024904677644,
#   'token': 975,
#   'token_str': 'fennel_seed'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot brown_rice hen </s>',
#   'score': 0.00011969931802013889,
#   'token': 412,
#   'token_str': 'brown_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot vermouth hen </s>',
#   'score': 0.00011950729094678536,
#   'token': 874,
#   'token_str': 'vermouth'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_thyme hen </s>',
#   'score': 0.00011934528447454795,
#   'token': 1473,
#   'token_str': 'ground_thyme'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_vegetables hen </s>',
#   'score': 0.00011890715541085228,
#   'token': 2255,
#   'token_str': 'frozen_vegetables'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_navy_beans hen </s>',
#   'score': 0.0001183919157483615,
#   'token': 2816,
#   'token_str': 'dried_navy_beans'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot buttermilk_biscuits hen </s>',
#   'score': 0.0001173128403024748,
#   'token': 1608,
#   'token_str': 'buttermilk_biscuits'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot hungarian_paprika hen </s>',
#   'score': 0.00011729756806744263,
#   'token': 1542,
#   'token_str': 'hungarian_paprika'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_puree hen </s>',
#   'score': 0.00011669049854390323,
#   'token': 797,
#   'token_str': 'tomato_puree'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pepper_powder hen </s>',
#   'score': 0.00011578566045500338,
#   'token': 2089,
#   'token_str': 'pepper_powder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_ginger hen </s>',
#   'score': 0.00011565791646717116,
#   'token': 215,
#   'token_str': 'ground_ginger'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cider hen </s>',
#   'score': 0.00011558695405256003,
#   'token': 1511,
#   'token_str': 'cider'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot color hen </s>',
#   'score': 0.00011518739484017715,
#   'token': 1061,
#   'token_str': 'color'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot scallops hen </s>',
#   'score': 0.00011474790517240763,
#   'token': 671,
#   'token_str': 'scallops'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_bouillon_granules hen </s>',
#   'score': 0.00011447808356024325,
#   'token': 1410,
#   'token_str': 'chicken_bouillon_granules'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dried_celery hen </s>',
#   'score': 0.00011415690823923796,
#   'token': 3054,
#   'token_str': 'dried_celery'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot baking_mix hen </s>',
#   'score': 0.00011305339285172522,
#   'token': 924,
#   'token_str': 'baking_mix'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot medium_zucchini hen </s>',
#   'score': 0.00011285137588856742,
#   'token': 649,
#   'token_str': 'medium_zucchini'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot instant_chicken_bouillon hen </s>',
#   'score': 0.00011206230556126684,
#   'token': 1948,
#   'token_str': 'instant_chicken_bouillon'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot turkey_meat hen </s>',
#   'score': 0.00011118863767478615,
#   'token': 2491,
#   'token_str': 'turkey_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cooking_wine hen </s>',
#   'score': 0.00011056561197619885,
#   'token': 1816,
#   'token_str': 'cooking_wine'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_stew hen </s>',
#   'score': 0.00011026024731108919,
#   'token': 1197,
#   'token_str': 'beef_stew'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot mustard hen </s>',
#   'score': 0.00010935609316220507,
#   'token': 54,
#   'token_str': 'mustard'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot ground_black_pepper hen </s>',
#   'score': 0.00010752923844847828,
#   'token': 35,
#   'token_str': 'ground_black_pepper'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot gelatin hen </s>',
#   'score': 0.00010702491272240877,
#   'token': 311,
#   'token_str': 'gelatin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cut_up_chicken hen </s>',
#   'score': 0.00010678766557248309,
#   'token': 2858,
#   'token_str': 'cut_up_chicken'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cubed_beef hen </s>',
#   'score': 0.00010644918074831367,
#   'token': 2784,
#   'token_str': 'cubed_beef'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot granulated_sugar hen </s>',
#   'score': 0.00010572473547654226,
#   'token': 110,
#   'token_str': 'granulated_sugar'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cake_flour hen </s>',
#   'score': 0.00010509783896850422,
#   'token': 371,
#   'token_str': 'cake_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot whipping_cream hen </s>',
#   'score': 0.00010494245361769572,
#   'token': 171,
#   'token_str': 'whipping_cream'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot blood hen </s>',
#   'score': 0.00010483776713954285,
#   'token': 1759,
#   'token_str': 'blood'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bass hen </s>',
#   'score': 0.00010476565512362868,
#   'token': 1712,
#   'token_str': 'bass'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot minute_rice hen </s>',
#   'score': 0.00010472095164004713,
#   'token': 1552,
#   'token_str': 'minute_rice'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot bacon_drippings hen </s>',
#   'score': 0.00010469294647919014,
#   'token': 1678,
#   'token_str': 'bacon_drippings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pastry hen </s>',
#   'score': 0.00010458048927830532,
#   'token': 287,
#   'token_str': 'pastry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot frozen_spinach hen </s>',
#   'score': 0.00010443262726766989,
#   'token': 453,
#   'token_str': 'frozen_spinach'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boneless_skinless_chicken hen </s>',
#   'score': 0.0001038476184476167,
#   'token': 142,
#   'token_str': 'boneless_skinless_chicken'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot boiling_potatoes hen </s>',
#   'score': 0.00010351133823860437,
#   'token': 1487,
#   'token_str': 'boiling_potatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_round hen </s>',
#   'score': 0.00010345404734835029,
#   'token': 1668,
#   'token_str': 'beef_round'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crescent_rolls hen </s>',
#   'score': 0.000102761056041345,
#   'token': 1116,
#   'token_str': 'crescent_rolls'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sprig hen </s>',
#   'score': 0.00010248150647385046,
#   'token': 547,
#   'token_str': 'sprig'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pork_roast hen </s>',
#   'score': 0.0001024664961732924,
#   'token': 1270,
#   'token_str': 'pork_roast'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sweet_basil hen </s>',
#   'score': 0.0001011135900625959,
#   'token': 1764,
#   'token_str': 'sweet_basil'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_stock hen </s>',
#   'score': 0.00010036266030510888,
#   'token': 141,
#   'token_str': 'chicken_stock'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_pepper_seasoning hen </s>',
#   'score': 0.0001003510260488838,
#   'token': 2223,
#   'token_str': 'garlic_pepper_seasoning'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot green_cabbage hen </s>',
#   'score': 0.00010019004548666999,
#   'token': 761,
#   'token_str': 'green_cabbage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot white_pepper hen </s>',
#   'score': 9.972408588510007e-05,
#   'token': 244,
#   'token_str': 'white_pepper'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot kale hen </s>',
#   'score': 9.969318489311263e-05,
#   'token': 689,
#   'token_str': 'kale'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot lardons hen </s>',
#   'score': 9.962490003090352e-05,
#   'token': 2720,
#   'token_str': 'lardons'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot light_corn_syrup hen </s>',
#   'score': 9.956130816135556e-05,
#   'token': 425,
#   'token_str': 'light_corn_syrup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot katakuriko hen </s>',
#   'score': 9.88391402643174e-05,
#   'token': 1076,
#   'token_str': 'katakuriko'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cumin hen </s>',
#   'score': 9.854046220425516e-05,
#   'token': 168,
#   'token_str': 'cumin'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot much hen </s>',
#   'score': 9.849100024439394e-05,
#   'token': 1555,
#   'token_str': 'much'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot artichoke_hearts hen </s>',
#   'score': 9.812582720769569e-05,
#   'token': 465,
#   'token_str': 'artichoke_hearts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_bulb hen </s>',
#   'score': 9.79523392743431e-05,
#   'token': 3305,
#   'token_str': 'garlic_bulb'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_stew_meat hen </s>',
#   'score': 9.753357153385878e-05,
#   'token': 1235,
#   'token_str': 'beef_stew_meat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot kosher hen </s>',
#   'score': 9.75230650510639e-05,
#   'token': 58,
#   'token_str': 'kosher'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot pie_pastry hen </s>',
#   'score': 9.723197581479326e-05,
#   'token': 2936,
#   'token_str': 'pie_pastry'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot condensed_cream_of_celery_soup hen </s>',
#   'score': 9.654649329604581e-05,
#   'token': 1947,
#   'token_str': 'condensed_cream_of_celery_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot self_rising_flour hen </s>',
#   'score': 9.612539724912494e-05,
#   'token': 1316,
#   'token_str': 'self_rising_flour'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot tomato_soup hen </s>',
#   'score': 9.583012433722615e-05,
#   'token': 804,
#   'token_str': 'tomato_soup'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot soda hen </s>',
#   'score': 9.56239746301435e-05,
#   'token': 48,
#   'token_str': 'soda'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot radish hen </s>',
#   'score': 9.548437083140016e-05,
#   'token': 1079,
#   'token_str': 'radish'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot partially hen </s>',
#   'score': 9.518021397525445e-05,
#   'token': 1365,
#   'token_str': 'partially'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cilantro hen </s>',
#   'score': 9.498136205365881e-05,
#   'token': 60,
#   'token_str': 'cilantro'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot shimeji_mushrooms hen </s>',
#   'score': 9.493037941865623e-05,
#   'token': 2251,
#   'token_str': 'shimeji_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot plum_tomatoes hen </s>',
#   'score': 9.454810060560703e-05,
#   'token': 350,
#   'token_str': 'plum_tomatoes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot crabmeat hen </s>',
#   'score': 9.443861927138641e-05,
#   'token': 597,
#   'token_str': 'crabmeat'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot rubbed_sage hen </s>',
#   'score': 9.423201117897406e-05,
#   'token': 1531,
#   'token_str': 'rubbed_sage'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot orzo_pasta hen </s>',
#   'score': 9.408909681951627e-05,
#   'token': 1118,
#   'token_str': 'orzo_pasta'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot sliced_carrots hen </s>',
#   'score': 9.302858234150335e-05,
#   'token': 1268,
#   'token_str': 'sliced_carrots'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot liquor hen </s>',
#   'score': 9.283811959903687e-05,
#   'token': 2152,
#   'token_str': 'liquor'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot celery_heart hen </s>',
#   'score': 9.256684279534966e-05,
#   'token': 2951,
#   'token_str': 'celery_heart'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot garlic_granules hen </s>',
#   'score': 9.236045298166573e-05,
#   'token': 3089,
#   'token_str': 'garlic_granules'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot unbaked_pie_crusts hen </s>',
#   'score': 9.232654701918364e-05,
#   'token': 2937,
#   'token_str': 'unbaked_pie_crusts'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot chicken_wings hen </s>',
#   'score': 9.226828115060925e-05,
#   'token': 782,
#   'token_str': 'chicken_wings'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot cucumbers hen </s>',
#   'score': 9.204688831232488e-05,
#   'token': 500,
#   'token_str': 'cucumbers'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot dough hen </s>',
#   'score': 9.198791667586192e-05,
#   'token': 431,
#   'token_str': 'dough'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot artichokes hen </s>',
#   'score': 9.173149737762287e-05,
#   'token': 1042,
#   'token_str': 'artichokes'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot beef_shoulder hen </s>',
#   'score': 9.154988947557285e-05,
#   'token': 3428,
#   'token_str': 'beef_shoulder'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot allspice_berries hen </s>',
#   'score': 9.124429925577715e-05,
#   'token': 1366,
#   'token_str': 'allspice_berries'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot porcini_mushrooms hen </s>',
#   'score': 9.081449388759211e-05,
#   'token': 1349,
#   'token_str': 'porcini_mushrooms'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot yams hen </s>',
#   'score': 9.001775470096618e-05,
#   'token': 2042,
#   'token_str': 'yams'},
#  {'sequence': '<s> cold_water pepper salt chicken celery onion carrot slab_bacon hen </s>',
#   'score': 8.984241139842197e-05,
#   'token': 2151,
#   'token_str': 'slab_bacon'}]

# %%
fill_mask_recipe('bagel cheddar_cheese <mask>')
# Out:
# [{'sequence': '<s> bagel cheddar_cheese wheat </s>',
#   'score': 0.1582866907119751,
#   'token': 147,
#   'token_str': 'wheat'},
#  {'sequence': '<s> bagel cheddar_cheese honey </s>',
#   'score': 0.059073228389024734,
#   'token': 71,
#   'token_str': 'honey'},
#  {'sequence': '<s> bagel cheddar_cheese bacon </s>',
#   'score': 0.04927658662199974,
#   'token': 90,
#   'token_str': 'bacon'},
#  {'sequence': '<s> bagel cheddar_cheese apple </s>',
#   'score': 0.03522687032818794,
#   'token': 172,
#   'token_str': 'apple'},
#  {'sequence': '<s> bagel cheddar_cheese turkey </s>',
#   'score': 0.029940197244286537,
#   'token': 206,
#   'token_str': 'turkey'},
#  {'sequence': '<s> bagel cheddar_cheese chips </s>',
#   'score': 0.027665911242365837,
#   'token': 297,
#   'token_str': 'chips'},
#  {'sequence': '<s> bagel cheddar_cheese butter </s>',
#   'score': 0.027140742167830467,
#   'token': 7,
#   'token_str': 'butter'},
#  {'sequence': '<s> bagel cheddar_cheese mayonnaise </s>',
#   'score': 0.02631981298327446,
#   'token': 81,
#   'token_str': 'mayonnaise'},
#  {'sequence': '<s> bagel cheddar_cheese peanut_butter </s>',
#   'score': 0.024668611586093903,
#   'token': 177,
#   'token_str': 'peanut_butter'},
#  {'sequence': '<s> bagel cheddar_cheese fruit </s>',
#   'score': 0.024137310683727264,
#   'token': 487,
#   'token_str': 'fruit'},
#  {'sequence': '<s> bagel cheddar_cheese cream_cheese </s>',
#   'score': 0.02002648264169693,
#   'token': 62,
#   'token_str': 'cream_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese avocado </s>',
#   'score': 0.016539333388209343,
#   'token': 257,
#   'token_str': 'avocado'},
#  {'sequence': '<s> bagel cheddar_cheese cooked_bacon </s>',
#   'score': 0.016249191015958786,
#   'token': 898,
#   'token_str': 'cooked_bacon'},
#  {'sequence': '<s> bagel cheddar_cheese egg </s>',
#   'score': 0.015344949439167976,
#   'token': 29,
#   'token_str': 'egg'},
#  {'sequence': '<s> bagel cheddar_cheese bbq_sauce </s>',
#   'score': 0.013694417662918568,
#   'token': 1493,
#   'token_str': 'bbq_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese deli_ham </s>',
#   'score': 0.009685211814939976,
#   'token': 1272,
#   'token_str': 'deli_ham'},
#  {'sequence': '<s> bagel cheddar_cheese cheese_slices </s>',
#   'score': 0.008542731404304504,
#   'token': 1330,
#   'token_str': 'cheese_slices'},
#  {'sequence': '<s> bagel cheddar_cheese pear </s>',
#   'score': 0.008361012674868107,
#   'token': 828,
#   'token_str': 'pear'},
#  {'sequence': '<s> bagel cheddar_cheese banana </s>',
#   'score': 0.008009880781173706,
#   'token': 274,
#   'token_str': 'banana'},
#  {'sequence': '<s> bagel cheddar_cheese unsalted_butter </s>',
#   'score': 0.0075303856283426285,
#   'token': 44,
#   'token_str': 'unsalted_butter'},
#  {'sequence': '<s> bagel cheddar_cheese mustard </s>',
#   'score': 0.007438040338456631,
#   'token': 54,
#   'token_str': 'mustard'},
#  {'sequence': '<s> bagel cheddar_cheese low_fat </s>',
#   'score': 0.006738531403243542,
#   'token': 710,
#   'token_str': 'low_fat'},
#  {'sequence': '<s> bagel cheddar_cheese ranch_dressing </s>',
#   'score': 0.006544715259224176,
#   'token': 623,
#   'token_str': 'ranch_dressing'},
#  {'sequence': '<s> bagel cheddar_cheese philadelphia_cream_cheese </s>',
#   'score': 0.006459004711359739,
#   'token': 591,
#   'token_str': 'philadelphia_cream_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese smoked_turkey </s>',
#   'score': 0.006054474040865898,
#   'token': 1125,
#   'token_str': 'smoked_turkey'},
#  {'sequence': '<s> bagel cheddar_cheese strawberries </s>',
#   'score': 0.006049289833754301,
#   'token': 212,
#   'token_str': 'strawberries'},
#  {'sequence': '<s> bagel cheddar_cheese wholewheat </s>',
#   'score': 0.005735399667173624,
#   'token': 977,
#   'token_str': 'wholewheat'},
#  {'sequence': '<s> bagel cheddar_cheese sliced_turkey </s>',
#   'score': 0.005544022191315889,
#   'token': 3114,
#   'token_str': 'sliced_turkey'},
#  {'sequence': '<s> bagel cheddar_cheese baby_spinach </s>',
#   'score': 0.005352586507797241,
#   'token': 376,
#   'token_str': 'baby_spinach'},
#  {'sequence': '<s> bagel cheddar_cheese tomato </s>',
#   'score': 0.0051691122353076935,
#   'token': 50,
#   'token_str': 'tomato'},
#  {'sequence': '<s> bagel cheddar_cheese sunflower_seeds </s>',
#   'score': 0.0048152669332921505,
#   'token': 682,
#   'token_str': 'sunflower_seeds'},
#  {'sequence': '<s> bagel cheddar_cheese turkey_bacon </s>',
#   'score': 0.004488714039325714,
#   'token': 1543,
#   'token_str': 'turkey_bacon'},
#  {'sequence': '<s> bagel cheddar_cheese flavor </s>',
#   'score': 0.004379841033369303,
#   'token': 344,
#   'token_str': 'flavor'},
#  {'sequence': '<s> bagel cheddar_cheese beans </s>',
#   'score': 0.0042749326676130295,
#   'token': 98,
#   'token_str': 'beans'},
#  {'sequence': '<s> bagel cheddar_cheese rye </s>',
#   'score': 0.00403654295951128,
#   'token': 2141,
#   'token_str': 'rye'},
#  {'sequence': '<s> bagel cheddar_cheese light_cream_cheese </s>',
#   'score': 0.004003114067018032,
#   'token': 1091,
#   'token_str': 'light_cream_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese pineapple </s>',
#   'score': 0.003911212086677551,
#   'token': 149,
#   'token_str': 'pineapple'},
#  {'sequence': '<s> bagel cheddar_cheese meat </s>',
#   'score': 0.0036341396626085043,
#   'token': 370,
#   'token_str': 'meat'},
#  {'sequence': '<s> bagel cheddar_cheese cranberry_sauce </s>',
#   'score': 0.003613977460190654,
#   'token': 867,
#   'token_str': 'cranberry_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese salami </s>',
#   'score': 0.003536080475896597,
#   'token': 968,
#   'token_str': 'salami'},
#  {'sequence': '<s> bagel cheddar_cheese flavour </s>',
#   'score': 0.0034908000379800797,
#   'token': 1742,
#   'token_str': 'flavour'},
#  {'sequence': '<s> bagel cheddar_cheese berries </s>',
#   'score': 0.0034687283914536238,
#   'token': 711,
#   'token_str': 'berries'},
#  {'sequence': '<s> bagel cheddar_cheese baby_spinach_leaves </s>',
#   'score': 0.0033554956316947937,
#   'token': 814,
#   'token_str': 'baby_spinach_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese cooking_spray </s>',
#   'score': 0.003337080590426922,
#   'token': 199,
#   'token_str': 'cooking_spray'},
#  {'sequence': '<s> bagel cheddar_cheese reduced_fat </s>',
#   'score': 0.0031218859367072582,
#   'token': 667,
#   'token_str': 'reduced_fat'},
#  {'sequence': '<s> bagel cheddar_cheese ham </s>',
#   'score': 0.0030045912135392427,
#   'token': 239,
#   'token_str': 'ham'},
#  {'sequence': '<s> bagel cheddar_cheese sprouts </s>',
#   'score': 0.0029361392371356487,
#   'token': 475,
#   'token_str': 'sprouts'},
#  {'sequence': '<s> bagel cheddar_cheese pesto </s>',
#   'score': 0.002805260941386223,
#   'token': 565,
#   'token_str': 'pesto'},
#  {'sequence': '<s> bagel cheddar_cheese strawberry </s>',
#   'score': 0.0027653551660478115,
#   'token': 373,
#   'token_str': 'strawberry'},
#  {'sequence': '<s> bagel cheddar_cheese alfalfa </s>',
#   'score': 0.002765274839475751,
#   'token': 2948,
#   'token_str': 'alfalfa'},
#  {'sequence': '<s> bagel cheddar_cheese smoked_ham </s>',
#   'score': 0.0026557196397334337,
#   'token': 860,
#   'token_str': 'smoked_ham'},
#  {'sequence': '<s> bagel cheddar_cheese fig </s>',
#   'score': 0.0026399726048111916,
#   'token': 2226,
#   'token_str': 'fig'},
#  {'sequence': '<s> bagel cheddar_cheese cinnamon </s>',
#   'score': 0.0025187141727656126,
#   'token': 37,
#   'token_str': 'cinnamon'},
#  {'sequence': '<s> bagel cheddar_cheese whipped_cream_cheese </s>',
#   'score': 0.0023811596911400557,
#   'token': 1790,
#   'token_str': 'whipped_cream_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese salt </s>',
#   'score': 0.002371478360146284,
#   'token': 5,
#   'token_str': 'salt'},
#  {'sequence': '<s> bagel cheddar_cheese creamy_peanut_butter </s>',
#   'score': 0.0023681267630308867,
#   'token': 619,
#   'token_str': 'creamy_peanut_butter'},
#  {'sequence': '<s> bagel cheddar_cheese nutella </s>',
#   'score': 0.002320852829143405,
#   'token': 1628,
#   'token_str': 'nutella'},
#  {'sequence': '<s> bagel cheddar_cheese dill_pickle </s>',
#   'score': 0.0022576521150767803,
#   'token': 1225,
#   'token_str': 'dill_pickle'},
#  {'sequence': '<s> bagel cheddar_cheese sugar </s>',
#   'score': 0.002199293114244938,
#   'token': 9,
#   'token_str': 'sugar'},
#  {'sequence': '<s> bagel cheddar_cheese sausage </s>',
#   'score': 0.0020897299982607365,
#   'token': 161,
#   'token_str': 'sausage'},
#  {'sequence': '<s> bagel cheddar_cheese sour_cream </s>',
#   'score': 0.00207572802901268,
#   'token': 59,
#   'token_str': 'sour_cream'},
#  {'sequence': '<s> bagel cheddar_cheese seed_oil </s>',
#   'score': 0.0020045191049575806,
#   'token': 1846,
#   'token_str': 'seed_oil'},
#  {'sequence': '<s> bagel cheddar_cheese roast_beef </s>',
#   'score': 0.001972919562831521,
#   'token': 1258,
#   'token_str': 'roast_beef'},
#  {'sequence': '<s> bagel cheddar_cheese sliced_tomatoes </s>',
#   'score': 0.0019598768558353186,
#   'token': 2009,
#   'token_str': 'sliced_tomatoes'},
#  {'sequence': '<s> bagel cheddar_cheese poppy_seed </s>',
#   'score': 0.001930965343490243,
#   'token': 1120,
#   'token_str': 'poppy_seed'},
#  {'sequence': '<s> bagel cheddar_cheese hot_dogs </s>',
#   'score': 0.001926748431287706,
#   'token': 1221,
#   'token_str': 'hot_dogs'},
#  {'sequence': '<s> bagel cheddar_cheese lettuce </s>',
#   'score': 0.0019112256122753024,
#   'token': 150,
#   'token_str': 'lettuce'},
#  {'sequence': '<s> bagel cheddar_cheese grain </s>',
#   'score': 0.0019006088841706514,
#   'token': 379,
#   'token_str': 'grain'},
#  {'sequence': '<s> bagel cheddar_cheese nonhydrogenated_margarine </s>',
#   'score': 0.001879821065813303,
#   'token': 1960,
#   'token_str': 'nonhydrogenated_margarine'},
#  {'sequence': '<s> bagel cheddar_cheese canola_oil </s>',
#   'score': 0.0018752702744677663,
#   'token': 152,
#   'token_str': 'canola_oil'},
#  {'sequence': '<s> bagel cheddar_cheese eggs </s>',
#   'score': 0.0018596434965729713,
#   'token': 18,
#   'token_str': 'eggs'},
#  {'sequence': '<s> bagel cheddar_cheese real_bacon </s>',
#   'score': 0.001806806423701346,
#   'token': 1787,
#   'token_str': 'real_bacon'},
#  {'sequence': '<s> bagel cheddar_cheese bacon_slices </s>',
#   'score': 0.001803552731871605,
#   'token': 1164,
#   'token_str': 'bacon_slices'},
#  {'sequence': '<s> bagel cheddar_cheese hass_avocado </s>',
#   'score': 0.0016901851631700993,
#   'token': 2273,
#   'token_str': 'hass_avocado'},
#  {'sequence': '<s> bagel cheddar_cheese tomatoes </s>',
#   'score': 0.0016725485911592841,
#   'token': 26,
#   'token_str': 'tomatoes'},
#  {'sequence': '<s> bagel cheddar_cheese prosciutto </s>',
#   'score': 0.0016616897191852331,
#   'token': 528,
#   'token_str': 'prosciutto'},
#  {'sequence': '<s> bagel cheddar_cheese bread </s>',
#   'score': 0.001649703597649932,
#   'token': 74,
#   'token_str': 'bread'},
#  {'sequence': '<s> bagel cheddar_cheese walnuts </s>',
#   'score': 0.001609288272447884,
#   'token': 129,
#   'token_str': 'walnuts'},
#  {'sequence': '<s> bagel cheddar_cheese rounds </s>',
#   'score': 0.001597926253452897,
#   'token': 778,
#   'token_str': 'rounds'},
#  {'sequence': '<s> bagel cheddar_cheese dijon_mustard </s>',
#   'score': 0.0015791909536346793,
#   'token': 148,
#   'token_str': 'dijon_mustard'},
#  {'sequence': '<s> bagel cheddar_cheese brown </s>',
#   'score': 0.0015704305842518806,
#   'token': 27,
#   'token_str': 'brown'},
#  {'sequence': '<s> bagel cheddar_cheese water </s>',
#   'score': 0.0015647526597604156,
#   'token': 13,
#   'token_str': 'water'},
#  {'sequence': '<s> bagel cheddar_cheese spicy_brown_mustard </s>',
#   'score': 0.001523509039543569,
#   'token': 1224,
#   'token_str': 'spicy_brown_mustard'},
#  {'sequence': '<s> bagel cheddar_cheese leaf_lettuce </s>',
#   'score': 0.0015142185147851706,
#   'token': 989,
#   'token_str': 'leaf_lettuce'},
#  {'sequence': '<s> bagel cheddar_cheese onion_slices </s>',
#   'score': 0.0014878906076774001,
#   'token': 1761,
#   'token_str': 'onion_slices'},
#  {'sequence': '<s> bagel cheddar_cheese wheat_bread </s>',
#   'score': 0.0014838655479252338,
#   'token': 771,
#   'token_str': 'wheat_bread'},
#  {'sequence': '<s> bagel cheddar_cheese pastrami </s>',
#   'score': 0.0014398557832464576,
#   'token': 2644,
#   'token_str': 'pastrami'},
#  {'sequence': '<s> bagel cheddar_cheese smoked_turkey_breast </s>',
#   'score': 0.001423924695700407,
#   'token': 2270,
#   'token_str': 'smoked_turkey_breast'},
#  {'sequence': '<s> bagel cheddar_cheese cream_cheese_spread </s>',
#   'score': 0.0013915365561842918,
#   'token': 1358,
#   'token_str': 'cream_cheese_spread'},
#  {'sequence': '<s> bagel cheddar_cheese hummus </s>',
#   'score': 0.0013896070886403322,
#   'token': 1452,
#   'token_str': 'hummus'},
#  {'sequence': '<s> bagel cheddar_cheese yellow_mustard </s>',
#   'score': 0.0013894062722101808,
#   'token': 614,
#   'token_str': 'yellow_mustard'},
#  {'sequence': '<s> bagel cheddar_cheese sesame_seeds </s>',
#   'score': 0.001360568217933178,
#   'token': 234,
#   'token_str': 'sesame_seeds'},
#  {'sequence': '<s> bagel cheddar_cheese cheese_cubes </s>',
#   'score': 0.0013435294385999441,
#   'token': 3128,
#   'token_str': 'cheese_cubes'},
#  {'sequence': '<s> bagel cheddar_cheese pesto_sauce </s>',
#   'score': 0.0013317232951521873,
#   'token': 1048,
#   'token_str': 'pesto_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese barbecue_sauce </s>',
#   'score': 0.0013146582059562206,
#   'token': 441,
#   'token_str': 'barbecue_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese green_onions </s>',
#   'score': 0.0013088557170704007,
#   'token': 103,
#   'token_str': 'green_onions'},
#  {'sequence': '<s> bagel cheddar_cheese basil_leaves </s>',
#   'score': 0.0012760953977704048,
#   'token': 238,
#   'token_str': 'basil_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese balsamic_vinaigrette </s>',
#   'score': 0.0012701298110187054,
#   'token': 1045,
#   'token_str': 'balsamic_vinaigrette'},
#  {'sequence': '<s> bagel cheddar_cheese dill_pickles </s>',
#   'score': 0.0012640106724575162,
#   'token': 1350,
#   'token_str': 'dill_pickles'},
#  {'sequence': '<s> bagel cheddar_cheese peach </s>',
#   'score': 0.0012420652201399207,
#   'token': 687,
#   'token_str': 'peach'},
#  {'sequence': '<s> bagel cheddar_cheese black_sesame_seeds </s>',
#   'score': 0.0012343389680609107,
#   'token': 1687,
#   'token_str': 'black_sesame_seeds'},
#  {'sequence': '<s> bagel cheddar_cheese onion </s>',
#   'score': 0.0012302404502406716,
#   'token': 11,
#   'token_str': 'onion'},
#  {'sequence': '<s> bagel cheddar_cheese fat_free </s>',
#   'score': 0.0012170893605798483,
#   'token': 407,
#   'token_str': 'fat_free'},
#  {'sequence': '<s> bagel cheddar_cheese spinach </s>',
#   'score': 0.001206801040098071,
#   'token': 113,
#   'token_str': 'spinach'},
#  {'sequence': '<s> bagel cheddar_cheese spam </s>',
#   'score': 0.00119463459122926,
#   'token': 2607,
#   'token_str': 'spam'},
#  {'sequence': '<s> bagel cheddar_cheese softened_butter </s>',
#   'score': 0.001173354685306549,
#   'token': 916,
#   'token_str': 'softened_butter'},
#  {'sequence': '<s> bagel cheddar_cheese black_forest_ham </s>',
#   'score': 0.0011455521453171968,
#   'token': 3113,
#   'token_str': 'black_forest_ham'},
#  {'sequence': '<s> bagel cheddar_cheese sliced_ham </s>',
#   'score': 0.0011445519048720598,
#   'token': 1682,
#   'token_str': 'sliced_ham'},
#  {'sequence': '<s> bagel cheddar_cheese canned_black_beans </s>',
#   'score': 0.0011429865844547749,
#   'token': 1866,
#   'token_str': 'canned_black_beans'},
#  {'sequence': '<s> bagel cheddar_cheese olive_oil </s>',
#   'score': 0.001113863312639296,
#   'token': 12,
#   'token_str': 'olive_oil'},
#  {'sequence': '<s> bagel cheddar_cheese carrot </s>',
#   'score': 0.0011079474352300167,
#   'token': 140,
#   'token_str': 'carrot'},
#  {'sequence': '<s> bagel cheddar_cheese seasonings </s>',
#   'score': 0.001067296601831913,
#   'token': 1652,
#   'token_str': 'seasonings'},
#  {'sequence': '<s> bagel cheddar_cheese stick_butter </s>',
#   'score': 0.001056108856573701,
#   'token': 405,
#   'token_str': 'stick_butter'},
#  {'sequence': '<s> bagel cheddar_cheese pickles </s>',
#   'score': 0.0010505798272788525,
#   'token': 835,
#   'token_str': 'pickles'},
#  {'sequence': '<s> bagel cheddar_cheese maple_syrup </s>',
#   'score': 0.001046145218424499,
#   'token': 241,
#   'token_str': 'maple_syrup'},
#  {'sequence': '<s> bagel cheddar_cheese roasted_turkey_breast </s>',
#   'score': 0.00104434450622648,
#   'token': 2210,
#   'token_str': 'roasted_turkey_breast'},
#  {'sequence': '<s> bagel cheddar_cheese red_onion </s>',
#   'score': 0.0010433405404910445,
#   'token': 120,
#   'token_str': 'red_onion'},
#  {'sequence': '<s> bagel cheddar_cheese salad </s>',
#   'score': 0.0010347060160711408,
#   'token': 459,
#   'token_str': 'salad'},
#  {'sequence': '<s> bagel cheddar_cheese apple_butter </s>',
#   'score': 0.00103195256087929,
#   'token': 1849,
#   'token_str': 'apple_butter'},
#  {'sequence': '<s> bagel cheddar_cheese alfalfa_sprouts </s>',
#   'score': 0.0010203205747529864,
#   'token': 2603,
#   'token_str': 'alfalfa_sprouts'},
#  {'sequence': '<s> bagel cheddar_cheese honey_mustard </s>',
#   'score': 0.0010058814659714699,
#   'token': 1319,
#   'token_str': 'honey_mustard'},
#  {'sequence': '<s> bagel cheddar_cheese chili_powder </s>',
#   'score': 0.0010022117057815194,
#   'token': 121,
#   'token_str': 'chili_powder'},
#  {'sequence': '<s> bagel cheddar_cheese lavash </s>',
#   'score': 0.000988377956673503,
#   'token': 3029,
#   'token_str': 'lavash'},
#  {'sequence': '<s> bagel cheddar_cheese fl </s>',
#   'score': 0.0009736143401823938,
#   'token': 1032,
#   'token_str': 'fl'},
#  {'sequence': '<s> bagel cheddar_cheese pickle_relish </s>',
#   'score': 0.0009603346697986126,
#   'token': 976,
#   'token_str': 'pickle_relish'},
#  {'sequence': '<s> bagel cheddar_cheese seasoning </s>',
#   'score': 0.0009591667912900448,
#   'token': 78,
#   'token_str': 'seasoning'},
#  {'sequence': '<s> bagel cheddar_cheese chili </s>',
#   'score': 0.0009543728083372116,
#   'token': 185,
#   'token_str': 'chili'},
#  {'sequence': '<s> bagel cheddar_cheese tapenade </s>',
#   'score': 0.0009481522138230503,
#   'token': 2855,
#   'token_str': 'tapenade'},
#  {'sequence': '<s> bagel cheddar_cheese vegetable </s>',
#   'score': 0.0009212212753482163,
#   'token': 32,
#   'token_str': 'vegetable'},
#  {'sequence': '<s> bagel cheddar_cheese mango </s>',
#   'score': 0.000912182149477303,
#   'token': 522,
#   'token_str': 'mango'},
#  {'sequence': '<s> bagel cheddar_cheese taco_seasoning_mix </s>',
#   'score': 0.0009086896316148341,
#   'token': 740,
#   'token_str': 'taco_seasoning_mix'},
#  {'sequence': '<s> bagel cheddar_cheese strawberry_jam </s>',
#   'score': 0.0008872424368746579,
#   'token': 1130,
#   'token_str': 'strawberry_jam'},
#  {'sequence': '<s> bagel cheddar_cheese instant_coffee </s>',
#   'score': 0.0008772797300480306,
#   'token': 599,
#   'token_str': 'instant_coffee'},
#  {'sequence': '<s> bagel cheddar_cheese sourdough </s>',
#   'score': 0.0008728408720344305,
#   'token': 758,
#   'token_str': 'sourdough'},
#  {'sequence': '<s> bagel cheddar_cheese salted_butter </s>',
#   'score': 0.0008680498576723039,
#   'token': 716,
#   'token_str': 'salted_butter'},
#  {'sequence': '<s> bagel cheddar_cheese in_water </s>',
#   'score': 0.0008529049227945507,
#   'token': 585,
#   'token_str': 'in_water'},
#  {'sequence': '<s> bagel cheddar_cheese pepperoni_slices </s>',
#   'score': 0.0008502371492795646,
#   'token': 2059,
#   'token_str': 'pepperoni_slices'},
#  {'sequence': '<s> bagel cheddar_cheese egg_white </s>',
#   'score': 0.0008442986290901899,
#   'token': 387,
#   'token_str': 'egg_white'},
#  {'sequence': '<s> bagel cheddar_cheese chicken </s>',
#   'score': 0.0008178214193321764,
#   'token': 24,
#   'token_str': 'chicken'},
#  {'sequence': '<s> bagel cheddar_cheese kosher </s>',
#   'score': 0.0007760017178952694,
#   'token': 58,
#   'token_str': 'kosher'},
#  {'sequence': '<s> bagel cheddar_cheese pepperoni </s>',
#   'score': 0.0007710300851613283,
#   'token': 733,
#   'token_str': 'pepperoni'},
#  {'sequence': '<s> bagel cheddar_cheese applesauce </s>',
#   'score': 0.0007628875900991261,
#   'token': 473,
#   'token_str': 'applesauce'},
#  {'sequence': '<s> bagel cheddar_cheese peaches </s>',
#   'score': 0.0007626868318766356,
#   'token': 427,
#   'token_str': 'peaches'},
#  {'sequence': '<s> bagel cheddar_cheese liquid_honey </s>',
#   'score': 0.0007571828900836408,
#   'token': 2005,
#   'token_str': 'liquid_honey'},
#  {'sequence': '<s> bagel cheddar_cheese mango_chutney </s>',
#   'score': 0.0007565613486804068,
#   'token': 1733,
#   'token_str': 'mango_chutney'},
#  {'sequence': '<s> bagel cheddar_cheese lettuce_leaves </s>',
#   'score': 0.0007175073260441422,
#   'token': 569,
#   'token_str': 'lettuce_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese vegan_mayonnaise </s>',
#   'score': 0.0007171218749135733,
#   'token': 3361,
#   'token_str': 'vegan_mayonnaise'},
#  {'sequence': '<s> bagel cheddar_cheese thousand_island_dressing </s>',
#   'score': 0.0007124952971935272,
#   'token': 1669,
#   'token_str': 'thousand_island_dressing'},
#  {'sequence': '<s> bagel cheddar_cheese dried_cranberries </s>',
#   'score': 0.0007027690880931914,
#   'token': 411,
#   'token_str': 'dried_cranberries'},
#  {'sequence': '<s> bagel cheddar_cheese avocados </s>',
#   'score': 0.000696756353136152,
#   'token': 509,
#   'token_str': 'avocados'},
#  {'sequence': '<s> bagel cheddar_cheese raspberry_preserves </s>',
#   'score': 0.0006754546775482595,
#   'token': 1622,
#   'token_str': 'raspberry_preserves'},
#  {'sequence': '<s> bagel cheddar_cheese custard </s>',
#   'score': 0.0006750077591277659,
#   'token': 1746,
#   'token_str': 'custard'},
#  {'sequence': '<s> bagel cheddar_cheese strawberry_preserves </s>',
#   'score': 0.0006732080364599824,
#   'token': 2130,
#   'token_str': 'strawberry_preserves'},
#  {'sequence': '<s> bagel cheddar_cheese grapes </s>',
#   'score': 0.000671449932269752,
#   'token': 613,
#   'token_str': 'grapes'},
#  {'sequence': '<s> bagel cheddar_cheese hot_pepper </s>',
#   'score': 0.0006671326118521392,
#   'token': 409,
#   'token_str': 'hot_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese pumpernickel </s>',
#   'score': 0.0006639210041612387,
#   'token': 1579,
#   'token_str': 'pumpernickel'},
#  {'sequence': '<s> bagel cheddar_cheese melted_butter </s>',
#   'score': 0.0006627990514971316,
#   'token': 270,
#   'token_str': 'melted_butter'},
#  {'sequence': '<s> bagel cheddar_cheese cucumbers </s>',
#   'score': 0.0006622528308071196,
#   'token': 500,
#   'token_str': 'cucumbers'},
#  {'sequence': '<s> bagel cheddar_cheese multigrain_bread </s>',
#   'score': 0.0006619686610065401,
#   'token': 2770,
#   'token_str': 'multigrain_bread'},
#  {'sequence': '<s> bagel cheddar_cheese kale </s>',
#   'score': 0.0006602962384931743,
#   'token': 689,
#   'token_str': 'kale'},
#  {'sequence': '<s> bagel cheddar_cheese frozen_raspberries </s>',
#   'score': 0.0006590285920538008,
#   'token': 1277,
#   'token_str': 'frozen_raspberries'},
#  {'sequence': '<s> bagel cheddar_cheese sausages </s>',
#   'score': 0.0006556184380315244,
#   'token': 766,
#   'token_str': 'sausages'},
#  {'sequence': '<s> bagel cheddar_cheese malt </s>',
#   'score': 0.0006391010247170925,
#   'token': 3107,
#   'token_str': 'malt'},
#  {'sequence': '<s> bagel cheddar_cheese sea_salt </s>',
#   'score': 0.0006363046704791486,
#   'token': 137,
#   'token_str': 'sea_salt'},
#  {'sequence': '<s> bagel cheddar_cheese sesame_seed </s>',
#   'score': 0.0006331240874715149,
#   'token': 1532,
#   'token_str': 'sesame_seed'},
#  {'sequence': '<s> bagel cheddar_cheese herbs </s>',
#   'score': 0.0006205962272360921,
#   'token': 656,
#   'token_str': 'herbs'},
#  {'sequence': '<s> bagel cheddar_cheese olive </s>',
#   'score': 0.0006161342025734484,
#   'token': 15,
#   'token_str': 'olive'},
#  {'sequence': '<s> bagel cheddar_cheese oscar_mayer_bacon </s>',
#   'score': 0.0006123718922026455,
#   'token': 1198,
#   'token_str': 'oscar_mayer_bacon'},
#  {'sequence': '<s> bagel cheddar_cheese chutney </s>',
#   'score': 0.0006046686903573573,
#   'token': 1208,
#   'token_str': 'chutney'},
#  {'sequence': '<s> bagel cheddar_cheese chives </s>',
#   'score': 0.0006022354937158525,
#   'token': 190,
#   'token_str': 'chives'},
#  {'sequence': '<s> bagel cheddar_cheese sesame </s>',
#   'score': 0.0005994923994876444,
#   'token': 106,
#   'token_str': 'sesame'},
#  {'sequence': '<s> bagel cheddar_cheese american_cheese </s>',
#   'score': 0.0005982781876809895,
#   'token': 700,
#   'token_str': 'american_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese jalapeno </s>',
#   'score': 0.0005973443039692938,
#   'token': 143,
#   'token_str': 'jalapeno'},
#  {'sequence': '<s> bagel cheddar_cheese mature_cheddar </s>',
#   'score': 0.0005876898067072034,
#   'token': 2962,
#   'token_str': 'mature_cheddar'},
#  {'sequence': '<s> bagel cheddar_cheese sweet_pickle_relish </s>',
#   'score': 0.0005829781293869019,
#   'token': 1244,
#   'token_str': 'sweet_pickle_relish'},
#  {'sequence': '<s> bagel cheddar_cheese orange </s>',
#   'score': 0.000564904126804322,
#   'token': 73,
#   'token_str': 'orange'},
#  {'sequence': '<s> bagel cheddar_cheese coarse_sea_salt </s>',
#   'score': 0.000563278968911618,
#   'token': 1122,
#   'token_str': 'coarse_sea_salt'},
#  {'sequence': '<s> bagel cheddar_cheese veggies </s>',
#   'score': 0.0005519347614608705,
#   'token': 2111,
#   'token_str': 'veggies'},
#  {'sequence': '<s> bagel cheddar_cheese onions </s>',
#   'score': 0.000550979922991246,
#   'token': 30,
#   'token_str': 'onions'},
#  {'sequence': '<s> bagel cheddar_cheese red_chili </s>',
#   'score': 0.0005470729083754122,
#   'token': 462,
#   'token_str': 'red_chili'},
#  {'sequence': '<s> bagel cheddar_cheese chia_seeds </s>',
#   'score': 0.0005373679450713098,
#   'token': 1466,
#   'token_str': 'chia_seeds'},
#  {'sequence': '<s> bagel cheddar_cheese sauce </s>',
#   'score': 0.0005340041243471205,
#   'token': 25,
#   'token_str': 'sauce'},
#  {'sequence': '<s> bagel cheddar_cheese seedless_watermelon </s>',
#   'score': 0.0005263497587293386,
#   'token': 1656,
#   'token_str': 'seedless_watermelon'},
#  {'sequence': '<s> bagel cheddar_cheese crumbles </s>',
#   'score': 0.0005208795773796737,
#   'token': 946,
#   'token_str': 'crumbles'},
#  {'sequence': '<s> bagel cheddar_cheese kosher_salt </s>',
#   'score': 0.0005163198802620173,
#   'token': 53,
#   'token_str': 'kosher_salt'},
#  {'sequence': '<s> bagel cheddar_cheese beet </s>',
#   'score': 0.0005104946321807802,
#   'token': 1550,
#   'token_str': 'beet'},
#  {'sequence': '<s> bagel cheddar_cheese coleslaw </s>',
#   'score': 0.0005087052122689784,
#   'token': 1039,
#   'token_str': 'coleslaw'},
#  {'sequence': '<s> bagel cheddar_cheese cucumber </s>',
#   'score': 0.0005049075116403401,
#   'token': 245,
#   'token_str': 'cucumber'},
#  {'sequence': '<s> bagel cheddar_cheese asian_pear </s>',
#   'score': 0.0005035367794334888,
#   'token': 3223,
#   'token_str': 'asian_pear'},
#  {'sequence': '<s> bagel cheddar_cheese pistachios </s>',
#   'score': 0.0004955188487656415,
#   'token': 618,
#   'token_str': 'pistachios'},
#  {'sequence': '<s> bagel cheddar_cheese calories </s>',
#   'score': 0.0004950069123879075,
#   'token': 2833,
#   'token_str': 'calories'},
#  {'sequence': '<s> bagel cheddar_cheese english_cucumber </s>',
#   'score': 0.0004895848105661571,
#   'token': 1066,
#   'token_str': 'english_cucumber'},
#  {'sequence': '<s> bagel cheddar_cheese wholemeal </s>',
#   'score': 0.000485951139125973,
#   'token': 2046,
#   'token_str': 'wholemeal'},
#  {'sequence': '<s> bagel cheddar_cheese laughing_cow </s>',
#   'score': 0.00048252110718749464,
#   'token': 3087,
#   'token_str': 'laughing_cow'},
#  {'sequence': '<s> bagel cheddar_cheese sandwich_bread </s>',
#   'score': 0.00048210093518719077,
#   'token': 1589,
#   'token_str': 'sandwich_bread'},
#  {'sequence': '<s> bagel cheddar_cheese havarti_cheese </s>',
#   'score': 0.0004742610617540777,
#   'token': 2164,
#   'token_str': 'havarti_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese pears </s>',
#   'score': 0.00047087602433748543,
#   'token': 567,
#   'token_str': 'pears'},
#  {'sequence': '<s> bagel cheddar_cheese herb </s>',
#   'score': 0.00046738877426832914,
#   'token': 978,
#   'token_str': 'herb'},
#  {'sequence': '<s> bagel cheddar_cheese sriracha </s>',
#   'score': 0.000466810364741832,
#   'token': 668,
#   'token_str': 'sriracha'},
#  {'sequence': '<s> bagel cheddar_cheese potato_chips </s>',
#   'score': 0.00046636315528303385,
#   'token': 1176,
#   'token_str': 'potato_chips'},
#  {'sequence': '<s> bagel cheddar_cheese walnut </s>',
#   'score': 0.00045690039405599236,
#   'token': 701,
#   'token_str': 'walnut'},
#  {'sequence': '<s> bagel cheddar_cheese endive </s>',
#   'score': 0.00045604517799802125,
#   'token': 1299,
#   'token_str': 'endive'},
#  {'sequence': '<s> bagel cheddar_cheese cherry </s>',
#   'score': 0.0004556187486741692,
#   'token': 402,
#   'token_str': 'cherry'},
#  {'sequence': '<s> bagel cheddar_cheese jam </s>',
#   'score': 0.00045338214840739965,
#   'token': 1342,
#   'token_str': 'jam'},
#  {'sequence': '<s> bagel cheddar_cheese croissants </s>',
#   'score': 0.00043083957280032337,
#   'token': 2863,
#   'token_str': 'croissants'},
#  {'sequence': '<s> bagel cheddar_cheese egg_whites </s>',
#   'score': 0.0004286167095415294,
#   'token': 184,
#   'token_str': 'egg_whites'},
#  {'sequence': '<s> bagel cheddar_cheese vegetables </s>',
#   'score': 0.0004267091862857342,
#   'token': 420,
#   'token_str': 'vegetables'},
#  {'sequence': '<s> bagel cheddar_cheese smoked_salmon </s>',
#   'score': 0.0004260020796209574,
#   'token': 995,
#   'token_str': 'smoked_salmon'},
#  {'sequence': '<s> bagel cheddar_cheese whole_wheat </s>',
#   'score': 0.0004173156921751797,
#   'token': 1937,
#   'token_str': 'whole_wheat'},
#  {'sequence': '<s> bagel cheddar_cheese heirloom_tomatoes </s>',
#   'score': 0.0004163846606388688,
#   'token': 2050,
#   'token_str': 'heirloom_tomatoes'},
#  {'sequence': '<s> bagel cheddar_cheese green_apple </s>',
#   'score': 0.00041553654591552913,
#   'token': 1573,
#   'token_str': 'green_apple'},
#  {'sequence': '<s> bagel cheddar_cheese salsa </s>',
#   'score': 0.00041372806299477816,
#   'token': 290,
#   'token_str': 'salsa'},
#  {'sequence': '<s> bagel cheddar_cheese raspberry </s>',
#   'score': 0.00041364794014953077,
#   'token': 397,
#   'token_str': 'raspberry'},
#  {'sequence': '<s> bagel cheddar_cheese chunky_peanut_butter </s>',
#   'score': 0.0004099129873793572,
#   'token': 1427,
#   'token_str': 'chunky_peanut_butter'},
#  {'sequence': '<s> bagel cheddar_cheese cheese </s>',
#   'score': 0.0004081870138179511,
#   'token': 21,
#   'token_str': 'cheese'},
#  {'sequence': '<s> bagel cheddar_cheese cooked_turkey </s>',
#   'score': 0.00040550765697844326,
#   'token': 882,
#   'token_str': 'cooked_turkey'},
#  {'sequence': '<s> bagel cheddar_cheese toasted_pecans </s>',
#   'score': 0.0004051705764140934,
#   'token': 1384,
#   'token_str': 'toasted_pecans'},
#  {'sequence': '<s> bagel cheddar_cheese watercress </s>',
#   'score': 0.00040106018423102796,
#   'token': 650,
#   'token_str': 'watercress'},
#  {'sequence': '<s> bagel cheddar_cheese olives </s>',
#   'score': 0.00039804825792089105,
#   'token': 196,
#   'token_str': 'olives'},
#  {'sequence': '<s> bagel cheddar_cheese dressing </s>',
#   'score': 0.0003969735116697848,
#   'token': 153,
#   'token_str': 'dressing'},
#  {'sequence': '<s> bagel cheddar_cheese grapeseed_oil </s>',
#   'score': 0.0003965966170653701,
#   'token': 893,
#   'token_str': 'grapeseed_oil'},
#  {'sequence': '<s> bagel cheddar_cheese cayenne_pepper </s>',
#   'score': 0.00039639166789129376,
#   'token': 115,
#   'token_str': 'cayenne_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese mild_salsa </s>',
#   'score': 0.00039428783929906785,
#   'token': 2779,
#   'token_str': 'mild_salsa'},
#  {'sequence': '<s> bagel cheddar_cheese food_coloring </s>',
#   'score': 0.00039280892815440893,
#   'token': 471,
#   'token_str': 'food_coloring'},
#  {'sequence': '<s> bagel cheddar_cheese bread_slices </s>',
#   'score': 0.0003871027729474008,
#   'token': 1492,
#   'token_str': 'bread_slices'},
#  {'sequence': '<s> bagel cheddar_cheese baguette </s>',
#   'score': 0.00038612642674706876,
#   'token': 551,
#   'token_str': 'baguette'},
#  {'sequence': '<s> bagel cheddar_cheese garlic </s>',
#   'score': 0.000382653612177819,
#   'token': 8,
#   'token_str': 'garlic'},
#  {'sequence': '<s> bagel cheddar_cheese chipotle_pepper </s>',
#   'score': 0.00037951814010739326,
#   'token': 1560,
#   'token_str': 'chipotle_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese cherry_tomatoes </s>',
#   'score': 0.0003786172310356051,
#   'token': 308,
#   'token_str': 'cherry_tomatoes'},
#  {'sequence': '<s> bagel cheddar_cheese cheese_spread </s>',
#   'score': 0.0003772449563257396,
#   'token': 1000,
#   'token_str': 'cheese_spread'},
#  {'sequence': '<s> bagel cheddar_cheese chorizo </s>',
#   'score': 0.00036738967173732817,
#   'token': 1038,
#   'token_str': 'chorizo'},
#  {'sequence': '<s> bagel cheddar_cheese flatbread </s>',
#   'score': 0.00035370441037230194,
#   'token': 2605,
#   'token_str': 'flatbread'},
#  {'sequence': '<s> bagel cheddar_cheese powder </s>',
#   'score': 0.00035220218705944717,
#   'token': 16,
#   'token_str': 'powder'},
#  {'sequence': '<s> bagel cheddar_cheese romaine_lettuce </s>',
#   'score': 0.0003452574019320309,
#   'token': 423,
#   'token_str': 'romaine_lettuce'},
#  {'sequence': '<s> bagel cheddar_cheese dried_apricots </s>',
#   'score': 0.00034507340751588345,
#   'token': 853,
#   'token_str': 'dried_apricots'},
#  {'sequence': '<s> bagel cheddar_cheese round_loaf </s>',
#   'score': 0.0003439694410189986,
#   'token': 3051,
#   'token_str': 'round_loaf'},
#  {'sequence': '<s> bagel cheddar_cheese reduced_fat_cream_cheese </s>',
#   'score': 0.0003422383451834321,
#   'token': 3217,
#   'token_str': 'reduced_fat_cream_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese bacon_bits </s>',
#   'score': 0.0003415211976971477,
#   'token': 999,
#   'token_str': 'bacon_bits'},
#  {'sequence': '<s> bagel cheddar_cheese mesclun </s>',
#   'score': 0.00034072124981321394,
#   'token': 1734,
#   'token_str': 'mesclun'},
#  {'sequence': '<s> bagel cheddar_cheese reduced_fat_mayonnaise </s>',
#   'score': 0.00033999691368080676,
#   'token': 1415,
#   'token_str': 'reduced_fat_mayonnaise'},
#  {'sequence': '<s> bagel cheddar_cheese hazelnut </s>',
#   'score': 0.00033471250208094716,
#   'token': 1381,
#   'token_str': 'hazelnut'},
#  {'sequence': '<s> bagel cheddar_cheese coconut </s>',
#   'score': 0.00033255413291044533,
#   'token': 112,
#   'token_str': 'coconut'},
#  {'sequence': '<s> bagel cheddar_cheese light_mayonnaise </s>',
#   'score': 0.00033217298914678395,
#   'token': 1177,
#   'token_str': 'light_mayonnaise'},
#  {'sequence': '<s> bagel cheddar_cheese salad_dressing </s>',
#   'score': 0.00033052838989533484,
#   'token': 413,
#   'token_str': 'salad_dressing'},
#  {'sequence': '<s> bagel cheddar_cheese seeds </s>',
#   'score': 0.00032801920315250754,
#   'token': 200,
#   'token_str': 'seeds'},
#  {'sequence': '<s> bagel cheddar_cheese margarine </s>',
#   'score': 0.00032789583201520145,
#   'token': 80,
#   'token_str': 'margarine'},
#  {'sequence': '<s> bagel cheddar_cheese soft_margarine </s>',
#   'score': 0.00032662556623108685,
#   'token': 2070,
#   'token_str': 'soft_margarine'},
#  {'sequence': '<s> bagel cheddar_cheese pizza_sauce </s>',
#   'score': 0.00032627006294205785,
#   'token': 856,
#   'token_str': 'pizza_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese chunky_salsa </s>',
#   'score': 0.0003248539287596941,
#   'token': 855,
#   'token_str': 'chunky_salsa'},
#  {'sequence': '<s> bagel cheddar_cheese canadian_bacon </s>',
#   'score': 0.00032359256874769926,
#   'token': 1635,
#   'token_str': 'canadian_bacon'},
#  {'sequence': '<s> bagel cheddar_cheese sunflower_oil </s>',
#   'score': 0.00032247102353721857,
#   'token': 987,
#   'token_str': 'sunflower_oil'},
#  {'sequence': '<s> bagel cheddar_cheese refried_beans </s>',
#   'score': 0.0003190853167325258,
#   'token': 820,
#   'token_str': 'refried_beans'},
#  {'sequence': '<s> bagel cheddar_cheese pancake </s>',
#   'score': 0.0003175501769874245,
#   'token': 985,
#   'token_str': 'pancake'},
#  {'sequence': '<s> bagel cheddar_cheese ingredients </s>',
#   'score': 0.0003158398321829736,
#   'token': 1424,
#   'token_str': 'ingredients'},
#  {'sequence': '<s> bagel cheddar_cheese grated_carrot </s>',
#   'score': 0.0003152323770336807,
#   'token': 1743,
#   'token_str': 'grated_carrot'},
#  {'sequence': '<s> bagel cheddar_cheese waffle </s>',
#   'score': 0.0003131227567791939,
#   'token': 2182,
#   'token_str': 'waffle'},
#  {'sequence': '<s> bagel cheddar_cheese muffin </s>',
#   'score': 0.00031266844598576427,
#   'token': 1101,
#   'token_str': 'muffin'},
#  {'sequence': '<s> bagel cheddar_cheese baking_soda </s>',
#   'score': 0.0003119164612144232,
#   'token': 57,
#   'token_str': 'baking_soda'},
#  {'sequence': '<s> bagel cheddar_cheese hot_sauce </s>',
#   'score': 0.0003098852757830173,
#   'token': 260,
#   'token_str': 'hot_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese coconut_oil </s>',
#   'score': 0.00030771648744121194,
#   'token': 625,
#   'token_str': 'coconut_oil'},
#  {'sequence': '<s> bagel cheddar_cheese spinach_leaves </s>',
#   'score': 0.0003047292702831328,
#   'token': 470,
#   'token_str': 'spinach_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese tofu </s>',
#   'score': 0.00030361374956555665,
#   'token': 403,
#   'token_str': 'tofu'},
#  {'sequence': '<s> bagel cheddar_cheese peanuts </s>',
#   'score': 0.00030198597232811153,
#   'token': 325,
#   'token_str': 'peanuts'},
#  {'sequence': '<s> bagel cheddar_cheese apple_pie_filling </s>',
#   'score': 0.0003017113485839218,
#   'token': 2150,
#   'token_str': 'apple_pie_filling'},
#  {'sequence': '<s> bagel cheddar_cheese much </s>',
#   'score': 0.000297692371532321,
#   'token': 1555,
#   'token_str': 'much'},
#  {'sequence': '<s> bagel cheddar_cheese white_sugar </s>',
#   'score': 0.00029523938428610563,
#   'token': 117,
#   'token_str': 'white_sugar'},
#  {'sequence': '<s> bagel cheddar_cheese gluten_free </s>',
#   'score': 0.00029468073626048863,
#   'token': 1335,
#   'token_str': 'gluten_free'},
#  {'sequence': '<s> bagel cheddar_cheese aged_cheddar </s>',
#   'score': 0.000294135621516034,
#   'token': 3117,
#   'token_str': 'aged_cheddar'},
#  {'sequence': '<s> bagel cheddar_cheese spring </s>',
#   'score': 0.00029373602592386305,
#   'token': 562,
#   'token_str': 'spring'},
#  {'sequence': '<s> bagel cheddar_cheese hamburger </s>',
#   'score': 0.00029326160438358784,
#   'token': 429,
#   'token_str': 'hamburger'},
#  {'sequence': '<s> bagel cheddar_cheese pure_maple_syrup </s>',
#   'score': 0.000291877833660692,
#   'token': 751,
#   'token_str': 'pure_maple_syrup'},
#  {'sequence': '<s> bagel cheddar_cheese blueberry </s>',
#   'score': 0.00028957644826732576,
#   'token': 1147,
#   'token_str': 'blueberry'},
#  {'sequence': '<s> bagel cheddar_cheese nonfat_plain_greek_yogurt </s>',
#   'score': 0.00028206579736433923,
#   'token': 2941,
#   'token_str': 'nonfat_plain_greek_yogurt'},
#  {'sequence': '<s> bagel cheddar_cheese sweet_potato </s>',
#   'score': 0.000279015424894169,
#   'token': 722,
#   'token_str': 'sweet_potato'},
#  {'sequence': '<s> bagel cheddar_cheese blackberry </s>',
#   'score': 0.0002783491217996925,
#   'token': 1374,
#   'token_str': 'blackberry'},
#  {'sequence': '<s> bagel cheddar_cheese red_pepper </s>',
#   'score': 0.00027768430300056934,
#   'token': 66,
#   'token_str': 'red_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese tuna </s>',
#   'score': 0.00027569866506382823,
#   'token': 517,
#   'token_str': 'tuna'},
#  {'sequence': '<s> bagel cheddar_cheese burgers </s>',
#   'score': 0.00027353630866855383,
#   'token': 2157,
#   'token_str': 'burgers'},
#  {'sequence': '<s> bagel cheddar_cheese egg_substitute </s>',
#   'score': 0.0002734823210630566,
#   'token': 694,
#   'token_str': 'egg_substitute'},
#  {'sequence': '<s> bagel cheddar_cheese lowfat_yogurt </s>',
#   'score': 0.00027255527675151825,
#   'token': 891,
#   'token_str': 'lowfat_yogurt'},
#  {'sequence': '<s> bagel cheddar_cheese vegetable_oil </s>',
#   'score': 0.00027242195210419595,
#   'token': 40,
#   'token_str': 'vegetable_oil'},
#  {'sequence': '<s> bagel cheddar_cheese condiments </s>',
#   'score': 0.00027166763902641833,
#   'token': 3443,
#   'token_str': 'condiments'},
#  {'sequence': '<s> bagel cheddar_cheese roasted_red_peppers </s>',
#   'score': 0.000270827702479437,
#   'token': 793,
#   'token_str': 'roasted_red_peppers'},
#  {'sequence': '<s> bagel cheddar_cheese light_tuna </s>',
#   'score': 0.000268464966211468,
#   'token': 3219,
#   'token_str': 'light_tuna'},
#  {'sequence': '<s> bagel cheddar_cheese genoa_salami </s>',
#   'score': 0.00026834505842998624,
#   'token': 2266,
#   'token_str': 'genoa_salami'},
#  {'sequence': '<s> bagel cheddar_cheese baby_arugula </s>',
#   'score': 0.0002677996235433966,
#   'token': 1050,
#   'token_str': 'baby_arugula'},
#  {'sequence': '<s> bagel cheddar_cheese monterey_jack_cheese </s>',
#   'score': 0.0002672346599865705,
#   'token': 313,
#   'token_str': 'monterey_jack_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese tuna_drained_and_flaked </s>',
#   'score': 0.0002665194624569267,
#   'token': 2601,
#   'token_str': 'tuna_drained_and_flaked'},
#  {'sequence': '<s> bagel cheddar_cheese sauerkraut </s>',
#   'score': 0.00026498589431867003,
#   'token': 754,
#   'token_str': 'sauerkraut'},
#  {'sequence': '<s> bagel cheddar_cheese ginger </s>',
#   'score': 0.00026116319349966943,
#   'token': 45,
#   'token_str': 'ginger'},
#  {'sequence': '<s> bagel cheddar_cheese relish </s>',
#   'score': 0.0002604992769192904,
#   'token': 1006,
#   'token_str': 'relish'},
#  {'sequence': '<s> bagel cheddar_cheese dill </s>',
#   'score': 0.00025904556969180703,
#   'token': 231,
#   'token_str': 'dill'},
#  {'sequence': '<s> bagel cheddar_cheese broccoli_florets </s>',
#   'score': 0.0002580982691142708,
#   'token': 545,
#   'token_str': 'broccoli_florets'},
#  {'sequence': '<s> bagel cheddar_cheese breadstick </s>',
#   'score': 0.000257809238974005,
#   'token': 2976,
#   'token_str': 'breadstick'},
#  {'sequence': '<s> bagel cheddar_cheese pink </s>',
#   'score': 0.000257611129200086,
#   'token': 1261,
#   'token_str': 'pink'},
#  {'sequence': '<s> bagel cheddar_cheese sweet_relish </s>',
#   'score': 0.0002573007659520954,
#   'token': 2083,
#   'token_str': 'sweet_relish'},
#  {'sequence': '<s> bagel cheddar_cheese green_olives </s>',
#   'score': 0.00025680827093310654,
#   'token': 631,
#   'token_str': 'green_olives'},
#  {'sequence': '<s> bagel cheddar_cheese creme_fraiche </s>',
#   'score': 0.00025673102936707437,
#   'token': 620,
#   'token_str': 'creme_fraiche'},
#  {'sequence': '<s> bagel cheddar_cheese crab_sticks </s>',
#   'score': 0.0002536329557187855,
#   'token': 2972,
#   'token_str': 'crab_sticks'},
#  {'sequence': '<s> bagel cheddar_cheese hard_salami </s>',
#   'score': 0.00025004055351018906,
#   'token': 2865,
#   'token_str': 'hard_salami'},
#  {'sequence': '<s> bagel cheddar_cheese cheese_sauce </s>',
#   'score': 0.0002487665042281151,
#   'token': 1553,
#   'token_str': 'cheese_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese havarti </s>',
#   'score': 0.0002462574921082705,
#   'token': 1884,
#   'token_str': 'havarti'},
#  {'sequence': '<s> bagel cheddar_cheese oil </s>',
#   'score': 0.00024508254136890173,
#   'token': 76,
#   'token_str': 'oil'},
#  {'sequence': '<s> bagel cheddar_cheese cooked_ham </s>',
#   'score': 0.00023790077830199152,
#   'token': 767,
#   'token_str': 'cooked_ham'},
#  {'sequence': '<s> bagel cheddar_cheese links </s>',
#   'score': 0.00023746772785671055,
#   'token': 1701,
#   'token_str': 'links'},
#  {'sequence': '<s> bagel cheddar_cheese green_onion </s>',
#   'score': 0.00023706856882199645,
#   'token': 209,
#   'token_str': 'green_onion'},
#  {'sequence': '<s> bagel cheddar_cheese sweet_onion </s>',
#   'score': 0.00023521785624325275,
#   'token': 434,
#   'token_str': 'sweet_onion'},
#  {'sequence': '<s> bagel cheddar_cheese molasses </s>',
#   'score': 0.0002350394643144682,
#   'token': 302,
#   'token_str': 'molasses'},
#  {'sequence': '<s> bagel cheddar_cheese jelly </s>',
#   'score': 0.0002350272552575916,
#   'token': 643,
#   'token_str': 'jelly'},
#  {'sequence': '<s> bagel cheddar_cheese pecans </s>',
#   'score': 0.00023318025341723114,
#   'token': 144,
#   'token_str': 'pecans'},
#  {'sequence': '<s> bagel cheddar_cheese raw_honey </s>',
#   'score': 0.0002321944193681702,
#   'token': 2143,
#   'token_str': 'raw_honey'},
#  {'sequence': '<s> bagel cheddar_cheese rosemary </s>',
#   'score': 0.00023035188496578485,
#   'token': 155,
#   'token_str': 'rosemary'},
#  {'sequence': '<s> bagel cheddar_cheese ice_cubes </s>',
#   'score': 0.00023003609385341406,
#   'token': 485,
#   'token_str': 'ice_cubes'},
#  {'sequence': '<s> bagel cheddar_cheese bibb_lettuce </s>',
#   'score': 0.00022656087821815163,
#   'token': 1671,
#   'token_str': 'bibb_lettuce'},
#  {'sequence': '<s> bagel cheddar_cheese spices </s>',
#   'score': 0.0002264611830469221,
#   'token': 910,
#   'token_str': 'spices'},
#  {'sequence': '<s> bagel cheddar_cheese cherries </s>',
#   'score': 0.00022506814275402576,
#   'token': 354,
#   'token_str': 'cherries'},
#  {'sequence': '<s> bagel cheddar_cheese cooked_black_beans </s>',
#   'score': 0.00022431153047364205,
#   'token': 1633,
#   'token_str': 'cooked_black_beans'},
#  {'sequence': '<s> bagel cheddar_cheese apples </s>',
#   'score': 0.00022311060456559062,
#   'token': 202,
#   'token_str': 'apples'},
#  {'sequence': '<s> bagel cheddar_cheese salad_greens </s>',
#   'score': 0.00022269765031524003,
#   'token': 744,
#   'token_str': 'salad_greens'},
#  {'sequence': '<s> bagel cheddar_cheese pumpkin_seeds </s>',
#   'score': 0.00022195906785782427,
#   'token': 886,
#   'token_str': 'pumpkin_seeds'},
#  {'sequence': '<s> bagel cheddar_cheese vegan </s>',
#   'score': 0.00022146673290990293,
#   'token': 1309,
#   'token_str': 'vegan'},
#  {'sequence': '<s> bagel cheddar_cheese shiso_leaves </s>',
#   'score': 0.00022135164181236178,
#   'token': 1666,
#   'token_str': 'shiso_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese olive_oil_cooking_spray </s>',
#   'score': 0.00021918359561823308,
#   'token': 2717,
#   'token_str': 'olive_oil_cooking_spray'},
#  {'sequence': '<s> bagel cheddar_cheese black_sesame_seed </s>',
#   'score': 0.00021827724413014948,
#   'token': 3239,
#   'token_str': 'black_sesame_seed'},
#  {'sequence': '<s> bagel cheddar_cheese wheat_cereal </s>',
#   'score': 0.00021682555961888283,
#   'token': 2160,
#   'token_str': 'wheat_cereal'},
#  {'sequence': '<s> bagel cheddar_cheese plain_chocolate </s>',
#   'score': 0.00021680197096429765,
#   'token': 2192,
#   'token_str': 'plain_chocolate'},
#  {'sequence': '<s> bagel cheddar_cheese chestnut </s>',
#   'score': 0.00021547998767346144,
#   'token': 1338,
#   'token_str': 'chestnut'},
#  {'sequence': '<s> bagel cheddar_cheese ketchup </s>',
#   'score': 0.00021448817278724164,
#   'token': 222,
#   'token_str': 'ketchup'},
#  {'sequence': '<s> bagel cheddar_cheese agave_syrup </s>',
#   'score': 0.00021430508058983833,
#   'token': 1664,
#   'token_str': 'agave_syrup'},
#  {'sequence': '<s> bagel cheddar_cheese temperature </s>',
#   'score': 0.0002132211666321382,
#   'token': 135,
#   'token_str': 'temperature'},
#  {'sequence': '<s> bagel cheddar_cheese steak_seasoning </s>',
#   'score': 0.00021175765141379088,
#   'token': 1114,
#   'token_str': 'steak_seasoning'},
#  {'sequence': '<s> bagel cheddar_cheese garnish </s>',
#   'score': 0.00021134063717909157,
#   'token': 95,
#   'token_str': 'garnish'},
#  {'sequence': '<s> bagel cheddar_cheese taco_sauce </s>',
#   'score': 0.00021114703849889338,
#   'token': 1346,
#   'token_str': 'taco_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese romaine_lettuce_leaves </s>',
#   'score': 0.0002097126707667485,
#   'token': 1825,
#   'token_str': 'romaine_lettuce_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese tomato_salsa </s>',
#   'score': 0.00020776668679900467,
#   'token': 2187,
#   'token_str': 'tomato_salsa'},
#  {'sequence': '<s> bagel cheddar_cheese batter </s>',
#   'score': 0.000207255405257456,
#   'token': 1480,
#   'token_str': 'batter'},
#  {'sequence': '<s> bagel cheddar_cheese hot_sausage </s>',
#   'score': 0.00020724661590065807,
#   'token': 2501,
#   'token_str': 'hot_sausage'},
#  {'sequence': '<s> bagel cheddar_cheese sweet_cream_butter </s>',
#   'score': 0.00020661689632106572,
#   'token': 3149,
#   'token_str': 'sweet_cream_butter'},
#  {'sequence': '<s> bagel cheddar_cheese rotisserie_chicken </s>',
#   'score': 0.0002057983074337244,
#   'token': 1175,
#   'token_str': 'rotisserie_chicken'},
#  {'sequence': '<s> bagel cheddar_cheese cilantro </s>',
#   'score': 0.00020508875604718924,
#   'token': 60,
#   'token_str': 'cilantro'},
#  {'sequence': '<s> bagel cheddar_cheese horseradish_sauce </s>',
#   'score': 0.00020479685917962343,
#   'token': 2564,
#   'token_str': 'horseradish_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese toasted_walnuts </s>',
#   'score': 0.00020437093917280436,
#   'token': 1423,
#   'token_str': 'toasted_walnuts'},
#  {'sequence': '<s> bagel cheddar_cheese fat </s>',
#   'score': 0.00020349817350506783,
#   'token': 937,
#   'token_str': 'fat'},
#  {'sequence': '<s> bagel cheddar_cheese flour_tortilla </s>',
#   'score': 0.0002023044798988849,
#   'token': 1627,
#   'token_str': 'flour_tortilla'},
#  {'sequence': '<s> bagel cheddar_cheese cracked_black_pepper </s>',
# ...
#  {'sequence': '<s> bagel cheddar_cheese turkey_sausage </s>',
#   'score': 0.00016709056217223406,
#   'token': 1271,
#   'token_str': 'turkey_sausage'},
#  {'sequence': '<s> bagel cheddar_cheese focaccia </s>',
#   'score': 0.00016642516129650176,
#   'token': 2759,
#   'token_str': 'focaccia'},
#  {'sequence': '<s> bagel cheddar_cheese beef </s>',
#   'score': 0.00016607904399279505,
#   'token': 188,
#   'token_str': 'beef'},
#  {'sequence': '<s> bagel cheddar_cheese honeydew </s>',
#   'score': 0.0001659897534409538,
#   'token': 1332,
#   'token_str': 'honeydew'},
#  {'sequence': '<s> bagel cheddar_cheese plain_yogurt </s>',
#   'score': 0.00016590610903222114,
#   'token': 314,
#   'token_str': 'plain_yogurt'},
#  {'sequence': '<s> bagel cheddar_cheese yogurt </s>',
#   'score': 0.00016576441703364253,
#   'token': 138,
#   'token_str': 'yogurt'},
#  {'sequence': '<s> bagel cheddar_cheese apricot_jam </s>',
#   'score': 0.00016574781329836696,
#   'token': 1209,
#   'token_str': 'apricot_jam'},
#  {'sequence': '<s> bagel cheddar_cheese slider_buns </s>',
#   'score': 0.00016446351946797222,
#   'token': 3363,
#   'token_str': 'slider_buns'},
#  {'sequence': '<s> bagel cheddar_cheese pickled_jalapenos </s>',
#   'score': 0.00016383318870794028,
#   'token': 1574,
#   'token_str': 'pickled_jalapenos'},
#  {'sequence': '<s> bagel cheddar_cheese light_sour_cream </s>',
#   'score': 0.0001629087346373126,
#   'token': 1008,
#   'token_str': 'light_sour_cream'},
#  {'sequence': '<s> bagel cheddar_cheese center_cut_bacon </s>',
#   'score': 0.00016276113456115127,
#   'token': 2356,
#   'token_str': 'center_cut_bacon'},
#  {'sequence': '<s> bagel cheddar_cheese sliced_pineapple </s>',
#   'score': 0.00016256776871159673,
#   'token': 3094,
#   'token_str': 'sliced_pineapple'},
#  {'sequence': '<s> bagel cheddar_cheese muenster_cheese </s>',
#   'score': 0.00016196694923564792,
#   'token': 1771,
#   'token_str': 'muenster_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese chocolates </s>',
#   'score': 0.00016140835941769183,
#   'token': 3357,
#   'token_str': 'chocolates'},
#  {'sequence': '<s> bagel cheddar_cheese philadelphia_light_cream_cheese </s>',
#   'score': 0.0001613959757378325,
#   'token': 2349,
#   'token_str': 'philadelphia_light_cream_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese italian_cheese_blend </s>',
#   'score': 0.00016137519560288638,
#   'token': 1829,
#   'token_str': 'italian_cheese_blend'},
#  {'sequence': '<s> bagel cheddar_cheese bananas </s>',
#   'score': 0.00016089444397948682,
#   'token': 243,
#   'token_str': 'bananas'},
#  {'sequence': '<s> bagel cheddar_cheese grape </s>',
#   'score': 0.00016075372695922852,
#   'token': 889,
#   'token_str': 'grape'},
#  {'sequence': '<s> bagel cheddar_cheese carrots </s>',
#   'score': 0.0001603063865331933,
#   'token': 67,
#   'token_str': 'carrots'},
#  {'sequence': '<s> bagel cheddar_cheese cinnamon_sugar </s>',
#   'score': 0.00016027115634642541,
#   'token': 1731,
#   'token_str': 'cinnamon_sugar'},
#  {'sequence': '<s> bagel cheddar_cheese pace_picante_sauce </s>',
#   'score': 0.00015987355436664075,
#   'token': 2689,
#   'token_str': 'pace_picante_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese arugula </s>',
#   'score': 0.00015895735123194754,
#   'token': 432,
#   'token_str': 'arugula'},
#  {'sequence': '<s> bagel cheddar_cheese mortadella </s>',
#   'score': 0.00015799944230820984,
#   'token': 3148,
#   'token_str': 'mortadella'},
#  {'sequence': '<s> bagel cheddar_cheese chilli </s>',
#   'score': 0.00015758081281092018,
#   'token': 1074,
#   'token_str': 'chilli'},
#  {'sequence': '<s> bagel cheddar_cheese bologna </s>',
#   'score': 0.00015607777459081262,
#   'token': 3040,
#   'token_str': 'bologna'},
#  {'sequence': '<s> bagel cheddar_cheese pecan_halves </s>',
#   'score': 0.00015592356794513762,
#   'token': 644,
#   'token_str': 'pecan_halves'},
#  {'sequence': '<s> bagel cheddar_cheese maraschino_cherries </s>',
#   'score': 0.0001556416682433337,
#   'token': 810,
#   'token_str': 'maraschino_cherries'},
#  {'sequence': '<s> bagel cheddar_cheese berry </s>',
#   'score': 0.000155641304445453,
#   'token': 1011,
#   'token_str': 'berry'},
#  {'sequence': '<s> bagel cheddar_cheese sweet_chili_sauce </s>',
#   'score': 0.00015558408631477505,
#   'token': 1288,
#   'token_str': 'sweet_chili_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese pineapple_rings </s>',
#   'score': 0.00015409708430524915,
#   'token': 2940,
#   'token_str': 'pineapple_rings'},
#  {'sequence': '<s> bagel cheddar_cheese cakes </s>',
#   'score': 0.0001531680318294093,
#   'token': 1685,
#   'token_str': 'cakes'},
#  {'sequence': '<s> bagel cheddar_cheese nuts </s>',
#   'score': 0.00015297862410079688,
#   'token': 229,
#   'token_str': 'nuts'},
#  {'sequence': '<s> bagel cheddar_cheese marshmallow </s>',
#   'score': 0.00015255306789185852,
#   'token': 819,
#   'token_str': 'marshmallow'},
#  {'sequence': '<s> bagel cheddar_cheese onion_soup_mix </s>',
#   'score': 0.0001500607468187809,
#   'token': 580,
#   'token_str': 'onion_soup_mix'},
#  {'sequence': '<s> bagel cheddar_cheese carrot_sticks </s>',
#   'score': 0.00014972467033658177,
#   'token': 2480,
#   'token_str': 'carrot_sticks'},
#  {'sequence': '<s> bagel cheddar_cheese light_margarine </s>',
#   'score': 0.0001495595497544855,
#   'token': 2963,
#   'token_str': 'light_margarine'},
#  {'sequence': '<s> bagel cheddar_cheese taco_seasoning </s>',
#   'score': 0.00014950672630220652,
#   'token': 419,
#   'token_str': 'taco_seasoning'},
#  {'sequence': '<s> bagel cheddar_cheese kefir </s>',
#   'score': 0.00014826603000983596,
#   'token': 3155,
#   'token_str': 'kefir'},
#  {'sequence': '<s> bagel cheddar_cheese albacore_tuna </s>',
#   'score': 0.00014782742073293775,
#   'token': 2751,
#   'token_str': 'albacore_tuna'},
#  {'sequence': '<s> bagel cheddar_cheese artificial_sweetener </s>',
#   'score': 0.00014615291729569435,
#   'token': 1447,
#   'token_str': 'artificial_sweetener'},
#  {'sequence': '<s> bagel cheddar_cheese grill_seasoning </s>',
#   'score': 0.0001459479535697028,
#   'token': 2115,
#   'token_str': 'grill_seasoning'},
#  {'sequence': '<s> bagel cheddar_cheese vegetable_oil_cooking_spray </s>',
#   'score': 0.00014502245176117867,
#   'token': 1056,
#   'token_str': 'vegetable_oil_cooking_spray'},
#  {'sequence': '<s> bagel cheddar_cheese powdered_sugar </s>',
#   'score': 0.00014312603161670268,
#   'token': 158,
#   'token_str': 'powdered_sugar'},
#  {'sequence': '<s> bagel cheddar_cheese garlic_salt </s>',
#   'score': 0.00014271480904426426,
#   'token': 335,
#   'token_str': 'garlic_salt'},
#  {'sequence': '<s> bagel cheddar_cheese agave_nectar </s>',
#   'score': 0.0001419612963218242,
#   'token': 783,
#   'token_str': 'agave_nectar'},
#  {'sequence': '<s> bagel cheddar_cheese oreos </s>',
#   'score': 0.00014195243420545012,
#   'token': 2811,
#   'token_str': 'oreos'},
#  {'sequence': '<s> bagel cheddar_cheese balsamic_vinegar </s>',
#   'score': 0.00014165132597554475,
#   'token': 203,
#   'token_str': 'balsamic_vinegar'},
#  {'sequence': '<s> bagel cheddar_cheese vanilla_yogurt </s>',
#   'score': 0.00014105885929893702,
#   'token': 883,
#   'token_str': 'vanilla_yogurt'},
#  {'sequence': '<s> bagel cheddar_cheese frozen_strawberries </s>',
#   'score': 0.00013977271737530828,
#   'token': 1144,
#   'token_str': 'frozen_strawberries'},
#  {'sequence': '<s> bagel cheddar_cheese orange_juice </s>',
#   'score': 0.00013962536468170583,
#   'token': 126,
#   'token_str': 'orange_juice'},
#  {'sequence': '<s> bagel cheddar_cheese wasabi_paste </s>',
#   'score': 0.00013961757940705866,
#   'token': 2144,
#   'token_str': 'wasabi_paste'},
#  {'sequence': '<s> bagel cheddar_cheese salad_leaves </s>',
#   'score': 0.00013898203906137496,
#   'token': 3458,
#   'token_str': 'salad_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese parsley </s>',
#   'score': 0.0001384723582305014,
#   'token': 36,
#   'token_str': 'parsley'},
#  {'sequence': '<s> bagel cheddar_cheese baked_ham </s>',
#   'score': 0.0001382870104862377,
#   'token': 2753,
#   'token_str': 'baked_ham'},
#  {'sequence': '<s> bagel cheddar_cheese cabbage </s>',
#   'score': 0.00013720005517825484,
#   'token': 182,
#   'token_str': 'cabbage'},
#  {'sequence': '<s> bagel cheddar_cheese preserves </s>',
#   'score': 0.00013685251178685576,
#   'token': 510,
#   'token_str': 'preserves'},
#  {'sequence': '<s> bagel cheddar_cheese pita_bread </s>',
#   'score': 0.00013660364493262023,
#   'token': 1093,
#   'token_str': 'pita_bread'},
#  {'sequence': '<s> bagel cheddar_cheese stevia </s>',
#   'score': 0.00013578240759670734,
#   'token': 1585,
#   'token_str': 'stevia'},
#  {'sequence': '<s> bagel cheddar_cheese coating </s>',
#   'score': 0.00013572971511166543,
#   'token': 923,
#   'token_str': 'coating'},
#  {'sequence': '<s> bagel cheddar_cheese hand </s>',
#   'score': 0.0001353646512143314,
#   'token': 1727,
#   'token_str': 'hand'},
#  {'sequence': '<s> bagel cheddar_cheese green_chiles </s>',
#   'score': 0.00013522428344003856,
#   'token': 868,
#   'token_str': 'green_chiles'},
#  {'sequence': '<s> bagel cheddar_cheese raisins </s>',
#   'score': 0.00013467993994709104,
#   'token': 157,
#   'token_str': 'raisins'},
#  {'sequence': '<s> bagel cheddar_cheese wheat_germ </s>',
#   'score': 0.0001343956246273592,
#   'token': 895,
#   'token_str': 'wheat_germ'},
#  {'sequence': '<s> bagel cheddar_cheese red_leaf_lettuce </s>',
#   'score': 0.00013408862287178636,
#   'token': 1625,
#   'token_str': 'red_leaf_lettuce'},
#  {'sequence': '<s> bagel cheddar_cheese crumbled_goat_cheese </s>',
#   'score': 0.00013352674432098866,
#   'token': 1763,
#   'token_str': 'crumbled_goat_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese chocolate_sauce </s>',
#   'score': 0.0001334522821707651,
#   'token': 2353,
#   'token_str': 'chocolate_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese beet_sugar </s>',
#   'score': 0.00013311156362760812,
#   'token': 3268,
#   'token_str': 'beet_sugar'},
#  {'sequence': '<s> bagel cheddar_cheese sunflower_kernels </s>',
#   'score': 0.00013294132077135146,
#   'token': 3116,
#   'token_str': 'sunflower_kernels'},
#  {'sequence': '<s> bagel cheddar_cheese natural_peanut_butter </s>',
#   'score': 0.000131533233798109,
#   'token': 2360,
#   'token_str': 'natural_peanut_butter'},
#  {'sequence': '<s> bagel cheddar_cheese corn_bread </s>',
#   'score': 0.00013153065810911357,
#   'token': 1902,
#   'token_str': 'corn_bread'},
#  {'sequence': '<s> bagel cheddar_cheese flax_meal </s>',
#   'score': 0.0001311527012148872,
#   'token': 2844,
#   'token_str': 'flax_meal'},
#  {'sequence': '<s> bagel cheddar_cheese jalapeno_peppers </s>',
#   'score': 0.00013060806668363512,
#   'token': 557,
#   'token_str': 'jalapeno_peppers'},
#  {'sequence': '<s> bagel cheddar_cheese chocolate_syrup </s>',
#   'score': 0.0001302407617913559,
#   'token': 769,
#   'token_str': 'chocolate_syrup'},
#  {'sequence': '<s> bagel cheddar_cheese roasted_red_bell_pepper </s>',
#   'score': 0.0001292540255235508,
#   'token': 2632,
#   'token_str': 'roasted_red_bell_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese pitted_black_olives </s>',
#   'score': 0.0001290876098209992,
#   'token': 1580,
#   'token_str': 'pitted_black_olives'},
#  {'sequence': '<s> bagel cheddar_cheese croutons </s>',
#   'score': 0.0001289799256483093,
#   'token': 974,
#   'token_str': 'croutons'},
#  {'sequence': '<s> bagel cheddar_cheese camembert </s>',
#   'score': 0.0001284582685912028,
#   'token': 2660,
#   'token_str': 'camembert'},
#  {'sequence': '<s> bagel cheddar_cheese mint_leaves </s>',
#   'score': 0.00012767953739967197,
#   'token': 372,
#   'token_str': 'mint_leaves'},
#  {'sequence': '<s> bagel cheddar_cheese vinaigrette </s>',
#   'score': 0.00012656100443564355,
#   'token': 544,
#   'token_str': 'vinaigrette'},
#  {'sequence': '<s> bagel cheddar_cheese twists </s>',
#   'score': 0.00012625232920981944,
#   'token': 1919,
#   'token_str': 'twists'},
#  {'sequence': '<s> bagel cheddar_cheese white_bread </s>',
#   'score': 0.0001260903081856668,
#   'token': 433,
#   'token_str': 'white_bread'},
#  {'sequence': '<s> bagel cheddar_cheese apricot </s>',
#   'score': 0.0001260713761439547,
#   'token': 526,
#   'token_str': 'apricot'},
#  {'sequence': '<s> bagel cheddar_cheese butter_cooking_spray </s>',
#   'score': 0.0001255846582353115,
#   'token': 3124,
#   'token_str': 'butter_cooking_spray'},
#  {'sequence': '<s> bagel cheddar_cheese yellow_onion </s>',
#   'score': 0.0001252418733201921,
#   'token': 247,
#   'token_str': 'yellow_onion'},
#  {'sequence': '<s> bagel cheddar_cheese beetroot </s>',
#   'score': 0.00012473308015614748,
#   'token': 2423,
#   'token_str': 'beetroot'},
#  {'sequence': '<s> bagel cheddar_cheese granola </s>',
#   'score': 0.00012423761654645205,
#   'token': 1162,
#   'token_str': 'granola'},
#  {'sequence': '<s> bagel cheddar_cheese greek_yogurt </s>',
#   'score': 0.00012398355465848,
#   'token': 456,
#   'token_str': 'greek_yogurt'},
#  {'sequence': '<s> bagel cheddar_cheese cashews </s>',
#   'score': 0.0001239452394656837,
#   'token': 659,
#   'token_str': 'cashews'},
#  {'sequence': '<s> bagel cheddar_cheese cane_sugar </s>',
#   'score': 0.0001238047843798995,
#   'token': 1504,
#   'token_str': 'cane_sugar'},
#  {'sequence': '<s> bagel cheddar_cheese rice_milk </s>',
#   'score': 0.00012361802509985864,
#   'token': 1603,
#   'token_str': 'rice_milk'},
#  {'sequence': '<s> bagel cheddar_cheese poppy_seeds </s>',
#   'score': 0.0001235529634868726,
#   'token': 734,
#   'token_str': 'poppy_seeds'},
#  {'sequence': '<s> bagel cheddar_cheese red_bell_pepper </s>',
#   'score': 0.00012341130059212446,
#   'token': 162,
#   'token_str': 'red_bell_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese hickory_smoke </s>',
#   'score': 0.00012339898967184126,
#   'token': 2738,
#   'token_str': 'hickory_smoke'},
#  {'sequence': '<s> bagel cheddar_cheese food_colouring </s>',
#   'score': 0.0001228157343575731,
#   'token': 2088,
#   'token_str': 'food_colouring'},
#  {'sequence': '<s> bagel cheddar_cheese brie_cheese </s>',
#   'score': 0.00012276713096071035,
#   'token': 1111,
#   'token_str': 'brie_cheese'},
#  {'sequence': '<s> bagel cheddar_cheese mint </s>',
#   'score': 0.00012249575229361653,
#   'token': 265,
#   'token_str': 'mint'},
#  {'sequence': '<s> bagel cheddar_cheese marinade </s>',
#   'score': 0.00012233447341714054,
#   'token': 1047,
#   'token_str': 'marinade'},
#  {'sequence': '<s> bagel cheddar_cheese sundried_tomatoes </s>',
#   'score': 0.00012200527271488681,
#   'token': 638,
#   'token_str': 'sundried_tomatoes'},
#  {'sequence': '<s> bagel cheddar_cheese figs </s>',
#   'score': 0.00012120732571929693,
#   'token': 1085,
#   'token_str': 'figs'},
#  {'sequence': '<s> bagel cheddar_cheese seasoned_chicken </s>',
#   'score': 0.00012065444025211036,
#   'token': 3335,
#   'token_str': 'seasoned_chicken'},
#  {'sequence': '<s> bagel cheddar_cheese corn </s>',
#   'score': 0.00011980858107563108,
#   'token': 109,
#   'token_str': 'corn'},
#  {'sequence': '<s> bagel cheddar_cheese brine </s>',
#   'score': 0.0001194340584333986,
#   'token': 2186,
#   'token_str': 'brine'},
#  {'sequence': '<s> bagel cheddar_cheese blue_cheese_dressing </s>',
#   'score': 0.00011922147677978501,
#   'token': 1797,
#   'token_str': 'blue_cheese_dressing'},
#  {'sequence': '<s> bagel cheddar_cheese egg_beaters </s>',
#   'score': 0.00011902789265150204,
#   'token': 1616,
#   'token_str': 'egg_beaters'},
#  {'sequence': '<s> bagel cheddar_cheese maple_sugar </s>',
#   'score': 0.00011867080320371315,
#   'token': 3396,
#   'token_str': 'maple_sugar'},
#  {'sequence': '<s> bagel cheddar_cheese liquid </s>',
#   'score': 0.00011830361472675577,
#   'token': 252,
#   'token_str': 'liquid'},
#  {'sequence': '<s> bagel cheddar_cheese cubed_ham </s>',
#   'score': 0.00011785965034505352,
#   'token': 2417,
#   'token_str': 'cubed_ham'},
#  {'sequence': '<s> bagel cheddar_cheese coarse_salt </s>',
#   'score': 0.00011734323925338686,
#   'token': 348,
#   'token_str': 'coarse_salt'},
#  {'sequence': '<s> bagel cheddar_cheese italian_bread </s>',
#   'score': 0.00011694586282828823,
#   'token': 799,
#   'token_str': 'italian_bread'},
#  {'sequence': '<s> bagel cheddar_cheese ground_black_pepper </s>',
#   'score': 0.00011675836867652833,
#   'token': 35,
#   'token_str': 'ground_black_pepper'},
#  {'sequence': '<s> bagel cheddar_cheese caramel_sauce </s>',
#   'score': 0.00011597072443692014,
#   'token': 1397,
#   'token_str': 'caramel_sauce'},
#  {'sequence': '<s> bagel cheddar_cheese marmite </s>',
#   'score': 0.00011590748181333765,
#   'token': 3400,
#   'token_str': 'marmite'}]

# %% [markdown]
# # Validation

# %%
from src.validation import validate
import pandas as pd
ks=[1, 2, 5, 10, 20, 50, 100]
validation_result = validate(fill_mask_recipe.model, tokenizer, 
                             ks=ks,
                             device=-1,
                             limit=5000, relative_base_path='../')
# Out:
# 38it [01:46,  2.81s/it]

# %%
df = pd.DataFrame([validation_result], columns=ks, index=['accuracy'])
(df*100).style.format('{:,.1f}%'.format)
# Out:
# <style  type="text/css" >
# </style><table id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >10</th>        <th class="col_heading level0 col4" >20</th>        <th class="col_heading level0 col5" >50</th>        <th class="col_heading level0 col6" >100</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col0" class="data row0 col0" >20.8%</td>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col1" class="data row0 col1" >29.4%</td>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col2" class="data row0 col2" >40.4%</td>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col3" class="data row0 col3" >49.3%</td>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col4" class="data row0 col4" >57.5%</td>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col5" class="data row0 col5" >68.6%</td>
#                         <td id="T_2aec39e0_22b0_11eb_b106_a5ee51eaef73row0_col6" class="data row0 col6" >76.0%</td>
#             </tr>
#     </tbody></table>

# %%
df = pd.DataFrame([validation_result], columns=ks, index=['accuracy'])
(df*100).style.format('{:,.1f}%'.format)
# Out:
# <style  type="text/css" >
# </style><table id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >10</th>        <th class="col_heading level0 col4" >20</th>        <th class="col_heading level0 col5" >50</th>        <th class="col_heading level0 col6" >100</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col0" class="data row0 col0" >19.6%</td>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col1" class="data row0 col1" >27.6%</td>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col2" class="data row0 col2" >38.8%</td>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col3" class="data row0 col3" >47.9%</td>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col4" class="data row0 col4" >56.7%</td>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col5" class="data row0 col5" >68.3%</td>
#                         <td id="T_0a0aa66a_1709_11eb_bba1_e9b7f80bd6d6row0_col6" class="data row0 col6" >75.7%</td>
#             </tr>
#     </tbody></table>

# %%
df = pd.DataFrame([validation_result], columns=ks, index=['accuracy'])
(df*100).style.format('{:,.1f}%'.format)
# Out:
# <style  type="text/css" >
# </style><table id="T_4b767424_1396_11eb_ae8d_51ccbea46047" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >10</th>        <th class="col_heading level0 col4" >20</th>        <th class="col_heading level0 col5" >50</th>        <th class="col_heading level0 col6" >100</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4b767424_1396_11eb_ae8d_51ccbea46047level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col0" class="data row0 col0" >20.1%</td>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col1" class="data row0 col1" >27.3%</td>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col2" class="data row0 col2" >38.4%</td>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col3" class="data row0 col3" >47.5%</td>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col4" class="data row0 col4" >56.3%</td>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col5" class="data row0 col5" >67.6%</td>
#                         <td id="T_4b767424_1396_11eb_ae8d_51ccbea46047row0_col6" class="data row0 col6" >75.6%</td>
#             </tr>
#     </tbody></table>
